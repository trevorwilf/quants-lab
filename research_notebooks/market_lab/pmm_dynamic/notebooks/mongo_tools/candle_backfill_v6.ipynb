# %% [markdown]
# # Candle Backfill v3 — Maximum-Depth Backfill
#
# This notebook backfills all (connector, pair, interval) combos in your MongoDB
# `candles` collection to the maximum depth available from each exchange, up to
# a 10-year ceiling.
#
# **Key differences from v2:**
#
# 1. **Config-driven.** Exchange URLs, interval targets, and rate-limit pacing
#    live in `candle_backfill_config.yaml` next to this notebook. To add a new
#    exchange (e.g., Kraken), edit the config and implement one fetcher +
#    ingester function in Cell 4/5.
#
# 2. **Auto-probed history floors.** Before running, v3 probes each
#    `(exchange, interval)` pair to discover the earliest timestamp the exchange
#    will serve, and caches the result in `candle_coverage_probes`. No wasted
#    requests reaching for data that doesn't exist.
#
# 3. **Per-interval target depth.** Each interval has its own target depth in
#    the config (e.g., 1m → 60 days, 1d → 10 years). The effective backfill
#    window is `min(target_days, exchange_floor)`.
#
# 4. **Parallel across exchanges, serial within.** Exchanges run in parallel
#    threads (Binance + MEXC + NonKYC + Coinbase all at once). Within each
#    exchange, pairs run serially to avoid triggering IP bans.
#
# 5. **Preview mode.** Cell 8 prints estimated request counts and wall-clock
#    time per exchange before you commit to a run.
#
# **Prerequisites:**
# ```bash
# pip install pymongo requests pyyaml
# ```
#
# **Place `candle_backfill_config.yaml` in the same directory as this notebook.**

# %%
# ── Cell 1: Load configuration ───────────────────────────────────────────────
import os
import pathlib
import yaml

CONFIG_PATH = pathlib.Path(os.environ.get(
    "CANDLE_BACKFILL_CONFIG",
    str(pathlib.Path.cwd() / "candle_backfill_config.yaml"),
))

if not CONFIG_PATH.exists():
    raise FileNotFoundError(
        f"Config file not found at {CONFIG_PATH}. "
        f"Set CANDLE_BACKFILL_CONFIG env var or place the yaml next to this notebook."
    )

with open(CONFIG_PATH) as f:
    CFG = yaml.safe_load(f)

# Mongo connection (env-var aware, same pattern as v2)
_m = CFG["mongo"]
TRUENAS_IP   = os.environ.get(_m["truenas_ip_env_var"], _m["default_truenas_ip"])
TRUENAS_PASS = os.environ.get(_m["truenas_pass_env_var"], _m["default_truenas_pass"])
MONGO_URI = os.environ.get(
    _m["uri_env_var"],
    f"mongodb://admin:{TRUENAS_PASS}@{TRUENAS_IP}:27017/{_m['database']}?authSource=admin",
)
MONGO_DATABASE     = _m["database"]
COLLECTION_NAME    = _m["collection"]
PROBE_COLL_NAME    = _m["probe_cache_collection"]
PAIR_START_COLL_NAME = f"{PROBE_COLL_NAME}_pair_starts"
COVERAGE_COLL_NAME   = f"{COLLECTION_NAME}_coverage"

# HTTP tuning
HTTP_TIMEOUT       = CFG["http"]["timeout_seconds"]
HTTP_MAX_RETRIES   = CFG["http"]["max_retries"]
HTTP_RETRY_BACKOFF = CFG["http"]["retry_backoff"]

# Per-interval target depth (days); capped by absolute_max_days
INTERVAL_TARGETS_DAYS = CFG["interval_targets_days"]
ABSOLUTE_MAX_DAYS     = CFG["absolute_max_days"]
RECENT_DAYS_OWNED = int(CFG.get("recent_days_owned_by_other_process", 0))

# Exchange table (URL, pacing, interval-map, max_per_request)
EXCHANGES = CFG["exchanges"]

SCHEMA_VERSION = 3

# Interval → seconds. Used everywhere.
INTERVAL_SECONDS = {
    "1m":  60,
    "3m":  180,
    "5m":  300,
    "15m": 900,
    "30m": 1800,
    "1h":  3600,
    "4h":  14400,
    "8h":  28800,
    "12h": 43200,
    "1d":  86400,
}

print(f"Loaded config from: {CONFIG_PATH}")
print(f"Configured exchanges: {', '.join(sorted(EXCHANGES.keys()))}")
print(f"Configured intervals: {', '.join(sorted(INTERVAL_TARGETS_DAYS.keys(), key=lambda k: INTERVAL_SECONDS.get(k, 0)))}")
print(f"Absolute max lookback: {ABSOLUTE_MAX_DAYS} days ({ABSOLUTE_MAX_DAYS / 365:.1f} years)")
print(f"Pair-start cache collection: {PAIR_START_COLL_NAME}")
print(f"Coverage collection: {COVERAGE_COLL_NAME}")
print(f"Skipping last {RECENT_DAYS_OWNED} days for existing pairs (0 = disabled)")
# Out:
# Loaded config from: /quants-lab/research_notebooks/market_lab/pmm_dynamic/notebooks/mongo_tools/candle_backfill_config.yaml
# Configured exchanges: binance, coinbase, kraken, mexc, nonkyc
# Configured intervals: 1m, 3m, 5m, 15m, 30m, 1h, 4h, 8h, 12h, 1d
# Absolute max lookback: 3650 days (10.0 years)
# Pair-start cache collection: candle_coverage_probes_pair_starts
# Coverage collection: candles_coverage
# Skipping last 7 days for existing pairs (0 = disabled)

# %%
# ── Cell 2: Imports & helpers ────────────────────────────────────────────────
import math
import threading
import time
from concurrent.futures import ThreadPoolExecutor, as_completed
from datetime import datetime, timezone
from typing import Any, Optional

import requests
from pymongo import MongoClient, UpdateOne
from pymongo.errors import BulkWriteError


def utc_now_ts() -> int:
    return int(time.time())


def align_floor(ts: int, step: int) -> int:
    return (ts // step) * step if step > 0 else ts


def last_closed_open_ts(now_ts: int, step: int) -> int:
    return align_floor(now_ts, step) - step


def fmt_ts(ts: int) -> str:
    return datetime.fromtimestamp(ts, tz=timezone.utc).strftime("%Y-%m-%d %H:%M")


def ts_to_iso8601(ts: int) -> str:
    return datetime.fromtimestamp(ts, tz=timezone.utc).isoformat().replace("+00:00", "Z")


def safe_float(x) -> float:
    try:
        return float(x)
    except Exception:
        return float("nan")


def to_hbot_pair(pair: str) -> str:
    p = pair.strip().upper()
    if "/" in p:
        base, quote = p.split("/", 1)
        return f"{base}-{quote}"
    if "_" in p:
        base, quote = p.split("_", 1)
        return f"{base}-{quote}"
    return p.replace("/", "-").replace("_", "-")


def split_hbot_pair(hbot_pair: str):
    return hbot_pair.split("-", 1)


def to_nonkyc_symbol(hbot_pair: str) -> str:
    return hbot_pair.replace("-", "_")


def to_binance_symbol(hbot_pair: str) -> str:
    return hbot_pair.replace("-", "")


def to_mexc_symbol(hbot_pair: str) -> str:
    return hbot_pair.replace("-", "")


def to_coinbase_product_id(hbot_pair: str) -> str:
    return hbot_pair  # already BASE-QUOTE


# Kraken uses "XBT" instead of "BTC", and "XDG" instead of "DOGE", in some
# contexts. This translation is applied to the request symbol; the response
# key returned by Kraken is NOT guaranteed to match and must be discovered
# at parse time (see fetch_kraken_candles).
_KRAKEN_BASE_TRANSLATIONS = {
    "BTC": "XBT",
    "DOGE": "XDG",
}


def to_kraken_symbol(hbot_pair: str) -> str:
    base, quote = split_hbot_pair(hbot_pair)
    kb = _KRAKEN_BASE_TRANSLATIONS.get(base, base)
    return f"{kb}{quote}"


def compute_qc_flags(o, h, l, c, v):
    flags = []
    if h < max(o, c): flags.append("high_lt_open_close")
    if l > min(o, c): flags.append("low_gt_open_close")
    if h < l: flags.append("high_lt_low")
    if v < 0: flags.append("neg_volume")
    for name, val in [("open", o), ("high", h), ("low", l), ("close", c), ("volume", v)]:
        if val != val: flags.append(f"nan_{name}")
    return flags


# Connection pooling for high-concurrency HTTP
from requests.adapters import HTTPAdapter

session = requests.Session()
_adapter = HTTPAdapter(pool_connections=16, pool_maxsize=32, max_retries=0)
session.mount("https://", _adapter)
session.mount("http://", _adapter)


class _TokenBucket:
    """Thread-safe token bucket with auto-decay on rate-limit signal.

    rate_per_sec   steady-state refill rate (tokens/s)
    burst_capacity max tokens in bucket (for burst tolerance)
    """

    def __init__(self, rate_per_sec: float, burst_capacity: float):
        self.rate = float(rate_per_sec)
        self.capacity = float(burst_capacity)
        self.tokens = float(burst_capacity)
        self.last = time.monotonic()
        self._cv = threading.Condition()
        self._min_rate = 0.5

    def acquire(self) -> None:
        with self._cv:
            while True:
                now = time.monotonic()
                elapsed = now - self.last
                self.last = now
                self.tokens = min(self.capacity, self.tokens + elapsed * self.rate)
                if self.tokens >= 1.0:
                    self.tokens -= 1.0
                    return
                wait = (1.0 - self.tokens) / self.rate
                self._cv.wait(timeout=wait)

    def on_rate_limited(self, retry_after_seconds):
        with self._cv:
            self.rate = max(self._min_rate, self.rate * 0.5)
            self.tokens = 0.0
            self._cv.notify_all()
        if retry_after_seconds:
            time.sleep(retry_after_seconds)

    def stats(self):
        with self._cv:
            return {"rate_per_sec": self.rate, "tokens": self.tokens,
                    "capacity": self.capacity}


# Per-exchange tuning. These values have been empirically validated for NonKYC.
# For other exchanges, values are conservative starting points close to the
# previous effective rates. If you need to reduce load, lower rate_per_sec.
_EXCHANGE_TUNING = {
    "nonkyc":   {"rate_per_sec": 4.0, "burst": 8.0, "parallel": 8},
    "binance":  {"rate_per_sec": 8.0, "burst": 16.0, "parallel": 2},
    "mexc":     {"rate_per_sec": 5.0,  "burst": 10.0, "parallel": 2},
    "coinbase": {"rate_per_sec": 3.0,  "burst": 6.0,  "parallel": 2},
    "kraken":   {"rate_per_sec": 1.0, "burst": 2.0,  "parallel": 1},
}

_exchange_buckets: dict = {}
_buckets_mutex = threading.Lock()


def _get_exchange_bucket(exchange: str) -> _TokenBucket:
    with _buckets_mutex:
        b = _exchange_buckets.get(exchange)
        if b is None:
            cfg = _EXCHANGE_TUNING.get(exchange, {"rate_per_sec": 2.0, "burst": 4.0})
            b = _TokenBucket(cfg["rate_per_sec"], cfg["burst"])
            _exchange_buckets[exchange] = b
        return b


def get_exchange_parallel_workers(exchange: str) -> int:
    return _EXCHANGE_TUNING.get(exchange, {}).get("parallel", 1)


def http_get_json(url: str, params: dict = None, prefix: str = "",
                  exchange: Optional[str] = None,
                  headers: Optional[dict] = None) -> Any:
    """GET + JSON with per-request session, watchdog, and robust 5xx retries.

    Behavior:
    - Watchdog thread enforces HARD_DEADLINE_SECONDS wall-clock ceiling.
    - 5xx errors (500, 502, 503, 504) are retried up to RETRY_BUDGET_5XX
      times with exponential backoff + random jitter. These are treated
      as transient backend hiccups.
    - Non-5xx errors (connection errors, timeouts, other exceptions)
      retry up to HTTP_MAX_RETRIES times using the standard backoff.
    - Rate limits (429, 418, 1015) use the token bucket's auto-decay.
    - Each attempt gets a fresh requests.Session so closing it on
      timeout doesn't affect other attempts.
    """
    import random  # stdlib

    HARD_DEADLINE_SECONDS = 20.0
    RETRY_BUDGET_5XX = 6            # More aggressive than HTTP_MAX_RETRIES for 5xx
    MAX_BACKOFF_5XX = 30.0          # Cap backoff so a single retry doesn't sleep forever

    bucket = _get_exchange_bucket(exchange) if exchange else None
    last_err = None
    attempt = 0
    attempt_5xx = 0

    # Use a looser attempt cap that accommodates either budget.
    max_attempts = max(HTTP_MAX_RETRIES, RETRY_BUDGET_5XX)

    while attempt < max_attempts:
        attempt += 1
        if bucket is not None:
            bucket.acquire()

        local_session = requests.Session()
        adapter = requests.adapters.HTTPAdapter(
            pool_connections=1, pool_maxsize=1, max_retries=0,
        )
        local_session.mount("https://", adapter)
        local_session.mount("http://", adapter)

        done = threading.Event()

        def _watchdog():
            if not done.wait(HARD_DEADLINE_SECONDS):
                try:
                    local_session.close()
                    print(f"  {prefix}Watchdog: killed hung connection after "
                          f"{HARD_DEADLINE_SECONDS:.0f}s")
                except Exception:
                    pass

        watchdog = threading.Thread(target=_watchdog, daemon=True)
        watchdog.start()

        try:
            resp = local_session.get(
                url, params=params, headers=headers,
                timeout=(5, 15),
            )
            if resp.status_code in (429, 418, 1015):
                retry_after = resp.headers.get("Retry-After")
                sleep_s = float(retry_after) if retry_after else HTTP_RETRY_BACKOFF ** attempt
                print(f"  {prefix}Rate limited (HTTP {resp.status_code}), "
                      f"sleeping {sleep_s:.1f}s and halving rate")
                if bucket is not None:
                    bucket.on_rate_limited(sleep_s)
                else:
                    time.sleep(sleep_s)
                done.set()
                continue
            if resp.status_code in (500, 502, 503, 504):
                # Transient backend error — treat with the 5xx-specific budget
                attempt_5xx += 1
                last_err = RuntimeError(f"HTTP {resp.status_code}: {resp.text[:200]}")
                done.set()
                if attempt_5xx >= RETRY_BUDGET_5XX:
                    break
                # Exponential backoff with jitter (0.7x - 1.3x multiplier)
                raw_backoff = min(MAX_BACKOFF_5XX,
                                   HTTP_RETRY_BACKOFF ** attempt_5xx)
                sleep_s = raw_backoff * (0.7 + 0.6 * random.random())
                print(f"  {prefix}HTTP {resp.status_code} transient, retrying in {sleep_s:.1f}s "
                      f"(attempt {attempt_5xx}/{RETRY_BUDGET_5XX})")
                time.sleep(sleep_s)
                continue
            resp.raise_for_status()
            result = resp.json()
            done.set()
            return result
        except (requests.exceptions.ReadTimeout,
                requests.exceptions.ConnectionError) as e:
            last_err = e
            done.set()
            if attempt >= HTTP_MAX_RETRIES:
                break
            time.sleep(HTTP_RETRY_BACKOFF ** (attempt - 1))
        except Exception as e:
            last_err = e
            done.set()
            if attempt >= HTTP_MAX_RETRIES:
                break
            time.sleep(HTTP_RETRY_BACKOFF ** (attempt - 1))
        finally:
            try:
                local_session.close()
            except Exception:
                pass

    raise last_err


def normalize_candle_doc(
    connector, hbot_pair, interval, ts_open, open_, high, low, close,
    base_volume, interval_seconds, now_ts,
    quote_volume=None, trade_count=None,
    taker_buy_base_volume=None, taker_buy_quote_volume=None,
):
    base, quote = split_hbot_pair(hbot_pair)
    close_ts = ts_open + interval_seconds
    is_closed = close_ts <= now_ts
    qv_estimated = quote_volume is None
    if quote_volume is None:
        vwap = (high + low + close) / 3.0
        quote_volume = base_volume * vwap
    qc_flags = compute_qc_flags(open_, high, low, close, base_volume)
    doc = {
        "schema_version": SCHEMA_VERSION,
        "connector": connector,
        "trading_pair": hbot_pair,
        "interval": interval,
        "timestamp": ts_open,
        "open_ts": ts_open,
        "close_ts": close_ts,
        "is_closed": is_closed,
        "base_asset": base,
        "quote_asset": quote,
        "open": float(open_),
        "high": float(high),
        "low": float(low),
        "close": float(close),
        "volume": float(base_volume),
        "base_volume": float(base_volume),
        "quote_volume": float(quote_volume),
        "quote_volume_is_estimated": qv_estimated,
        "qc_ok": len(qc_flags) == 0,
        "qc_flags": qc_flags,
        "is_synthetic": False,
        "updated_at": now_ts,
    }
    if trade_count is not None: doc["trade_count"] = int(trade_count)
    if taker_buy_base_volume is not None: doc["taker_buy_base_volume"] = float(taker_buy_base_volume)
    if taker_buy_quote_volume is not None: doc["taker_buy_quote_volume"] = float(taker_buy_quote_volume)
    return doc


def upsert_candles(coll, candles, is_backfill=False):
    if not candles:
        return 0
    now_ts = utc_now_ts()
    if is_backfill:
        for c in candles:
            c.setdefault("ingested_at", now_ts)
        try:
            res = coll.insert_many(candles, ordered=False)
            return len(res.inserted_ids)
        except BulkWriteError as bwe:
            return int(bwe.details.get("nInserted", 0))
    ops = []
    for c in candles:
        key = {"connector": c["connector"], "trading_pair": c["trading_pair"],
               "interval": c["interval"], "timestamp": c["timestamp"]}
        ops.append(UpdateOne(key, {"$set": c, "$setOnInsert": {"ingested_at": now_ts}}, upsert=True))
    try:
        res = coll.bulk_write(ops, ordered=False)
        return int(res.upserted_count + res.modified_count)
    except BulkWriteError:
        return 0


def merge_step_ranges(ranges, step):
    """Merge overlapping/adjacent [start_ts, end_ts] ranges in candle-open space."""
    cleaned = [(int(s), int(e)) for s, e in ranges if s is not None and e is not None and s <= e]
    if not cleaned:
        return []
    cleaned.sort(key=lambda x: (x[0], x[1]))
    merged = [cleaned[0]]
    for s, e in cleaned[1:]:
        last_s, last_e = merged[-1]
        if s <= last_e + step:
            merged[-1] = (last_s, max(last_e, e))
        else:
            merged.append((s, e))
    return merged


def format_ts_ranges(ranges, limit=5):
    if not ranges:
        return "—"
    parts = []
    for s, e in ranges[:limit]:
        parts.append(f"{fmt_ts(s)} → {fmt_ts(e)}")
    if len(ranges) > limit:
        parts.append(f"... (+{len(ranges) - limit} more)")
    return " | ".join(parts)


def scan_doc_ranges(coll, connector, pair, interval, step, window_start, window_end):
    """Return contiguous candle ranges already present in Mongo for one series."""
    effective_start = align_floor(window_start, step)
    effective_end = align_floor(window_end, step)
    if effective_end < effective_start:
        return {"ranges": [], "count": 0, "first_ts": None, "last_ts": None}

    cursor = coll.find(
        {
            "connector": connector,
            "trading_pair": pair,
            "interval": interval,
            "timestamp": {"$gte": effective_start, "$lte": effective_end},
        },
        projection={"timestamp": 1, "_id": 0},
        sort=[("timestamp", 1)],
        batch_size=5000,
    )

    ranges = []
    count = 0
    first_ts = None
    last_ts = None
    range_start = None
    prev = None

    for doc in cursor:
        ts = int(doc["timestamp"])
        count += 1
        if first_ts is None:
            first_ts = ts
            range_start = ts
        elif prev is not None and ts > prev + step:
            ranges.append((range_start, prev))
            range_start = ts
        prev = ts
        last_ts = ts

    if range_start is not None and prev is not None:
        ranges.append((range_start, prev))

    return {
        "ranges": ranges,
        "count": count,
        "first_ts": first_ts,
        "last_ts": last_ts,
    }


def load_recorded_coverage_ranges(coverage_coll, connector, pair, interval, step, window_start, window_end):
    """Load recorded backfill coverage receipts for one series, merged/clamped."""
    effective_start = align_floor(window_start, step)
    effective_end = align_floor(window_end, step)
    if effective_end < effective_start:
        return []

    cursor = coverage_coll.find(
        {
            "connector": connector,
            "trading_pair": pair,
            "interval": interval,
            "end_ts": {"$gte": effective_start},
            "start_ts": {"$lte": effective_end},
        },
        projection={"start_ts": 1, "end_ts": 1, "_id": 0},
        sort=[("start_ts", 1), ("end_ts", 1)],
    )

    ranges = []
    for doc in cursor:
        s = max(effective_start, int(doc["start_ts"]))
        e = min(effective_end, int(doc["end_ts"]))
        if s <= e:
            ranges.append((s, e))
    return merge_step_ranges(ranges, step)


def complement_ranges(window_start, window_end, covered_ranges, step):
    """Return uncovered ranges inside [window_start, window_end] inclusive."""
    effective_start = align_floor(window_start, step)
    effective_end = align_floor(window_end, step)
    if effective_end < effective_start:
        return []

    covered = merge_step_ranges(covered_ranges, step)
    if not covered:
        return [(effective_start, effective_end)]

    gaps = []
    cursor = effective_start
    for s, e in covered:
        if e < effective_start or s > effective_end:
            continue
        s = max(s, effective_start)
        e = min(e, effective_end)
        if cursor < s:
            gaps.append((cursor, s - step))
        cursor = max(cursor, e + step)
    if cursor <= effective_end:
        gaps.append((cursor, effective_end))
    return [(s, e) for s, e in gaps if s <= e]


def summarize_series_window(coll, connector, pair, interval, step, window_start, window_end):
    """Summarize doc coverage + uncovered ranges for one series window.

    For Kraken, coverage receipts are unioned with observed candles so that
    intervals with no trades (and therefore no candles) do not get retried
    forever once a range has been scanned successfully.
    """
    effective_start = align_floor(window_start, step)
    effective_end = align_floor(window_end, step)
    expected = ((effective_end - effective_start) // step) + 1 if effective_end >= effective_start else 0

    doc_summary = scan_doc_ranges(coll, connector, pair, interval, step, effective_start, effective_end)
    recorded_ranges = []
    if connector == "kraken":
        recorded_ranges = load_recorded_coverage_ranges(
            coverage_coll, connector, pair, interval, step, effective_start, effective_end
        )

    covered_ranges = list(doc_summary["ranges"])
    if connector == "kraken" and recorded_ranges:
        covered_ranges = merge_step_ranges(doc_summary["ranges"] + recorded_ranges, step)

    gap_ranges = complement_ranges(effective_start, effective_end, covered_ranges, step)
    missing = sum(((e - s) // step) + 1 for s, e in gap_ranges)
    covered_buckets = max(0, expected - missing)
    pct = (covered_buckets / expected * 100.0) if expected > 0 else 100.0

    return {
        "effective_start": effective_start,
        "effective_end": effective_end,
        "expected": expected,
        "docs_in_window": doc_summary["count"],
        "first_doc_ts": doc_summary["first_ts"],
        "last_doc_ts": doc_summary["last_ts"],
        "doc_ranges": doc_summary["ranges"],
        "recorded_ranges": recorded_ranges,
        "covered_ranges": covered_ranges,
        "gap_ranges": gap_ranges,
        "covered_buckets": covered_buckets,
        "missing": missing,
        "pct": pct,
    }


def record_coverage_range(coverage_coll, connector, pair, interval, start_ts, end_ts, source="backfill"):
    if end_ts < start_ts:
        return
    now_ts = utc_now_ts()
    coverage_coll.update_one(
        {
            "connector": connector,
            "trading_pair": pair,
            "interval": interval,
            "start_ts": int(start_ts),
            "end_ts": int(end_ts),
        },
        {
            "$set": {
                "connector": connector,
                "trading_pair": pair,
                "interval": interval,
                "start_ts": int(start_ts),
                "end_ts": int(end_ts),
                "source": source,
                "updated_at": now_ts,
            },
            "$setOnInsert": {"created_at": now_ts},
        },
        upsert=True,
    )


print("Helpers loaded.")
# Out:
# Helpers loaded.

# %%
# ── Cell 3: Exchange-specific candle fetchers ────────────────────────────────
#
# Each fetcher takes (hbot_pair, interval, window params) and returns a list of
# candles. To add a new exchange, add a fetcher here matching this signature
# style, then add a corresponding ingester in Cell 4.

def fetch_nonkyc_candles(hbot_pair, interval, to_ts, count):
    ex_cfg = EXCHANGES["nonkyc"]
    res = ex_cfg["interval_map"].get(interval)
    if res is None:
        return []
    url = ex_cfg["base_url"].rstrip("/") + "/market/candles"
    params = {
        "symbol": to_nonkyc_symbol(hbot_pair),
        "resolution": int(res),
        "countBack": int(count),
        "to": int(to_ts),
    }
    data = http_get_json(url, params, prefix="[nonkyc] ",
                         exchange="nonkyc",
                         headers={"Connection": "close"})
    if not isinstance(data, dict):
        return []
    candles = []
    # Format 1: TradingView UDF arrays
    if data.get("s") == "ok" and "t" in data:
        t_arr = data.get("t", [])
        o_arr = data.get("o", []); h_arr = data.get("h", [])
        l_arr = data.get("l", []); c_arr = data.get("c", [])
        v_arr = data.get("v", [])
        for i in range(min(len(t_arr), len(o_arr), len(h_arr), len(l_arr), len(c_arr), len(v_arr))):
            candles.append({
                "timestamp": int(int(t_arr[i]) // 1000),
                "open": safe_float(o_arr[i]), "high": safe_float(h_arr[i]),
                "low": safe_float(l_arr[i]), "close": safe_float(c_arr[i]),
                "volume": safe_float(v_arr[i]),
            })
        return candles
    # Format 2: { bars: [...] }
    bars = data.get("bars")
    if isinstance(bars, list):
        for bar in bars:
            if not isinstance(bar, dict): continue
            ts_val = int(bar.get("time", 0))
            if ts_val > 1e12: ts_val = ts_val // 1000
            candles.append({
                "timestamp": ts_val,
                "open": safe_float(bar.get("open")), "high": safe_float(bar.get("high")),
                "low": safe_float(bar.get("low")), "close": safe_float(bar.get("close")),
                "volume": safe_float(bar.get("volume")),
            })
    return candles


def fetch_binance_candles(hbot_pair, interval, start_ms, end_ms, limit):
    ex_cfg = EXCHANGES["binance"]
    api_interval = ex_cfg["interval_map"].get(interval)
    if api_interval is None:
        return []
    url = ex_cfg["base_url"].rstrip("/") + "/api/v3/klines"
    params = {"symbol": to_binance_symbol(hbot_pair), "interval": api_interval,
              "startTime": int(start_ms), "endTime": int(end_ms), "limit": int(limit)}
    data = http_get_json(url, params, prefix="[binance] ", exchange="binance")
    return data if isinstance(data, list) else []


def fetch_mexc_candles(hbot_pair, interval, start_ms, end_ms, limit):
    ex_cfg = EXCHANGES["mexc"]
    api_interval = ex_cfg["interval_map"].get(interval)
    if api_interval is None:
        return []
    url = ex_cfg["base_url"].rstrip("/") + "/api/v3/klines"
    params = {"symbol": to_mexc_symbol(hbot_pair), "interval": api_interval,
              "startTime": int(start_ms), "endTime": int(end_ms), "limit": int(limit)}
    data = http_get_json(url, params, prefix="[mexc] ", exchange="mexc")
    return data if isinstance(data, list) else []


def fetch_coinbase_candles(hbot_pair, interval, start_ts, end_ts):
    ex_cfg = EXCHANGES["coinbase"]
    granularity = ex_cfg["interval_map"].get(interval)
    if granularity is None:
        return []
    product_id = to_coinbase_product_id(hbot_pair)
    url = ex_cfg["base_url"].rstrip("/") + f"/products/{product_id}/candles"
    params = {"granularity": int(granularity),
              "start": ts_to_iso8601(int(start_ts)), "end": ts_to_iso8601(int(end_ts))}
    data = http_get_json(url, params, prefix="[coinbase] ", exchange="coinbase")
    return data if isinstance(data, list) else []


# --- Adding a new exchange? Template: ---

def fetch_kraken_candles(hbot_pair, interval, since_ts=None):
    """Fetch OHLC candles from Kraken's public /0/public/OHLC endpoint.

    Kraken caps this endpoint at 720 bars per response and does NOT support
    paging further back. Deep history is therefore handled in Cell 4 via the
    /0/public/Trades endpoint plus local candle aggregation.
    """
    ex_cfg = EXCHANGES["kraken"]
    api_interval = ex_cfg["interval_map"].get(interval)
    if api_interval is None:
        return []
    url = ex_cfg["base_url"].rstrip("/") + "/0/public/OHLC"
    params = {
        "pair": to_kraken_symbol(hbot_pair),
        "interval": int(api_interval),
    }
    if since_ts is not None:
        params["since"] = int(since_ts)
    data = http_get_json(url, params, prefix="[kraken] ", exchange="kraken")

    # Kraken response shape:
    #   {"error": [...], "result": {"<pair_key>": [[ts,o,h,l,c,vwap,vol,count], ...], "last": <ts>}}
    if not isinstance(data, dict):
        return []
    if data.get("error"):
        print(f"  [kraken] API error for {hbot_pair}: {data['error']}")
        return []
    result = data.get("result", {})
    if not isinstance(result, dict):
        return []
    pair_key = None
    for k in result.keys():
        if k != "last":
            pair_key = k
            break
    if pair_key is None:
        return []
    rows = result.get(pair_key, [])
    if not isinstance(rows, list):
        return []

    candles = []
    for r in rows:
        if not isinstance(r, (list, tuple)) or len(r) < 7:
            continue
        ts_open = int(r[0])
        candles.append({
            "timestamp": ts_open,
            "open": safe_float(r[1]),
            "high": safe_float(r[2]),
            "low": safe_float(r[3]),
            "close": safe_float(r[4]),
            "volume": safe_float(r[6]),
        })
    return candles


def fetch_kraken_trades(hbot_pair, since_ns=None):
    """Fetch historical trades from Kraken's public /0/public/Trades endpoint.

    Returns
    -------
    tuple[list[dict], str|int|None]
        (trades, next_cursor)

    Each trade dict has:
      {price, volume, timestamp}

    Notes
    -----
    - `since_ns=0` starts at the beginning of the market for that pair.
    - Subsequent requests should pass the `last` cursor returned by the
      previous response.
    """
    ex_cfg = EXCHANGES["kraken"]
    url = ex_cfg["base_url"].rstrip("/") + "/0/public/Trades"
    params = {"pair": to_kraken_symbol(hbot_pair)}
    if since_ns is not None:
        params["since"] = str(since_ns)

    data = http_get_json(url, params, prefix="[kraken] ", exchange="kraken")
    if not isinstance(data, dict):
        return [], None
    if data.get("error"):
        print(f"  [kraken] Trades API error for {hbot_pair}: {data['error']}")
        return [], None

    result = data.get("result", {})
    if not isinstance(result, dict):
        return [], None

    pair_key = None
    for k in result.keys():
        if k != "last":
            pair_key = k
            break
    rows = result.get(pair_key, []) if pair_key is not None else []
    if not isinstance(rows, list):
        rows = []

    trades = []
    for r in rows:
        if not isinstance(r, (list, tuple)) or len(r) < 3:
            continue
        price = safe_float(r[0])
        volume = safe_float(r[1])
        ts = float(r[2])
        if price != price or volume != volume:
            continue
        trades.append({
            "price": price,
            "volume": volume,
            "timestamp": ts,
        })
    return trades, result.get("last")


FETCHERS = {
    "nonkyc": fetch_nonkyc_candles,
    "binance": fetch_binance_candles,
    "mexc": fetch_mexc_candles,
    "coinbase": fetch_coinbase_candles,
    "kraken": fetch_kraken_candles,
}

print(f"Fetchers loaded: {', '.join(sorted(FETCHERS.keys()))}")
# Out:
# Fetchers loaded: binance, coinbase, kraken, mexc, nonkyc

# %%
# ── Cell 4: Range ingesters (per exchange) ──────────────────────────────────
#
# Each ingester paginates a time range and writes normalized candle docs to Mongo.

def ingest_nonkyc_range(coll, hbot_pair, interval, start_ts, end_ts):
    ex_cfg = EXCHANGES["nonkyc"]
    if ex_cfg["interval_map"].get(interval) is None:
        return 0
    step = INTERVAL_SECONDS[interval]
    now_ts = utc_now_ts()
    max_per = ex_cfg["max_per_request"]
    page_to = end_ts + step - 1
    total = 0
    safety = 0
    started = time.perf_counter()
    last_heartbeat = started
    requests_made = 0
    while page_to >= start_ts and safety < 100000:
        safety += 1
        requests_made += 1
        bars = fetch_nonkyc_candles(hbot_pair, interval, to_ts=page_to, count=max_per)
        # Heartbeat: show live progress when a single pair is taking a while
        now_pc = time.perf_counter()
        if now_pc - last_heartbeat >= 30.0:
            elapsed = now_pc - started
            print(f"    [nonkyc] {hbot_pair} {interval}: "
                  f"{requests_made} reqs, {total:,} written, {elapsed:.0f}s elapsed")
            last_heartbeat = now_pc
        if not bars:
            break
        docs = []
        oldest = None
        for b in bars:
            ts_open = int(b["timestamp"])
            if ts_open < start_ts or ts_open > end_ts:
                continue
            oldest = ts_open if oldest is None else min(oldest, ts_open)
            docs.append(normalize_candle_doc(
                connector="nonkyc", hbot_pair=hbot_pair, interval=interval,
                ts_open=ts_open, open_=b["open"], high=b["high"], low=b["low"],
                close=b["close"], base_volume=b["volume"],
                interval_seconds=step, now_ts=now_ts,
            ))
        if docs:
            total += upsert_candles(coll, docs, is_backfill=True)
        if oldest is None or oldest <= start_ts or oldest >= page_to:
            break
        page_to = oldest - 1
        # No explicit sleep — the token bucket inside http_get_json paces requests
    return total


def ingest_binance_range(coll, hbot_pair, interval, start_ts, end_ts):
    ex_cfg = EXCHANGES["binance"]
    if ex_cfg["interval_map"].get(interval) is None:
        return 0
    step = INTERVAL_SECONDS[interval]
    now_ts = utc_now_ts()
    max_per = ex_cfg["max_per_request"]
    delay = ex_cfg["request_delay_seconds"]
    cur = start_ts
    total = 0
    consecutive_empty = 0
    safety = 0
    while cur <= end_ts and safety < 100000:
        safety += 1
        window_end = min(cur + (max_per - 1) * step, end_ts)
        rows = fetch_binance_candles(hbot_pair, interval, cur * 1000, window_end * 1000, max_per)
        if not rows:
            consecutive_empty += 1
            if consecutive_empty >= 3:
                # Three empty windows in a row — the pair likely didn't exist yet.
                break
            cur = window_end + step
            time.sleep(delay)
            continue
        consecutive_empty = 0
        docs = []
        max_row_ts = None
        for r in rows:
            ts_open = int(r[0]) // 1000
            if ts_open < start_ts or ts_open > end_ts:
                continue
            max_row_ts = ts_open if max_row_ts is None else max(max_row_ts, ts_open)
            docs.append(normalize_candle_doc(
                connector="binance", hbot_pair=hbot_pair, interval=interval,
                ts_open=ts_open, open_=safe_float(r[1]), high=safe_float(r[2]),
                low=safe_float(r[3]), close=safe_float(r[4]),
                base_volume=safe_float(r[5]), interval_seconds=step, now_ts=now_ts,
                quote_volume=safe_float(r[7]),
                trade_count=int(r[8]) if len(r) > 8 else None,
                taker_buy_base_volume=safe_float(r[9]) if len(r) > 9 else None,
                taker_buy_quote_volume=safe_float(r[10]) if len(r) > 10 else None,
            ))
        if docs:
            total += upsert_candles(coll, docs, is_backfill=True)
        cur = (max_row_ts + step) if max_row_ts else (cur + max_per * step)
        time.sleep(delay)
    return total


def ingest_mexc_range(coll, hbot_pair, interval, start_ts, end_ts):
    ex_cfg = EXCHANGES["mexc"]
    if ex_cfg["interval_map"].get(interval) is None:
        return 0
    step = INTERVAL_SECONDS[interval]
    now_ts = utc_now_ts()
    max_per = ex_cfg["max_per_request"]
    delay = ex_cfg["request_delay_seconds"]
    cur = start_ts
    total = 0
    consecutive_empty = 0
    safety = 0
    while cur <= end_ts and safety < 100000:
        safety += 1
        window_end = min(cur + (max_per - 1) * step, end_ts)
        rows = fetch_mexc_candles(hbot_pair, interval, cur * 1000, window_end * 1000, max_per)
        if not rows:
            consecutive_empty += 1
            if consecutive_empty >= 3:
                break
            cur = window_end + step
            time.sleep(delay)
            continue
        consecutive_empty = 0
        docs = []
        max_row_ts = None
        for r in rows:
            ts_open = int(r[0]) // 1000
            if ts_open < start_ts or ts_open > end_ts:
                continue
            max_row_ts = ts_open if max_row_ts is None else max(max_row_ts, ts_open)
            docs.append(normalize_candle_doc(
                connector="mexc", hbot_pair=hbot_pair, interval=interval,
                ts_open=ts_open, open_=safe_float(r[1]), high=safe_float(r[2]),
                low=safe_float(r[3]), close=safe_float(r[4]),
                base_volume=safe_float(r[5]), interval_seconds=step, now_ts=now_ts,
                quote_volume=safe_float(r[7]) if len(r) > 7 else None,
            ))
        if docs:
            total += upsert_candles(coll, docs, is_backfill=True)
        cur = (max_row_ts + step) if max_row_ts else (cur + max_per * step)
        time.sleep(delay)
    return total


def ingest_coinbase_range(coll, hbot_pair, interval, start_ts, end_ts):
    ex_cfg = EXCHANGES["coinbase"]
    if ex_cfg["interval_map"].get(interval) is None:
        return 0
    step = INTERVAL_SECONDS[interval]
    now_ts = utc_now_ts()
    max_per = ex_cfg["max_per_request"]
    delay = ex_cfg["request_delay_seconds"]
    cur = start_ts
    total = 0
    consecutive_empty = 0
    safety = 0
    while cur <= end_ts and safety < 100000:
        safety += 1
        window_end = min(cur + (max_per - 1) * step, end_ts)
        rows = fetch_coinbase_candles(hbot_pair, interval, cur, window_end)
        if not rows:
            consecutive_empty += 1
            if consecutive_empty >= 3:
                break
            cur = window_end + step
            time.sleep(delay)
            continue
        consecutive_empty = 0
        docs = []
        max_row_ts = None
        for r in rows:
            ts_open = int(r[0])
            if ts_open < start_ts or ts_open > end_ts:
                continue
            max_row_ts = ts_open if max_row_ts is None else max(max_row_ts, ts_open)
            docs.append(normalize_candle_doc(
                connector="coinbase", hbot_pair=hbot_pair, interval=interval,
                ts_open=ts_open, open_=safe_float(r[3]), high=safe_float(r[2]),
                low=safe_float(r[1]), close=safe_float(r[4]),
                base_volume=safe_float(r[5]), interval_seconds=step, now_ts=now_ts,
            ))
        if docs:
            total += upsert_candles(coll, docs, is_backfill=True)
        cur = (max_row_ts + step) if max_row_ts else (cur + max_per * step)
        time.sleep(delay)
    return total



def _ingest_kraken_recent_ohlc_range(coll, hbot_pair, interval, start_ts, end_ts):
    """Use Kraken's OHLC endpoint for the recent <= 720-bar window."""
    step = INTERVAL_SECONDS[interval]
    now_ts = utc_now_ts()

    bars = fetch_kraken_candles(hbot_pair, interval, since_ts=max(0, start_ts - step))
    if not bars:
        return 0

    docs = []
    for b in bars:
        ts_open = int(b["timestamp"])
        if ts_open < start_ts or ts_open > end_ts:
            continue
        docs.append(normalize_candle_doc(
            connector="kraken", hbot_pair=hbot_pair, interval=interval,
            ts_open=ts_open, open_=b["open"], high=b["high"], low=b["low"],
            close=b["close"], base_volume=b["volume"],
            interval_seconds=step, now_ts=now_ts,
        ))
    if docs:
        return upsert_candles(coll, docs, is_backfill=True)
    return 0


def _ingest_kraken_trades_range(coll, hbot_pair, interval, start_ts, end_ts):
    """Deep-history Kraken backfill via /0/public/Trades + local aggregation.

    This scans trades forward from `start_ts`, aggregates them into candles for
    `interval`, and writes only buckets whose open timestamp falls inside the
    requested range [start_ts, end_ts].

    Important:
    - This is much heavier than Kraken's OHLC endpoint.
    - It is the only public REST path Kraken documents for deep history.
    - Missing candles inside a successfully scanned range can be legitimate
      "no trades happened" intervals; Cell 11 records coverage receipts so
      those ranges are not retried forever.
    """
    ex_cfg = EXCHANGES["kraken"]
    if ex_cfg["interval_map"].get(interval) is None:
        return 0

    step = INTERVAL_SECONDS[interval]
    start_ts = align_floor(start_ts, step)
    end_ts = align_floor(end_ts, step)
    if end_ts < start_ts:
        return 0

    now_ts = utc_now_ts()
    cursor = str(max(0, int(start_ts) * 1_000_000_000 - 1))
    total_written = 0
    pending_docs = []
    current = None
    page = 0
    progress_every = 100
    last_cursor = None
    no_progress = 0
    reached_end = False

    def flush_current():
        nonlocal current, pending_docs, total_written
        if current is None:
            return
        ts_open = current["ts_open"]
        if start_ts <= ts_open <= end_ts:
            pending_docs.append(normalize_candle_doc(
                connector="kraken", hbot_pair=hbot_pair, interval=interval,
                ts_open=ts_open,
                open_=current["open"], high=current["high"],
                low=current["low"], close=current["close"],
                base_volume=current["base_volume"],
                quote_volume=current["quote_volume"],
                trade_count=current["trade_count"],
                interval_seconds=step, now_ts=now_ts,
            ))
            if len(pending_docs) >= 2000:
                total_written += upsert_candles(coll, pending_docs, is_backfill=True)
                pending_docs = []
        current = None

    while True:
        trades, next_cursor = fetch_kraken_trades(hbot_pair, since_ns=cursor)
        page += 1

        if not trades:
            break

        for tr in trades:
            ts_float = float(tr["timestamp"])
            bucket_open = align_floor(int(ts_float), step)

            if bucket_open < start_ts:
                continue
            if bucket_open > end_ts:
                reached_end = True
                break

            price = tr["price"]
            volume = tr["volume"]

            if current is None:
                current = {
                    "ts_open": bucket_open,
                    "open": price,
                    "high": price,
                    "low": price,
                    "close": price,
                    "base_volume": volume,
                    "quote_volume": price * volume,
                    "trade_count": 1,
                }
                continue

            if bucket_open != current["ts_open"]:
                flush_current()
                current = {
                    "ts_open": bucket_open,
                    "open": price,
                    "high": price,
                    "low": price,
                    "close": price,
                    "base_volume": volume,
                    "quote_volume": price * volume,
                    "trade_count": 1,
                }
            else:
                current["high"] = max(current["high"], price)
                current["low"] = min(current["low"], price)
                current["close"] = price
                current["base_volume"] += volume
                current["quote_volume"] += price * volume
                current["trade_count"] += 1

        if reached_end:
            break

        next_cursor = str(next_cursor) if next_cursor is not None else str(cursor)
        if next_cursor == str(cursor) or next_cursor == str(last_cursor):
            no_progress += 1
        else:
            no_progress = 0

        if no_progress >= 2:
            raise RuntimeError(
                f"[kraken] {hbot_pair} {interval}: cursor stopped advancing at {cursor}"
            )

        if page % progress_every == 0:
            try:
                through_ts = int(float(trades[-1]["timestamp"]))
                print(f"  [kraken] {hbot_pair} {interval}: page {page:,}, scanned through {fmt_ts(through_ts)}")
            except Exception:
                pass

        last_cursor = cursor
        cursor = next_cursor

    flush_current()
    if pending_docs:
        total_written += upsert_candles(coll, pending_docs, is_backfill=True)
    return total_written


def ingest_kraken_range(coll, hbot_pair, interval, start_ts, end_ts):
    """Hybrid Kraken ingester.

    - Deep history: /0/public/Trades + local aggregation.
    - Recent <= 720 bars: /0/public/OHLC for efficiency.
    """
    ex_cfg = EXCHANGES["kraken"]
    if ex_cfg["interval_map"].get(interval) is None:
        return 0

    step = INTERVAL_SECONDS[interval]
    start_ts = align_floor(start_ts, step)
    end_ts = align_floor(end_ts, step)
    if end_ts < start_ts:
        return 0

    now_ts = utc_now_ts()
    recent_floor = align_floor(now_ts - (ex_cfg["max_per_request"] * step), step)

    total = 0
    if start_ts < recent_floor:
        deep_end = min(end_ts, recent_floor - step)
        if deep_end >= start_ts:
            total += _ingest_kraken_trades_range(coll, hbot_pair, interval, start_ts, deep_end)

    if end_ts >= recent_floor:
        recent_start = max(start_ts, recent_floor)
        if end_ts >= recent_start:
            total += _ingest_kraken_recent_ohlc_range(coll, hbot_pair, interval, recent_start, end_ts)

    return total

INGESTERS = {
    "nonkyc": ingest_nonkyc_range,
    "binance": ingest_binance_range,
    "mexc": ingest_mexc_range,
    "coinbase": ingest_coinbase_range,
    "kraken": ingest_kraken_range,
}

# Sanity check: every configured exchange must have a fetcher + ingester.
_missing = []
for ex in EXCHANGES.keys():
    if ex not in FETCHERS:
        _missing.append(f"fetcher for {ex}")
    if ex not in INGESTERS:
        _missing.append(f"ingester for {ex}")
if _missing:
    print(f"⚠ Missing implementations (edit Cells 3 and 4): {', '.join(_missing)}")
else:
    print(f"Ingesters loaded: {', '.join(sorted(INGESTERS.keys()))}")
# Out:
# Ingesters loaded: binance, coinbase, kraken, mexc, nonkyc

# %%
# ── Cell 5: Connect to MongoDB & ensure indexes ─────────────────────────────

client = MongoClient(MONGO_URI, serverSelectionTimeoutMS=10000)
client.admin.command("ping")
db = client[MONGO_DATABASE]
coll = db[COLLECTION_NAME]
probe_coll = db[PROBE_COLL_NAME]
pair_start_coll = db[PAIR_START_COLL_NAME]
coverage_coll = db[COVERAGE_COLL_NAME]

coll.create_index(
    [("connector", 1), ("trading_pair", 1), ("interval", 1), ("timestamp", 1)],
    unique=True, name="idx_connector_pair_interval_ts",
)
probe_coll.create_index(
    [("exchange", 1), ("interval", 1)],
    unique=True, name="idx_exchange_interval",
)
pair_start_coll.create_index(
    [("exchange", 1), ("pair", 1)],
    unique=True, name="idx_exchange_pair_start",
)
coverage_coll.create_index(
    [("connector", 1), ("trading_pair", 1), ("interval", 1), ("start_ts", 1), ("end_ts", 1)],
    unique=True, name="idx_series_coverage_exact",
)

print(f"Connected to MongoDB: {MONGO_URI.split('@')[-1]}")
print(f"Database: {MONGO_DATABASE}  Candles collection: {COLLECTION_NAME}")
print(f"Probe cache: {PROBE_COLL_NAME}  Pair-start cache: {PAIR_START_COLL_NAME}")
print(f"Coverage receipts: {COVERAGE_COLL_NAME}")
print(f"Total candle documents: {coll.estimated_document_count():,}")
print(f"Cached probes: {probe_coll.estimated_document_count()}")
print(f"Cached pair-starts: {pair_start_coll.estimated_document_count()}")
print(f"Coverage receipts: {coverage_coll.estimated_document_count()}")
# Out:
# Connected to MongoDB: 192.168.1.54:27017/quants_lab?authSource=admin&retryWrites=true&w=majority
# Database: quants_lab  Candles collection: candles
# Probe cache: candle_coverage_probes  Pair-start cache: candle_coverage_probes_pair_starts
# Coverage receipts: candles_coverage
# Total candle documents: 25,576,682
# Cached probes: 37
# Cached pair-starts: 0
# Coverage receipts: 0

# %%
# ── Cell 6: Earliest-available probe (one-time per exchange × interval) ─────
#
# For exchanges with proper historical candle pagination, we probe an
# exchange-wide earliest timestamp per interval and cache it in Mongo.
#
# Kraken is different:
#   - its OHLC endpoint only returns the most recent 720 bars, regardless of
#     the `since` value, so an exchange-wide OHLC probe is not meaningful;
#   - its public Trades endpoint can start from the beginning of a market
#     (`since=0`), so we cache pair-specific market starts instead.

REFERENCE_PAIR = {
    "nonkyc":   "BTC-USDT",
    "binance":  "BTC-USDT",
    "mexc":     "BTC-USDT",
    "coinbase": "BTC-USD",
    "kraken":   "BTC-USD",
}

_EXCHANGE_HOST_RESOLUTION_CACHE = {}


def get_cached_pair_start_ts(exchange: str, hbot_pair: str):
    doc = pair_start_coll.find_one(
        {"exchange": exchange, "pair": hbot_pair},
        projection={"pair_start_ts": 1, "_id": 0},
    )
    if not doc:
        return None
    ts = doc.get("pair_start_ts")
    return int(ts) if ts is not None else None


def cache_pair_start_ts(exchange: str, hbot_pair: str, pair_start_ts: int, source: str = "probe"):
    now_ts = utc_now_ts()
    pair_start_coll.update_one(
        {"exchange": exchange, "pair": hbot_pair},
        {
            "$set": {
                "exchange": exchange,
                "pair": hbot_pair,
                "pair_start_ts": int(pair_start_ts),
                "source": source,
                "updated_at": now_ts,
            },
            "$setOnInsert": {"created_at": now_ts},
        },
        upsert=True,
    )


def get_exchange_host(exchange: str) -> str:
    from urllib.parse import urlparse

    base_url = EXCHANGES[exchange]["base_url"]
    return urlparse(base_url).hostname or base_url


def check_exchange_host_resolution(exchange: str, force: bool = False):
    """Return {'ok', 'host', 'reason'} for the exchange base URL host.

    This is a fast DNS-only preflight used to avoid noisy per-pair errors when
    an environment cannot resolve a host like api.kraken.com at all.
    """
    cache_key = ("host_resolution", exchange)
    if cache_key in _EXCHANGE_HOST_RESOLUTION_CACHE and not force:
        return _EXCHANGE_HOST_RESOLUTION_CACHE[cache_key]

    import socket

    host = get_exchange_host(exchange)
    try:
        socket.getaddrinfo(host, 443, type=socket.SOCK_STREAM)
        result = {"ok": True, "host": host, "reason": None}
    except Exception as e:
        result = {"ok": False, "host": host, "reason": f"{type(e).__name__}: {e}"}

    _EXCHANGE_HOST_RESOLUTION_CACHE[cache_key] = result
    return result


def short_exc(e: Exception) -> str:
    return f"{type(e).__name__}: {e}"


def probe_kraken_pair_start_ts(hbot_pair: str, force: bool = False):
    cached = get_cached_pair_start_ts("kraken", hbot_pair)
    if cached is not None and not force:
        return cached

    trades, _cursor = fetch_kraken_trades(hbot_pair, since_ns=0)
    if not trades:
        return None

    first_trade_ts = int(math.floor(float(trades[0]["timestamp"])))
    cache_pair_start_ts("kraken", hbot_pair, first_trade_ts, source="trades_since_zero")
    return first_trade_ts


def get_kraken_pair_start_ts(hbot_pair: str, mode: str = "auto", force: bool = False):
    """Return (pair_start_ts, source, note) for a Kraken pair.

    mode
    ----
    auto
        Use cached value if present. On cache miss, only live-probe if the
        Kraken host resolves in the current environment.
    cached_only
        Never hit the network; use cached value only.
    force_live
        Use cached value if present, otherwise attempt the live Trades probe
        without the DNS preflight gate.
    """
    cached = get_cached_pair_start_ts("kraken", hbot_pair)
    if cached is not None and not force:
        return cached, "cache", None

    mode = str(mode).strip().lower()
    if mode not in {"auto", "cached_only", "force_live"}:
        raise ValueError("mode must be one of: auto, cached_only, force_live")

    if mode == "cached_only":
        return None, None, "cached_only"

    if mode == "auto":
        host_state = check_exchange_host_resolution("kraken")
        if not host_state["ok"]:
            return None, None, f"cannot resolve {host_state['host']} ({host_state['reason']})"

    try:
        ts = probe_kraken_pair_start_ts(hbot_pair, force=force)
    except Exception as e:
        return None, None, short_exc(e)

    if ts is None:
        return None, None, "no trades returned"

    return ts, "live_probe", None


def _probe_has_data(exchange: str, interval: str, center_ts: int) -> bool:
    """Return True iff the exchange serves any candles in a small window
    centered on `center_ts`. Uses the reference pair for that exchange."""
    ex_cfg = EXCHANGES[exchange]
    if ex_cfg["interval_map"].get(interval) is None:
        return False
    ref = REFERENCE_PAIR.get(exchange)
    if ref is None:
        raise RuntimeError(f"No REFERENCE_PAIR configured for {exchange}; add one at the top of Cell 6.")
    step = INTERVAL_SECONDS[interval]
    half = 5 * step
    start_ts = max(0, center_ts - half)
    end_ts = center_ts + half

    try:
        if exchange == "nonkyc":
            bars = fetch_nonkyc_candles(ref, interval, to_ts=end_ts, count=10)
            return any(start_ts <= int(b["timestamp"]) <= end_ts for b in bars)
        elif exchange == "binance":
            rows = fetch_binance_candles(ref, interval, start_ts * 1000, end_ts * 1000, 10)
            return len(rows) > 0
        elif exchange == "mexc":
            rows = fetch_mexc_candles(ref, interval, start_ts * 1000, end_ts * 1000, 10)
            return len(rows) > 0
        elif exchange == "coinbase":
            rows = fetch_coinbase_candles(ref, interval, start_ts, end_ts)
            return len(rows) > 0
        elif exchange == "kraken":
            # Only meaningful near the present; Kraken's deep-history floor is
            # pair-specific and handled via Trades rather than this probe.
            bars = fetch_kraken_candles(ref, interval, since_ts=max(0, start_ts - step))
            return any(start_ts <= int(b["timestamp"]) <= end_ts for b in bars)
        else:
            raise RuntimeError(f"No probe branch implemented for {exchange}")
    except Exception as e:
        print(f"  probe error {exchange} {interval} @ {fmt_ts(center_ts)}: {e}")
        return False


def probe_earliest_available_ts(exchange: str, interval: str, absolute_max_days: int, force: bool = False) -> int:
    """Return the earliest-available UTC timestamp (seconds) for a given
    (exchange, interval), using binary search. Cached in Mongo.

    Kraken is special-cased: its actual market start is pair-specific, so this
    function only returns the absolute ceiling for Kraken and Cell 8 later
    refines each pair via `get_kraken_pair_start_ts`.
    """
    now_ts = utc_now_ts()

    if exchange == "kraken":
        return now_ts - absolute_max_days * 86400

    cached = probe_coll.find_one({"exchange": exchange, "interval": interval})
    if cached and not force:
        age_days = (now_ts - cached["earliest_ts"]) / 86400
        if age_days <= absolute_max_days:
            return int(cached["earliest_ts"])

    lo = now_ts - absolute_max_days * 86400
    hi = now_ts - INTERVAL_SECONDS[interval]

    if not _probe_has_data(exchange, interval, center_ts=hi):
        probe_coll.update_one(
            {"exchange": exchange, "interval": interval},
            {"$set": {"exchange": exchange, "interval": interval,
                      "earliest_ts": now_ts, "no_data": True, "probed_at": now_ts}},
            upsert=True,
        )
        return now_ts

    if _probe_has_data(exchange, interval, center_ts=lo):
        earliest = lo
    else:
        step = INTERVAL_SECONDS[interval]
        low, high = lo, hi
        tolerance = max(2 * 86400, 10 * step)
        while high - low > tolerance:
            mid = (low + high) // 2
            if _probe_has_data(exchange, interval, center_ts=mid):
                high = mid
            else:
                low = mid
        earliest = high

    probe_coll.update_one(
        {"exchange": exchange, "interval": interval},
        {"$set": {"exchange": exchange, "interval": interval,
                  "earliest_ts": earliest, "no_data": False, "probed_at": now_ts}},
        upsert=True,
    )
    return earliest


print("Probe helpers loaded. Kraken pair-start helpers are ready too.")
# Out:
# Probe helpers loaded. Kraken pair-start helpers are ready too.

# %%
# ── Cell 7: Run probes for every configured exchange × interval ─────────────
#
# Builds the effective per-(exchange, interval) window for discovery. Kraken is
# special-cased: Cell 7 does NOT use OHLC to limit Kraken because Kraken's OHLC
# endpoint only exposes the most recent 720 bars. Pair-specific starts are
# discovered/cached later in Cell 8 via the Trades endpoint.

FORCE_REPROBE = False

now_ts = utc_now_ts()
absolute_floor_ts = now_ts - ABSOLUTE_MAX_DAYS * 86400

effective_windows = {}   # (exchange, interval) -> earliest_ts

print("Probing each (exchange, interval) — this is cached after first run.")
print(f"Absolute ceiling: {ABSOLUTE_MAX_DAYS} days  (earliest date: {fmt_ts(absolute_floor_ts)})\n")
print(f"{'Exchange':12s} {'Interval':8s} {'Target days':>12s} {'Probed ts':>20s} {'Days back':>11s}  Effective start")
print("─" * 95)

for exchange in sorted(EXCHANGES.keys()):
    for interval in sorted(INTERVAL_TARGETS_DAYS.keys(), key=lambda k: INTERVAL_SECONDS[k]):
        if EXCHANGES[exchange]["interval_map"].get(interval) is None:
            continue

        target_days = min(INTERVAL_TARGETS_DAYS[interval], ABSOLUTE_MAX_DAYS)
        target_floor_ts = now_ts - target_days * 86400

        if exchange == "kraken":
            effective_start = target_floor_ts
            effective_windows[(exchange, interval)] = effective_start
            print(f"{exchange:12s} {interval:8s} {target_days:>12d} {'pair-specific':>20s} "
                  f"{'n/a':>10s}  {fmt_ts(effective_start)}")
            continue

        probed_floor_ts = probe_earliest_available_ts(exchange, interval, ABSOLUTE_MAX_DAYS, force=FORCE_REPROBE)
        effective_start = max(target_floor_ts, probed_floor_ts)
        effective_windows[(exchange, interval)] = effective_start

        days_back = (now_ts - probed_floor_ts) / 86400
#
# Probes complete. effective_windows is ready.
# Kraken pair starts are discovered lazily in Cell 8 and cached in Mongo.

# %%
# ── Cell 8: Discover all (connector, pair, interval) combos and show gaps ──
#
# In addition to the gap/uncovered summary, this cell prints the date ranges
# that are already covered for each series.
#
# For Kraken:
#   - pair starts are discovered once per pair via Trades `since=0`;
#   - coverage receipts are unioned with actual candles so that intervals with
#     no trades do not look like permanent gaps after a successful scan;
#   - if the environment cannot resolve api.kraken.com, the cell falls back to
#     cached pair starts (if any) and otherwise uses the interval window start.

KRAKEN_PAIR_START_MODE = "auto"   # auto | cached_only | force_live
COVERAGE_RANGE_PREVIEW_LIMIT = 5

pipeline = [
    {"$group": {
        "_id": {"connector": "$connector", "trading_pair": "$trading_pair", "interval": "$interval"},
        "count": {"$sum": 1},
        "min_ts": {"$min": "$timestamp"},
        "max_ts": {"$max": "$timestamp"},
    }},
    {"$sort": {"_id.connector": 1, "_id.trading_pair": 1, "_id.interval": 1}},
]
raw_combos = list(coll.aggregate(pipeline, allowDiskUse=True))

combos = []
kraken_pair_start_cache = {}
kraken_live_probe_allowed = (KRAKEN_PAIR_START_MODE != "cached_only")
kraken_pair_start_notice = None

if kraken_live_probe_allowed and KRAKEN_PAIR_START_MODE == "auto":
    host_state = check_exchange_host_resolution("kraken")
    if not host_state["ok"]:
        kraken_live_probe_allowed = False
        kraken_pair_start_notice = (
            f"live pair-start discovery disabled: cannot resolve {host_state['host']} "
            f"({host_state['reason']}). Using cached pair starts when available; "
            f"otherwise the configured interval window start is used."
        )

for doc in raw_combos:
    connector = doc["_id"]["connector"]
    pair = doc["_id"]["trading_pair"]
    interval = doc["_id"]["interval"]

    if connector not in EXCHANGES:
        continue
    if EXCHANGES[connector]["interval_map"].get(interval) is None:
        continue

    step = INTERVAL_SECONDS.get(interval)
    if step is None:
        continue

    window_start = effective_windows.get((connector, interval))
    if window_start is None:
        continue

    pair_start_ts = None
    pair_start_source = None

    if connector == "kraken":
        cached_pair_start = get_cached_pair_start_ts("kraken", pair)
        if cached_pair_start is not None:
            pair_start_ts = cached_pair_start
            pair_start_source = "cache"
        else:
            if pair not in kraken_pair_start_cache:
                if kraken_live_probe_allowed:
                    ts, source, note = get_kraken_pair_start_ts(pair, mode="force_live")
                    kraken_pair_start_cache[pair] = {"ts": ts, "source": source, "note": note}
                    if note is not None:
                        kraken_live_probe_allowed = False
                        kraken_pair_start_notice = (
                            f"live pair-start discovery failed on {pair}: {note}. "
                            f"Using cached pair starts when available; otherwise the "
                            f"configured interval window start is used for remaining Kraken pairs."
                        )
                else:
                    kraken_pair_start_cache[pair] = {"ts": None, "source": None, "note": kraken_pair_start_notice}

            cached_info = kraken_pair_start_cache[pair]
            pair_start_ts = cached_info.get("ts")
            pair_start_source = cached_info.get("source")

        if pair_start_ts is not None:
            window_start = align_floor(pair_start_ts, step)

    effective_start = align_floor(window_start, step)

    recent_cutoff = now_ts - (RECENT_DAYS_OWNED * 86400) if RECENT_DAYS_OWNED > 0 else now_ts
    effective_end = min(
        last_closed_open_ts(now_ts, step),
        last_closed_open_ts(recent_cutoff, step),
    )

    summary = summarize_series_window(
        coll, connector, pair, interval, step, effective_start, effective_end
    )

    combos.append({
        "connector": connector,
        "pair": pair,
        "interval": interval,
        "total_docs": int(doc["count"]),
        "docs_in_window": summary["docs_in_window"],
        "covered_buckets": summary["covered_buckets"],
        "expected": summary["expected"],
        "missing": summary["missing"],
        "pct": summary["pct"],
        "step": step,
        "window_start": effective_start,
        "window_end": summary["effective_end"],
        "covered_ranges": summary["covered_ranges"],
        "covered_range_display": format_ts_ranges(summary["covered_ranges"], limit=COVERAGE_RANGE_PREVIEW_LIMIT),
        "doc_ranges": summary["doc_ranges"],
        "recorded_ranges": summary["recorded_ranges"],
        "first_doc_ts": doc.get("min_ts"),
        "last_doc_ts": doc.get("max_ts"),
        "pair_start_ts": pair_start_ts,
        "pair_start_source": pair_start_source,
    })

connectors_found = sorted(set(c["connector"] for c in combos))
print(f"Found {len(combos)} (connector, pair, interval) combos already in Mongo "
      f"across {len(connectors_found)} connector(s)")

if kraken_pair_start_notice:
    print(f"  [kraken] {kraken_pair_start_notice}")

print("\nConnector Summary:")
for conn in connectors_found:
    conn_combos = [c for c in combos if c["connector"] == conn]
    total_missing = sum(c["missing"] for c in conn_combos)
    pairs = len(set(c["pair"] for c in conn_combos))
    intervals = len(set(c["interval"] for c in conn_combos))
    row_indices = [i for i, c in enumerate(combos) if c["connector"] == conn]
    print(f"  {conn:12s} — {pairs} pairs × {intervals} intervals = {len(conn_combos)} series, "
          f"{total_missing:,} uncovered intervals  (rows {row_indices[0]}–{row_indices[-1]})")

print(f"\n{'─' * 128}")
print(f"{'Idx':>5s}  {'Connector':12s} {'Pair':16s} {'Intv':6s} {'Docs':>10s} {'Covered':>10s} {'Expected':>10s} {'Missing':>10s} {'Complete':>9s}")
print(f"{'─' * 128}")
for i, c in enumerate(combos):
    flag = " ✓" if c["missing"] == 0 else f" ← {c['missing']:,}"
    print(f"{i:>5d}  {c['connector']:12s} {c['pair']:16s} {c['interval']:6s} "
          f"{c['docs_in_window']:>10,d} {c['covered_buckets']:>10,d} "
          f"{c['expected']:>10,d} {c['missing']:>10,d} {c['pct']:>8.1f}%{flag}")
print(f"{'─' * 128}")

print("\nCovered date ranges per series (within the active backfill window):")
for i, c in enumerate(combos):
    extra_bits = [f"window {fmt_ts(c['window_start'])}→{fmt_ts(c['window_end'])}"]
    if c["connector"] == "kraken" and c.get("pair_start_ts") is not None:
        source = c.get("pair_start_source") or "pair-start"
        extra_bits.append(f"pair start {fmt_ts(c['pair_start_ts'])} via {source}")
    extra = "  [" + " | ".join(extra_bits) + "]"
    print(f"  [{i:>4d}] {c['connector']:12s} {c['pair']:16s} {c['interval']:6s}  "
          f"{c['covered_range_display']}{extra}")
# Out:
# Found 596 (connector, pair, interval) combos already in Mongo across 4 connector(s)
#
# Connector Summary:
#   coinbase     — 3 pairs × 5 intervals = 15 series, 0 uncovered intervals  (rows 0–14)
#   kraken       — 4 pairs × 7 intervals = 25 series, 21,434,456 uncovered intervals  (rows 15–39)
#   mexc         — 32 pairs × 7 intervals = 224 series, 2,766,164 uncovered intervals  (rows 40–263)
#   nonkyc       — 47 pairs × 8 intervals = 332 series, 6,812,158 uncovered intervals  (rows 264–595)
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   
#    34  kraken       XMR-USDT         1d            177        177      1,283      1,106     13.8% ← 1,106
#    35  kraken       XMR-USDT         1h              0          0     30,783     30,783      0.0% ← 30,783
#    36  kraken       XMR-USDT         1m              0          0  1,847,018  1,847,018      0.0% ← 1,847,018
#    37  kraken       XMR-USDT         30m             0          0     61,567     61,567      0.0% ← 61,567
#    38  kraken       XMR-USDT         4h            698        698      7,696      6,998      9.1% ← 6,998
#    39  kraken       XMR-USDT         5m              0          0    369,403    369,403      0.0% ← 369,403
#    40  mexc         ADA-USDT         15m        34,476     34,476     34,478          2    100.0% ← 2
#    41  mexc         ADA-USDT         1d          2,484      2,484      3,093        609     80.3% ← 609
#    42  mexc         ADA-USDT         1h          4,876      4,876     69,015     64,139      7.1% ← 64,139
#    43  mexc         ADA-USDT         1m         39,811     39,811     39,811          0    100.0% ✓
#    44  mexc         ADA-USDT         4h          1,219      1,219     17,254     16,035      7.1% ← 16,035
#    45  mexc         ADA-USDT         5m        103,429    103,429    103,433          4    100.0% ← 4
#    46  mexc         ADA-USDT         8h          7,452      7,452      8,632      1,180     86.3% ← 1,180
#    47  mexc         APT-USDT         15m        34,476     34,476     34,478          2    100.0% ← 2
#    48  mexc         APT-USDT         1d            219        219      3,093      2,874      7.1% ← 2,874
#    49  mexc         APT-USDT         1h          5,275      5,275     69,015     63,740      7.6% ← 63,740
#    50  mexc         APT-USDT         1m         39,811     39,811     39,811          0    100.0% ✓
#    51  mexc         APT-USDT         4h          1,318      1,318     17,254     15,936      7.6% ← 15,936
#    52  mexc         APT-USDT         5m        103,429    103,429    103,433          4    100.0% ← 4
#    53  mexc         APT-USDT         8h            537        537      8,632      8,095      6.2% ← 8,095
#    54  mexc         ASTER-USDT       15m        19,504     19,504     34,478     14,974     56.6% ← 14,974
#    55  mexc         ASTER-USDT       1d            203        203      3,093      2,890      6.6% ← 2,890
#    56  mexc         ASTER-USDT       1h          4,876      4,876     69,015     64,139      7.1% ← 64,139
#    57  mexc         ASTER-USDT       1m         39,811     39,811     39,811          0    100.0% ✓
#    58  mexc         ASTER-USDT       4h          1,219      1,219     17,254     16,035      7.1% ← 16,035
#    59  mexc         ASTER-USDT       5m         58,513     58,513    103,433     44,920     56.6% ← 44,920
#    60  mexc         ASTER-USDT       8h            537        537      8,632      8,095      6.2% ← 8,095
#    61  mexc         ATOM-USDT        15m        34,476     34,476     34,478          2    100.0% ← 2
#    62  mexc         ATOM-USDT        1d          2,550      2,550      3,093        543     82.4% ← 543
#    63  mexc         ATOM-USDT        1h          4,876      4,876     69,015     64,139      7.1% ← 64,139
#    64  mexc         ATOM-USDT        1m         39,811     39,811     39,811          0    100.0% ✓
#    65  mexc         ATOM-USDT        4h          1,219      1,219     17,254     16,035      7.1% ← 16,035
#    66  mexc         ATOM-USDT        5m        103,428    103,428    103,433          5    100.0% ← 5
#    67  mexc         ATOM-USDT        8h          7,650      7,650      8,632        982     88.6% ← 982
#    68  mexc         BNB-USDT         15m        34,476     34,476     34,478          2    100.0% ← 2
#    69  mexc         BNB-USDT         1d          2,597      2,597      3,093        496     84.0% ← 496
#    70  mexc         BNB-USDT         1h          5,276      5,276     69,015     63,739      7.6% ← 63,739
#    71  mexc         BNB-USDT         1m         39,811     39,811     39,811          0    100.0% ✓
#    72  mexc         BNB-USDT         4h          1,318      1,318     17,254     15,936      7.6% ← 15,936
#    73  mexc         BNB-USDT         5m        103,428    103,428    103,433          5    100.0% ← 5
#    74  mexc         BNB-USDT         8h          7,790      7,790      8,632        842     90.2% ← 842
#    75  mexc         BTC-USDT         15m        34,476     34,476     34,478          2    100.0% ← 2
#    76  mexc         BTC-USDT         1d          3,093      3,093      3,093          0    100.0% ✓
#    77  mexc         BTC-USDT         1h         69,015     69,015     69,015          0    100.0% ✓
#    78  mexc         BTC-USDT         1m         39,811     39,811     39,811          0    100.0% ✓
USDT         1m         39,811     39,811     39,811          0    100.0% ✓
#   212  mexc         WLD-USDT         4h          1,219      1,219     17,254     16,035      7.1% ← 16,035
#   213  mexc         WLD-USDT         5m        103,423    103,423    103,433         10    100.0% ← 10
#   214  mexc         WLD-USDT         8h            537        537      8,632      8,095      6.2% ← 8,095
#   215  mexc         WLFI-USDT        15m        19,504     19,504     34,478     14,974     56.6% ← 14,974
#   216  mexc         WLFI-USDT        1d            203        203      3,093      2,890      6.6% ← 2,890
#   217  mexc         WLFI-USDT        1h          4,876      4,876     69,015     64,139      7.1% ← 64,139
#   218  mexc         WLFI-USDT        1m         39,811     39,811     39,811          0    100.0% ✓
#   219  mexc         WLFI-USDT        4h          1,219      1,219     17,254     16,035      7.1% ← 16,035
#   220  mexc         WLFI-USDT        5m         57,442     57,442    103,433     45,991     55.5% ← 45,991
#   221  mexc         WLFI-USDT        8h            537        537      8,632      8,095      6.2% ← 8,095
#   222  mexc         WXT-USDT         15m        34,474     34,474     34,478          4    100.0% ← 4
#   223  mexc         WXT-USDT         1d            203        203      3,093      2,890      6.6% ← 2,890
#   224  mexc         WXT-USDT         1h          4,876      4,876     69,015     64,139      7.1% ← 64,139
#   225  mexc         WXT-USDT         1m         39,811     39,811     39,811          0    100.0% ✓
#   226  mexc         WXT-USDT         4h          1,219      1,219     17,254     16,035      7.1% ← 16,035
#   227  mexc         WXT-USDT         5m        103,423    103,423    103,433         10    100.0% ← 10
#   228  mexc         WXT-USDT         8h            537        537      8,632      8,095      6.2% ← 8,095
#   229  mexc         XLM-USDT         15m        34,474     34,474     34,478          4    100.0% ← 4
#   230  mexc         XLM-USDT         1d          2,490      2,490      3,093        603     80.5% ← 603
#   231  mexc         XLM-USDT         1h          4,876      4,876     69,015     64,139      7.1% ← 64,139
#   232  mexc         XLM-USDT         1m         39,811     39,811     39,811          0    100.0% ✓
#   233  mexc         XLM-USDT         4h          1,219      1,219     17,254     16,035      7.1% ← 16,035
#   234  mexc         XLM-USDT         5m        103,422    103,422    103,433         11    100.0% ← 11
#   235  mexc         XLM-USDT         8h          7,469      7,469      8,632      1,163     86.5% ← 1,163
#   236  mexc         XMR-USDC         15m        34,474     34,474     34,478          4    100.0% ← 4
#   237  mexc         XMR-USDC         1d            223        223      3,093      2,870      7.2% ← 2,870
#   238  mexc         XMR-USDC         1h          5,379      5,379     69,015     63,636      7.8% ← 63,636
#   239  mexc         XMR-USDC         1m         39,811     39,811     39,811          0    100.0% ✓
#   240  mexc         XMR-USDC         4h          1,344      1,344     17,254     15,910      7.8% ← 15,910
#   241  mexc         XMR-USDC         5m        103,422    103,422    103,433         11    100.0% ← 11
#   242  mexc         XMR-USDC         8h            537        537      8,632      8,095      6.2% ← 8,095
#   243  mexc         XMR-USDT         15m        34,474     34,474     34,478          4    100.0% ← 4
#   244  mexc         XMR-USDT         1d          2,318      2,318      3,093        775     74.9% ← 775
#   245  mexc         XMR-USDT         1h          5,379      5,379     69,015     63,636      7.8% ← 63,636
#   246  mexc         XMR-USDT         1m         39,811     39,811     39,811          0    100.0% ✓
#   247  mexc         XMR-USDT         4h          1,344      1,344     17,254     15,910      7.8% ← 15,910
#   248  mexc         XMR-USDT         5m        103,422    103,422    103,433         11    100.0% ← 11
#   249  mexc         XMR-USDT         8h            537        537      8,632      8,095      6.2% ← 8,095
#   250  mexc         XRP-USDT         15m        34,474     34,474     34,478          4    100.0% ← 4
#   251  mexc         XRP-USDT         1d          2,535      2,535      3,093        558     82.0% ← 558
#   252  mexc         XRP-USDT         1h          5,275      5,275     69,015     63,740      7.6% ← 63,740
#   253  mexc         XRP-USDT         1m         39,811     39,811     39,811          0    100.0% ✓
#   254  mexc         XRP-USDT         4h          1,318      1,318     17,254     15,936      7.6% ← 15,936
#   255  mexc         XRP-USDT         5m        103,422    103,422    103,433         11    100.0% ← 11
#   256  mexc         XRP-USDT         8h          7,604      7,604      8,632      1,028     88.1% ← 1,028
#   257  mexc         ZRO-USDT         15m        34,474     34,474     34,478          4    100.0% ← 4
#   258  mexc         ZRO-USDT         1d            203        203      3,093      2,890      6.6% ← 2,890
#   259  mexc         ZRO-USDT         1h          4,876      4,876     69,015     64,139      7.1% ← 64,139
[window 2023-05-01 04:00→2026-04-16 00:00]
#   [ 587] nonkyc       ZEC-XMR          5m      2023-10-23 16:20 → 2023-10-23 16:20 | 2023-10-23 16:35 → 2023-10-23 16:35 | 2023-10-23 17:00 → 2023-10-23 17:00 | 2023-10-23 17:10 → 2023-10-23 17:10 | 2023-10-23 17:45 → 2023-10-23 17:45 | ... (+36353 more)  [window 2023-05-29 19:40→2026-04-16 05:50]
#   [ 588] nonkyc       ZEC-XMR          8h      2023-10-23 16:00 → 2026-04-15 16:00  [window 2023-05-01 00:00→2026-04-15 16:00]
#   [ 589] nonkyc       ZSD-USDT         12h     2023-10-18 12:00 → 2026-04-15 12:00  [window 2023-05-02 12:00→2026-04-15 12:00]
#   [ 590] nonkyc       ZSD-USDT         15m     2023-10-18 22:30 → 2023-10-19 03:00 | 2023-10-19 03:30 → 2023-10-19 05:00 | 2023-10-19 05:30 → 2023-10-19 08:15 | 2023-10-19 08:45 → 2023-10-19 11:15 | 2023-10-19 11:45 → 2023-10-19 12:00 | ... (+4671 more)  [window 2023-05-29 19:30→2026-04-16 05:30]
#   [ 591] nonkyc       ZSD-USDT         1d      2023-10-18 00:00 → 2026-04-15 00:00  [window 2023-04-28 00:00→2026-04-15 00:00]
#   [ 592] nonkyc       ZSD-USDT         1h      2023-10-18 22:00 → 2024-06-12 11:00 | 2024-06-12 17:00 → 2024-06-18 18:00 | 2024-06-18 20:00 → 2024-07-16 21:00 | 2024-07-16 23:00 → 2024-08-04 05:00 | 2024-08-04 07:00 → 2025-01-18 04:00 | ... (+5 more)  [window 2023-05-03 01:00→2026-04-16 04:00]
#   [ 593] nonkyc       ZSD-USDT         4h      2023-10-18 20:00 → 2024-06-12 08:00 | 2024-06-12 16:00 → 2026-04-16 00:00  [window 2023-05-01 04:00→2026-04-16 00:00]
#   [ 594] nonkyc       ZSD-USDT         5m      2023-10-18 22:40 → 2023-10-18 22:45 | 2023-10-18 23:05 → 2023-10-18 23:05 | 2023-10-18 23:15 → 2023-10-18 23:30 | 2023-10-18 23:45 → 2023-10-18 23:45 | 2023-10-18 23:55 → 2023-10-19 00:00 | ... (+39653 more)  [window 2023-05-29 19:40→2026-04-16 05:50]
#   [ 595] nonkyc       ZSD-USDT         8h      2023-10-18 16:00 → 2026-04-15 16:00  [window 2023-05-01 00:00→2026-04-15 16:00]

# %%
# ── Cell 9: Select + preview ────────────────────────────────────────────────
#
# Selection modes:
#   SELECTION = "all"               — every combo with uncovered ranges
#   SELECTION = "binance"           — all series for one connector
#   SELECTION = ["binance", "mexc"] — all series for multiple connectors
#   SELECTION = [0, 1, 5]           — specific row indices from Cell 8
#
# NEW_PAIRS: if you want to backfill a pair that is not yet in Mongo at all,
# list it here as (connector, pair) tuples. The script will fetch full history
# within the configured windows. Kraken NEW_PAIRS use cached/probed pair starts
# when available. If Kraken is unreachable, the notebook falls back to the
# configured interval window start.

import random

# Pair download order controls the order in which series are submitted per
# connector in Cell 11. Because Cell 11 uses multiple workers per connector,
# this affects submission/start order rather than completion order.
#
# Allowed values:
#   - "alphabetical"
#   - "reverse alphabetical"
#   - "random"
#
# Examples for nonkyc:
#   alphabetical         -> AAVE-USDT ... ZSD-USDT
#   reverse alphabetical -> ZSD-USDT ... AAVE-USDT
#   random               -> shuffled pair order
PAIR_DOWNLOAD_ORDER = "reverse alphabetical"
PAIR_DOWNLOAD_RANDOM_SEED = None   # e.g. 42 for reproducible random order
PAIR_ORDER_PREVIEW_LIMIT = 12


def normalize_pair_download_order(value):
    raw = str(value if value is not None else "alphabetical").strip().lower()
    raw = raw.replace("_", " ").replace("-", " ")
    raw = " ".join(raw.split())
    aliases = {
        "alphabetical": "alphabetical",
        "alpha": "alphabetical",
        "asc": "alphabetical",
        "ascending": "alphabetical",
        "reverse alphabetical": "reverse alphabetical",
        "reverse alpha": "reverse alphabetical",
        "reverse": "reverse alphabetical",
        "descending": "reverse alphabetical",
        "desc": "reverse alphabetical",
        "random": "random",
        "shuffle": "random",
        "shuffled": "random",
    }
    canonical = aliases.get(raw)
    if canonical is None:
        raise ValueError(
            "PAIR_DOWNLOAD_ORDER must be one of: alphabetical, reverse alphabetical, random"
        )
    return canonical


def order_selected_combos_by_pair(selected_combos, pair_order="alphabetical", random_seed=None):
    canonical_order = normalize_pair_download_order(pair_order)
    if not selected_combos:
        return [], canonical_order, {}

    connector_order = []
    seen_connectors = set()
    grouped = {}

    for original_pos, combo in enumerate(selected_combos):
        connector = combo["connector"]
        pair = combo["pair"]
        if connector not in seen_connectors:
            seen_connectors.add(connector)
            connector_order.append(connector)
        grouped.setdefault(connector, {}).setdefault(pair, []).append((original_pos, combo))

    rng = random.Random(random_seed) if canonical_order == "random" else None
    ordered = []
    pair_order_preview = {}

    for connector in connector_order:
        pair_map = grouped.get(connector, {})
        ordered_pairs = sorted(pair_map.keys())
        if canonical_order == "reverse alphabetical":
            ordered_pairs.reverse()
        elif canonical_order == "random":
            rng.shuffle(ordered_pairs)

        pair_order_preview[connector] = list(ordered_pairs)

        for pair_rank, pair in enumerate(ordered_pairs, 1):
            series_for_pair = sorted(pair_map[pair], key=lambda item: item[0])
            for series_rank, (_original_pos, combo) in enumerate(series_for_pair, 1):
                combo_view = dict(combo)
                combo_view["pair_order_rank"] = pair_rank
                combo_view["series_order_within_pair"] = series_rank
                ordered.append(combo_view)

    return ordered, canonical_order, pair_order_preview


SELECTION = "all"
NEW_PAIRS = []   # e.g. [("binance", "SOL-USDT"), ("kraken", "XMR-USD")]

if SELECTION == "all":
    selected_combos = [c for c in combos if c["missing"] > 0]
elif isinstance(SELECTION, str):
    selected_combos = [c for c in combos if c["connector"] == SELECTION and c["missing"] > 0]
elif isinstance(SELECTION, (list, tuple)) and all(isinstance(x, str) for x in SELECTION):
    selected_combos = [c for c in combos if c["connector"] in set(SELECTION) and c["missing"] > 0]
else:
    indices = list(SELECTION)
    selected_combos = [combos[i] for i in indices if i < len(combos) and combos[i]["missing"] > 0]

kraken_new_pairs_notice_printed = False

for (nconn, npair) in NEW_PAIRS:
    if nconn not in EXCHANGES:
        print(f"  ⚠ NEW_PAIRS skipping {nconn}:{npair} — exchange not in config")
        continue

    cached_pair_start = None
    cached_pair_start_source = None

    if nconn == "kraken":
        cached_pair_start, cached_pair_start_source, cached_pair_start_note = get_kraken_pair_start_ts(
            npair, mode=KRAKEN_PAIR_START_MODE
        )
        if cached_pair_start_note and not kraken_new_pairs_notice_printed:
            print(f"  [kraken] NEW_PAIRS pair-start discovery unavailable: {cached_pair_start_note}. "
                  f"Using cached pair starts when available; otherwise the configured interval window start is used.")
            kraken_new_pairs_notice_printed = True

    for interval in INTERVAL_TARGETS_DAYS.keys():
        if EXCHANGES[nconn]["interval_map"].get(interval) is None:
            continue

        step = INTERVAL_SECONDS[interval]
        window_start = effective_windows.get((nconn, interval))
        if window_start is None:
            continue

        if cached_pair_start is not None:
            window_start = align_floor(cached_pair_start, step)

        effective_start = align_floor(window_start, step)
        effective_end = last_closed_open_ts(now_ts, step)
        expected = ((effective_end - effective_start) // step) + 1 if effective_end >= effective_start else 0
        if expected == 0:
            continue

        already = any(c["connector"] == nconn and c["pair"] == npair and c["interval"] == interval
                      for c in combos)
        if already:
            continue

        selected_combos.append({
            "connector": nconn,
            "pair": npair,
            "interval": interval,
            "total_docs": 0,
            "docs_in_window": 0,
            "covered_buckets": 0,
            "expected": expected,
            "missing": expected,
            "pct": 0.0,
            "step": step,
            "window_start": effective_start,
            "window_end": effective_end,
            "covered_ranges": [],
            "covered_range_display": "—",
            "pair_start_ts": cached_pair_start,
            "pair_start_source": cached_pair_start_source,
            "is_new_pair": True,
        })

selected_combos, pair_download_order_mode, pair_order_preview = order_selected_combos_by_pair(
    selected_combos,
    pair_order=PAIR_DOWNLOAD_ORDER,
    random_seed=PAIR_DOWNLOAD_RANDOM_SEED,
)

def estimate_requests(combo):
    ex_cfg = EXCHANGES[combo["connector"]]
    max_per = ex_cfg["max_per_request"]
    if combo["connector"] == "kraken":
        # Lower bound only: deep Kraken backfill may need many Trades pages.
        return max(1, math.ceil(combo["missing"] / max_per))
    return max(1, math.ceil(combo["missing"] / max_per))


by_exchange = {}
for c in selected_combos:
    by_exchange.setdefault(c["connector"], []).append(c)

print(f"Selection: {len(selected_combos)} series to backfill")
print(f"{'─' * 92}")
print(f"{'Exchange':12s} {'Series':>8s} {'Uncovered':>12s} {'Est. requests':>15s} {'Est. wall-clock':>18s}")
print(f"{'─' * 92}")
grand_requests = 0
grand_missing = 0
worst_wall_clock = 0.0
for ex in sorted(by_exchange.keys()):
    cs = by_exchange[ex]
    missing = sum(c["missing"] for c in cs)
    reqs = sum(estimate_requests(c) for c in cs)
    delay = EXCHANGES[ex]["request_delay_seconds"]
    secs = reqs * delay
    mins = secs / 60
    grand_requests += reqs
    grand_missing += missing
    worst_wall_clock = max(worst_wall_clock, secs)
    print(f"{ex:12s} {len(cs):>8d} {missing:>12,d} {reqs:>15,d} {mins:>15.1f} min")

print(f"{'─' * 92}")
print(f"{'TOTAL':12s} {len(selected_combos):>8d} {grand_missing:>12,d} {grand_requests:>15,d}  "
      f"(parallel: ~{worst_wall_clock/60:.1f} min)")
print(f"{'─' * 92}")

if "kraken" in by_exchange:
    print("Note: Kraken estimates are lower bounds. Deep-history Kraken backfill uses paginated Trades scans,")
    print("      so actual request count depends on trade volume, not just missing candle buckets.")

print(f"Pair download order: {pair_download_order_mode}", end="")
if pair_download_order_mode == "random" and PAIR_DOWNLOAD_RANDOM_SEED is not None:
    print(f"  (seed={PAIR_DOWNLOAD_RANDOM_SEED})")
elif pair_download_order_mode == "random":
    print("  (reshuffled on each Cell 9 run)")
else:
    print()
print("  Pair order is applied within each connector; interval order within a pair stays unchanged.")
print("  With multiple workers per connector, this controls submission/start order, not completion order.")

print("\nPair order preview (first pairs per connector):")
for ex in sorted(by_exchange.keys()):
    ordered_pairs = pair_order_preview.get(ex, [])
    preview = ordered_pairs[:PAIR_ORDER_PREVIEW_LIMIT]
    preview_text = ", ".join(preview) if preview else "—"
    extra = "" if len(ordered_pairs) <= PAIR_ORDER_PREVIEW_LIMIT else f", ... (+{len(ordered_pairs) - PAIR_ORDER_PREVIEW_LIMIT} more)"
    print(f"  {ex:12s} {preview_text}{extra}")

if selected_combos:
    preview_count = min(12, len(selected_combos))
    print(f"\nSeries submission preview (first {preview_count}):")
    for idx, combo in enumerate(selected_combos[:preview_count], 1):
        print(f"  {idx:>2d}. {combo['connector']:12s} {combo['pair']:16s} {combo['interval']:6s} "
              f"(pair #{combo.get('pair_order_rank', '?')}, series #{combo.get('series_order_within_pair', '?')})")

if selected_combos:
    print("\nReady. Run Cell 11 to execute.")
else:
    print("\nNothing to backfill.")
# Out:
# Selection: 526 series to backfill
# ────────────────────────────────────────────────────────────────────────────────────────────
# Exchange       Series    Uncovered   Est. requests    Est. wall-clock
# ────────────────────────────────────────────────────────────────────────────────────────────
# kraken             25   21,434,456          29,784             0.0 min
# mexc              183    2,766,164           5,660            18.9 min
# nonkyc            318    6,812,158           1,592             0.0 min
# ────────────────────────────────────────────────────────────────────────────────────────────
# TOTAL             526   31,012,778          37,036  (parallel: ~18.9 min)
# ────────────────────────────────────────────────────────────────────────────────────────────
# Note: Kraken estimates are lower bounds. Deep-history Kraken backfill uses paginated Trades scans,
#       so actual request count depends on trade volume, not just missing candle buckets.
# Pair download order: reverse alphabetical
#   Pair order is applied within each connector; interval order within a pair stays unchanged.
#   With multiple workers per connector, this controls submission/start order, not completion order.
#
# Pair order preview (first pairs per connector):
#   kraken       XMR-USDT, SOL-USD, ETH-USD, BTC-USD
#   mexc         ZRO-USDT, XRP-USDT, XMR-USDT, XMR-USDC, XLM-USDT, WXT-USDT, WLFI-USDT, WLD-USDT, TRX-USDT, TON-USDT, SUI-USDT, SOL-USDT, ... (+20 more)
#   nonkyc       ZSD-USDT, ZEC-XMR, ZANO-USDT, XTM-XMR, XRP-USDT, XNV-XMR, XMR-ZSD, XMR-USDT, XMR-BTC, XKR-XMR, VEIL-XMR, USDC-USDT, ... (+35 more)
#
# Series submission preview (first 12):
#    1. kraken       XMR-USDT         15m    (pair #1, series #1)
#    2. kraken       XMR-USDT         1d     (pair #1, series #2)
#    3. kraken       XMR-USDT         1h     (pair #1, series #3)
#    4. kraken       XMR-USDT         1m     (pair #1, series #4)
#    5. kraken       XMR-USDT         30m    (pair #1, series #5)
#    6. kraken       XMR-USDT         4h     (pair #1, series #6)
#    7. kraken       XMR-USDT         5m     (pair #1, series #7)
#    8. kraken       SOL-USD          15m    (pair #2, series #1)
#    9. kraken       SOL-USD          1d     (pair #2, series #2)
#   10. kraken       SOL-USD          1h     (pair #2, series #3)
#   11. kraken       SOL-USD          1m     (pair #2, series #4)
#   12. kraken       SOL-USD          4h     (pair #2, series #5)
#
# Ready. Run Cell 11 to execute.

# %%
# ── Cell 10: Gap detection (streaming, memory-safe) ─────────────────────────

def find_gaps_in_window(coll, connector, pair, interval, step, window_start, window_end):
    effective_start = align_floor(window_start, step)
    effective_end = min(
        align_floor(window_end, step),
        last_closed_open_ts(utc_now_ts(), step),
    )
    if effective_end < effective_start:
        return []
    summary = summarize_series_window(
        coll, connector, pair, interval, step, effective_start, effective_end
    )
    return summary["gap_ranges"]


print("Gap detection loaded.")
# Out:
# Gap detection loaded.

# %%
# Cell 11: Run the backfill
#
# Layered parallelism:
#   - Outer: one thread per exchange.
#   - Inner: per-exchange parallel pair-workers (from _EXCHANGE_TUNING).
#   - Pacing: shared per-exchange token bucket enforces sustained rate caps.
# All pair-workers within an exchange share the same bucket, so adding
# workers raises parallelism without exceeding the rate-per-second cap.

if not selected_combos:
    print("Nothing to backfill.")
else:
    per_exchange = {}
    for c in selected_combos:
        per_exchange.setdefault(c["connector"], []).append(c)

    results = {}
    results_lock = threading.Lock()
    counter_lock = threading.Lock()
    total_series = len(selected_combos)
    counter = {"done": 0}

    def exchange_worker(exchange: str, combos_for_ex: list):
        ingester = INGESTERS.get(exchange)
        if ingester is None:
            with counter_lock:
                counter["done"] += len(combos_for_ex)
                done = counter["done"]
            sweep_elapsed = time.time() - start_wall
            eta = (sweep_elapsed / done * (total_series - done)) if done > 0 else 0
            msg = f"{exchange}: no ingester; skipped {len(combos_for_ex)} series"
            print(f"[{done}/{total_series}] {msg}  [sweep {sweep_elapsed/60:.1f}min, ETA {eta/60:.1f}min]")
            with results_lock:
                results[exchange] = {"written": 0,
                                     "errors": [f"{exchange}: no ingester"],
                                     "gap_ranges": 0}
            return

        if exchange == "kraken":
            host_state = check_exchange_host_resolution("kraken")
            if not host_state["ok"]:
                with counter_lock:
                    counter["done"] += len(combos_for_ex)
                    done = counter["done"]
                sweep_elapsed = time.time() - start_wall
                eta = (sweep_elapsed / done * (total_series - done)) if done > 0 else 0
                msg = (
                    f"kraken public API unavailable: cannot resolve {host_state['host']} "
                    f"({host_state['reason']}). Deep Kraken backfill requires the "
                    f"Kraken Trades/OHLC API, so {len(combos_for_ex)} series were skipped."
                )
                print(f"[{done}/{total_series}] {msg}  [sweep {sweep_elapsed/60:.1f}min, ETA {eta/60:.1f}min]")
                with results_lock:
                    results[exchange] = {"written": 0,
                                         "errors": [msg],
                                         "gap_ranges": 0}
                return

        parallel_workers = get_exchange_parallel_workers(exchange)
        rate_cap = _EXCHANGE_TUNING.get(exchange, {}).get("rate_per_sec", "?")
        print(f"[{exchange}] {len(combos_for_ex)} series, "
              f"{parallel_workers} parallel pair-workers, rate cap = {rate_cap} req/s")

        local_written = 0
        local_errors: list = []
        local_gaps = 0
        local_lock = threading.Lock()

        def one_combo(combo):
            combo_started = time.perf_counter()
            combo_written = 0
            pair = combo["pair"]
            interval = combo["interval"]
            step = combo["step"]
            is_new = combo.get("is_new_pair", False)
            win_start = combo["window_start"]
            win_end = combo.get("window_end", last_closed_open_ts(utc_now_ts(), step))

            if is_new:
                eff_start = align_floor(win_start, step)
                eff_end = win_end
                gaps = [(eff_start, eff_end)] if eff_end >= eff_start else []
            else:
                gaps = find_gaps_in_window(coll, exchange, pair, interval, step,
                                            win_start, win_end)

            if not gaps:
                with counter_lock:
                    counter["done"] += 1
                    done = counter["done"]
                sweep_elapsed = time.time() - start_wall
                eta = (sweep_elapsed / done * (total_series - done)) if done > 0 else 0
                print(f"[{done}/{total_series}] {exchange} {pair} {interval} "
                      f"✓ no uncovered ranges  [sweep {sweep_elapsed/60:.1f}min, ETA {eta/60:.1f}min]")
                return 0, 0, []

            errors_here = []
            for gs, ge in gaps:
                try:
                    combo_written += ingester(coll, pair, interval, gs, ge)
                    if exchange == "kraken":
                        record_coverage_range(
                            coverage_coll, exchange, pair, interval, gs, ge,
                            source="backfill_success",
                        )
                except Exception as e:
                    err = f"{exchange} {pair} {interval} [{fmt_ts(gs)}→{fmt_ts(ge)}]: {e}"
                    errors_here.append(err)
                    print(f"  ✗ {err}")

            combo_elapsed = time.perf_counter() - combo_started
            with counter_lock:
                counter["done"] += 1
                done = counter["done"]
            sweep_elapsed = time.time() - start_wall
            eta = (sweep_elapsed / done * (total_series - done)) if done > 0 else 0
            print(f"[{done}/{total_series}] {exchange} {pair} {interval}: "
                  f"wrote {combo_written:,} across {len(gaps)} range(s) "
                  f"in {combo_elapsed:.1f}s  "
                  f"[sweep {sweep_elapsed/60:.1f}min, ETA {eta/60:.1f}min]")
            return combo_written, len(gaps), errors_here

        with ThreadPoolExecutor(max_workers=parallel_workers) as pair_pool:
            futs = {pair_pool.submit(one_combo, c): c for c in combos_for_ex}
            for fut in as_completed(futs):
                try:
                    w, g, errs = fut.result()
                    with local_lock:
                        local_written += w
                        local_gaps += g
                        local_errors.extend(errs)
                except Exception as e:
                    c = futs[fut]
                    with local_lock:
                        local_errors.append(
                            f"{exchange} {c['pair']} {c['interval']}: worker crashed: {e}"
                        )

        with results_lock:
            results[exchange] = {"written": local_written,
                                 "errors": local_errors,
                                 "gap_ranges": local_gaps}

    start_wall = time.time()
    n_exchange_workers = max(1, len(per_exchange))
    print(f"Running {n_exchange_workers} exchange(s) in parallel, "
          f"with per-exchange parallel pair-workers as configured.\n")

    with ThreadPoolExecutor(max_workers=n_exchange_workers) as pool:
        futures = {pool.submit(exchange_worker, ex, cs): ex
                   for ex, cs in per_exchange.items()}
        for fut in as_completed(futures):
            ex = futures[fut]
            try:
                fut.result()
            except Exception as e:
                print(f"  ✗ Worker for {ex} crashed: {e}")

    elapsed = time.time() - start_wall

    print(f"\n{'═' * 70}")
    print("BACKFILL COMPLETE")
    print(f"  Wall clock: {elapsed/60:.1f} min")
    total_written = sum(r["written"] for r in results.values())
    total_errors = sum(len(r["errors"]) for r in results.values())
    total_gaps = sum(r["gap_ranges"] for r in results.values())
    print(f"  Gap / uncovered ranges processed: {total_gaps:,}")
    print(f"  Total candles written: {total_written:,}")
    print(f"  Errors: {total_errors}")
    for ex in sorted(results.keys()):
        r = results[ex]
        print(f"    {ex:12s} wrote {r['written']:>10,d} across "
              f"{r['gap_ranges']:>4} ranges, {len(r['errors'])} error(s)")
        try:
            s = _get_exchange_bucket(ex).stats()
            initial = _EXCHANGE_TUNING.get(ex, {}).get("rate_per_sec", "?")
            print(f"      final bucket rate: {s['rate_per_sec']:.2f} req/s "
                  f"(initial: {initial})")
            if isinstance(initial, (int, float)) and s["rate_per_sec"] < initial:
                print(f"      ↪ rate was auto-decayed — {ex} returned 429s during the run")
        except Exception:
            pass
        for e in r["errors"][:5]:
            print(f"      ✗ {e}")
        if len(r["errors"]) > 5:
            print(f"      ... and {len(r['errors']) - 5} more")
    print(f"{'═' * 70}")
# Out:
# Running 3 exchange(s) in parallel, with per-exchange parallel pair-workers as configured.
#
# [kraken] 25 series, 1 parallel pair-workers, rate cap = 1.0 req/s
# [mexc] 183 series, 2 parallel pair-workers, rate cap = 5.0 req/s
# [nonkyc] 318 series, 8 parallel pair-workers, rate cap = 4.0 req/s
# [1/526] nonkyc ZSD-USDT 12h: wrote 0 across 1 range(s) in 0.5s  [sweep 0.0min, ETA 4.5min]
# [2/526] nonkyc ZSD-USDT 1d: wrote 0 across 1 range(s) in 0.5s  [sweep 0.0min, ETA 2.3min]
# [3/526] nonkyc ZEC-XMR 12h: wrote 0 across 1 range(s) in 0.7s  [sweep 0.0min, ETA 1.9min]
# [4/526] nonkyc ZEC-XMR 1d: wrote 0 across 1 range(s) in 0.4s  [sweep 0.0min, ETA 1.9min]
# [5/526] mexc ZRO-USDT 15m: wrote 0 across 1 range(s) in 1.2s  [sweep 0.0min, ETA 2.0min]
# [6/526] nonkyc ZSD-USDT 8h: wrote 0 across 1 range(s) in 1.2s  [sweep 0.0min, ETA 1.7min]
# [7/526] mexc ZRO-USDT 1d: wrote 0 across 1 range(s) in 1.6s  [sweep 0.0min, ETA 2.0min]
# [8/526] nonkyc ZSD-USDT 4h: wrote 0 across 2 range(s) in 2.0s  [sweep 0.0min, ETA 2.2min]
# [9/526] mexc ZRO-USDT 1h: wrote 0 across 1 range(s) in 1.6s  [sweep 0.0min, ETA 2.6min]
# [10/526] mexc ZRO-USDT 4h: wrote 0 across 1 range(s) in 1.3s  [sweep 0.0min, ETA 2.5min]
# [11/526] nonkyc ZEC-XMR 4h: wrote 0 across 2 range(s) in 2.5s  [sweep 0.1min, ETA 2.9min]
# [12/526] mexc ZRO-USDT 8h: wrote 0 across 1 range(s) in 1.4s  [sweep 0.1min, ETA 3.1min]
# [13/526] nonkyc ZEC-XMR 8h: wrote 0 across 1 range(s) in 1.0s  [sweep 0.1min, ETA 3.1min]
# [14/526] mexc ZRO-USDT 5m: wrote 0 across 1 range(s) in 2.6s  [sweep 0.1min, ETA 3.3min]
# [15/526] mexc XRP-USDT 15m: wrote 0 across 1 range(s) in 1.2s  [sweep 0.1min, ETA 3.2min]
# [16/526] mexc XRP-USDT 1d: wrote 0 across 1 range(s) in 0.9s  [sweep 0.1min, ETA 3.3min]
# [17/526] mexc XRP-USDT 1h: wrote 0 across 1 range(s) in 1.2s  [sweep 0.1min, ETA 3.4min]
# [18/526] mexc XRP-USDT 4h: wrote 0 across 1 range(s) in 1.3s  [sweep 0.1min, ETA 3.6min]
# [19/526] mexc XRP-USDT 5m: wrote 0 across 1 range(s) in 2.2s  [sweep 0.2min, ETA 4.0min]
# [20/526] mexc XRP-USDT 8h: wrote 0 across 1 range(s) in 1.5s  [sweep 0.2min, ETA 3.8min]
# [21/526] mexc XMR-USDT 15m: wrote 0 across 1 range(s) in 0.9s  [sweep 0.2min, ETA 4.0min]
# [22/526] mexc XMR-USDT 1d: wrote 0 across 1 range(s) in 1.0s  [sweep 0.2min, ETA 3.8min]
# [23/526] mexc XMR-USDT 1h: wrote 0 across 1 range(s) in 1.3s  [sweep 0.2min, ETA 4.1min]
# [24/526] mexc XMR-USDT 4h: wrote 0 across 1 range(s) in 1.3s  [sweep 0.2min, ETA 4.0min]
# [25/526] mexc XMR-USDT 8h: wrote 0 across 1 range(s) in 1.3s  [sweep 0.2min, ETA 4.3min]
# [26/526] mexc XMR-USDT 5m: wrote 0 across 1 range(s) in 1.9s  [sweep 0.2min, ETA 4.2min]
# [27/526] mexc XMR-USDC 15m: wrote 0 across 1 range(s) in 0.8s  [sweep 0.2min, ETA 4.2min]
# [28/526] mexc XMR-USDC 1d: wrote 0 across 1 range(s) in 1.2s  [sweep 0.2min, ETA 4.2min]
# [29/526] mexc XMR-USDC 1h: wrote 0 across 1 range(s) in 1.2s  [sweep 0.2min, ETA 4.2min]
# [30/526] mexc XMR-USDC 4h: wrote 0 across 1 range(s) in 1.4s  [sweep 0.3min, ETA 4.3min]
# [31/526] mexc XMR-USDC 5m: wrote 0 across 1 range(s) in 1.8s  [sweep 0.3min, ETA 4.4min]
# [32/526] mexc XMR-USDC 8h: wrote 0 across 1 range(s) in 1.2s  [sweep 0.3min, ETA 4.3min]
# [33/526] mexc XLM-USDT 15m: wrote 0 across 1 range(s) in 0.7s  [sweep 0.3min, ETA 4.3min]
# [34/526] mexc XLM-USDT 1d: wrote 0 across 1 range(s) in 0.9s  [sweep 0.3min, ETA 4.3min]
# [35/526] mexc XLM-USDT 1h: wrote 0 across 1 range(s) in 1.2s  [sweep 0.3min, ETA 4.3min]
# [36/526] nonkyc ZSD-USDT 1h: wrote 0 across 10 range(s) in 18.7s  [sweep 0.3min, ETA 4.2min]
# [37/526] mexc XLM-USDT 4h: wrote 0 across 1 range(s) in 1.1s  [sweep 0.3min, ETA 4.2min]
# [38/526] mexc XLM-USDT 5m: wrote 0 across 1 range(s) in 1.8s  [sweep 0.3min, ETA 4.3min]
# [39/526] mexc XLM-USDT 8h: wrote 0 across 1 range(s) in 1.4s  [sweep 0.3min, ETA 4.2min]
# [40/526] mexc WXT-USDT 15m: wrote 0 across 1 range(s) in 0.7s  [sweep 0.3min, ETA 4.2min]
# [41/526] mexc WXT-USDT 1d: wrote 0 across 1 range(s) in 1.2s  [sweep 0.4min, ETA 4.2min]
# [42/526] mexc WXT-USDT 1h: wrote 0 across 1 range(s) in 1.2s  [sweep 0.4min, ETA 4.3min]
# [43/526] mexc WXT-USDT 4h: wrote 0 across 1 range(s) in 1.2s  [sweep 0.4min, ETA 4.2min]
# [44/526] mexc WXT-USDT 8h: wrote 0 across 1 range(s) in 1.2s  [sweep 0.4min, ETA 4.4min]
# [45/526] mexc WXT-USDT 5m: wrote 0 across 1 range(s) in 1.8s  [sweep 0.4min, ETA 4.3min]
# [46/526] mexc WLFI-USDT 1d: wrote 0 across 1 range(s) in 1.2s  [sweep 0.4min, ETA 4.4min]
# [47/526] mexc WLFI-USDT 15m: wrote 0 across 1 range(s) in 1.4s  [sweep 0.4min, ETA 4.3min]
# [48/526] mexc WLFI-USDT 1h: wrote 0 across 1 range(s) in 1.2s  [sweep 0.4min, ETA 4.4min]
# [49/526] mexc WLFI-USDT 4h: wrote 0 across 1 range(s) in 1.2s  [sweep 0.4min, ETA 4.3min]
# [50/526] mexc WLFI-USDT 8h: wrote 0 across 1 range(s) in 1.2s  [sweep 0.5min, ETA 4.4min]
# [51/526] mexc WLFI-USDT 5m: wrote 0 across 1 range(s) in 2.1s  [sweep 0.5min, ETA 4.4min]
# [52/526] mexc WLD-USDT 15m: wrote 0 across 1 range(s) in 1.0s  [sweep 0.5min, ETA 4.4min]
# [53/526] mexc WLD-USDT 1d: wrote 0 across 1 range(s) in 1.4s  [sweep 0.5min, ETA 4.4min]
# [54/526] mexc WLD-USDT 1h: wrote 0 across 1 range(s) in 1.4s  [sweep 0.5min, ETA 4.4min]
# [55/526] mexc WLD-USDT 4h: wrote 0 across 1 range(s) in 1.3s  [sweep 0.5min, ETA 4.4min]
# [56/526] mexc WLD-USDT 8h: wrote 0 across 1 range(s) in 1.2s  [sweep 0.5min, ETA 4.5min]
# [57/526] mexc WLD-USDT 5m: wrote 0 across 1 range(s) in 2.4s  [sweep 0.5min, ETA 4.5min]
# [58/526] mexc TRX-USDT 1d: wrote 0 across 1 range(s) in 0.5s  [sweep 0.6min, ETA 4.4min]
# [59/526] mexc TRX-USDT 15m: wrote 0 across 1 range(s) in 1.0s  [sweep 0.6min, ETA 4.4min]
# [60/526] mexc TRX-USDT 1h: wrote 0 across 1 range(s) in 1.3s  [sweep 0.6min, ETA 4.4min]
# [61/526] mexc TRX-USDT 4h: wrote 0 across 1 range(s) in 1.5s  [sweep 0.6min, ETA 4.4min]
# [62/526] mexc TRX-USDT 8h: wrote 0 across 1 range(s) in 1.2s  [sweep 0.6min, ETA 4.5min]
# [63/526] mexc TRX-USDT 5m: wrote 0 across 1 range(s) in 2.5s  [sweep 0.6min, ETA 4.5min]
# [64/526] mexc TON-USDT 15m: wrote 0 across 1 range(s) in 1.1s  [sweep 0.6min, ETA 4.5min]
# [65/526] nonkyc ZANO-USDT 12h: wrote 0 across 18 range(s) in 32.7s  [sweep 0.6min, ETA 4.4min]
# [66/526] mexc TON-USDT 1d: wrote 0 across 1 range(s) in 1.2s  [sweep 0.6min, ETA 4.4min]
# [67/526] mexc TON-USDT 1h: wrote 0 across 1 range(s) in 1.3s  [sweep 0.6min, ETA 4.4min]
# [68/526] mexc TON-USDT 4h: wrote 0 across 1 range(s) in 1.2s  [sweep 0.7min, ETA 4.4min]
# [69/526] mexc TON-USDT 5m: wrote 0 across 1 range(s) in 1.6s  [sweep 0.7min, ETA 4.4min]
# [70/526] mexc TON-USDT 8h: wrote 0 across 1 range(s) in 1.4s  [sweep 0.7min, ETA 4.4min]
# [71/526] mexc SUI-USDT 15m: wrote 0 across 1 range(s) in 1.0s  [sweep 0.7min, ETA 4.4min]
# [72/526] mexc SUI-USDT 1d: wrote 0 across 1 range(s) in 1.4s  [sweep 0.7min, ETA 4.4min]
# [73/526] mexc SUI-USDT 1h: wrote 0 across 1 range(s) in 1.4s  [sweep 0.7min, ETA 4.4min]
# [74/526] mexc SUI-USDT 4h: wrote 0 across 1 range(s) in 1.2s  [sweep 0.7min, ETA 4.4min]
# [75/526] mexc SUI-USDT 5m: wrote 0 across 1 range(s) in 1.5s  [sweep 0.7min, ETA 4.4min]
# [76/526] mexc SUI-USDT 8h: wrote 0 across 1 range(s) in 1.2s  [sweep 0.7min, ETA 4.4min]
# [77/526] mexc SOL-USDT 15m: wrote 0 across 1 range(s) in 0.9s  [sweep 0.7min, ETA 4.4min]
# [78/526] mexc SOL-USDT 1d: wrote 0 across 1 range(s) in 0.9s  [sweep 0.8min, ETA 4.3min]
# [79/526] mexc SOL-USDT 1h: wrote 0 across 1 range(s) in 1.2s  [sweep 0.8min, ETA 4.3min]
# [80/526] mexc SOL-USDT 4h: wrote 0 across 1 range(s) in 1.2s  [sweep 0.8min, ETA 4.3min]
# [81/526] mexc SOL-USDT 5m: wrote 0 across 1 range(s) in 1.3s  [sweep 0.8min, ETA 4.3min]
# [82/526] mexc SOL-USDT 8h: wrote 0 across 1 range(s) in 1.1s  [sweep 0.8min, ETA 4.3min]
# [83/526] mexc SHIB-USDT 15m: wrote 0 across 1 range(s) in 0.8s  [sweep 0.8min, ETA 4.3min]
# [84/526] mexc SHIB-USDT 1d: wrote 0 across 1 range(s) in 1.3s  [sweep 0.8min, ETA 4.3min]
# [85/526] mexc SHIB-USDT 1h: wrote 0 across 1 range(s) in 1.2s  [sweep 0.8min, ETA 4.3min]
# [86/526] mexc SHIB-USDT 4h: wrote 0 across 1 range(s) in 1.3s  [sweep 0.8min, ETA 4.3min]
# [87/526] mexc SHIB-USDT 8h: wrote 0 across 1 range(s) in 1.4s  [sweep 0.9min, ETA 4.3min]
# [88/526] mexc SHIB-USDT 5m: wrote 0 across 1 range(s) in 2.4s  [sweep 0.9min, ETA 4.3min]
# [89/526] mexc SAL-USDT 15m: wrote 0 across 1 range(s) in 0.9s  [sweep 0.9min, ETA 4.3min]
# [90/526] mexc SAL-USDT 1d: wrote 0 across 1 range(s) in 1.2s  [sweep 0.9min, ETA 4.3min]
# [91/526] nonkyc ZANO-USDT 1d: wrote 0 across 7 range(s) in 16.1s  [sweep 0.9min, ETA 4.3min]
# [92/526] mexc SAL-USDT 1h: wrote 0 across 1 range(s) in 1.4s  [sweep 0.9min, ETA 4.2min]
# [93/526] mexc SAL-USDT 4h: wrote 0 across 1 range(s) in 1.4s  [sweep 0.9min, ETA 4.2min]
# [94/526] mexc SAL-USDT 8h: wrote 0 across 1 range(s) in 1.2s  [sweep 0.9min, ETA 4.2min]
# [95/526] mexc SAL-USDT 5m: wrote 0 across 1 range(s) in 2.7s  [sweep 0.9min, ETA 4.3min]
# [96/526] mexc SAHARA-USDT 15m: wrote 0 across 1 range(s) in 1.5s  [sweep 0.9min, ETA 4.3min]
# [97/526] mexc SAHARA-USDT 1d: wrote 0 across 1 range(s) in 1.2s  [sweep 1.0min, ETA 4.3min]
# [98/526] mexc SAHARA-USDT 1h: wrote 0 across 1 range(s) in 1.3s  [sweep 1.0min, ETA 4.2min]
# [99/526] mexc SAHARA-USDT 4h: wrote 0 across 1 range(s) in 1.3s  [sweep 1.0min, ETA 4.2min]
# [100/526] mexc SAHARA-USDT 5m: wrote 0 across 1 range(s) in 1.9s  [sweep 1.0min, ETA 4.3min]
# [101/526] mexc SAHARA-USDT 8h: wrote 0 across 1 range(s) in 1.5s  [sweep 1.0min, ETA 4.2min]
# [102/526] mexc RENDER-USDT 15m: wrote 0 across 1 range(s) in 1.3s  [sweep 1.0min, ETA 4.3min]
# [103/526] mexc RENDER-USDT 1d: wrote 0 across 1 range(s) in 1.2s  [sweep 1.0min, ETA 4.2min]
# [104/526] mexc RENDER-USDT 1h: wrote 0 across 1 range(s) in 1.4s  [sweep 1.0min, ETA 4.3min]
# [105/526] mexc RENDER-USDT 4h: wrote 0 across 1 range(s) in 1.2s  [sweep 1.1min, ETA 4.2min]
# [106/526] mexc RENDER-USDT 8h: wrote 0 across 1 range(s) in 1.5s  [sweep 1.1min, ETA 4.3min]
# [107/526] mexc RENDER-USDT 5m: wrote 0 across 1 range(s) in 1.9s  [sweep 1.1min, ETA 4.2min]
# [108/526] mexc PUMP-USDT 1d: wrote 0 across 1 range(s) in 1.1s  [sweep 1.1min, ETA 4.3min]
# [109/526] mexc PUMP-USDT 15m: wrote 0 across 1 range(s) in 1.6s  [sweep 1.1min, ETA 4.2min]
# [110/526] mexc PUMP-USDT 1h: wrote 0 across 1 range(s) in 1.2s  [sweep 1.1min, ETA 4.2min]
# [111/526] mexc PUMP-USDT 4h: wrote 0 across 1 range(s) in 1.2s  [sweep 1.1min, ETA 4.2min]
# [112/526] mexc PUMP-USDT 8h: wrote 0 across 1 range(s) in 1.2s  [sweep 1.1min, ETA 4.2min]
# [113/526] mexc PUMP-USDT 5m: wrote 0 across 1 range(s) in 1.7s  [sweep 1.1min, ETA 4.2min]
# [114/526] mexc PEPE-USDT 15m: wrote 0 across 1 range(s) in 0.8s  [sweep 1.2min, ETA 4.2min]
# [115/526] mexc PEPE-USDT 1d: wrote 0 across 1 range(s) in 1.1s  [sweep 1.2min, ETA 4.2min]
# [116/526] mexc PEPE-USDT 1h: wrote 0 across 1 range(s) in 1.1s  [sweep 1.2min, ETA 4.1min]
# [117/526] mexc PEPE-USDT 4h: wrote 0 across 1 range(s) in 1.1s  [sweep 1.2min, ETA 4.1min]
# [118/526] mexc PEPE-USDT 5m: wrote 0 across 1 range(s) in 1.5s  [sweep 1.2min, ETA 4.1min]
# [119/526] mexc PEPE-USDT 8h: wrote 0 across 1 range(s) in 1.1s  [sweep 1.2min, ETA 4.1min]
# [120/526] mexc OP-USDT 15m: wrote 0 across 1 range(s) in 0.7s  [sweep 1.2min, ETA 4.1min]
# [121/526] mexc OP-USDT 1d: wrote 0 across 1 range(s) in 1.1s  [sweep 1.2min, ETA 4.1min]
# [122/526] mexc OP-USDT 1h: wrote 0 across 1 range(s) in 1.2s  [sweep 1.2min, ETA 4.1min]
# [123/526] mexc OP-USDT 4h: wrote 0 across 1 range(s) in 1.2s  [sweep 1.2min, ETA 4.1min]
# [124/526] mexc OP-USDT 5m: wrote 0 across 1 range(s) in 1.8s  [sweep 1.3min, ETA 4.1min]
# [125/526] mexc OP-USDT 8h: wrote 0 across 1 range(s) in 1.3s  [sweep 1.3min, ETA 4.1min]
# [126/526] mexc LTC-USDT 15m: wrote 0 across 1 range(s) in 0.9s  [sweep 1.3min, ETA 4.0min]
# [127/526] mexc LTC-USDT 8h: wrote 0 across 1 range(s) in 0.8s  [sweep 1.3min, ETA 4.0min]
# [128/526] mexc LTC-USDT 5m: wrote 0 across 1 range(s) in 2.1s  [sweep 1.3min, ETA 4.0min]
# [129/526] mexc ICP-USDT 15m: wrote 0 across 1 range(s) in 1.0s  [sweep 1.3min, ETA 4.0min]
# [130/526] mexc ICP-USDT 1d: wrote 0 across 1 range(s) in 1.2s  [sweep 1.3min, ETA 4.0min]
# [131/526] mexc ICP-USDT 1h: wrote 0 across 1 range(s) in 1.3s  [sweep 1.3min, ETA 4.0min]
# [132/526] mexc ICP-USDT 4h: wrote 0 across 1 range(s) in 1.2s  [sweep 1.3min, ETA 4.0min]
# [133/526] mexc ICP-USDT 5m: wrote 0 across 1 range(s) in 1.7s  [sweep 1.4min, ETA 4.0min]
# [134/526] mexc ICP-USDT 8h: wrote 0 across 1 range(s) in 1.3s  [sweep 1.4min, ETA 4.0min]
# [135/526] mexc HYPE-USDT 15m: wrote 0 across 1 range(s) in 0.9s  [sweep 1.4min, ETA 4.0min]
# [136/526] mexc HYPE-USDT 1d: wrote 0 across 1 range(s) in 1.1s  [sweep 1.4min, ETA 4.0min]
# [137/526] mexc HYPE-USDT 1h: wrote 0 across 1 range(s) in 1.4s  [sweep 1.4min, ETA 4.0min]
# [138/526] mexc HYPE-USDT 4h: wrote 0 across 1 range(s) in 1.3s  [sweep 1.4min, ETA 3.9min]
# [139/526] mexc HYPE-USDT 8h: wrote 0 across 1 range(s) in 1.2s  [sweep 1.4min, ETA 4.0min]
# [140/526] mexc HYPE-USDT 5m: wrote 0 across 1 range(s) in 2.3s  [sweep 1.4min, ETA 3.9min]
# [141/526] mexc FET-USDT 1d: wrote 0 across 1 range(s) in 0.5s  [sweep 1.4min, ETA 3.9min]
# [142/526] mexc FET-USDT 15m: wrote 0 across 1 range(s) in 1.1s  [sweep 1.4min, ETA 3.9min]
# [143/526] mexc FET-USDT 1h: wrote 0 across 1 range(s) in 1.2s  [sweep 1.5min, ETA 3.9min]
# [144/526] mexc FET-USDT 4h: wrote 0 across 1 range(s) in 1.2s  [sweep 1.5min, ETA 3.9min]
# [145/526] mexc FET-USDT 8h: wrote 0 across 1 range(s) in 1.0s  [sweep 1.5min, ETA 3.9min]
# [146/526] mexc ETH-USDT 15m: wrote 0 across 1 range(s) in 1.0s  [sweep 1.5min, ETA 3.9min]
# [147/526] mexc FET-USDT 5m: wrote 0 across 1 range(s) in 2.2s  [sweep 1.5min, ETA 3.9min]
# [148/526] mexc ETH-USDT 8h: wrote 0 across 1 range(s) in 0.6s  [sweep 1.5min, ETA 3.8min]
# [149/526] mexc DOT-USDT 15m: wrote 0 across 1 range(s) in 0.9s  [sweep 1.5min, ETA 3.8min]
# [150/526] mexc ETH-USDT 5m: wrote 0 across 1 range(s) in 1.6s  [sweep 1.5min, ETA 3.8min]
# [151/526] mexc DOT-USDT 1d: wrote 0 across 1 range(s) in 1.1s  [sweep 1.5min, ETA 3.8min]
# [152/526] mexc DOT-USDT 1h: wrote 0 across 1 range(s) in 1.1s  [sweep 1.5min, ETA 3.8min]
# [153/526] mexc DOT-USDT 4h: wrote 0 across 1 range(s) in 1.2s  [sweep 1.6min, ETA 3.8min]
# [154/526] mexc DOT-USDT 5m: wrote 0 across 1 range(s) in 1.7s  [sweep 1.6min, ETA 3.8min]
# [155/526] mexc DOT-USDT 8h: wrote 0 across 1 range(s) in 1.1s  [sweep 1.6min, ETA 3.8min]
# [156/526] mexc DOGE-USDT 15m: wrote 0 across 1 range(s) in 0.9s  [sweep 1.6min, ETA 3.8min]
# [157/526] mexc DOGE-USDT 1d: wrote 0 across 1 range(s) in 0.5s  [sweep 1.6min, ETA 3.7min]
# [158/526] mexc DOGE-USDT 1h: wrote 0 across 1 range(s) in 1.2s  [sweep 1.6min, ETA 3.7min]
# [159/526] mexc DOGE-USDT 4h: wrote 0 across 1 range(s) in 1.4s  [sweep 1.6min, ETA 3.7min]
# [160/526] mexc DOGE-USDT 8h: wrote 0 across 1 range(s) in 1.0s  [sweep 1.6min, ETA 3.7min]
# [161/526] mexc DOGE-USDT 5m: wrote 0 across 1 range(s) in 1.6s  [sweep 1.6min, ETA 3.7min]
#   [kraken] XMR-USDT 15m: page 100, scanned through 2023-11-10 08:57
# [162/526] mexc BTC-USDT 15m: wrote 0 across 1 range(s) in 0.9s  [sweep 1.6min, ETA 3.7min]
# [163/526] mexc BTC-USDT 8h: wrote 0 across 1 range(s) in 0.7s  [sweep 1.6min, ETA 3.7min]
# [164/526] mexc BTC-USDT 5m: wrote 0 across 1 range(s) in 1.7s  [sweep 1.7min, ETA 3.7min]
# [165/526] mexc BNB-USDT 15m: wrote 0 across 1 range(s) in 0.9s  [sweep 1.7min, ETA 3.6min]
# [166/526] mexc BNB-USDT 1d: wrote 0 across 1 range(s) in 0.5s  [sweep 1.7min, ETA 3.6min]
# [167/526] mexc BNB-USDT 4h: wrote 0 across 1 range(s) in 1.2s  [sweep 1.7min, ETA 3.6min]
# [168/526] mexc BNB-USDT 1h: wrote 0 across 1 range(s) in 1.5s  [sweep 1.7min, ETA 3.6min]
# [169/526] mexc BNB-USDT 8h: wrote 0 across 1 range(s) in 1.4s  [sweep 1.7min, ETA 3.6min]
# [170/526] mexc BNB-USDT 5m: wrote 0 across 1 range(s) in 2.4s  [sweep 1.7min, ETA 3.6min]
# [171/526] mexc ATOM-USDT 15m: wrote 0 across 1 range(s) in 1.0s  [sweep 1.7min, ETA 3.6min]
# [172/526] mexc ATOM-USDT 1d: wrote 0 across 1 range(s) in 0.9s  [sweep 1.7min, ETA 3.6min]
# [173/526] mexc ATOM-USDT 1h: wrote 0 across 1 range(s) in 1.3s  [sweep 1.8min, ETA 3.6min]
# [174/526] mexc ATOM-USDT 4h: wrote 0 across 1 range(s) in 1.3s  [sweep 1.8min, ETA 3.6min]
# [175/526] mexc ATOM-USDT 8h: wrote 0 across 1 range(s) in 1.0s  [sweep 1.8min, ETA 3.6min]
# [176/526] mexc ATOM-USDT 5m: wrote 0 across 1 range(s) in 2.2s  [sweep 1.8min, ETA 3.6min]
# [177/526] mexc ASTER-USDT 15m: wrote 0 across 1 range(s) in 1.6s  [sweep 1.8min, ETA 3.6min]
# [178/526] mexc ASTER-USDT 1d: wrote 0 across 1 range(s) in 1.1s  [sweep 1.8min, ETA 3.5min]
# [179/526] mexc ASTER-USDT 4h: wrote 0 across 1 range(s) in 1.2s  [sweep 1.8min, ETA 3.5min]
# [180/526] mexc ASTER-USDT 1h: wrote 0 across 1 range(s) in 1.4s  [sweep 1.8min, ETA 3.5min]
# [181/526] mexc ASTER-USDT 8h: wrote 0 across 1 range(s) in 1.3s  [sweep 1.9min, ETA 3.5min]
# [182/526] mexc ASTER-USDT 5m: wrote 0 across 1 range(s) in 2.1s  [sweep 1.9min, ETA 3.5min]
# [183/526] mexc APT-USDT 15m: wrote 0 across 1 range(s) in 1.1s  [sweep 1.9min, ETA 3.5min]
# [184/526] mexc APT-USDT 1d: wrote 0 across 1 range(s) in 1.3s  [sweep 1.9min, ETA 3.5min]
# [185/526] mexc APT-USDT 1h: wrote 0 across 1 range(s) in 1.4s  [sweep 1.9min, ETA 3.5min]
# [186/526] mexc APT-USDT 4h: wrote 0 across 1 range(s) in 1.3s  [sweep 1.9min, ETA 3.5min]
# [187/526] mexc APT-USDT 5m: wrote 0 across 1 range(s) in 1.3s  [sweep 1.9min, ETA 3.5min]
# [188/526] mexc APT-USDT 8h: wrote 0 across 1 range(s) in 1.2s  [sweep 1.9min, ETA 3.5min]
# [189/526] mexc ADA-USDT 15m: wrote 0 across 1 range(s) in 0.7s  [sweep 1.9min, ETA 3.4min]
# [190/526] mexc ADA-USDT 1d: wrote 0 across 1 range(s) in 0.9s  [sweep 1.9min, ETA 3.4min]
# [191/526] mexc ADA-USDT 1h: wrote 0 across 1 range(s) in 1.1s  [sweep 1.9min, ETA 3.4min]
# [192/526] mexc ADA-USDT 4h: wrote 0 across 1 range(s) in 1.1s  [sweep 2.0min, ETA 3.4min]
# [193/526] mexc ADA-USDT 5m: wrote 0 across 1 range(s) in 1.8s  [sweep 2.0min, ETA 3.4min]
# [194/526] mexc ADA-USDT 8h: wrote 0 across 1 range(s) in 1.3s  [sweep 2.0min, ETA 3.4min]
#   [kraken] XMR-USDT 15m: page 200, scanned through 2024-02-28 10:19
#   [kraken] XMR-USDT 15m: page 300, scanned through 2024-04-05 21:57
#   [kraken] XMR-USDT 15m: page 400, scanned through 2024-05-05 16:27
# [195/526] nonkyc ZEC-XMR 1h: wrote 0 across 146 range(s) in 407.4s  [sweep 6.8min, ETA 11.5min]
#   [kraken] XMR-USDT 15m: page 500, scanned through 2024-06-02 17:45
# [196/526] nonkyc ZANO-USDT 1h: wrote 0 across 204 range(s) in 486.3s  [sweep 9.0min, ETA 15.1min]
# [197/526] nonkyc ZANO-USDT 4h: wrote 0 across 56 range(s) in 142.5s  [sweep 9.2min, ETA 15.3min]
#   [kraken] Trades API error for XMR-USDT: ['EGeneral:Too many requests']
# [198/526] kraken XMR-USDT 15m: wrote 33,907 across 1 range(s) in 597.5s  [sweep 10.0min, ETA 16.5min]
# [199/526] nonkyc ZANO-USDT 8h: wrote 0 across 27 range(s) in 90.9s  [sweep 10.7min, ETA 17.6min]
# [200/526] nonkyc XTM-XMR 12h: wrote 0 across 1 range(s) in 0.5s  [sweep 10.7min, ETA 17.4min]
#   [kraken] Trades API error for XMR-USDT: ['EGeneral:Too many requests']
# [201/526] kraken XMR-USDT 1d: wrote 830 across 1 range(s) in 58.1s  [sweep 10.9min, ETA 17.7min]
# [202/526] nonkyc XTM-XMR 15m: wrote 0 across 6 range(s) in 14.4s  [sweep 10.9min, ETA 17.5min]
# [203/526] nonkyc XTM-XMR 1d: wrote 0 across 1 range(s) in 1.6s  [sweep 11.0min, ETA 17.4min]
# [204/526] nonkyc XTM-XMR 1h: wrote 0 across 1 range(s) in 0.5s  [sweep 11.0min, ETA 17.3min]
# [205/526] nonkyc XTM-XMR 4h: wrote 0 across 1 range(s) in 0.5s  [sweep 11.0min, ETA 17.2min]
#   [kraken] XMR-USDT 1h: page 100, scanned through 2023-11-10 08:57
#   [kraken] Trades API error for XMR-USDT: ['EGeneral:Too many requests']
# [206/526] kraken XMR-USDT 1h: wrote 9,188 across 1 range(s) in 150.0s  [sweep 13.4min, ETA 20.9min]
#   [kraken] XMR-USDT 1m: page 100, scanned through 2023-11-10 08:57
#   [nonkyc] HTTP 502 transient, retrying in 1.5s (attempt 1/6)
#   [kraken] XMR-USDT 1m: page 200, scanned through 2024-02-28 10:19
#   [kraken] XMR-USDT 1m: page 300, scanned through 2024-04-05 21:57
# [207/526] nonkyc XTM-XMR 5m: wrote 0 across 244 range(s) in 542.6s  [sweep 20.0min, ETA 30.9min]
# [208/526] nonkyc XTM-XMR 8h: wrote 0 across 1 range(s) in 0.9s  [sweep 20.0min, ETA 30.6min]
#   [kraken] XMR-USDT 1m: page 400, scanned through 2024-05-05 16:27
# [209/526] nonkyc XRP-USDT 12h: wrote 0 across 4 range(s) in 3.3s  [sweep 20.1min, ETA 30.5min]
#   [kraken] Trades API error for XMR-USDT: ['EGeneral:Too many requests']
# [210/526] kraken XMR-USDT 1m: wrote 85,909 across 1 range(s) in 411.1s  [sweep 20.3min, ETA 30.5min]
#   [kraken] XMR-USDT 30m: page 100, scanned through 2023-11-10 08:57
#   [kraken] XMR-USDT 30m: page 200, scanned through 2024-02-28 10:19
#   [nonkyc] HTTP 502 transient, retrying in 2.0s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.5s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.9s (attempt 1/6)
#   [kraken] XMR-USDT 30m: page 300, scanned through 2024-04-05 21:57
#   [kraken] XMR-USDT 30m: page 400, scanned through 2024-05-05 16:27
#   [kraken] XMR-USDT 30m: page 500, scanned through 2024-06-02 17:45
#   [nonkyc] HTTP 502 transient, retrying in 1.6s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.3s (attempt 1/6)
#   
(attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 3.3s (attempt 2/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.9s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.0s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.5s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 4.8s (attempt 3/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.9s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.7s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.9s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.2s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 3.3s (attempt 2/6)
#   [nonkyc] HTTP 502 transient, retrying in 3.3s (attempt 2/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.7s (attempt 1/6)
#   [kraken] SOL-USD 15m: page 1,100, scanned through 2021-10-02 12:46
#   [kraken] SOL-USD 15m: page 1,200, scanned through 2021-10-11 19:53
#   [nonkyc] HTTP 502 transient, retrying in 2.2s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.0s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.6s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.5s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.9s (attempt 2/6)
#   [kraken] SOL-USD 15m: page 1,300, scanned through 2021-10-21 08:27
# [216/526] nonkyc XRP-USDT 1h: wrote 0 across 221 range(s) in 401.8s  [sweep 88.3min, ETA 126.7min]
# [217/526] nonkyc XRP-USDT 4h: wrote 0 across 13 range(s) in 21.9s  [sweep 88.7min, ETA 126.3min]
#   [kraken] SOL-USD 15m: page 1,400, scanned through 2021-10-26 21:56
#   [kraken] SOL-USD 15m: page 1,500, scanned through 2021-11-02 23:54
#   [kraken] SOL-USD 15m: page 1,600, scanned through 2021-11-09 14:58
#   [nonkyc] HTTP 502 transient, retrying in 1.9s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.9s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 3.2s (attempt 2/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.0s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.0s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.9s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.3s (attempt 1/6)
#   [kraken] SOL-USD 15m: page 1,700, scanned through 2021-11-17 22:54
#   [nonkyc] HTTP 502 transient, retrying in 1.9s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.0s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.6s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.7s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.2s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.8s (attempt 2/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.6s (attempt 2/6)
#   [kraken] SOL-USD 15m: page 1,800, scanned through 2021-11-26 08:24
#   [kraken] SOL-USD 15m: page 1,900, scanned through 2021-12-03 17:24
#   [kraken] SOL-USD 15m: page 2,000, scanned through 2021-12-07 08:16
#   [kraken] SOL-USD 15m: page 2,100, scanned through 2021-12-15 18:21
#   [kraken] SOL-USD 15m: page 2,200, scanned through 2021-12-24 06:44
#   [nonkyc] HTTP 502 transient, retrying in 1.8s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.5s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.0s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 3.9s (attempt 2/6)
#   [kraken] SOL-USD 15m: page 2,300, scanned through 2022-01-05 22:24
#   [nonkyc] HTTP 502 transient, retrying in 1.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.9s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.6s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.3s (attempt 1/6)
#   [kraken] SOL-USD 15m: page 2,400, scanned through 2022-01-17 02:52
#   [kraken] SOL-USD 15m: page 2,500, scanned through 2022-01-24 04:55
#   [kraken] SOL-USD 15m: page 2,600, scanned through 2022-01-31 23:18
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [kraken] SOL-USD 15m: page 2,700, scanned through 2022-02-07 03:36
#   [kraken] SOL-USD 15m: page 2,800, scanned through 2022-02-15 11:57
#   [nonkyc] HTTP 502 transient, retrying in 1.5s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.6s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [kraken] SOL-USD 15m: page 2,900, scanned through 2022-02-24 03:41
#   [nonkyc] HTTP 502 transient, retrying in 2.0s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.4s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.6s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.5s (attempt 1/6)
#   [kraken] SOL-USD 15m: page 3,000, scanned through 2022-03-01 10:51
#   [nonkyc] HTTP 502 transient, retrying in 2.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.7s (attempt 1/6)
# [218/526] nonkyc ZANO-USDT 15m: wrote 0 across 3424 range(s) in 7009.3s  [sweep 117.1min, ETA 165.5min]
# [219/526] nonkyc XRP-USDT 8h: wrote 0 across 4 range(s) in 4.7s  [sweep 117.2min, ETA 164.3min]
# [220/526] nonkyc XNV-XMR 12h: wrote 0 across 1 range(s) in 0.7s  [sweep 117.2min, ETA 163.0min]
# [221/526] nonkyc XNV-XMR 15m: wrote 0 across 1 range(s) in 0.5s  [sweep 117.2min, ETA 161.8min]
# [222/526] nonkyc XNV-XMR 1d: wrote 0 across 1 range(s) in 0.7s  [sweep 117.2min, ETA 160.5min]
# [223/526] nonkyc XNV-XMR 1h: wrote 0 across 1 range(s) in 0.8s  [sweep 117.2min, ETA 159.3min]
# [224/526] nonkyc XNV-XMR 4h: wrote 0 across 1 range(s) in 0.5s  [sweep 117.3min, ETA 158.1min]
# [225/526] nonkyc XNV-XMR 5m: wrote 0 across 1 range(s) in 1.5s  [sweep 117.3min, ETA 156.9min]
# [226/526] nonkyc XNV-XMR 8h: wrote 0 across 1 range(s) in 1.1s  [sweep 117.3min, ETA 155.7min]
# [227/526] nonkyc XMR-ZSD 12h: wrote 0 across 3 range(s) in 4.5s  [sweep 117.4min, ETA 154.6min]
#   [kraken] SOL-USD 15m: page 3,100, scanned through 2022-03-04 08:29
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.5s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.8s (attempt 2/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.9s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 5.4s (attempt 3/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.9s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.6s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.0s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.4s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.7s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.4s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.8s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.8s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.8s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.7s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 3.1s (attempt 2/6)
#   [kraken] SOL-USD 15m: page 3,200, scanned through 2022-03-07 07:51
#   [kraken] SOL-USD 15m: page 3,300, scanned through 2022-03-10 06:54
#   [kraken] SOL-USD 15m: page 3,400, scanned through 2022-03-14 12:00
#   [nonkyc] HTTP 502 transient, retrying in 1.8s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.0s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.7s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.6s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 3.5s (attempt 2/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.7s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.7s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 3.6s (attempt 2/6)
#   [kraken] SOL-USD 15m: page 3,500, scanned through 2022-03-18 04:34
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [kraken] Trades API error for SOL-USD: ['EGeneral:Too many requests']
# [228/526] kraken SOL-USD 15m: wrote 26,220 across 1 range(s) in 3588.2s  [sweep 125.9min, ETA 164.5min]
#   [kraken] Trades API error for SOL-USD: ['EGeneral:Too many requests']
# [229/526] kraken SOL-USD 1d: wrote 557 across 1 range(s) in 26.2s  [sweep 126.3min, ETA 163.8min]
#   [kraken] SOL-USD 1h: page 100, scanned through 2021-08-13 20:08
#   [nonkyc] HTTP 502 transient, retrying in 1.4s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.0s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.5s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.7s (attempt 2/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.6s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 4.2s (attempt 2/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.0s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.4s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.4s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.3s (attempt 1/6)
#   [kraken] SOL-USD 1h: page 200, scanned through 2021-08-24 08:18
#   [nonkyc] HTTP 502 transient, retrying in 2.2s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.2s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.4s (attempt 1/6)
#   [kraken] SOL-USD 1h: page 300, scanned through 2021-08-31 01:29
#   [nonkyc] HTTP 502 transient, retrying in 2.2s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.5s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.7s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.8s (attempt 1/6)
#   [kraken] SOL-USD 1h: page 400, scanned through 2021-09-03 16:07
#   [kraken] SOL-USD 1h: page 500, scanned through 2021-09-07 15:05
#   [nonkyc] HTTP 502 transient, retrying in 1.4s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.9s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.8s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.7s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 4.1s (attempt 2/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.8s (attempt 1/6)
#   [kraken] SOL-USD 1h: page 600, scanned through 2021-09-08 21:51
#   [kraken] Trades API error for SOL-USD: ['EGeneral:Too many requests']
# [230/526] kraken SOL-USD 1h: wrote 2,018 across 1 range(s) in 668.8s  [sweep 137.5min, ETA 176.9min]
#   [nonkyc] HTTP 502 transient, retrying in 1.5s (attempt 1/6)
#   [kraken] Trades API error for SOL-USD: ['EGeneral:Too many requests']
# [231/526] kraken SOL-USD 1m: wrote 12,989 across 1 range(s) in 51.1s  [sweep 138.3min, ETA 176.6min]
#   [nonkyc] HTTP 502 transient, retrying in 2.0s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.3s (attempt 1/6)
#   [kraken] Trades API error for SOL-USD: ['EGeneral:Too many requests']
# [232/526] kraken SOL-USD 4h: wrote 111 across 1 range(s) in 22.9s  [sweep 138.7min, ETA 175.8min]
#   [kraken] Trades API error for SOL-USD: ['EGeneral:Too many requests']
# [233/526] kraken SOL-USD 5m: wrote 11,463 across 1 range(s) in 93.1s  [sweep 140.2min, ETA 176.4min]
#   [kraken] ETH-USD 15m: page 100, scanned through 2016-05-15 18:37
#   [kraken] ETH-USD 15m: page 200, scanned through 2016-07-21 07:29
#   [kraken] ETH-USD 15m: page 300, scanned through 2016-11-29 14:07
#   [kraken] ETH-USD 15m: page 400, scanned through 2017-03-09 00:02
#   [kraken] ETH-USD 15m: page 500, scanned through 2017-03-27 23:34
#   [kraken] ETH-USD 15m: page 600, scanned through 2017-04-28 21:03
#   [kraken] ETH-USD 15m: page 700, scanned through 2017-05-05 23:00
#   [kraken] ETH-USD 15m: page 800, scanned through 2017-05-13 00:19
#   [kraken] ETH-USD 15m: page 900, scanned through 2017-05-21 18:44
#   [kraken] Trades API error for ETH-USD: ['EGeneral:Too many requests']
# [234/526] kraken ETH-USD 15m: wrote 37,903 across 1 range(s) in 949.1s  [sweep 156.1min, ETA 194.7min]
#   [kraken] ETH-USD 1d: page 100, scanned through 2016-05-15 18:37
#   [kraken] ETH-USD 1d: page 200, scanned through 2016-07-21 07:29
#   [kraken] ETH-USD 1d: page 300, scanned through 2016-11-29 14:07
#   [kraken] ETH-USD 1d: page 400, scanned through 2017-03-09 00:02
#   [kraken] ETH-USD 1d: page 500, scanned through 2017-03-27 23:34
#   [kraken] ETH-USD 1d: page 600, scanned through 2017-04-28 21:03
# [235/526] nonkyc XRP-USDT 15m: wrote 0 across 4235 range(s) in 8776.4s  [sweep 166.4min, ETA 206.0min]
# [236/526] nonkyc XMR-ZSD 1d: wrote 0 across 1 range(s) in 2.3s  [sweep 166.4min, ETA 204.5min]
# [237/526] nonkyc XMR-ZSD 1h: wrote 0 across 7 range(s) in 22.7s  [sweep 166.8min, ETA 203.4min]
# [238/526] nonkyc XMR-ZSD 4h: wrote 0 across 2 range(s) in 4.3s  [sweep 166.8min, ETA 201.9min]
# [239/526] nonkyc ZSD-USDT 15m: wrote 0 across 4676 range(s) in 10021.9s  [sweep 167.0min, ETA 200.6min]
# [240/526] nonkyc XMR-ZSD 8h: wrote 0 across 3 range(s) in 5.2s  [sweep 167.1min, ETA 199.1min]
# [241/526] nonkyc XMR-USDT 12h: wrote 0 across 5 range(s) in 4.1s  [sweep 167.2min, ETA 197.7min]
#   [kraken] ETH-USD 1d: page 700, scanned through 2017-05-05 23:00
#   [nonkyc] HTTP 502 transient, retrying in 1.6s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.6s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.3s (attempt 1/6)
#   [kraken] ETH-USD 1d: page 800, scanned through 2017-05-13 00:19
#   [kraken] ETH-USD 1d: page 900, scanned through 2017-05-21 18:44
#   [kraken] ETH-USD 1d: page 1,000, scanned through 2017-05-26 00:18
#   [kraken] ETH-USD 1d: page 1,100, scanned through 2017-05-30 04:47
#   [kraken] ETH-USD 1d: page 1,200, scanned through 2017-06-04 16:08
#   [nonkyc] HTTP 502 transient, retrying in 1.6s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.8s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.6s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.5s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 3.3s (attempt 2/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.8s (attempt 1/6)
#   [kraken] ETH-USD 1d: page 1,300, scanned through 2017-06-11 09:18
#   [kraken] ETH-USD 1d: page 1,400, scanned through 2017-06-15 09:37
#   [kraken] ETH-USD 1d: page 1,500, scanned through 2017-06-20 05:17
#   [kraken] ETH-USD 1d: page 1,600, scanned through 2017-06-25 15:10
#   [kraken] ETH-USD 1d: page 1,700, scanned through 2017-06-28 13:16
#   [nonkyc] HTTP 502 transient, retrying in 1.5s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.4s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 3.3s (attempt 2/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.2s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 6.1s (attempt 3/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.4s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.6s (attempt 2/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.7s (attempt 1/6)
#   [kraken] ETH-USD 1d: page 1,800, scanned through 2017-07-03 00:44
#   [kraken] Trades API error for ETH-USD: ['EGeneral:No data']
# [242/526] kraken ETH-USD 1d: wrote 1,232 across 1 range(s) in 1870.5s  [sweep 187.2min, ETA 219.7min]
#   [kraken] ETH-USD 1h: page 100, scanned through 2016-05-15 18:37
#   [kraken] ETH-USD 1h: page 200, scanned through 2016-07-21 07:29
#   [kraken] Trades API error for ETH-USD: ['EGeneral:No data']
# [243/526] kraken ETH-USD 1h: wrote 5,151 across 1 range(s) in 202.3s  [sweep 190.6min, ETA 222.0min]
#   [kraken] ETH-USD 1m: page 100, scanned through 2016-05-15 18:37
#   [kraken] ETH-USD 1m: page 200, scanned through 2016-07-21 07:29
#   [kraken] ETH-USD 1m: page 300, scanned through 2016-11-29 14:07
#   [kraken] ETH-USD 1m: page 400, scanned through 2017-03-09 00:02
#   [nonkyc] HTTP 502 transient, retrying in 2.2s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.4s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.5s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.8s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.2s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.2s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.8s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.8s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.5s (attempt 1/6)
#   [kraken] ETH-USD 1m: page 500, scanned through 2017-03-27 23:34
#   [kraken] ETH-USD 1m: page 600, scanned through 2017-04-28 21:03
#   [nonkyc] HTTP 502 transient, retrying in 2.0s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 3.4s (attempt 2/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.5s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.8s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.9s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.7s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.5s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.5s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.7s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.7s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.2s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.6s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.5s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.6s (attempt 1/6)
#   [kraken] ETH-USD 1m: page 700, scanned through 2017-05-05 23:00
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.9s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.5s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.8s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.2s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.8s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.0s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.5s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.0s (attempt 1/6)
#   [kraken] ETH-USD 1m: page 800, scanned through 2017-05-13 00:19
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.0s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.9s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.7s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.7s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.4s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.8s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 4.1s (attempt 2/6)
#   [kraken] ETH-USD 1m: page 900, scanned through 2017-05-21 18:44
#   [kraken] ETH-USD 1m: page 1,000, scanned through 2017-05-26 00:18
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.0s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.0s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.2s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.5s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 3.7s (attempt 2/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.7s (attempt 1/6)
#   [kraken] ETH-USD 1m: page 1,100, scanned through 2017-05-30 04:47
#   [kraken] ETH-USD 1m: page 1,200, scanned through 2017-06-04 16:08
#   [kraken] ETH-USD 1m: page 1,300, scanned through 2017-06-11 09:18
#   [nonkyc] HTTP 502 transient, retrying in 1.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.8s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.5s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.4s (attempt 2/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.2s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.2s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.5s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [kraken] ETH-USD 1m: page 1,400, scanned through 2017-06-15 09:37
#   [kraken] ETH-USD 1m: page 1,500, scanned through 2017-06-20 05:17
#   [kraken] ETH-USD 1m: page 1,600, scanned through 2017-06-25 15:10
#   [nonkyc] HTTP 502 transient, retrying in 1.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.9s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.2s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.4s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.5s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.9s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 3.6s (attempt 2/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.9s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 5.3s (attempt 3/6)
# ...
#   [nonkyc] Watchdog: killed hung connection after 20s
#   [nonkyc] Watchdog: killed hung connection after 20s
#     [nonkyc] SHIB-USDT 5m: 1 reqs, 0 written, 43s elapsed
#   [nonkyc] Watchdog: killed hung connection after 20s
#   [nonkyc] Watchdog: killed hung connection after 20s
#     [nonkyc] TRX-USDT 5m: 1 reqs, 0 written, 53s elapsed
#   [nonkyc] Watchdog: killed hung connection after 20s
#   [nonkyc] Watchdog: killed hung connection after 20s
#     [nonkyc] VEIL-XMR 5m: 1 reqs, 0 written, 49s elapsed
#     [nonkyc] SOL-USDT 5m: 1 reqs, 0 written, 49s elapsed
#     [nonkyc] SAL-USDT 5m: 1 reqs, 0 written, 81s elapsed
#     [nonkyc] SHIB-USDT 5m: 1 reqs, 0 written, 33s elapsed
#     [nonkyc] RXD-USDT 5m: 1 reqs, 0 written, 34s elapsed
#   [nonkyc] HTTP 502 transient, retrying in 1.9s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.6s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.4s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.7s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.7s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.0s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.4s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.6s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.4s (attempt 2/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.0s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.6s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.9s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.7s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.4s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.8s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.0s (attempt 1/6)
# [521/526] nonkyc SOL-USDT 5m: wrote 0 across 18379 range(s) in 53379.9s  [sweep 2212.1min, ETA 21.2min]
#   [nonkyc] HTTP 502 transient, retrying in 2.2s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.0s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.8s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.8s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.8s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.5s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.2s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.7s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.7s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.6s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.9s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.9s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 3.6s (attempt 2/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.2s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 6.8s (attempt 3/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.8s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.8s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.2s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.0s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.6s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 3.4s (attempt 2/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.6s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.6s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.4s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 3.6s (attempt 2/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.4s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 4.1s (attempt 2/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.9s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 7.2s (attempt 3/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.9s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.5s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.5s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.5s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.4s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.4s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.8s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.4s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.0s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.6s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.6s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 3.9s (attempt 2/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.4s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.6s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.4s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.6s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.7s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.2s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.8s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.2s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.6s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 3.9s (attempt 2/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.4s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.7s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.9s (attempt 1/6)
# [522/526] nonkyc SAL-USDT 5m: wrote 0 across 13543 range(s) in 42869.6s  [sweep 2262.0min, ETA 17.3min]
#   [nonkyc] HTTP 502 transient, retrying in 1.9s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.7s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.4s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.7s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.0s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 3.7s (attempt 2/6)
#   [nonkyc] HTTP 502 transient, retrying in 3.1s (attempt 2/6)
# [523/526] nonkyc RXD-USDT 5m: wrote 0 across 13084 range(s) in 41672.4s  [sweep 2282.1min, ETA 13.1min]
# [524/526] nonkyc TRX-USDT 5m: wrote 0 across 25758 range(s) in 65664.6s  [sweep 2292.2min, ETA 8.7min]
#   [nonkyc] HTTP 502 transient, retrying in 1.4s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.8s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.6s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.6s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 3.0s (attempt 2/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.4s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.7s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 3.5s (attempt 2/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 7.1s (attempt 3/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.5s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.3s (attempt 2/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.6s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 6.8s (attempt 3/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.9s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.6s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.2s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.2s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.2s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.6s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.9s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.6s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.5s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 3.7s (attempt 2/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.8s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.3s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.5s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.4s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.6s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.2s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 3.1s (attempt 2/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.7s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.2s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.7s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.7s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.6s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.7s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.2s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.4s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.2s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.1s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.7s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.7s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.6s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 2.2s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.5s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.8s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.7s (attempt 1/6)
# [525/526] nonkyc SHIB-USDT 5m: wrote 0 across 27436 range(s) in 60961.7s  [sweep 2551.2min, ETA 4.9min]
#   [nonkyc] HTTP 502 transient, retrying in 1.7s (attempt 1/6)
#   [nonkyc] HTTP 502 transient, retrying in 1.4s (attempt 1/6)
# [526/526] nonkyc VEIL-XMR 5m: wrote 0 across 48350 range(s) in 102334.3s  [sweep 2617.6min, ETA 0.0min]
#
# ══════════════════════════════════════════════════════════════════════
# BACKFILL COMPLETE
#   Wall clock: 2617.6 min
#   Gap / uncovered ranges processed: 488,036
#   Total candles written: 2,082,456
#   Errors: 3601
#     kraken       wrote  2,082,456 across   25 ranges, 6 error(s)
#       final bucket rate: 1.00 req/s (initial: 1.0)
#       ✗ kraken ETH-USD 1m [2015-08-07 14:03→2026-04-16 05:58]: HTTPSConnectionPool(host='api.kraken.com', port=443): Max retries exceeded with url: /0/public/Trades?pair=ETHUSD&since=1520946841931730799 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7dbd45f221b0>: Failed to establish a new connection: [Errno -2] Name or service not known'))
#       ✗ kraken ETH-USD 4h [2015-08-07 12:00→2025-12-20 16:00]: HTTPSConnectionPool(host='api.kraken.com', port=443): Max retries exceeded with url: /0/public/Trades?pair=ETHUSD&since=1438948799999999999 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7dbd560d0620>: Failed to establish a new connection: [Errno -2] Name or service not known'))
#       ✗ kraken ETH-USD 5m [2015-08-07 14:00→2026-04-16 05:50]: HTTPSConnectionPool(host='api.kraken.com', port=443): Max retries exceeded with url: /0/public/Trades?pair=ETHUSD&since=1438955999999999999 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7dbd45f23530>: Failed to establish a new connection: [Errno -2] Name or service not known'))
#       ✗ kraken BTC-USD 15m [2013-10-06 21:30→2026-04-12 10:45]: HTTPSConnectionPool(host='api.kraken.com', port=443): Max retries exceeded with url: /0/public/Trades?pair=XBTUSD&since=1381094999999999999 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7dbd44541ee0>: Failed to establish a new connection: [Errno -2] Name or service not known'))
#       ✗ kraken BTC-USD 1d [2013-10-06 00:00→2025-10-20 00:00]: HTTPSConnectionPool(host='api.kraken.com', port=443): Max retries exceeded with url: /0/public/Trades?pair=XBTUSD&since=1381017599999999999 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dbd460ed1f0>, 'Connection to api.kraken.com timed out. (connect timeout=5)'))
#       ... and 1 more
#     mexc         wrote          0 across  183 ranges, 0 error(s)
#       final bucket rate: 5.00 req/s (initial: 5.0)
#     nonkyc       wrote          0 across 487828 ranges, 3595 error(s)
#       final bucket rate: 4.00 req/s (initial: 4.0)
#       ✗ nonkyc XMR-ZSD 15m [2025-07-10 12:30→2025-07-10 12:30]: HTTPSConnectionPool(host='api.nonkyc.io', port=443): Max retries exceeded with url: /api/v2/market/candles?symbol=XMR_ZSD&resolution=15&countBack=5000&to=1752151499 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dbd3717d190>, 'Connection to api.nonkyc.io timed out. (connect timeout=5)'))
#       ✗ nonkyc XMR-ZSD 15m [2025-07-10 14:15→2025-07-10 14:30]: HTTPSConnectionPool(host='api.nonkyc.io', port=443): Max retries exceeded with url: /api/v2/market/candles?symbol=XMR_ZSD&resolution=15&countBack=5000&to=1752158699 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dbd34272e40>, 'Connection to api.nonkyc.io timed out. (connect timeout=5)'))
#       ✗ nonkyc ZEC-XMR 15m [2025-01-07 00:30→2025-01-07 00:30]: HTTPSConnectionPool(host='api.nonkyc.io', port=443): Max retries exceeded with url: /api/v2/market/candles?symbol=ZEC_XMR&resolution=15&countBack=5000&to=1736210699 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dbd3717c8c0>, 'Connection to api.nonkyc.io timed out. (connect timeout=5)'))
#       ✗ nonkyc ZEC-XMR 15m [2025-01-07 03:00→2025-01-07 03:15]: HTTPSConnectionPool(host='api.nonkyc.io', port=443): Max retries exceeded with url: /api/v2/market/candles?symbol=ZEC_XMR&resolution=15&countBack=5000&to=1736220599 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dbd34270ef0>, 'Connection to api.nonkyc.io timed out. (connect timeout=5)'))
#       ✗ nonkyc XMR-USDT 5m [2023-06-25 12:30→2023-06-25 12:30]: HTTPSConnectionPool(host='api.nonkyc.io', port=443): Max retries exceeded with url: /api/v2/market/candles?symbol=XMR_USDT&resolution=5&countBack=5000&to=1687696499 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dbd46ebc920>, 'Connection to api.nonkyc.io timed out. (connect timeout=5)'))
#       ... and 3590 more
# ══════════════════════════════════════════════════════════════════════

# %%
# ── Cell 12: Post-backfill verification ──────────────────────────────────────

selected_connectors_set = set(c["connector"] for c in selected_combos)

print(f"Post-backfill verification ({', '.join(sorted(selected_connectors_set))})")
print(f"{'─' * 128}")
print(f"{'Idx':>5s}  {'Connector':12s} {'Pair':16s} {'Intv':6s} {'Docs':>10s} {'Covered':>10s} {'Expected':>10s} {'Missing':>10s} {'Complete':>9s}")
print(f"{'─' * 128}")

still_missing_total = 0

pipeline = [
    {"$group": {
        "_id": {"connector": "$connector", "trading_pair": "$trading_pair", "interval": "$interval"},
        "count": {"$sum": 1},
    }},
    {"$sort": {"_id.connector": 1, "_id.trading_pair": 1, "_id.interval": 1}},
]
all_combos_after = list(coll.aggregate(pipeline, allowDiskUse=True))

for i, agg in enumerate(all_combos_after):
    connector = agg["_id"]["connector"]
    if connector not in selected_connectors_set:
        continue

    pair = agg["_id"]["trading_pair"]
    interval = agg["_id"]["interval"]
    if EXCHANGES.get(connector, {}).get("interval_map", {}).get(interval) is None:
        continue

    step = INTERVAL_SECONDS[interval]
    win_start = effective_windows.get((connector, interval))
    if win_start is None:
        continue

    if connector == "kraken":
        cached_pair_start = get_cached_pair_start_ts("kraken", pair)
        if cached_pair_start is not None:
            win_start = align_floor(cached_pair_start, step)

    recent_cutoff = utc_now_ts() - (RECENT_DAYS_OWNED * 86400) if RECENT_DAYS_OWNED > 0 else utc_now_ts()
    win_end = min(
        last_closed_open_ts(utc_now_ts(), step),
        last_closed_open_ts(recent_cutoff, step),
    )

    summary = summarize_series_window(coll, connector, pair, interval, step, win_start, win_end)
    missing = summary["missing"]
    pct = summary["pct"]
    still_missing_total += missing

    flag = " ✓" if missing == 0 else f" ← {missing:,} still uncovered"
    print(f"{i:>5d}  {connector:12s} {pair:16s} {interval:6s} "
          f"{summary['docs_in_window']:>10,d} {summary['covered_buckets']:>10,d} "
          f"{summary['expected']:>10,d} {missing:>10,d} {pct:>8.1f}%{flag}")

print(f"{'─' * 128}")
if still_missing_total == 0:
    print("✓ All selected series are 100% covered!")
else:
    print(f"⚠ {still_missing_total:,} intervals still uncovered "
          f"(or, for Kraken, not yet scanned and recorded as covered)")
# Out:
# Post-backfill verification (kraken, mexc, nonkyc)
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   Idx  Connector    Pair             Intv         Docs    Covered   Expected    Missing  Complete
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#    15  kraken       BTC-USD          15m           538        538    439,312    438,774      0.1% ← 438,774 still uncovered
#    16  kraken       BTC-USD          1d            179        179      4,577      4,398      3.9% ← 4,398 still uncovered
#    17  kraken       BTC-USD          1h            674        674    109,828    109,154      0.6% ← 109,154 still uncovered
#    18  kraken       BTC-USD          1m      1,566,378  6,587,065  6,589,689      2,624    100.0% ← 2,624 still uncovered
#    19  kraken       BTC-USD          4h            977     27,457     27,457          0    100.0% ✓
#    20  kraken       BTC-USD          5m        220,012  1,317,588  1,317,938        350    100.0% ← 350 still uncovered
#    21  kraken       ETH-USD          15m        38,441    375,022    375,022          0    100.0% ✓
#    22  kraken       ETH-USD          1d          1,411      3,907      3,907          0    100.0% ✓
#    23  kraken       ETH-USD          1h          5,825     93,755     93,755          0    100.0% ✓
#    24  kraken       ETH-USD          1m        548,000    548,000  5,625,341  5,077,341      9.7% ← 5,077,341 still uncovered
#    25  kraken       ETH-USD          4h            709        709     23,439     22,730      3.0% ← 22,730 still uncovered
#    26  kraken       ETH-USD          5m            175        175  1,125,068  1,124,893      0.0% ← 1,124,893 still uncovered
#    27  kraken       SOL-USD          15m        26,758    169,480    169,480          0    100.0% ✓
#    28  kraken       SOL-USD          1d            736      1,766      1,766          0    100.0% ✓
#    29  kraken       SOL-USD          1h          2,692     42,370     42,370          0    100.0% ✓
#    30  kraken       SOL-USD          1m         12,989  2,539,587  2,542,212      2,625     99.9% ← 2,625 still uncovered
#    31  kraken       SOL-USD          4h            820     10,593     10,593          0    100.0% ✓
#    32  kraken       SOL-USD          5m         11,638    508,092    508,442        350     99.9% ← 350 still uncovered
#    33  kraken       XMR-USDT         15m        33,907    123,134    123,309        175     99.9% ← 175 still uncovered
#    34  kraken       XMR-USDT         1d          1,009      1,285      1,285          0    100.0% ✓
#    35  kraken       XMR-USDT         1h          9,188     30,783     30,827         44     99.9% ← 44 still uncovered
#    36  kraken       XMR-USDT         1m         85,909  1,847,018  1,849,643      2,625     99.9% ← 2,625 still uncovered
#    37  kraken       XMR-USDT         30m        43,036     61,567     61,655         88     99.9% ← 88 still uncovered
#    38  kraken       XMR-USDT         4h          4,201      7,707      7,707          0    100.0% ✓
#    39  kraken       XMR-USDT         5m         21,967    369,403    369,928        525     99.9% ← 525 still uncovered
#    40  mexc         ADA-USDT         15m        34,651     34,651     34,653          2    100.0% ← 2 still uncovered
#    41  mexc         ADA-USDT         1d          2,486      2,486      3,095        609     80.3% ← 609 still uncovered
#    42  mexc         ADA-USDT         1h          4,920      4,920     69,059     64,139      7.1% ← 64,139 still uncovered
#    43  mexc         ADA-USDT         1m         42,436     42,436     42,436          0    100.0% ✓
#    44  mexc         ADA-USDT         4h          1,230      1,230     17,265     16,035      7.1% ← 16,035 still uncovered
#    45  mexc         ADA-USDT         5m        103,954    103,954    103,958          4    100.0% ← 4 still uncovered
#    46  mexc         ADA-USDT         8h          7,458      7,458      8,638      1,180     86.3% ← 1,180 still uncovered
#    47  mexc         APT-USDT         15m        34,651     34,651     34,653          2    100.0% ← 2 still uncovered
#    48  mexc         APT-USDT         1d            221        221      3,095      2,874      7.1% ← 2,874 still uncovered
#    49  mexc         APT-USDT         1h          5,319      5,319     69,059     63,740      7.7% ← 63,740 still uncovered
#    50  mexc         APT-USDT         1m         42,436     42,436     42,436          0    100.0% ✓
#    51  mexc         APT-USDT         4h          1,329      1,329     17,265     15,936      7.7% ← 15,936 still uncovered
#    52  mexc         APT-USDT         5m        103,954    103,954    103,958          4    100.0% ← 4 still uncovered
#    53  mexc         APT-USDT         8h            543        543      8,638      8,095      6.3% ← 8,095 still uncovered
#    54  mexc         ASTER-USDT       15m        19,679     19,679     34,653     14,974     56.8% ← 14,974 still uncovered
#    55  mexc         ASTER-USDT       1d            205        205      3,095      2,890      6.6% ← 2,890 still uncovered
#    56  mexc         ASTER-USDT       1h          4,920      4,920     69,059     64,139      7.1% ← 64,139 still uncovered
#    57  mexc         ASTER-USDT       1m         42,436     42,436     42,436          0    100.0% ✓
#    58  mexc         ASTER-USDT       4h          1,230      1,230     17,265     16,035      7.1% ← 16,035 still uncovered
#    59  mexc         ASTER-USDT       5m         59,038     59,038    103,958     44,920     56.8% ← 44,920 still uncovered
#    60  mexc         ASTER-USDT       8h            543        543      8,638      8,095      6.3% ← 8,095 still uncovered
#    61  mexc         ATOM-USDT        15m        34,651     34,651     34,653          2    100.0% ← 2 still uncovered
#    62  mexc         ATOM-USDT        1d          2,552      2,552      3,095        543     82.5% ← 543 still uncovered
#    63  mexc         ATOM-USDT        1h          4,920      4,920     69,059     64,139      7.1% ← 64,139 still uncovered
#    64  mexc         ATOM-USDT        1m         42,436     42,436     42,436          0    100.0% ✓
#    65  mexc         ATOM-USDT        4h          1,230      1,230     17,265     16,035      7.1% ← 16,035 still uncovered
#    66  mexc         ATOM-USDT        5m        103,953    103,953    103,958          5    100.0% ← 5 still uncovered
#    67  mexc         ATOM-USDT        8h          7,656      7,656      8,638        982     88.6% ← 982 still uncovered
#    68  mexc         BNB-USDT         15m        34,651     34,651     34,653          2    100.0% ← 2 still uncovered
#    69  mexc         BNB-USDT         1d          2,599      2,599      3,095        496     84.0% ← 496 still uncovered
#    70  mexc         BNB-USDT         1h          5,320      5,320     69,059     63,739      7.7% ← 63,739 still uncovered
#    71  mexc         BNB-USDT         1m         42,436     42,436     42,436          0    100.0% ✓
#    72  mexc         BNB-USDT         4h          1,329      1,329     17,265     15,936      7.7% ← 15,936 still uncovered
#    73  mexc         BNB-USDT         5m        103,953    103,953    103,958          5    100.0% ← 5 still uncovered
#    74  mexc         BNB-USDT         8h          7,796      7,796      8,638        842     90.3% ← 842 still uncovered
#    75  mexc         BTC-USDT         15m        34,651     34,651     34,653          2    100.0% ← 2 still uncovered
#    76  mexc         BTC-USDT         1d          3,095      3,095      3,095          0    100.0% ✓
#    77  mexc         BTC-USDT         1h         69,059     69,059     69,059          0    100.0% ✓
#    78  mexc         BTC-USDT         1m         42,436     42,436     42,436          0    100.0% ✓
#    79  mexc         BTC-USDT         4h         17,265     17,265     17,265          0    100.0% ✓
#    80  mexc         BTC-USDT         5m        103,953    103,953    103,958          5    100.0% ← 5 still uncovered
#    81  mexc         BTC-USDT         8h          8,634      8,634      8,638          4    100.0% ← 4 still uncovered
#    82  mexc         DOGE-USDT        15m        34,651     34,651     34,653          2    100.0% ← 2 still uncovered
#    83  mexc         DOGE-USDT        1d          2,700      2,700      3,095        395     87.2% ← 395 still uncovered
#    84  mexc         DOGE-USDT        1h          5,424      5,424     69,059     63,635      7.9% ← 63,635 still uncovered
#    85  mexc         DOGE-USDT        1m         42,436     42,436     42,436          0    100.0% ✓
#    86  mexc         DOGE-USDT        4h         16,198     16,198     17,265      1,067     93.8% ← 1,067 still uncovered
#    87  mexc         DOGE-USDT        5m        103,952    103,952    103,958          6    100.0% ← 6 still uncovered
#    88  mexc         DOGE-USDT        8h          8,099      8,099      8,638        539     93.8% ← 539 still uncovered
#    89  mexc         DOT-USDT         15m        34,650     34,650     34,653          3    100.0% ← 3 still uncovered
#    90  mexc         DOT-USDT         1d          2,065      2,065      3,095      1,030     66.7% ← 1,030 still uncovered
#    91  mexc         DOT-USDT         1h          4,920      4,920     69,059     64,139      7.1% ← 64,139 still uncovered
#    92  mexc         DOT-USDT         1m         42,436     42,436     42,436          0    100.0% ✓
#    93  mexc         DOT-USDT         4h          1,230      1,230     17,265     16,035      7.1% ← 16,035 still uncovered
#    94  mexc         DOT-USDT         5m        103,952    103,952    103,958          6    100.0% ← 6 still uncovered
#    95  mexc         DOT-USDT         8h            543        543      8,638      8,095      6.3% ← 8,095 still uncovered
#    96  mexc         ETH-USDT         15m        34,650     34,650     34,653          3    100.0% ← 3 still uncovered
#    97  mexc         ETH-USDT         1d          3,095      3,095      3,095          0    100.0% ✓
#    98  mexc         ETH-USDT         1h         69,059     69,059     69,059          0    100.0% ✓
#    99  mexc         ETH-USDT         1m         42,436     42,436     42,436          0    100.0% ✓
#   100  mexc         ETH-USDT         4h         17,265     17,265     17,265          0    100.0% ✓
#   101  mexc         ETH-USDT         5m        103,952    103,952    103,958          6    100.0% ← 6 still uncovered
#   102  mexc         ETH-USDT         8h          8,634      8,634      8,638          4    100.0% ← 4 still uncovered
#   103  mexc         FET-USDT         15m        34,650     34,650     34,653          3    100.0% ← 3 still uncovered
#   104  mexc         FET-USDT         1d          2,607      2,607      3,095        488     84.2% ← 488 still uncovered
#   105  mexc         FET-USDT         1h          4,658      4,658     69,059     64,401      6.7% ← 64,401 still uncovered
#   106  mexc         FET-USDT         1m         42,436     42,436     42,436          0    100.0% ✓
#   107  mexc         FET-USDT         4h          1,165      1,165     17,265     16,100      6.7% ← 16,100 still uncovered
#   108  mexc         FET-USDT         5m        103,952    103,952    103,958          6    100.0% ← 6 still uncovered
#   109  mexc         FET-USDT         8h          7,824      7,824      8,638        814     90.6% ← 814 still uncovered
#   110  mexc         HYPE-USDT        15m        34,650     34,650     34,653          3    100.0% ← 3 still uncovered
#   111  mexc         HYPE-USDT        1d            205        205      3,095      2,890      6.6% ← 2,890 still uncovered
#   112  mexc         HYPE-USDT        1h          4,920      4,920     69,059     64,139      7.1% ← 64,139 still uncovered
#   113  mexc         HYPE-USDT        1m         42,436     42,436     42,436          0    100.0% ✓
#   114  mexc         HYPE-USDT        4h          1,230      1,230     17,265     16,035      7.1% ← 16,035 still uncovered
#   115  mexc         HYPE-USDT        5m        103,951    103,951    103,958          7    100.0% ← 7 still uncovered
#   116  mexc         HYPE-USDT        8h            543        543      8,638      8,095      6.3% ← 8,095 still uncovered
#   117  mexc         ICP-USDT         15m        34,650     34,650     34,653          3    100.0% ← 3 still uncovered
#   118  mexc         ICP-USDT         1d          1,803      1,803      3,095      1,292     58.3% ← 1,292 still uncovered
#   119  mexc         ICP-USDT         1h          4,920      4,920     69,059     64,139      7.1% ← 64,139 still uncovered
#   120  mexc         ICP-USDT         1m         42,436     42,436     42,436          0    100.0% ✓
#   121  mexc         ICP-USDT         4h          1,230      1,230     17,265     16,035      7.1% ← 16,035 still uncovered
#   122  mexc         ICP-USDT         5m        103,951    103,951    103,958          7    100.0% ← 7 still uncovered
#   123  mexc         ICP-USDT         8h            543        543      8,638      8,095      6.3% ← 8,095 still uncovered
#   124  mexc         LTC-USDT         15m        34,650     34,650     34,653          3    100.0% ← 3 still uncovered
#   125  mexc         LTC-USDT         1d          3,095      3,095      3,095          0    100.0% ✓
#   126  mexc         LTC-USDT         1h         69,059     69,059     69,059          0    100.0% ✓
#   127  mexc         LTC-USDT         1m         42,436     42,436     42,436          0    100.0% ✓
#   128  mexc         LTC-USDT         4h         17,265     17,265     17,265          0    100.0% ✓
#   129  mexc         LTC-USDT         5m        103,951    103,951    103,958          7    100.0% ← 7 still uncovered
#   130  mexc         LTC-USDT         8h          8,634      8,634      8,638          4    100.0% ← 4 still uncovered
#   131  mexc         OP-USDT          15m        34,650     34,650     34,653          3    100.0% ← 3 still uncovered
#   132  mexc         OP-USDT          1d            205        205      3,095      2,890      6.6% ← 2,890 still uncovered
#   133  mexc         OP-USDT          1h          4,920      4,920     69,059     64,139      7.1% ← 64,139 still uncovered
#   134  mexc         OP-USDT          1m         42,436     42,436     42,436          0    100.0% ✓
#   135  mexc         OP-USDT          4h          1,230      1,230     17,265     16,035      7.1% ← 16,035 still uncovered
#   136  mexc         OP-USDT          5m        103,950    103,950    103,958          8    100.0% ← 8 still uncovered
#   137  mexc         OP-USDT          8h            543        543      8,638      8,095      6.3% ← 8,095 still uncovered
#   138  mexc         PEPE-USDT        15m        34,650     34,650     34,653          3    100.0% ← 3 still uncovered
USDT         15m        34,650     34,650     34,654          4    100.0% ← 4 still uncovered
#   181  mexc         SOL-USDT         1d          2,110      2,110      3,095        985     68.2% ← 985 still uncovered
#   182  mexc         SOL-USDT         1h          5,424      5,424     69,059     63,635      7.9% ← 63,635 still uncovered
#   183  mexc         SOL-USDT         1m         42,437     42,437     42,437          0    100.0% ✓
#   184  mexc         SOL-USDT         4h          1,355      1,355     17,265     15,910      7.8% ← 15,910 still uncovered
#   185  mexc         SOL-USDT         5m        103,950    103,950    103,959          9    100.0% ← 9 still uncovered
#   186  mexc         SOL-USDT         8h            543        543      8,638      8,095      6.3% ← 8,095 still uncovered
#   187  mexc         SUI-USDT         15m        34,650     34,650     34,654          4    100.0% ← 4 still uncovered
#   188  mexc         SUI-USDT         1d            205        205      3,095      2,890      6.6% ← 2,890 still uncovered
#   189  mexc         SUI-USDT         1h          4,920      4,920     69,059     64,139      7.1% ← 64,139 still uncovered
#   190  mexc         SUI-USDT         1m         42,437     42,437     42,437          0    100.0% ✓
#   191  mexc         SUI-USDT         4h          1,230      1,230     17,265     16,035      7.1% ← 16,035 still uncovered
#   192  mexc         SUI-USDT         5m        103,950    103,950    103,959          9    100.0% ← 9 still uncovered
#   193  mexc         SUI-USDT         8h            543        543      8,638      8,095      6.3% ← 8,095 still uncovered
#   194  mexc         TON-USDT         15m        34,650     34,650     34,654          4    100.0% ← 4 still uncovered
#   195  mexc         TON-USDT         1d            221        221      3,095      2,874      7.1% ← 2,874 still uncovered
#   196  mexc         TON-USDT         1h          5,320      5,320     69,059     63,739      7.7% ← 63,739 still uncovered
#   197  mexc         TON-USDT         1m         42,437     42,437     42,437          0    100.0% ✓
#   198  mexc         TON-USDT         4h          1,329      1,329     17,265     15,936      7.7% ← 15,936 still uncovered
#   199  mexc         TON-USDT         5m        103,950    103,950    103,959          9    100.0% ← 9 still uncovered
#   200  mexc         TON-USDT         8h            543        543      8,638      8,095      6.3% ← 8,095 still uncovered
#   201  mexc         TRX-USDT         15m        34,650     34,650     34,654          4    100.0% ← 4 still uncovered
#   202  mexc         TRX-USDT         1d          2,642      2,642      3,095        453     85.4% ← 453 still uncovered
#   203  mexc         TRX-USDT         1h          4,920      4,920     69,059     64,139      7.1% ← 64,139 still uncovered
#   204  mexc         TRX-USDT         1m         42,437     42,437     42,437          0    100.0% ✓
#   205  mexc         TRX-USDT         4h         15,850     15,850     17,265      1,415     91.8% ← 1,415 still uncovered
#   206  mexc         TRX-USDT         5m        103,949    103,949    103,959         10    100.0% ← 10 still uncovered
#   207  mexc         TRX-USDT         8h          7,925      7,925      8,638        713     91.7% ← 713 still uncovered
#   208  mexc         WLD-USDT         15m        34,650     34,650     34,654          4    100.0% ← 4 still uncovered
#   209  mexc         WLD-USDT         1d            205        205      3,095      2,890      6.6% ← 2,890 still uncovered
#   210  mexc         WLD-USDT         1h          4,920      4,920     69,059     64,139      7.1% ← 64,139 still uncovered
#   211  mexc         WLD-USDT         1m         42,437     42,437     42,437          0    100.0% ✓
#   212  mexc         WLD-USDT         4h          1,230      1,230     17,265     16,035      7.1% ← 16,035 still uncovered
#   213  mexc         WLD-USDT         5m        103,949    103,949    103,959         10    100.0% ← 10 still uncovered
#   214  mexc         WLD-USDT         8h            543        543      8,638      8,095      6.3% ← 8,095 still uncovered
#   215  mexc         WLFI-USDT        15m        19,680     19,680     34,654     14,974     56.8% ← 14,974 still uncovered
#   216  mexc         WLFI-USDT        1d            205        205      3,095      2,890      6.6% ← 2,890 still uncovered
#   217  mexc         WLFI-USDT        1h          4,920      4,920     69,059     64,139      7.1% ← 64,139 still uncovered
#   218  mexc         WLFI-USDT        1m         42,437     42,437     42,437          0    100.0% ✓
#   219  mexc         WLFI-USDT        4h          1,230      1,230     17,265     16,035      7.1% ← 16,035 still uncovered
#   220  mexc         WLFI-USDT        5m         57,968     57,968    103,959     45,991     55.8% ← 45,991 still uncovered
#   221  mexc         WLFI-USDT        8h            543        543      8,638      8,095      6.3% ← 8,095 still uncovered
#   222  mexc         WXT-USDT         15m        34,650     34,650     34,654          4    100.0% ← 4 still uncovered
#   223  mexc         WXT-USDT         1d            205        205      3,095      2,890      6.6% ← 2,890 still uncovered
#   224  mexc         WXT-USDT         1h          4,920      4,920     69,059     64,139      7.1% ← 64,139 still uncovered
#   225  mexc         WXT-USDT         1m         42,437     42,437     42,437          0    100.0% ✓
#   226  mexc         WXT-USDT         4h          1,230      1,230     17,265     16,035      7.1% ← 16,035 still uncovered
#   227  mexc         WXT-USDT         5m        103,949    103,949    103,959         10    100.0% ← 10 still uncovered
#   228  mexc         WXT-USDT         8h            543        543      8,638      8,095      6.3% ← 8,095 still uncovered
#   229  mexc         XLM-USDT         15m        34,650     34,650     34,654          4    100.0% ← 4 still uncovered
#   230  mexc         XLM-USDT         1d          2,492      2,492      3,095        603     80.5% ← 603 still uncovered
#   231  mexc         XLM-USDT         1h          4,920      4,920     69,059     64,139      7.1% ← 64,139 still uncovered
#   232  mexc         XLM-USDT         1m         42,437     42,437     42,437          0    100.0% ✓
#   233  mexc         XLM-USDT         4h          1,230      1,230     17,265     16,035      7.1% ← 16,035 still uncovered
#   234  mexc         XLM-USDT         5m        103,948    103,948    103,959         11    100.0% ← 11 still uncovered
#   235  mexc         XLM-USDT         8h          7,475      7,475      8,638      1,163     86.5% ← 1,163 still uncovered
#   236  mexc         XMR-USDC         15m        34,650     34,650     34,654          4    100.0% ← 4 still uncovered
#   237  mexc         XMR-USDC         1d            225        225      3,095      2,870      7.3% ← 2,870 still uncovered
#   238  mexc         XMR-USDC         1h          5,423      5,423     69,059     63,636      7.9% ← 63,636 still uncovered
#   239  mexc         XMR-USDC         1m         42,437     42,437     42,437          0    100.0% ✓
#   240  mexc         XMR-USDC         4h          1,355      1,355     17,265     15,910      7.8% ← 15,910 still uncovered
#   241  mexc         XMR-USDC         5m        103,948    103,948    103,959         11    100.0% ← 11 still uncovered
#   242  mexc         XMR-USDC         8h            543        543      8,638      8,095      6.3% ← 8,095 still uncovered
#   243  mexc         XMR-USDT         15m        34,650     34,650     34,654          4    100.0% ← 4 still uncovered
#   244  mexc         XMR-USDT         1d          2,320      2,320      3,095        775     75.0% ← 775 still uncovered
#   245  mexc         XMR-USDT         1h          5,423      5,423     69,059     63,636      7.9% ← 63,636 still uncovered
#   246  mexc         XMR-USDT         1m         42,437     42,437     42,437          0    100.0% ✓
#   247  mexc         XMR-USDT         4h          1,355      1,355     17,265     15,910      7.8% ← 15,910 still uncovered
#   248  mexc         XMR-USDT         5m        103,948    103,948    103,959         11    100.0% ← 11 still uncovered
#   249  mexc         XMR-USDT         8h            543        543      8,638      8,095      6.3% ← 8,095 still uncovered
#   250  mexc         XRP-USDT         15m        34,650     34,650     34,654          4    100.0% ← 4 still uncovered
#   251  mexc         XRP-USDT         1d          2,537      2,537      3,095        558     82.0% ← 558 still uncovered
#   252  mexc         XRP-USDT         1h          5,319      5,319     69,059     63,740      7.7% ← 63,740 still uncovered
#   253  mexc         XRP-USDT         1m         42,437     42,437     42,437          0    100.0% ✓
#   254  mexc         XRP-USDT         4h          1,329      1,329     17,265     15,936      7.7% ← 15,936 still uncovered
#   255  mexc         XRP-USDT         5m        103,948    103,948    103,959         11    100.0% ← 11 still uncovered
#   256  mexc         XRP-USDT         8h          7,610      7,610      8,638      1,028     88.1% ← 1,028 still uncovered
#   257  mexc         ZRO-USDT         15m        34,650     34,650     34,654          4    100.0% ← 4 still uncovered
#   258  mexc         ZRO-USDT         1d            205        205      3,095      2,890      6.6% ← 2,890 still uncovered
#   259  mexc         ZRO-USDT         1h          4,920      4,920     69,059     64,139      7.1% ← 64,139 still uncovered
#   260  mexc         ZRO-USDT         1m         42,437     42,437     42,437          0    100.0% ✓
#   261  mexc         ZRO-USDT         4h          1,230      1,230     17,265     16,035      7.1% ← 16,035 still uncovered
#   262  mexc         ZRO-USDT         5m        103,948    103,948    103,959         11    100.0% ← 11 still uncovered
#   263  mexc         ZRO-USDT         8h            543        543      8,638      8,095      6.3% ← 8,095 still uncovered
#   264  nonkyc       AAVE-USDT        12h         1,977      1,977      2,163        186     91.4% ← 186 still uncovered
#   265  nonkyc       AAVE-USDT        15m        94,893     94,893    101,209      6,316     93.8% ← 6,316 still uncovered
#   266  nonkyc       AAVE-USDT        1d            989        989      1,086         97     91.1% ← 97 still uncovered
#   267  nonkyc       AAVE-USDT        1h         23,723     23,723     25,944      2,221     91.4% ← 2,221 still uncovered
#   268  nonkyc       AAVE-USDT        4h          5,931      5,931      6,497        566     91.3% ← 566 still uncovered
#   269  nonkyc       AAVE-USDT        5m        284,679    284,679    303,625     18,946     93.8% ← 18,946 still uncovered
#   270  nonkyc       AAVE-USDT        8h          2,966      2,966      3,249        283     91.3% ← 283 still uncovered
#   271  nonkyc       ADA-USDT         12h         1,783      1,783      2,163        380     82.4% ← 380 still uncovered
#   272  nonkyc       ADA-USDT         15m        85,575     85,575    101,209     15,634     84.6% ← 15,634 still uncovered
#   273  nonkyc       ADA-USDT         1d            892        892      1,086        194     82.1% ← 194 still uncovered
#   274  nonkyc       ADA-USDT         1h         21,393     21,393     25,944      4,551     82.5% ← 4,551 still uncovered
#   275  nonkyc       ADA-USDT         4h          5,348      5,348      6,497      1,149     82.3% ← 1,149 still uncovered
#   276  nonkyc       ADA-USDT         5m        256,725    256,725    303,625     46,900     84.6% ← 46,900 still uncovered
#   277  nonkyc       ADA-USDT         8h          2,674      2,674      3,249        575     82.3% ← 575 still uncovered
#   278  nonkyc       ALIAS-XMR        12h           893        893      2,163      1,270     41.3% ← 1,270 still uncovered
#   279  nonkyc       ALIAS-XMR        15m        42,834     42,834    101,209     58,375     42.3% ← 58,375 still uncovered
#   280  nonkyc       ALIAS-XMR        1d            447        447      1,086        639     41.2% ← 639 still uncovered
#   281  nonkyc       ALIAS-XMR        1h         10,708     10,708     25,944     15,236     41.3% ← 15,236 still uncovered
#   282  nonkyc       ALIAS-XMR        4h          2,677      2,677      6,497      3,820     41.2% ← 3,820 still uncovered
#   283  nonkyc       ALIAS-XMR        5m        128,502    128,502    303,625    175,123     42.3% ← 175,123 still uncovered
#   284  nonkyc       ALIAS-XMR        8h          1,339      1,339      3,249      1,910     41.2% ← 1,910 still uncovered
#   285  nonkyc       ARB-USDT         12h         1,993      1,993      2,163        170     92.1% ← 170 still uncovered
#   286  nonkyc       ARB-USDT         15m        95,663     95,663    101,209      5,546     94.5% ← 5,546 still uncovered
#   287  nonkyc       ARB-USDT         1d            997        997      1,086         89     91.8% ← 89 still uncovered
#   288  nonkyc       ARB-USDT         1h         23,915     23,915     25,944      2,029     92.2% ← 2,029 still uncovered
#   289  nonkyc       ARB-USDT         4h          5,979      5,979      6,497        518     92.0% ← 518 still uncovered
#   290  nonkyc       ARB-USDT         5m        286,987    286,987    303,625     16,638     94.5% ← 16,638 still uncovered
#   291  nonkyc       ARB-USDT         8h          2,990      2,990      3,249        259     92.0% ← 259 still uncovered
#   292  nonkyc       ARRR-USDT        12h         2,160      2,160      2,163          3     99.9% ← 3 still uncovered
#   293  nonkyc       ARRR-USDT        15m       101,209    101,209    101,209          0    100.0% ✓
#   294  nonkyc       ARRR-USDT        1d          1,080      1,080      1,086          6     99.4% ← 6 still uncovered
#   295  nonkyc       ARRR-USDT        1h         25,910     25,910     25,944         34     99.9% ← 34 still uncovered
#   296  nonkyc       ARRR-USDT        4h          6,478      6,478      6,497         19     99.7% ← 19 still uncovered
#   297  nonkyc       ARRR-USDT        5m        303,624    303,624    303,625          1    100.0% ← 1 still uncovered
#   298  nonkyc       ARRR-USDT        8h          3,239      3,239      3,249         10     99.7% ← 10 still uncovered
#   299  nonkyc       ARRR-XMR         12h         1,840      1,840      2,163        323     85.1% ← 323 still uncovered
#   300  nonkyc       ARRR-XMR         15m        88,306     88,306    101,209     12,903     87.3% ← 12,903 still uncovered
#   301  nonkyc       ARRR-XMR         1d            920        920      1,086        166     84.7% ← 166 still uncovered
#   302  nonkyc       ARRR-XMR         1h         22,076     22,076     25,944      3,868     85.1% ← 3,868 still uncovered
#   303  nonkyc       ARRR-XMR         4h          5,519      5,519      6,497        978     84.9% ← 978 still uncovered
#   304  nonkyc       ARRR-XMR         5m        264,916    264,916    303,625     38,709     87.3% ← 38,709 still uncovered
#   305  nonkyc       ARRR-XMR         8h          2,760      2,760      3,249        489     84.9% ← 489 still uncovered
#   306  nonkyc       AVAX-USDT        12h         1,489      1,489      2,163        674     68.8% ← 674 still uncovered
#   307  nonkyc       AVAX-USDT        15m        71,445     71,445    101,209     29,764     70.6% ← 29,764 still uncovered
#   308  nonkyc       AVAX-USDT        1d            745        745      1,086        341     68.6% ← 341 still uncovered
#   309  nonkyc       AVAX-USDT        1h         17,861     17,861     25,944      8,083     68.8% ← 8,083 still uncovered
#   310  nonkyc       AVAX-USDT        4h          4,465      4,465      6,497      2,032     68.7% ← 2,032 still uncovered
#   311  nonkyc       AVAX-USDT        5m        214,335    214,335    303,625     89,290     70.6% ← 89,290 still uncovered
#   312  nonkyc       AVAX-USDT        8h          2,233      2,233      3,249      1,016     68.7% ← 1,016 still uncovered
#   313  nonkyc       BCH-USDT         12h         2,161      2,161      2,163          2     99.9% ← 2 still uncovered
#   314  nonkyc       BCH-USDT         15m       101,209    101,209    101,209          0    100.0% ✓
#   315  nonkyc       BCH-USDT         1d          1,081      1,081      1,086          5     99.5% ← 5 still uncovered
#   316  nonkyc       BCH-USDT         1h         25,929     25,929     25,944         15     99.9% ← 15 still uncovered
#   317  nonkyc       BCH-USDT         4h          6,482      6,482      6,497         15     99.8% ← 15 still uncovered
#   318  nonkyc       BCH-USDT         5m        303,625    303,625    303,625          0    100.0% ✓
#   319  nonkyc       BCH-USDT         8h          3,241      3,241      3,249          8     99.8% ← 8 still uncovered
#   320  nonkyc       BDX-USDT         12h           568        568      2,163      1,595     26.3% ← 1,595 still uncovered
#   321  nonkyc       BDX-USDT         15m        27,243     27,243    101,209     73,966     26.9% ← 73,966 still uncovered
#   322  nonkyc       BDX-USDT         1d            284        284      1,086        802     26.2% ← 802 still uncovered
#   323  nonkyc       BDX-USDT         1h          6,810      6,810     25,944     19,134     26.2% ← 19,134 still uncovered
#   324  nonkyc       BDX-USDT         4h          1,703      1,703      6,497      4,794     26.2% ← 4,794 still uncovered
#   325  nonkyc       BDX-USDT         5m         81,728     81,728    303,625    221,897     26.9% ← 221,897 still uncovered
#   326  nonkyc       BDX-USDT         8h            852        852      3,249      2,397     26.2% ← 2,397 still uncovered
#   327  nonkyc       BNB-USDT         12h         2,161      2,161      2,163          2     99.9% ← 2 still uncovered
#   328  nonkyc       BNB-USDT         15m       101,209    101,209    101,209          0    100.0% ✓
#   329  nonkyc       BNB-USDT         1d          1,081      1,081      1,086          5     99.5% ← 5 still uncovered
#   330  nonkyc       BNB-USDT         1h         25,929     25,929     25,944         15     99.9% ← 15 still uncovered
#   331  nonkyc       BNB-USDT         4h          6,482      6,482      6,497         15     99.8% ← 15 still uncovered
#   332  nonkyc       BNB-USDT         5m        303,625    303,625    303,625          0    100.0% ✓
#   333  nonkyc       BNB-USDT         8h          3,241      3,241      3,249          8     99.8% ← 8 still uncovered
#   334  nonkyc       BTC-USDT         12h         2,163      2,163      2,163          0    100.0% ✓
#   335  nonkyc       BTC-USDT         15m       101,209    101,209    101,209          0    100.0% ✓
#   336  nonkyc       BTC-USDT         1d          1,082      1,082      1,086          4     99.6% ← 4 still uncovered
#   337  nonkyc       BTC-USDT         1h         25,931     25,931     25,944         13     99.9% ← 13 still uncovered
#   338  nonkyc       BTC-USDT         4h          6,492      6,492      6,497          5     99.9% ← 5 still uncovered
#   339  nonkyc       BTC-USDT         5m        303,624    303,624    303,625          1    100.0% ← 1 still uncovered
#   340  nonkyc       BTC-USDT         8h          3,246      3,246      3,249          3     99.9% ← 3 still uncovered
#   341  nonkyc       DIVI-USDT        12h           329        329      2,163      1,834     15.2% ← 1,834 still uncovered
#   342  nonkyc       DIVI-USDT        15m        15,790     15,790    101,209     85,419     15.6% ← 85,419 still uncovered
#   343  nonkyc       DIVI-USDT        1d            165        165      1,086        921     15.2% ← 921 still uncovered
#   344  nonkyc       DIVI-USDT        1h          3,947      3,947     25,944     21,997     15.2% ← 21,997 still uncovered
#   345  nonkyc       DIVI-USDT        4h            987        987      6,497      5,510     15.2% ← 5,510 still uncovered
#   346  nonkyc       DIVI-USDT        5m         47,369     47,369    303,625    256,256     15.6% ← 256,256 still uncovered
#   347  nonkyc       DIVI-USDT        8h            494        494      3,249      2,755     15.2% ← 2,755 still uncovered
#   348  nonkyc       DOGE-USDT        12h         2,161      2,161      2,163          2     99.9% ← 2 still uncovered
#   349  nonkyc       DOGE-USDT        15m       101,209    101,209    101,209          0    100.0% ✓
#   350  nonkyc       DOGE-USDT        1d          1,081      1,081      1,086          5     99.5% ← 5 still uncovered
#   351  nonkyc       DOGE-USDT        1h         25,929     25,929     25,944         15     99.9% ← 15 still uncovered
#   352  nonkyc       DOGE-USDT        4h          6,482      6,482      6,497         15     99.8% ← 15 still uncovered
#   353  nonkyc       DOGE-USDT        5m        303,624    303,624    303,625          1    100.0% ← 1 still uncovered
#   354  nonkyc       DOGE-USDT        8h          3,241      3,241      3,249          8     99.8% ← 8 still uncovered
#   355  nonkyc       ENA-USDT         12h           383        383      2,163      1,780     17.7% ← 1,780 still uncovered
#   356  nonkyc       ENA-USDT         15m        18,377     18,377    101,209     82,832     18.2% ← 82,832 still uncovered
#   357  nonkyc       ENA-USDT         1d            192        192      1,086        894     17.7% ← 894 still uncovered
#   358  nonkyc       ENA-USDT         1h          4,594      4,594     25,944     21,350     17.7% ← 21,350 still uncovered
#   359  nonkyc       ENA-USDT         4h          1,149      1,149      6,497      5,348     17.7% ← 5,348 still uncovered
#   360  nonkyc       ENA-USDT         5m         55,131     55,131    303,625    248,494     18.2% ← 248,494 still uncovered
#   361  nonkyc       ENA-USDT         8h            575        575      3,249      2,674     17.7% ← 2,674 still uncovered
#   362  nonkyc       EPIC-USDT        12h           267        267      2,163      1,896     12.3% ← 1,896 still uncovered
#   363  nonkyc       EPIC-USDT        15m        12,782     12,782    101,209     88,427     12.6% ← 88,427 still uncovered
#   364  nonkyc       EPIC-USDT        1d            134        134      1,086        952     12.3% ← 952 still uncovered
#   365  nonkyc       EPIC-USDT        1h          3,195      3,195     25,944     22,749     12.3% ← 22,749 still uncovered
#   366  nonkyc       EPIC-USDT        4h            799        799      6,497      5,698     12.3% ← 5,698 still uncovered
#   367  nonkyc       EPIC-USDT        5m         38,344     38,344    303,625    265,281     12.6% ← 265,281 still uncovered
#   368  nonkyc       EPIC-USDT        8h            400        400      3,249      2,849     12.3% ← 2,849 still uncovered
#   369  nonkyc       EPIC-XMR         12h           267        267      2,163      1,896     12.3% ← 1,896 still uncovered
#   370  nonkyc       EPIC-XMR         15m        12,781     12,781    101,209     88,428     12.6% ← 88,428 still uncovered
#   371  nonkyc       EPIC-XMR         1d            134        134      1,086        952     12.3% ← 952 still uncovered
#   372  nonkyc       EPIC-XMR         1h          3,195      3,195     25,944     22,749     12.3% ← 22,749 still uncovered
#   373  nonkyc       EPIC-XMR         4h            799        799      6,497      5,698     12.3% ← 5,698 still uncovered
#   374  nonkyc       EPIC-XMR         5m         38,341     38,341    303,625    265,284     12.6% ← 265,284 still uncovered
#   375  nonkyc       EPIC-XMR         8h            400        400      3,249      2,849     12.3% ← 2,849 still uncovered
#   376  nonkyc       ERG-USDT         12h         1,870      1,870      2,163        293     86.5% ← 293 still uncovered
#   377  nonkyc       ERG-USDT         15m        89,763     89,763    101,209     11,446     88.7% ← 11,446 still uncovered
#   378  nonkyc       ERG-USDT         1d            935        935      1,086        151     86.1% ← 151 still uncovered
#   379  nonkyc       ERG-USDT         1h         22,440     22,440     25,944      3,504     86.5% ← 3,504 still uncovered
#   380  nonkyc       ERG-USDT         4h          5,610      5,610      6,497        887     86.3% ← 887 still uncovered
#   381  nonkyc       ERG-USDT         5m        269,288    269,288    303,625     34,337     88.7% ← 34,337 still uncovered
#   382  nonkyc       ERG-USDT         8h          2,805      2,805      3,249        444     86.3% ← 444 still uncovered
#   383  nonkyc       ERG-XMR          12h         1,868      1,868      2,163        295     86.4% ← 295 still uncovered
#   384  nonkyc       ERG-XMR          15m        89,626     89,626    101,209     11,583     88.6% ← 11,583 still uncovered
#   385  nonkyc       ERG-XMR          1d            934        934      1,086        152     86.0% ← 152 still uncovered
#   386  nonkyc       ERG-XMR          1h         22,406     22,406     25,944      3,538     86.4% ← 3,538 still uncovered
#   387  nonkyc       ERG-XMR          4h          5,602      5,602      6,497        895     86.2% ← 895 still uncovered
#   388  nonkyc       ERG-XMR          5m        268,878    268,878    303,625     34,747     88.6% ← 34,747 still uncovered
#   389  nonkyc       ERG-XMR          8h          2,801      2,801      3,249        448     86.2% ← 448 still uncovered
#   390  nonkyc       ETH-USDT         12h         2,163      2,163      2,163          0    100.0% ✓
#   391  nonkyc       ETH-USDT         15m       101,209    101,209    101,209          0    100.0% ✓
#   392  nonkyc       ETH-USDT         1d          1,082      1,082      1,086          4     99.6% ← 4 still uncovered
#   393  nonkyc       ETH-USDT         1h         25,929     25,929     25,944         15     99.9% ← 15 still uncovered
#   394  nonkyc       ETH-USDT         4h          6,487      6,487      6,497         10     99.8% ← 10 still uncovered
#   395  nonkyc       ETH-USDT         5m        303,624    303,624    303,625          1    100.0% ← 1 still uncovered
#   396  nonkyc       ETH-USDT         8h          3,244      3,244      3,249          5     99.8% ← 5 still uncovered
#   397  nonkyc       FUSD-XMR         12h           691        691      2,163      1,472     31.9% ← 1,472 still uncovered
#   398  nonkyc       FUSD-XMR         15m        33,138     33,138    101,209     68,071     32.7% ← 68,071 still uncovered
#   399  nonkyc       FUSD-XMR         1d            346        346      1,086        740     31.9% ← 740 still uncovered
#   400  nonkyc       FUSD-XMR         1h          8,284      8,284     25,944     17,660     31.9% ← 17,660 still uncovered
#   401  nonkyc       FUSD-XMR         4h          2,071      2,071      6,497      4,426     31.9% ← 4,426 still uncovered
#   402  nonkyc       FUSD-XMR         5m         99,413     99,413    303,625    204,212     32.7% ← 204,212 still uncovered
#   403  nonkyc       FUSD-XMR         8h          1,036      1,036      3,249      2,213     31.9% ← 2,213 still uncovered
#   404  nonkyc       GHOST-XMR        12h         1,989      1,989      2,163        174     92.0% ← 174 still uncovered
#   405  nonkyc       GHOST-XMR        15m        95,444     95,444    101,209      5,765     94.3% ← 5,765 still uncovered
#   406  nonkyc       GHOST-XMR        1d            995        995      1,086         91     91.6% ← 91 still uncovered
#   407  nonkyc       GHOST-XMR        1h         23,861     23,861     25,944      2,083     92.0% ← 2,083 still uncovered
#   408  nonkyc       GHOST-XMR        4h          5,965      5,965      6,497        532     91.8% ← 532 still uncovered
#   409  nonkyc       GHOST-XMR        5m        286,330    286,330    303,625     17,295     94.3% ← 17,295 still uncovered
#   410  nonkyc       GHOST-XMR        8h          2,983      2,983      3,249        266     91.8% ← 266 still uncovered
#   411  nonkyc       INJ-USDT         12h           383        383      2,163      1,780     17.7% ← 1,780 still uncovered
#   412  nonkyc       INJ-USDT         15m        18,377     18,377    101,209     82,832     18.2% ← 82,832 still uncovered
#   413  nonkyc       INJ-USDT         1d            192        192      1,086        894     17.7% ← 894 still uncovered
#   414  nonkyc       INJ-USDT         1h          4,594      4,594     25,944     21,350     17.7% ← 21,350 still uncovered
#   415  nonkyc       INJ-USDT         4h          1,149      1,149      6,497      5,348     17.7% ← 5,348 still uncovered
#   416  nonkyc       INJ-USDT         5m         55,129     55,129    303,625    248,496     18.2% ← 248,496 still uncovered
#   417  nonkyc       INJ-USDT         8h            575        575      3,249      2,674     17.7% ← 2,674 still uncovered
# ...
#   466  nonkyc       POL-USDT         8h          3,241      3,241      3,249          8     99.8% ← 8 still uncovered
#   467  nonkyc       RVN-USDT         12h         2,005      2,005      2,163        158     92.7% ← 158 still uncovered
#   468  nonkyc       RVN-USDT         15m        96,244     96,244    101,209      4,965     95.1% ← 4,965 still uncovered
#   469  nonkyc       RVN-USDT         1d          1,003      1,003      1,086         83     92.4% ← 83 still uncovered
#   470  nonkyc       RVN-USDT         1h         24,061     24,061     25,944      1,883     92.7% ← 1,883 still uncovered
#   471  nonkyc       RVN-USDT         4h          6,015      6,015      6,497        482     92.6% ← 482 still uncovered
#   472  nonkyc       RVN-USDT         5m        288,731    288,731    303,625     14,894     95.1% ← 14,894 still uncovered
#   473  nonkyc       RVN-USDT         8h          2,981      2,981      3,249        268     91.8% ← 268 still uncovered
#   474  nonkyc       RXD-USDT         12h         1,726      1,726      2,163        437     79.8% ← 437 still uncovered
#   475  nonkyc       RXD-USDT         15m        95,741     95,741    101,209      5,468     94.6% ← 5,468 still uncovered
#   476  nonkyc       RXD-USDT         1d            998        998      1,086         88     91.9% ← 88 still uncovered
#   477  nonkyc       RXD-USDT         1h         23,935     23,935     25,944      2,009     92.3% ← 2,009 still uncovered
#   478  nonkyc       RXD-USDT         4h          5,984      5,984      6,497        513     92.1% ← 513 still uncovered
#   479  nonkyc       RXD-USDT         5m        240,930    240,930    303,625     62,695     79.4% ← 62,695 still uncovered
#   480  nonkyc       RXD-USDT         8h          2,568      2,568      3,249        681     79.0% ← 681 still uncovered
#   481  nonkyc       SAL-USDT         12h         1,211      1,211      2,163        952     56.0% ← 952 still uncovered
#   482  nonkyc       SAL-USDT         15m        58,129     58,129    101,209     43,080     57.4% ← 43,080 still uncovered
#   483  nonkyc       SAL-USDT         1d            606        606      1,086        480     55.8% ← 480 still uncovered
#   484  nonkyc       SAL-USDT         1h         14,532     14,532     25,944     11,412     56.0% ← 11,412 still uncovered
#   485  nonkyc       SAL-USDT         4h          3,633      3,633      6,497      2,864     55.9% ← 2,864 still uncovered
#   486  nonkyc       SAL-USDT         5m        174,387    174,387    303,625    129,238     57.4% ← 129,238 still uncovered
#   487  nonkyc       SAL-USDT         8h          1,817      1,817      3,249      1,432     55.9% ← 1,432 still uncovered
#   488  nonkyc       SHIB-USDT        12h         2,157      2,157      2,163          6     99.7% ← 6 still uncovered
#   489  nonkyc       SHIB-USDT        15m       101,208    101,208    101,209          1    100.0% ← 1 still uncovered
#   490  nonkyc       SHIB-USDT        1d          1,084      1,084      1,086          2     99.8% ← 2 still uncovered
#   491  nonkyc       SHIB-USDT        1h         25,929     25,929     25,944         15     99.9% ← 15 still uncovered
#   492  nonkyc       SHIB-USDT        30m        48,634     48,634     50,605      1,971     96.1% ← 1,971 still uncovered
#   493  nonkyc       SHIB-USDT        4h          6,482      6,482      6,497         15     99.8% ← 15 still uncovered
#   494  nonkyc       SHIB-USDT        5m        271,100    271,100    303,625     32,525     89.3% ← 32,525 still uncovered
#   495  nonkyc       SHIB-USDT        8h          3,232      3,232      3,249         17     99.5% ← 17 still uncovered
#   496  nonkyc       SOL-USDT         12h         1,779      1,779      2,163        384     82.2% ← 384 still uncovered
#   497  nonkyc       SOL-USDT         15m        85,575     85,575    101,209     15,634     84.6% ← 15,634 still uncovered
#   498  nonkyc       SOL-USDT         1d            892        892      1,086        194     82.1% ← 194 still uncovered
#   499  nonkyc       SOL-USDT         1h         21,393     21,393     25,944      4,551     82.5% ← 4,551 still uncovered
#   500  nonkyc       SOL-USDT         4h          5,348      5,348      6,497      1,149     82.3% ← 1,149 still uncovered
#   501  nonkyc       SOL-USDT         5m        246,841    246,841    303,625     56,784     81.3% ← 56,784 still uncovered
#   502  nonkyc       SOL-USDT         8h          2,667      2,667      3,249        582     82.1% ← 582 still uncovered
#   503  nonkyc       TRX-USDT         12h         2,157      2,157      2,163          6     99.7% ← 6 still uncovered
#   504  nonkyc       TRX-USDT         15m       101,209    101,209    101,209          0    100.0% ✓
#   505  nonkyc       TRX-USDT         1d          1,081      1,081      1,086          5     99.5% ← 5 still uncovered
#   506  nonkyc       TRX-USDT         1h         25,929     25,929     25,944         15     99.9% ← 15 still uncovered
#   507  nonkyc       TRX-USDT         4h          6,482      6,482      6,497         15     99.8% ← 15 still uncovered
#   508  nonkyc       TRX-USDT         5m        275,621    275,621    303,625     28,004     90.8% ← 28,004 still uncovered
#   509  nonkyc       TRX-USDT         8h          3,233      3,233      3,249         16     99.5% ← 16 still uncovered
#   510  nonkyc       USDC-USDT        12h         1,976      1,976      2,163        187     91.4% ← 187 still uncovered
#   511  nonkyc       USDC-USDT        15m        94,952     94,952    101,209      6,257     93.8% ← 6,257 still uncovered
#   512  nonkyc       USDC-USDT        1d            990        990      1,086         96     91.2% ← 96 still uncovered
#   513  nonkyc       USDC-USDT        1h         23,738     23,738     25,944      2,206     91.5% ← 2,206 still uncovered
#   514  nonkyc       USDC-USDT        30m        45,652     45,576     50,605      5,029     90.1% ← 5,029 still uncovered
#   515  nonkyc       USDC-USDT        4h          5,935      5,935      6,497        562     91.3% ← 562 still uncovered
#   516  nonkyc       USDC-USDT        5m        263,336    263,336    303,625     40,289     86.7% ← 40,289 still uncovered
#   517  nonkyc       USDC-USDT        8h          2,963      2,963      3,249        286     91.2% ← 286 still uncovered
#   518  nonkyc       VEIL-XMR         12h         1,844      1,844      2,163        319     85.3% ← 319 still uncovered
#   519  nonkyc       VEIL-XMR         15m        90,157     90,157    101,209     11,052     89.1% ← 11,052 still uncovered
#   520  nonkyc       VEIL-XMR         1d            940        940      1,086        146     86.6% ← 146 still uncovered
#   521  nonkyc       VEIL-XMR         1h         22,539     22,539     25,944      3,405     86.9% ← 3,405 still uncovered
#   522  nonkyc       VEIL-XMR         4h          5,635      5,635      6,497        862     86.7% ← 862 still uncovered
#   523  nonkyc       VEIL-XMR         5m        172,992    172,992    303,625    130,633     57.0% ← 130,633 still uncovered
#   524  nonkyc       VEIL-XMR         8h          2,762      2,762      3,249        487     85.0% ← 487 still uncovered
#   525  nonkyc       XKR-XMR          12h         1,281      1,281      2,163        882     59.2% ← 882 still uncovered
#   526  nonkyc       XKR-XMR          15m        56,922     56,922    101,209     44,287     56.2% ← 44,287 still uncovered
#   527  nonkyc       XKR-XMR          1d            641        641      1,086        445     59.0% ← 445 still uncovered
#   528  nonkyc       XKR-XMR          1h         15,373     15,373     25,944     10,571     59.3% ← 10,571 still uncovered
#   529  nonkyc       XKR-XMR          4h          3,845      3,845      6,497      2,652     59.2% ← 2,652 still uncovered
#   530  nonkyc       XKR-XMR          5m        127,779    127,779    303,625    175,846     42.1% ← 175,846 still uncovered
#   531  nonkyc       XKR-XMR          8h          1,921      1,921      3,249      1,328     59.1% ← 1,328 still uncovered
#   532  nonkyc       XMR-BTC          12h         2,154      2,154      2,163          9     99.6% ← 9 still uncovered
#   533  nonkyc       XMR-BTC          15m        95,345     95,345    101,209      5,864     94.2% ← 5,864 still uncovered
#   534  nonkyc       XMR-BTC          1d          1,080      1,080      1,086          6     99.4% ← 6 still uncovered
#   535  nonkyc       XMR-BTC          1h         25,653     25,653     25,944        291     98.9% ← 291 still uncovered
#   536  nonkyc       XMR-BTC          4h          6,445      6,445      6,497         52     99.2% ← 52 still uncovered
#   537  nonkyc       XMR-BTC          5m        239,787    239,787    303,625     63,838     79.0% ← 63,838 still uncovered
#   538  nonkyc       XMR-BTC          8h          3,228      3,228      3,249         21     99.4% ← 21 still uncovered
#   539  nonkyc       XMR-USDT         12h         2,155      2,155      2,163          8     99.6% ← 8 still uncovered
#   540  nonkyc       XMR-USDT         15m        96,965     96,965    101,209      4,244     95.8% ← 4,244 still uncovered
#   541  nonkyc       XMR-USDT         1d          1,080      1,080      1,086          6     99.4% ← 6 still uncovered
#   542  nonkyc       XMR-USDT         1h         25,560     25,560     25,944        384     98.5% ← 384 still uncovered
#   543  nonkyc       XMR-USDT         4h          6,451      6,451      6,497         46     99.3% ← 46 still uncovered
#   544  nonkyc       XMR-USDT         5m        271,317    271,317    303,625     32,308     89.4% ← 32,308 still uncovered
#   545  nonkyc       XMR-USDT         8h          3,231      3,231      3,249         18     99.4% ← 18 still uncovered
#   546  nonkyc       XMR-ZSD          12h         1,823      1,823      2,163        340     84.3% ← 340 still uncovered
#   547  nonkyc       XMR-ZSD          15m        80,984     80,984    101,209     20,225     80.0% ← 20,225 still uncovered
#   548  nonkyc       XMR-ZSD          1d            913        913      1,086        173     84.1% ← 173 still uncovered
#   549  nonkyc       XMR-ZSD          1h         21,878     21,878     25,944      4,066     84.3% ← 4,066 still uncovered
#   550  nonkyc       XMR-ZSD          4h          5,472      5,472      6,497      1,025     84.2% ← 1,025 still uncovered
#   551  nonkyc       XMR-ZSD          5m        175,457    175,457    303,625    128,168     57.8% ← 128,168 still uncovered
#   552  nonkyc       XMR-ZSD          8h          2,734      2,734      3,249        515     84.1% ← 515 still uncovered
#   553  nonkyc       XNV-XMR          12h           155        155      2,163      2,008      7.2% ← 2,008 still uncovered
#   554  nonkyc       XNV-XMR          15m         7,441      7,441    101,209     93,768      7.4% ← 93,768 still uncovered
#   555  nonkyc       XNV-XMR          1d             78         78      1,086      1,008      7.2% ← 1,008 still uncovered
#   556  nonkyc       XNV-XMR          1h          1,860      1,860     25,944     24,084      7.2% ← 24,084 still uncovered
#   557  nonkyc       XNV-XMR          4h            465        465      6,497      6,032      7.2% ← 6,032 still uncovered
#   558  nonkyc       XNV-XMR          5m         22,319     22,319    303,625    281,306      7.4% ← 281,306 still uncovered
#   559  nonkyc       XNV-XMR          8h            233        233      3,249      3,016      7.2% ← 3,016 still uncovered
#   560  nonkyc       XRP-USDT         12h         2,156      2,156      2,163          7     99.7% ← 7 still uncovered
#   561  nonkyc       XRP-USDT         15m        93,357     93,357    101,209      7,852     92.2% ← 7,852 still uncovered
#   562  nonkyc       XRP-USDT         1d          1,080      1,080      1,086          6     99.4% ← 6 still uncovered
#   563  nonkyc       XRP-USDT         1h         25,509     25,509     25,944        435     98.3% ← 435 still uncovered
#   564  nonkyc       XRP-USDT         4h          6,452      6,452      6,497         45     99.3% ← 45 still uncovered
#   565  nonkyc       XRP-USDT         5m        245,580    245,580    303,625     58,045     80.9% ← 58,045 still uncovered
#   566  nonkyc       XRP-USDT         8h          3,232      3,232      3,249         17     99.5% ← 17 still uncovered
#   567  nonkyc       XTM-XMR          12h           653        653      2,163      1,510     30.2% ← 1,510 still uncovered
#   568  nonkyc       XTM-XMR          15m        31,299     31,299    101,209     69,910     30.9% ← 69,910 still uncovered
#   569  nonkyc       XTM-XMR          1d            327        327      1,086        759     30.1% ← 759 still uncovered
#   570  nonkyc       XTM-XMR          1h          7,830      7,830     25,944     18,114     30.2% ← 18,114 still uncovered
#   571  nonkyc       XTM-XMR          4h          1,958      1,958      6,497      4,539     30.1% ← 4,539 still uncovered
#   572  nonkyc       XTM-XMR          5m         93,484     93,484    303,625    210,141     30.8% ← 210,141 still uncovered
#   573  nonkyc       XTM-XMR          8h            979        979      3,249      2,270     30.1% ← 2,270 still uncovered
#   574  nonkyc       ZANO-USDT        12h         1,839      1,839      2,163        324     85.0% ← 324 still uncovered
#   575  nonkyc       ZANO-USDT        15m        80,667     80,667    101,209     20,542     79.7% ← 20,542 still uncovered
#   576  nonkyc       ZANO-USDT        1d            931        931      1,086        155     85.7% ← 155 still uncovered
#   577  nonkyc       ZANO-USDT        1h         21,282     21,282     25,944      4,662     82.0% ← 4,662 still uncovered
#   578  nonkyc       ZANO-USDT        4h          5,425      5,425      6,497      1,072     83.5% ← 1,072 still uncovered
#   579  nonkyc       ZANO-USDT        5m        200,962    200,962    303,625    102,663     66.2% ← 102,663 still uncovered
#   580  nonkyc       ZANO-USDT        8h          2,744      2,744      3,249        505     84.5% ← 505 still uncovered
#   581  nonkyc       ZEC-XMR          12h         1,815      1,815      2,163        348     83.9% ← 348 still uncovered
#   582  nonkyc       ZEC-XMR          15m        70,808     70,808    101,209     30,401     70.0% ← 30,401 still uncovered
#   583  nonkyc       ZEC-XMR          1d            908        908      1,086        178     83.6% ← 178 still uncovered
#   584  nonkyc       ZEC-XMR          1h         21,623     21,623     25,944      4,321     83.3% ← 4,321 still uncovered
#   585  nonkyc       ZEC-XMR          30m        40,929     40,929     50,605      9,676     80.9% ← 9,676 still uncovered
#   586  nonkyc       ZEC-XMR          4h          5,443      5,443      6,497      1,054     83.8% ← 1,054 still uncovered
#   587  nonkyc       ZEC-XMR          5m        152,636    152,636    303,625    150,989     50.3% ← 150,989 still uncovered
#   588  nonkyc       ZEC-XMR          8h          2,722      2,722      3,249        527     83.8% ← 527 still uncovered
#   589  nonkyc       ZSD-USDT         12h         1,825      1,825      2,163        338     84.4% ← 338 still uncovered
#   590  nonkyc       ZSD-USDT         15m        82,291     82,291    101,209     18,918     81.3% ← 18,918 still uncovered
#   591  nonkyc       ZSD-USDT         1d            913        913      1,086        173     84.1% ← 173 still uncovered
#   592  nonkyc       ZSD-USDT         1h         21,878     21,878     25,944      4,066     84.3% ← 4,066 still uncovered
#   593  nonkyc       ZSD-USDT         4h          5,472      5,472      6,497      1,025     84.2% ← 1,025 still uncovered
#   594  nonkyc       ZSD-USDT         5m        189,375    189,375    303,625    114,250     62.4% ← 114,250 still uncovered
#   595  nonkyc       ZSD-USDT         8h          2,737      2,737      3,249        512     84.2% ← 512 still uncovered
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ⚠ 15,775,709 intervals still uncovered (or, for Kraken, not yet scanned and recorded as covered)

# %%
# ── Cell 13 (Optional): Inspect a specific series ──────────────────────────

INSPECT_CONNECTOR = "nonkyc"
INSPECT_PAIR = "XMR-USDT"
INSPECT_INTERVAL = "5m"

step = INTERVAL_SECONDS.get(INSPECT_INTERVAL)
win_start = effective_windows.get((INSPECT_CONNECTOR, INSPECT_INTERVAL))
if step is None or win_start is None:
    print(f"Unknown (exchange, interval): ({INSPECT_CONNECTOR}, {INSPECT_INTERVAL})")
else:
    gaps = find_gaps_in_window(coll, INSPECT_CONNECTOR, INSPECT_PAIR, INSPECT_INTERVAL,
                               step, win_start, utc_now_ts())
    total_missing = sum(((e - s) // step) + 1 for s, e in gaps)
    print(f"Gaps for {INSPECT_CONNECTOR} {INSPECT_PAIR} {INSPECT_INTERVAL}:")
    print(f"  Window start: {fmt_ts(win_start)}")
    print(f"  Total gap ranges: {len(gaps)}")
    print(f"  Total missing candles: {total_missing:,}")
    print()
    for i, (gs, ge) in enumerate(gaps[:20]):
        cnt = ((ge - gs) // step) + 1
        dur_h = cnt * step / 3600
        print(f"  [{i+1:3d}] {fmt_ts(gs)} → {fmt_ts(ge)}  ({cnt:>6,d} candles, {dur_h:>7.1f}h)")
    if len(gaps) > 20:
        print(f"  ... and {len(gaps) - 20} more ranges")
# Out:
# Gaps for nonkyc XMR-USDT 5m:
#   Window start: 2023-05-29 19:42
#   Total gap ranges: 14178
#   Total missing candles: 32,425
#
#   [  1] 2023-05-29 19:40 → 2023-05-29 19:40  (     1 candles,     0.1h)
#   [  2] 2023-05-29 19:55 → 2023-05-29 20:05  (     3 candles,     0.2h)
#   [  3] 2023-05-29 20:15 → 2023-05-29 20:20  (     2 candles,     0.2h)
#   [  4] 2023-05-29 20:30 → 2023-05-29 20:30  (     1 candles,     0.1h)
#   [  5] 2023-05-29 20:55 → 2023-05-29 21:00  (     2 candles,     0.2h)
#   [  6] 2023-05-29 21:10 → 2023-05-29 21:15  (     2 candles,     0.2h)
#   [  7] 2023-05-29 21:35 → 2023-05-29 21:35  (     1 candles,     0.1h)
#   [  8] 2023-05-29 22:05 → 2023-05-29 22:05  (     1 candles,     0.1h)
#   [  9] 2023-05-29 22:20 → 2023-05-29 22:25  (     2 candles,     0.2h)
#   [ 10] 2023-05-29 22:35 → 2023-05-29 22:40  (     2 candles,     0.2h)
#   [ 11] 2023-05-29 22:50 → 2023-05-29 22:50  (     1 candles,     0.1h)
#   [ 12] 2023-05-29 23:00 → 2023-05-29 23:05  (     2 candles,     0.2h)
#   [ 13] 2023-05-29 23:40 → 2023-05-29 23:50  (     3 candles,     0.2h)
#   [ 14] 2023-05-30 00:15 → 2023-05-30 00:15  (     1 candles,     0.1h)
#   [ 15] 2023-05-30 00:25 → 2023-05-30 00:30  (     2 candles,     0.2h)
#   [ 16] 2023-05-30 00:40 → 2023-05-30 00:40  (     1 candles,     0.1h)
#   [ 17] 2023-05-30 00:50 → 2023-05-30 00:55  (     2 candles,     0.2h)
#   [ 18] 2023-05-30 01:05 → 2023-05-30 01:10  (     2 candles,     0.2h)
#   [ 19] 2023-05-30 01:20 → 2023-05-30 01:20  (     1 candles,     0.1h)
#   [ 20] 2023-05-30 01:45 → 2023-05-30 01:50  (     2 candles,     0.2h)
#   ... and 14158 more ranges

# %% [markdown]
# ## Smoke test for NonKYC pacing
#
# Delete this cell + the code cell below after one successful run.
# The code cell issues 20 NonKYC requests and prints the observed throughput.
# Expected: 1.5-3.0 seconds for 20 requests (rate cap 12 req/s + ~300ms RTT).
# If > 10s, pacing is still serialized somewhere — do NOT run Cell 11 yet.

# %%
# Stress smoke test — validates slow-loris mitigation.
# Expected outcome: 100 requests complete in 15-30 seconds with 2 pair-workers
# (6 req/s cap, plus TCP+TLS handshake per request). No single request should
# exceed the 15s read timeout.
import time as _t
from concurrent.futures import ThreadPoolExecutor, as_completed

N_REQUESTS = 100
N_WORKERS = 2

def _one(i):
    t0 = _t.perf_counter()
    try:
        bars = fetch_nonkyc_candles("BTC-USDT", "1h",
                                    to_ts=int(_t.time()) - i*3600, count=100)
        return ("ok", _t.perf_counter() - t0, len(bars))
    except Exception as e:
        return ("err", _t.perf_counter() - t0, str(e))

_start = _t.perf_counter()
with ThreadPoolExecutor(max_workers=N_WORKERS) as pool:
    results = [f.result() for f in as_completed(
        pool.submit(_one, i) for i in range(N_REQUESTS)
    )]
_wall = _t.perf_counter() - _start

ok = [r for r in results if r[0] == "ok"]
err = [r for r in results if r[0] == "err"]
latencies = sorted(r[1] for r in ok)

print(f"Stress smoke test: {N_REQUESTS} requests, {N_WORKERS} workers")
print(f"  Wall time: {_wall:.2f}s = {N_REQUESTS/_wall:.1f} req/s effective")
print(f"  OK: {len(ok)}  Errors: {len(err)}")
if latencies:
    p50 = latencies[len(latencies)//2]
    p95 = latencies[int(len(latencies)*0.95)]
    p99 = latencies[int(len(latencies)*0.99)]
    pmax = latencies[-1]
    print(f"  Latency p50={p50*1000:.0f}ms  p95={p95*1000:.0f}ms  "
          f"p99={p99*1000:.0f}ms  max={pmax*1000:.0f}ms")
print(f"  Bucket stats: {_get_exchange_bucket('nonkyc').stats()}")
print()
if len(err) > 0:
    print(f"  ⚠  Errors occurred:")
    for e in err[:5]:
        print(f"      {e[2]}")
    print(f"      (showing first 5 of {len(err)})")
if latencies and latencies[-1] > 14.5:
    print(f"  ✗ FAIL — at least one request hung near the 15s timeout.")
    print(f"    Slow-loris is still occurring. Do NOT run full backfill.")
elif len(err) > len(ok) * 0.05:
    print(f"  ⚠  >5% errors. Consider lowering rate_per_sec or parallel.")
elif N_REQUESTS / _wall < 4.0:
    print(f"  ⚠  Throughput below 4 req/s — slower than expected with 2 workers.")
    print(f"    May still be fine; try full backfill but watch for stalls.")
else:
    print(f"  ✓ PASS — no stalls, no errors, sustained throughput looks healthy.")
    print(f"    Ready to run Cell 11 for full backfill.")
# Out:
# Stress smoke test: 100 requests, 2 workers
#   Wall time: 23.30s = 4.3 req/s effective
#   OK: 100  Errors: 0
#   Latency p50=485ms  p95=563ms  p99=997ms  max=997ms
#   Bucket stats: {'rate_per_sec': 4.0, 'tokens': 0.0008918042294681072, 'capacity': 8.0}
#
#   ✓ PASS — no stalls, no errors, sustained throughput looks healthy.
#     Ready to run Cell 11 for full backfill.

# %%
# Run the EXACT same ingester function the notebook uses, but serially and
# observably. Just the first few pairs. This isolates whether the hang is in
# the ingester itself or in Cell 11's threading wrapper.

import time

# Force a clean bucket state — reset it so we don't inherit any weirdness
_exchange_buckets.pop("nonkyc", None)

test_cases = [
    ("AAVE-USDT", "12h"),  # pair 1 — writes 0
    ("AAVE-USDT", "15m"),  # pair 2
    ("AAVE-USDT", "1d"),   # pair 3
    ("AAVE-USDT", "1h"),   # pair 4
    ("AAVE-USDT", "4h"),   # pair 5
    ("AAVE-USDT", "8h"),   # pair 6 — the one that hangs
    ("AAVE-USDT", "5m"),   # pair 7
]

for i, (pair, interval) in enumerate(test_cases, 1):
    step = INTERVAL_SECONDS[interval]
    target_days = CFG["interval_targets_days"][interval]
    target_days = min(target_days, CFG["absolute_max_days"])
    end_ts = utc_now_ts()
    start_ts = end_ts - target_days * 86400

    t0 = time.perf_counter()
    try:
        # Call the SAME ingester Cell 11 calls
        written = ingest_nonkyc_range(coll, pair, interval, start_ts, end_ts)
        dt = time.perf_counter() - t0
        print(f"[{i}] {pair} {interval}: wrote {written} in {dt:.1f}s")
    except Exception as e:
        dt = time.perf_counter() - t0
        print(f"[{i}] {pair} {interval}: FAILED after {dt:.1f}s: {type(e).__name__}: {e}")
# Out:
# [1] AAVE-USDT 12h: wrote 5 in 1.4s
#     [nonkyc] AAVE-USDT 15m: 13 reqs, 204 written, 30s elapsed
# [2] AAVE-USDT 15m: wrote 204 in 43.9s
# [3] AAVE-USDT 1d: wrote 3 in 1.5s
# [4] AAVE-USDT 1h: wrote 51 in 11.7s
# [5] AAVE-USDT 4h: wrote 14 in 4.2s
# [6] AAVE-USDT 8h: wrote 7 in 1.8s
#     [nonkyc] AAVE-USDT 5m: 13 reqs, 11 written, 30s elapsed
#     [nonkyc] AAVE-USDT 5m: 25 reqs, 11 written, 61s elapsed
#     [nonkyc] AAVE-USDT 5m: 39 reqs, 11 written, 92s elapsed
# [7] AAVE-USDT 5m: wrote 11 in 115.0s
