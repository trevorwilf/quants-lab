# %% [markdown]
# # Candle Backfill — 180-Day Gap Repair
#
# This notebook connects to your MongoDB `candles` collection, discovers all existing
# (connector, pair, interval) combos, shows gap statistics, and lets you select a
# connector to backfill all missing candles for the last 180 days.
#
# **Prerequisites:**
# ```bash
# pip install pymongo requests pyyaml ipywidgets
# ```

# %%
# ── Cell 1: Configuration ────────────────────────────────────────────────────
import os

TRUENAS_IP      = os.environ.get("TRUENAS_LAN_IP", "192.168.1.54")
TRUENAS_DB_PASS = os.environ.get("MONGO_ROOT_PASSWORD", "mypass")
MONGO_URI = os.environ.get(
    "MONGO_URI",
    f"mongodb://admin:{TRUENAS_DB_PASS}@{TRUENAS_IP}:27017/quants_lab?authSource=admin",
)

MONGO_DATABASE = "quants_lab"
COLLECTION_NAME = "candles"

# How far back to look for gaps (days)
BACKFILL_DAYS = 180

# HTTP tuning
HTTP_TIMEOUT = 30
HTTP_MAX_RETRIES = 3
HTTP_RETRY_BACKOFF = 1.8

# Exchange base URLs
BASE_URLS = {
    "nonkyc": "https://api.nonkyc.io/api/v2",
    "binance": "https://api.binance.com",
    "mexc": "https://api.mexc.com",
    "coinbase": "https://api.exchange.coinbase.com",
}

# Per-exchange request delays (seconds)
REQUEST_DELAYS = {
    "nonkyc": 0.5,
    "binance": 0.12,
    "mexc": 0.2,
    "coinbase": 0.35,
}

# Max candles per API request
MAX_PER_REQUEST = {
    "nonkyc": 500,
    "binance": 1000,
    "mexc": 500,
    "coinbase": 300,
}

# Interval specifications
# max_days: caps how far back we backfill for each interval.
# 1m candles typically only have ~30 days of exchange history;
# 3m ~90 days; everything else defaults to BACKFILL_DAYS.
INTERVAL_SPEC = {
    "1m":  {"seconds": 60,     "binance": "1m",  "mexc": "1m",  "coinbase": 60,    "nonkyc": None,  "max_days": 30},
    "3m":  {"seconds": 180,    "binance": "3m",  "mexc": None,  "coinbase": None,  "nonkyc": None,  "max_days": 90},
    "5m":  {"seconds": 300,    "binance": "5m",  "mexc": "5m",  "coinbase": 300,   "nonkyc": 5,     "max_days": 180},
    "15m": {"seconds": 900,    "binance": "15m", "mexc": "15m", "coinbase": 900,   "nonkyc": 15,    "max_days": 180},
    "30m": {"seconds": 1800,   "binance": "30m", "mexc": "30m", "coinbase": None,  "nonkyc": 30,    "max_days": 180},
    "1h":  {"seconds": 3600,   "binance": "1h",  "mexc": "60m", "coinbase": 3600,  "nonkyc": 60,    "max_days": 180},
    "4h":  {"seconds": 14400,  "binance": "4h",  "mexc": "4h",  "coinbase": None,  "nonkyc": 240,   "max_days": 180},
    "1d":  {"seconds": 86400,  "binance": "1d",  "mexc": "1d",  "coinbase": 86400, "nonkyc": 1440,  "max_days": 180},
}

SCHEMA_VERSION = 3

print("Configuration loaded.")
# Out:
# Configuration loaded.

# %%
# ── Cell 2: Imports & Helpers ────────────────────────────────────────────────

import time
import math
from datetime import datetime, timezone
from typing import Any, Optional

import requests
from pymongo import MongoClient, UpdateOne
from pymongo.errors import BulkWriteError


def utc_now_ts() -> int:
    return int(time.time())


def align_floor(ts: int, step: int) -> int:
    return (ts // step) * step if step > 0 else ts


def last_closed_open_ts(now_ts: int, step: int) -> int:
    return align_floor(now_ts, step) - step


def fmt_ts(ts: int) -> str:
    return datetime.fromtimestamp(ts, tz=timezone.utc).strftime("%Y-%m-%d %H:%M")


def ts_to_iso8601(ts: int) -> str:
    return datetime.fromtimestamp(ts, tz=timezone.utc).isoformat().replace("+00:00", "Z")


def safe_float(x) -> float:
    try:
        return float(x)
    except Exception:
        return float("nan")


def to_hbot_pair(pair: str) -> str:
    p = pair.strip().upper()
    if "/" in p:
        base, quote = p.split("/", 1)
        return f"{base}-{quote}"
    if "_" in p:
        base, quote = p.split("_", 1)
        return f"{base}-{quote}"
    return p.replace("/", "-").replace("_", "-")


def split_hbot_pair(hbot_pair: str):
    return hbot_pair.split("-", 1)


def to_nonkyc_symbol(hbot_pair: str) -> str:
    return hbot_pair.replace("-", "_")


def to_binance_symbol(hbot_pair: str) -> str:
    return hbot_pair.replace("-", "")


def to_mexc_symbol(hbot_pair: str) -> str:
    return hbot_pair.replace("-", "")


def to_coinbase_product_id(hbot_pair: str) -> str:
    return hbot_pair  # already BASE-QUOTE


def compute_qc_flags(o, h, l, c, v):
    flags = []
    if h < max(o, c): flags.append("high_lt_open_close")
    if l > min(o, c): flags.append("low_gt_open_close")
    if h < l: flags.append("high_lt_low")
    if v < 0: flags.append("neg_volume")
    for name, val in [("open", o), ("high", h), ("low", l), ("close", c), ("volume", v)]:
        if val != val: flags.append(f"nan_{name}")
    return flags


print("Helpers loaded.")
# Out:
# Helpers loaded.

# %%
# ── Cell 3: HTTP + MongoDB helpers ───────────────────────────────────────────

session = requests.Session()


def http_get_json(url: str, params: dict = None, prefix: str = "") -> Any:
    """GET + JSON with retries."""
    last_err = None
    for attempt in range(1, HTTP_MAX_RETRIES + 1):
        try:
            resp = session.get(url, params=params, timeout=HTTP_TIMEOUT)
            if resp.status_code in (429, 418):
                retry_after = resp.headers.get("Retry-After")
                sleep_s = float(retry_after) if retry_after else HTTP_RETRY_BACKOFF ** attempt
                print(f"  {prefix}Rate limited (HTTP {resp.status_code}), sleeping {sleep_s:.1f}s")
                time.sleep(sleep_s)
                continue
            if resp.status_code in (500, 502, 503, 504):
                raise RuntimeError(f"HTTP {resp.status_code}: {resp.text[:200]}")
            resp.raise_for_status()
            return resp.json()
        except Exception as e:
            last_err = e
            if attempt >= HTTP_MAX_RETRIES:
                break
            sleep_s = HTTP_RETRY_BACKOFF ** (attempt - 1)
            time.sleep(sleep_s)
    raise last_err


def normalize_candle_doc(
    connector, hbot_pair, interval, ts_open, open_, high, low, close,
    base_volume, interval_seconds, now_ts,
    quote_volume=None, trade_count=None,
    taker_buy_base_volume=None, taker_buy_quote_volume=None,
):
    base, quote = split_hbot_pair(hbot_pair)
    close_ts = ts_open + interval_seconds
    is_closed = close_ts <= now_ts
    qv_estimated = quote_volume is None
    if quote_volume is None:
        vwap = (high + low + close) / 3.0
        quote_volume = base_volume * vwap
    qc_flags = compute_qc_flags(open_, high, low, close, base_volume)

    doc = {
        "schema_version": SCHEMA_VERSION,
        "connector": connector,
        "trading_pair": hbot_pair,
        "interval": interval,
        "timestamp": ts_open,
        "open_ts": ts_open,
        "close_ts": close_ts,
        "is_closed": is_closed,
        "base_asset": base,
        "quote_asset": quote,
        "open": float(open_),
        "high": float(high),
        "low": float(low),
        "close": float(close),
        "volume": float(base_volume),
        "base_volume": float(base_volume),
        "quote_volume": float(quote_volume),
        "quote_volume_is_estimated": qv_estimated,
        "qc_ok": len(qc_flags) == 0,
        "qc_flags": qc_flags,
        "is_synthetic": False,
        "updated_at": now_ts,
    }
    if trade_count is not None: doc["trade_count"] = int(trade_count)
    if taker_buy_base_volume is not None: doc["taker_buy_base_volume"] = float(taker_buy_base_volume)
    if taker_buy_quote_volume is not None: doc["taker_buy_quote_volume"] = float(taker_buy_quote_volume)
    return doc


def upsert_candles(coll, candles, is_backfill=False):
    if not candles:
        return 0
    now_ts = utc_now_ts()
    if is_backfill:
        for c in candles:
            c.setdefault("ingested_at", now_ts)
        try:
            res = coll.insert_many(candles, ordered=False)
            return len(res.inserted_ids)
        except BulkWriteError as bwe:
            return int(bwe.details.get("nInserted", 0))
    ops = []
    for c in candles:
        key = {"connector": c["connector"], "trading_pair": c["trading_pair"],
               "interval": c["interval"], "timestamp": c["timestamp"]}
        ops.append(UpdateOne(key, {"$set": c, "$setOnInsert": {"ingested_at": now_ts}}, upsert=True))
    try:
        res = coll.bulk_write(ops, ordered=False)
        return int(res.upserted_count + res.modified_count)
    except BulkWriteError:
        return 0


print("HTTP + MongoDB helpers loaded.")
# Out:
# HTTP + MongoDB helpers loaded.

# %%
# ── Cell 4: Exchange-specific candle fetchers ────────────────────────────────

def fetch_nonkyc_candles(hbot_pair, interval, to_ts, count):
    spec = INTERVAL_SPEC.get(interval)
    if not spec or spec.get("nonkyc") is None:
        return []
    url = BASE_URLS["nonkyc"].rstrip("/") + "/market/candles"
    params = {
        "symbol": to_nonkyc_symbol(hbot_pair),
        "resolution": int(spec["nonkyc"]),
        "countBack": int(count),
        "to": int(to_ts),
    }
    data = http_get_json(url, params, prefix="[nonkyc] ")
    if not isinstance(data, dict):
        return []
    candles = []
    # Format 1: TradingView UDF arrays
    if data.get("s") == "ok" and "t" in data:
        t_arr = data.get("t", [])
        o_arr = data.get("o", [])
        h_arr = data.get("h", [])
        l_arr = data.get("l", [])
        c_arr = data.get("c", [])
        v_arr = data.get("v", [])
        for i in range(min(len(t_arr), len(o_arr), len(h_arr), len(l_arr), len(c_arr), len(v_arr))):
            candles.append({
                "timestamp": int(int(t_arr[i]) // 1000),
                "open": safe_float(o_arr[i]), "high": safe_float(h_arr[i]),
                "low": safe_float(l_arr[i]), "close": safe_float(c_arr[i]),
                "volume": safe_float(v_arr[i]),
            })
        return candles
    # Format 2: { bars: [...] }
    bars = data.get("bars")
    if isinstance(bars, list):
        for bar in bars:
            if not isinstance(bar, dict): continue
            ts_val = int(bar.get("time", 0))
            if ts_val > 1e12: ts_val = ts_val // 1000
            candles.append({
                "timestamp": ts_val,
                "open": safe_float(bar.get("open")), "high": safe_float(bar.get("high")),
                "low": safe_float(bar.get("low")), "close": safe_float(bar.get("close")),
                "volume": safe_float(bar.get("volume")),
            })
    return candles


def fetch_binance_candles(hbot_pair, interval, start_ms, end_ms, limit):
    spec = INTERVAL_SPEC.get(interval)
    if not spec or spec.get("binance") is None:
        return []
    url = BASE_URLS["binance"].rstrip("/") + "/api/v3/klines"
    params = {"symbol": to_binance_symbol(hbot_pair), "interval": spec["binance"],
              "startTime": int(start_ms), "endTime": int(end_ms), "limit": int(limit)}
    data = http_get_json(url, params, prefix="[binance] ")
    return data if isinstance(data, list) else []


def fetch_mexc_candles(hbot_pair, interval, start_ms, end_ms, limit):
    spec = INTERVAL_SPEC.get(interval)
    if not spec or spec.get("mexc") is None:
        return []
    url = BASE_URLS["mexc"].rstrip("/") + "/api/v3/klines"
    params = {"symbol": to_mexc_symbol(hbot_pair), "interval": spec["mexc"],
              "startTime": int(start_ms), "endTime": int(end_ms), "limit": int(limit)}
    data = http_get_json(url, params, prefix="[mexc] ")
    return data if isinstance(data, list) else []


def fetch_coinbase_candles(hbot_pair, interval, start_ts, end_ts):
    spec = INTERVAL_SPEC.get(interval)
    if not spec or spec.get("coinbase") is None:
        return []
    product_id = to_coinbase_product_id(hbot_pair)
    url = BASE_URLS["coinbase"].rstrip("/") + f"/products/{product_id}/candles"
    params = {"granularity": int(spec["coinbase"]),
              "start": ts_to_iso8601(int(start_ts)), "end": ts_to_iso8601(int(end_ts))}
    data = http_get_json(url, params, prefix="[coinbase] ")
    return data if isinstance(data, list) else []


print("Exchange fetchers loaded.")
# Out:
# Exchange fetchers loaded.

# %%
# ── Cell 5: Range ingesters (per exchange) ──────────────────────────────────

def ingest_nonkyc_range(coll, hbot_pair, interval, start_ts, end_ts):
    spec = INTERVAL_SPEC.get(interval)
    if not spec or spec.get("nonkyc") is None:
        return 0
    step = spec["seconds"]
    now_ts = utc_now_ts()
    max_per = MAX_PER_REQUEST["nonkyc"]
    delay = REQUEST_DELAYS["nonkyc"]
    page_to = end_ts + step - 1
    total = 0
    safety = 0
    while page_to >= start_ts and safety < 100000:
        safety += 1
        bars = fetch_nonkyc_candles(hbot_pair, interval, to_ts=page_to, count=max_per)
        if not bars:
            break
        docs = []
        oldest = None
        for b in bars:
            ts_open = int(b["timestamp"])
            if ts_open < start_ts or ts_open > end_ts:
                continue
            oldest = ts_open if oldest is None else min(oldest, ts_open)
            docs.append(normalize_candle_doc(
                connector="nonkyc", hbot_pair=hbot_pair, interval=interval,
                ts_open=ts_open, open_=b["open"], high=b["high"], low=b["low"],
                close=b["close"], base_volume=b["volume"],
                interval_seconds=step, now_ts=now_ts,
            ))
        if docs:
            total += upsert_candles(coll, docs, is_backfill=True)
        if oldest is None or oldest <= start_ts or oldest >= page_to:
            break
        page_to = oldest - 1
        time.sleep(delay)
    return total


def ingest_binance_range(coll, hbot_pair, interval, start_ts, end_ts):
    spec = INTERVAL_SPEC.get(interval)
    if not spec or spec.get("binance") is None:
        return 0
    step = spec["seconds"]
    now_ts = utc_now_ts()
    max_per = MAX_PER_REQUEST["binance"]
    delay = REQUEST_DELAYS["binance"]
    cur = start_ts
    total = 0
    safety = 0
    while cur <= end_ts and safety < 100000:
        safety += 1
        window_end = min(cur + (max_per - 1) * step, end_ts)
        rows = fetch_binance_candles(hbot_pair, interval, cur * 1000, window_end * 1000, max_per)
        if not rows:
            cur = window_end + step
            time.sleep(delay)
            continue
        docs = []
        max_row_ts = None
        for r in rows:
            ts_open = int(r[0]) // 1000
            if ts_open < start_ts or ts_open > end_ts:
                continue
            max_row_ts = ts_open if max_row_ts is None else max(max_row_ts, ts_open)
            docs.append(normalize_candle_doc(
                connector="binance", hbot_pair=hbot_pair, interval=interval,
                ts_open=ts_open, open_=safe_float(r[1]), high=safe_float(r[2]),
                low=safe_float(r[3]), close=safe_float(r[4]),
                base_volume=safe_float(r[5]), interval_seconds=step, now_ts=now_ts,
                quote_volume=safe_float(r[7]),
                trade_count=int(r[8]) if len(r) > 8 else None,
                taker_buy_base_volume=safe_float(r[9]) if len(r) > 9 else None,
                taker_buy_quote_volume=safe_float(r[10]) if len(r) > 10 else None,
            ))
        if docs:
            total += upsert_candles(coll, docs, is_backfill=True)
        cur = (max_row_ts + step) if max_row_ts else (cur + max_per * step)
        time.sleep(delay)
    return total


def ingest_mexc_range(coll, hbot_pair, interval, start_ts, end_ts):
    spec = INTERVAL_SPEC.get(interval)
    if not spec or spec.get("mexc") is None:
        return 0
    step = spec["seconds"]
    now_ts = utc_now_ts()
    max_per = MAX_PER_REQUEST["mexc"]
    delay = REQUEST_DELAYS["mexc"]
    cur = start_ts
    total = 0
    safety = 0
    while cur <= end_ts and safety < 100000:
        safety += 1
        window_end = min(cur + (max_per - 1) * step, end_ts)
        rows = fetch_mexc_candles(hbot_pair, interval, cur * 1000, window_end * 1000, max_per)
        if not rows:
            cur = window_end + step
            time.sleep(delay)
            continue
        docs = []
        max_row_ts = None
        for r in rows:
            ts_open = int(r[0]) // 1000
            if ts_open < start_ts or ts_open > end_ts:
                continue
            max_row_ts = ts_open if max_row_ts is None else max(max_row_ts, ts_open)
            docs.append(normalize_candle_doc(
                connector="mexc", hbot_pair=hbot_pair, interval=interval,
                ts_open=ts_open, open_=safe_float(r[1]), high=safe_float(r[2]),
                low=safe_float(r[3]), close=safe_float(r[4]),
                base_volume=safe_float(r[5]), interval_seconds=step, now_ts=now_ts,
                quote_volume=safe_float(r[7]) if len(r) > 7 else None,
            ))
        if docs:
            total += upsert_candles(coll, docs, is_backfill=True)
        cur = (max_row_ts + step) if max_row_ts else (cur + max_per * step)
        time.sleep(delay)
    return total


def ingest_coinbase_range(coll, hbot_pair, interval, start_ts, end_ts):
    spec = INTERVAL_SPEC.get(interval)
    if not spec or spec.get("coinbase") is None:
        return 0
    step = spec["seconds"]
    now_ts = utc_now_ts()
    max_per = MAX_PER_REQUEST["coinbase"]
    delay = REQUEST_DELAYS["coinbase"]
    cur = start_ts
    total = 0
    safety = 0
    while cur <= end_ts and safety < 100000:
        safety += 1
        window_end = min(cur + (max_per - 1) * step, end_ts)
        rows = fetch_coinbase_candles(hbot_pair, interval, cur, window_end)
        if not rows:
            cur = window_end + step
            time.sleep(delay)
            continue
        docs = []
        max_row_ts = None
        # Coinbase format: [time, low, high, open, close, volume] — time in seconds
        for r in rows:
            ts_open = int(r[0])
            if ts_open < start_ts or ts_open > end_ts:
                continue
            max_row_ts = ts_open if max_row_ts is None else max(max_row_ts, ts_open)
            docs.append(normalize_candle_doc(
                connector="coinbase", hbot_pair=hbot_pair, interval=interval,
                ts_open=ts_open, open_=safe_float(r[3]), high=safe_float(r[2]),
                low=safe_float(r[1]), close=safe_float(r[4]),
                base_volume=safe_float(r[5]), interval_seconds=step, now_ts=now_ts,
            ))
        if docs:
            total += upsert_candles(coll, docs, is_backfill=True)
        cur = (max_row_ts + step) if max_row_ts else (cur + max_per * step)
        time.sleep(delay)
    return total


INGESTERS = {
    "nonkyc": ingest_nonkyc_range,
    "binance": ingest_binance_range,
    "mexc": ingest_mexc_range,
    "coinbase": ingest_coinbase_range,
}

print("Range ingesters loaded.")
# Out:
# Range ingesters loaded.

# %%
# ── Cell 6: Connect to MongoDB & discover all combos ─────────────────────────

client = MongoClient(MONGO_URI, serverSelectionTimeoutMS=10000)
client.admin.command("ping")
db = client[MONGO_DATABASE]
coll = db[COLLECTION_NAME]

# Ensure indexes
coll.create_index(
    [("connector", 1), ("trading_pair", 1), ("interval", 1), ("timestamp", 1)],
    unique=True, name="idx_connector_pair_interval_ts",
)

print(f"Connected to MongoDB: {MONGO_URI.split('@')[-1]}")
print(f"Database: {MONGO_DATABASE}, Collection: {COLLECTION_NAME}")
print(f"Total documents: {coll.estimated_document_count():,}")
# Out:
# Connected to MongoDB: 192.168.1.54:27017/quants_lab?authSource=admin&retryWrites=true&w=majority
# Database: quants_lab, Collection: candles
# Total documents: 9,300,635

# %%
# ── Cell 7: Scan all combos and compute gap statistics ───────────────────────

now_ts = utc_now_ts()
# Global window_start used as the *maximum* lookback (for display / grouping).
# Per-interval effective window is capped by INTERVAL_SPEC["max_days"].
window_start = now_ts - BACKFILL_DAYS * 86400

# Aggregation: discover all (connector, pair, interval) combos
pipeline = [
    {"$group": {
        "_id": {"connector": "$connector", "trading_pair": "$trading_pair", "interval": "$interval"},
        "count": {"$sum": 1},
        "min_ts": {"$min": "$timestamp"},
        "max_ts": {"$max": "$timestamp"},
    }},
    {"$sort": {"_id.connector": 1, "_id.trading_pair": 1, "_id.interval": 1}},
]

raw_combos = list(coll.aggregate(pipeline, allowDiskUse=True))

combos = []
for doc in raw_combos:
    connector = doc["_id"]["connector"]
    pair = doc["_id"]["trading_pair"]
    interval = doc["_id"]["interval"]
    spec = INTERVAL_SPEC.get(interval)
    if not spec:
        continue
    step = spec["seconds"]
    # Per-interval lookback: use the smaller of BACKFILL_DAYS and the
    # interval's max_days so we don't chase history that doesn't exist.
    interval_max_days = spec.get("max_days", BACKFILL_DAYS)
    combo_window_start = now_ts - min(BACKFILL_DAYS, interval_max_days) * 86400
    min_ts = max(int(doc["min_ts"]), combo_window_start)
    max_ts = int(doc["max_ts"])
    
    # Count candles in this interval's window
    candles_in_window = coll.count_documents({
        "connector": connector, "trading_pair": pair, "interval": interval,
        "timestamp": {"$gte": combo_window_start}
    })
    
    # Expected candles in the interval-specific window (up to last closed candle)
    effective_start = align_floor(combo_window_start, step)
    effective_end = last_closed_open_ts(now_ts, step)
    expected = ((effective_end - effective_start) // step) + 1 if effective_end >= effective_start else 0
    missing = max(0, expected - candles_in_window)
    pct_complete = (candles_in_window / expected * 100) if expected > 0 else 100.0
    
    combos.append({
        "connector": connector,
        "pair": pair,
        "interval": interval,
        "total_docs": int(doc["count"]),
        "in_window": candles_in_window,
        "expected": expected,
        "missing": missing,
        "pct": pct_complete,
        "step": step,
        "window_start": combo_window_start,  # per-interval lookback
    })

# Group by connector for display
connectors_found = sorted(set(c["connector"] for c in combos))

print(f"Found {len(combos)} (connector, pair, interval) combos across {len(connectors_found)} connector(s)")
print(f"Default window: {fmt_ts(window_start)} → {fmt_ts(now_ts)}  (per-interval caps apply)")

# ── Connector summary ──
print(f"\nConnector Summary:")
for cidx, conn in enumerate(connectors_found):
    conn_combos = [c for c in combos if c["connector"] == conn]
    total_missing = sum(c["missing"] for c in conn_combos)
    pairs_count = len(set(c["pair"] for c in conn_combos))
    intervals_count = len(set(c["interval"] for c in conn_combos))
    row_indices = [i for i, c in enumerate(combos) if c["connector"] == conn]
    print(f"  {conn:12s} — {pairs_count} pairs × {intervals_count} intervals = {len(conn_combos)} series, "
          f"{total_missing:,} missing  (rows {row_indices[0]}–{row_indices[-1]})")

# ── Detail table with row index ──
print(f"\n{'─' * 100}")
print(f"{'Idx':>5s}  {'Connector':12s} {'Pair':16s} {'Intv':6s} {'In Window':>10s} {'Expected':>10s} {'Missing':>10s} {'Complete':>9s}")
print(f"{'─' * 100}")
for i, c in enumerate(combos):
    flag = " ✓" if c["missing"] == 0 else f" ← {c['missing']:,}"
    print(f"{i:>5d}  {c['connector']:12s} {c['pair']:16s} {c['interval']:6s} "
          f"{c['in_window']:>10,d} {c['expected']:>10,d} {c['missing']:>10,d} {c['pct']:>8.1f}%{flag}")
print(f"{'─' * 100}")
print(f"\nUse these indices in Cell 8 to select what to backfill.")
# Out:
# Found 444 (connector, pair, interval) combos across 3 connector(s)
# Default window: 2025-10-06 00:22 → 2026-04-04 00:22  (per-interval caps apply)
#
# Connector Summary:
#   coinbase     — 3 pairs × 5 intervals = 15 series, 129 missing  (rows 0–14)
#   mexc         — 32 pairs × 6 intervals = 192 series, 2,123 missing  (rows 15–206)
#   nonkyc       — 47 pairs × 6 intervals = 237 series, 495,170 missing  (rows 207–443)
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   Idx  Connector    Pair             Intv    In Window   Expected    Missing  Complete
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#     0  coinbase     BTC-USD          15m        17,277     17,280          3    100.0% ← 3
#     1  coinbase     BTC-USD          1d            178        180          2     98.9% ← 2
#     2  coinbase     BTC-USD          1h          4,318      4,320          2    100.0% ← 2
#     3  coinbase     BTC-USD          1m         43,171     43,200         29     99.9% ← 29
#     4  coinbase     BTC-USD          5m         51,833     51,840          7    100.0% ← 7
#     5  coinbase     ETH-USD          15m        17,277     17,280          3    100.0% ← 3
#     6  coinbase     ETH-USD          1d            178        180          2     98.9% ← 2
#     7  coinbase     ETH-USD          1h          4,318      4,320          2    100.0% ← 2
#     8  coinbase     ETH-USD          1m         43,171     43,200         29     99.9% ← 29
#     9  coinbase     ETH-USD          5m         51,833     51,840          7    100.0% ← 7
#    10  coinbase     USDT-USD         15m        17,277     17,280          3    100.0% ← 3
#    11  coinbase     USDT-USD         1d            178        180          2     98.9% ← 2
#    12  coinbase     USDT-USD         1h          4,318      4,320          2    100.0% ← 2
#    13  coinbase     USDT-USD         1m         43,171     43,200         29     99.9% ← 29
#    14  coinbase     USDT-USD         5m         51,833     51,840          7    100.0% ← 7
#    15  mexc         ADA-USDT         15m        17,276     17,280          4    100.0% ← 4
#    16  mexc         ADA-USDT         1d            177        180          3     98.3% ← 3
#    17  mexc         ADA-USDT         1h          4,317      4,320          3     99.9% ← 3
#    18  mexc         ADA-USDT         1m         43,170     43,200         30     99.9% ← 30
#    19  mexc         ADA-USDT         4h          1,077      1,080          3     99.7% ← 3
#    20  mexc         ADA-USDT         5m         51,833     51,840          7    100.0% ← 7
#    21  mexc         APT-USDT         15m        17,276     17,280          4    100.0% ← 4
#    22  mexc         APT-USDT         1d            177        180          3     98.3% ← 3
#    23  mexc         APT-USDT         1h          4,317      4,320          3     99.9% ← 3
#    24  mexc         APT-USDT         1m         43,172     43,200         28     99.9% ← 28
#    25  mexc         APT-USDT         4h          1,077      1,080          3     99.7% ← 3
#    26  mexc         APT-USDT         5m         51,833     51,840          7    100.0% ← 7
#    27  mexc         ASTER-USDT       15m        17,276     17,280          4    100.0% ← 4
#    28  mexc         ASTER-USDT       1d            177        180          3     98.3% ← 3
#    29  mexc         ASTER-USDT       1h          4,317      4,320          3     99.9% ← 3
#    30  mexc         ASTER-USDT       1m         43,175     43,200         25     99.9% ← 25
#    31  mexc         ASTER-USDT       4h          1,078      1,080          2     99.8% ← 2
#    32  mexc         ASTER-USDT       5m         51,834     51,840          6    100.0% ← 6
#    33  mexc         ATOM-USDT        15m        17,277     17,280          3    100.0% ← 3
#    34  mexc         ATOM-USDT        1d            178        180          2     98.9% ← 2
#    35  mexc         ATOM-USDT        1h          4,318      4,320          2    100.0% ← 2
#    36  mexc         ATOM-USDT        1m         43,177     43,200         23     99.9% ← 23
#    37  mexc         ATOM-USDT        4h          1,078      1,080          2     99.8% ← 2
#    38  mexc         ATOM-USDT        5m         51,834     51,840          6    100.0% ← 6
#    39  mexc         BNB-USDT         15m        17,277     17,280          3    100.0% ← 3
#    40  mexc         BNB-USDT         1d            178        180          2     98.9% ← 2
#    41  mexc         BNB-USDT         1h          4,318      4,320          2    100.0% ← 2
#    42  mexc         BNB-USDT         1m         43,180     43,200         20    100.0% ← 20
#    43  mexc         BNB-USDT         4h          1,078      1,080          2     99.8% ← 2
#    44  mexc         BNB-USDT         5m         51,835     51,840          5    100.0% ← 5
#    45  mexc         BTC-USDT         15m        17,277     17,280          3    100.0% ← 3
#    46  mexc         BTC-USDT         1d            178        180          2     98.9% ← 2
#    47  mexc         BTC-USDT         1h          4,318      4,320          2    100.0% ← 2
#    48  mexc         BTC-USDT         1m         43,181     43,200         19    100.0% ← 19
#    49  mexc         BTC-USDT         4h          1,078      1,080          2     99.8% ← 2
#    50  mexc         BTC-USDT         5m         51,835     51,840          5    100.0% ← 5
#    51  mexc         DOGE-USDT        15m        17,277     17,280          3    100.0% ← 3
#    52  mexc         DOGE-USDT        1d            178        180          2     98.9% ← 2
#    53  mexc         DOGE-USDT        1h          4,318      4,320          2    100.0% ← 2
#    54  mexc         DOGE-USDT        1m         43,184     43,200         16    100.0% ← 16
#    55  mexc         DOGE-USDT        4h          1,078      1,080          2     99.8% ← 2
#    56  mexc         DOGE-USDT        5m         51,836     51,840          4    100.0% ← 4
#    57  mexc         DOT-USDT         15m        17,277     17,280          3    100.0% ← 3
#    58  mexc         DOT-USDT         1d            178        180          2     98.9% ← 2
#    59  mexc         DOT-USDT         1h          4,318      4,320          2    100.0% ← 2
#    60  mexc         DOT-USDT         1m         43,187     43,200         13    100.0% ← 13
#    61  mexc         DOT-USDT         4h          1,078      1,080          2     99.8% ← 2
#    62  mexc         DOT-USDT         5m         51,836     51,840          4    100.0% ← 4
#    63  mexc         ETH-USDT         15m        17,277     17,280          3    100.0% ← 3
#    64  mexc         ETH-USDT         1d            178        180          2     98.9% ← 2
#    65  mexc         ETH-USDT         1h          4,318      4,320          2    100.0% ← 2
#    66  mexc         ETH-USDT         1m         43,189     43,200         11    100.0% ← 11
#    67  mexc         ETH-USDT         4h          1,078      1,080          2     99.8% ← 2
#    68  mexc         ETH-USDT         5m         51,837     51,840          3    100.0% ← 3
#    69  mexc         FET-USDT         15m        17,276     17,280          4    100.0% ← 4
#    70  mexc         FET-USDT         1d            177        180          3     98.3% ← 3
#    71  mexc         FET-USDT         1h          4,317      4,320          3     99.9% ← 3
#    72  mexc         FET-USDT         1m         43,166     43,200         34     99.9% ← 34
#    73  mexc         FET-USDT         4h          1,077      1,080          3     99.7% ← 3
#    74  mexc         FET-USDT         5m         51,832     51,840          8    100.0% ← 8
#    75  mexc         HYPE-USDT        15m        17,278     17,280          2    100.0% ← 2
#    76  mexc         HYPE-USDT        1d            178        180          2     98.9% ← 2
#    77  mexc         HYPE-USDT        1h          4,318      4,320          2    100.0% ← 2
#    78  mexc         HYPE-USDT        1m         43,191     43,200          9    100.0% ← 9
#    79  mexc         HYPE-USDT        4h          1,078      1,080          2     99.8% ← 2
#    80  mexc         HYPE-USDT        5m         51,836     51,840          4    100.0% ← 4
#    81  mexc         ICP-USDT         15m        17,278     17,280          2    100.0% ← 2
#    82  mexc         ICP-USDT         1d            178        180          2     98.9% ← 2
#    83  mexc         ICP-USDT         1h          4,318      4,320          2    100.0% ← 2
#    84  mexc         ICP-USDT         1m         43,168     43,200         32     99.9% ← 32
#    85  mexc         ICP-USDT         4h          1,077      1,080          3     99.7% ← 3
#    86  mexc         ICP-USDT         5m         51,832     51,840          8    100.0% ← 8
#    87  mexc         LTC-USDT         15m        17,276     17,280          4    100.0% ← 4
#    88  mexc         LTC-USDT         1d            177        180          3     98.3% ← 3
#    89  mexc         LTC-USDT         1h          4,317      4,320          3     99.9% ← 3
#    90  mexc         LTC-USDT         1m         43,092     43,200        108     99.8% ← 108
#    91  mexc         LTC-USDT         4h          1,077      1,080          3     99.7% ← 3
#    92  mexc         LTC-USDT         5m         51,832     51,840          8    100.0% ← 8
#    93  mexc         OP-USDT          15m        17,276     17,280          4    100.0% ← 4
#    94  mexc         OP-USDT          1d            177        180          3     98.3% ← 3
#    95  mexc         OP-USDT          1h          4,317      4,320          3     99.9% ← 3
#    96  mexc         OP-USDT          1m         43,166     43,200         34     99.9% ← 34
#    97  mexc         OP-USDT          4h          1,077      1,080          3     99.7% ← 3
#    98  mexc         OP-USDT          5m         51,832     51,840          8    100.0% ← 8
#    99  mexc         PEPE-USDT        15m        17,276     17,280          4    100.0% ← 4
#   100  mexc         PEPE-USDT        1d            177        180          3     98.3% ← 3
#   101  mexc         PEPE-USDT        1h          4,317      4,320          3     99.9% ← 3
#   102  mexc         PEPE-USDT        1m         43,166     43,200         34     99.9% ← 34
#   103  mexc         PEPE-USDT        4h          1,077      1,080          3     99.7% ← 3
#   104  mexc         PEPE-USDT        5m         51,832     51,840          8    100.0% ← 8
#   105  mexc         PUMP-USDT        15m        17,276     17,280          4    100.0% ← 4
#   106  mexc         PUMP-USDT        1d            177        180          3     98.3% ← 3
#   107  mexc         PUMP-USDT        1h          4,317      4,320          3     99.9% ← 3
#   108  mexc         PUMP-USDT        1m         43,096     43,200        104     99.8% ← 104
#   109  mexc         PUMP-USDT        4h          1,077      1,080          3     99.7% ← 3
#   110  mexc         PUMP-USDT        5m         51,832     51,840          8    100.0% ← 8
#   111  mexc         RENDER-USDT      15m        17,276     17,280          4    100.0% ← 4
#   112  mexc         RENDER-USDT      1d            177        180          3     98.3% ← 3
#   113  mexc         RENDER-USDT      1h          4,317      4,320          3     99.9% ← 3
#   114  mexc         RENDER-USDT      1m         43,166     43,200         34     99.9% ← 34
#   115  mexc         RENDER-USDT      4h          1,077      1,080          3     99.7% ← 3
#   116  mexc         RENDER-USDT      5m         51,832     51,840          8    100.0% ← 8
#   117  mexc         SAHARA-USDT      15m        17,276     17,280          4    100.0% ← 4
#   118  mexc         SAHARA-USDT      1d            177        180          3     98.3% ← 3
#   119  mexc         SAHARA-USDT      1h          4,317      4,320          3     99.9% ← 3
#   120  mexc         SAHARA-USDT      1m         43,076     43,200        124     99.7% ← 124
#   121  mexc         SAHARA-USDT      4h          1,077      1,080          3     99.7% ← 3
#   122  mexc         SAHARA-USDT      5m         51,832     51,840          8    100.0% ← 8
#   123  mexc         SAL-USDT         15m        17,276     17,280          4    100.0% ← 4
#   124  mexc         SAL-USDT         1d            177        180          3     98.3% ← 3
#   125  mexc         SAL-USDT         1h          4,317      4,320          3     99.9% ← 3
#   126  mexc         SAL-USDT         1m         43,166     43,200         34     99.9% ← 34
#   127  mexc         SAL-USDT         4h          1,077      1,080          3     99.7% ← 3
#   128  mexc         SAL-USDT         5m         51,832     51,840          8    100.0% ← 8
#   129  mexc         SHIB-USDT        15m        17,276     17,280          4    100.0% ← 4
#   130  mexc         SHIB-USDT        1d            177        180          3     98.3% ← 3
#   131  mexc         SHIB-USDT        1h          4,317      4,320          3     99.9% ← 3
#   132  mexc         SHIB-USDT        1m         43,166     43,200         34     99.9% ← 34
#   133  mexc         SHIB-USDT        4h          1,077      1,080          3     99.7% ← 3
#   134  mexc         SHIB-USDT        5m         51,832     51,840          8    100.0% ← 8
#   135  mexc         SOL-USDT         15m        17,276     17,280          4    100.0% ← 4
#   136  mexc         SOL-USDT         1d            177        180          3     98.3% ← 3
#   137  mexc         SOL-USDT         1h          4,317      4,320          3     99.9% ← 3
#   138  mexc         SOL-USDT         1m         43,093     43,200        107     99.8% ← 107
#   139  mexc         SOL-USDT         4h          1,077      1,080          3     99.7% ← 3
#   140  mexc         SOL-USDT         5m         51,830     51,840         10    100.0% ← 10
#   141  mexc         SUI-USDT         15m        17,276     17,280          4    100.0% ← 4
#   142  mexc         SUI-USDT         1d            177        180          3     98.3% ← 3
#   143  mexc         SUI-USDT         1h          4,317      4,320          3     99.9% ← 3
#   144  mexc         SUI-USDT         1m         43,167     43,200         33     99.9% ← 33
#   145  mexc         SUI-USDT         4h          1,077      1,080          3     99.7% ← 3
#   146  mexc         SUI-USDT         5m         51,832     51,840          8    100.0% ← 8
#   147  mexc         TON-USDT         15m        17,276     17,280          4    100.0% ← 4
#   148  mexc         TON-USDT         1d            177        180          3     98.3% ← 3
#   149  mexc         TON-USDT         1h          4,317      4,320          3     99.9% ← 3
#   150  mexc         TON-USDT         1m         43,166     43,200         34     99.9% ← 34
#   151  mexc         TON-USDT         4h          1,077      1,080          3     99.7% ← 3
#   152  mexc         TON-USDT         5m         51,832     51,840          8    100.0% ← 8
#   153  mexc         TRX-USDT         15m        17,276     17,280          4    100.0% ← 4
#   154  mexc         TRX-USDT         1d            177        180          3     98.3% ← 3
#   155  mexc         TRX-USDT         1h          4,317      4,320          3     99.9% ← 3
#   156  mexc         TRX-USDT         1m         43,166     43,200         34     99.9% ← 34
#   157  mexc         TRX-USDT         4h          1,077      1,080          3     99.7% ← 3
#   158  mexc         TRX-USDT         5m         51,832     51,840          8    100.0% ← 8
#   159  mexc         WLD-USDT         15m        17,276     17,280          4    100.0% ← 4
#   160  mexc         WLD-USDT         1d            177        180          3     98.3% ← 3
#   161  mexc         WLD-USDT         1h          4,317      4,320          3     99.9% ← 3
#   162  mexc         WLD-USDT         1m         43,166     43,200         34     99.9% ← 34
#   163  mexc         WLD-USDT         4h          1,077      1,080          3     99.7% ← 3
#   164  mexc         WLD-USDT         5m         51,832     51,840          8    100.0% ← 8
#   165  mexc         WLFI-USDT        15m        17,276     17,280          4    100.0% ← 4
#   166  mexc         WLFI-USDT        1d            177        180          3     98.3% ← 3
#   167  mexc         WLFI-USDT        1h          4,317      4,320          3     99.9% ← 3
#   168  mexc         WLFI-USDT        1m         43,166     43,200         34     99.9% ← 34
#   169  mexc         WLFI-USDT        4h          1,077      1,080          3     99.7% ← 3
#   170  mexc         WLFI-USDT        5m         51,832     51,840          8    100.0% ← 8
#   171  mexc         WXT-USDT         15m        17,276     17,280          4    100.0% ← 4
#   172  mexc         WXT-USDT         1d            177        180          3     98.3% ← 3
#   173  mexc         WXT-USDT         1h          4,317      4,320          3     99.9% ← 3
#   174  mexc         WXT-USDT         1m         43,166     43,200         34     99.9% ← 34
#   175  mexc         WXT-USDT         4h          1,077      1,080          3     99.7% ← 3
#   176  mexc         WXT-USDT         5m         51,832     51,840          8    100.0% ← 8
#   177  mexc         XLM-USDT         15m        17,276     17,280          4    100.0% ← 4
#   178  mexc         XLM-USDT         1d            177        180          3     98.3% ← 3
#   179  mexc         XLM-USDT         1h          4,317      4,320          3     99.9% ← 3
#   180  mexc         XLM-USDT         1m         43,166     43,200         34     99.9% ← 34
#   181  mexc         XLM-USDT         4h          1,077      1,080          3     99.7% ← 3
#   182  mexc         XLM-USDT         5m         51,832     51,840          8    100.0% ← 8
#   183  mexc         XMR-USDC         15m        17,276     17,280          4    100.0% ← 4
#   184  mexc         XMR-USDC         1d            177        180          3     98.3% ← 3
#   185  mexc         XMR-USDC         1h          4,317      4,320          3     99.9% ← 3
#   186  mexc         XMR-USDC         1m         43,120     43,200         80     99.8% ← 80
#   187  mexc         XMR-USDC         4h          1,077      1,080          3     99.7% ← 3
#   188  mexc         XMR-USDC         5m         51,832     51,840          8    100.0% ← 8
#   189  mexc         XMR-USDT         15m        17,276     17,280          4    100.0% ← 4
#   190  mexc         XMR-USDT         1d            177        180          3     98.3% ← 3
#   191  mexc         XMR-USDT         1h          4,317      4,320          3     99.9% ← 3
#   192  mexc         XMR-USDT         1m         43,098     43,200        102     99.8% ← 102
#   193  mexc         XMR-USDT         4h          1,077      1,080          3     99.7% ← 3
#   194  mexc         XMR-USDT         5m         51,832     51,840          8    100.0% ← 8
#   195  mexc         XRP-USDT         15m        17,276     17,280          4    100.0% ← 4
#   196  mexc         XRP-USDT         1d            177        180          3     98.3% ← 3
#   197  mexc         XRP-USDT         1h          4,317      4,320          3     99.9% ← 3
#   198  mexc         XRP-USDT         1m         43,092     43,200        108     99.8% ← 108
#   199  mexc         XRP-USDT         4h          1,077      1,080          3     99.7% ← 3
#   200  mexc         XRP-USDT         5m         51,818     51,840         22    100.0% ← 22
#   201  mexc         ZRO-USDT         15m        17,276     17,280          4    100.0% ← 4
#   202  mexc         ZRO-USDT         1d            177        180          3     98.3% ← 3
#   203  mexc         ZRO-USDT         1h          4,317      4,320          3     99.9% ← 3
#   204  mexc         ZRO-USDT         1m         43,112     43,200         88     99.8% ← 88
#   205  mexc         ZRO-USDT         4h          1,077      1,080          3     99.7% ← 3
#   206  mexc         ZRO-USDT         5m         51,822     51,840         18    100.0% ← 18
#   207  nonkyc       AAVE-USDT        15m           556     17,280     16,724      3.2% ← 16,724
#   208  nonkyc       AAVE-USDT        1d            103        180         77     57.2% ← 77
#   209  nonkyc       AAVE-USDT        1h            212      4,320      4,108      4.9% ← 4,108
#   210  nonkyc       AAVE-USDT        4h            127      1,080        953     11.8% ← 953
#   211  nonkyc       AAVE-USDT        5m         51,833     51,840          7    100.0% ← 7
#   212  nonkyc       ADA-USDT         15m        17,277     17,280          3    100.0% ← 3
#   213  nonkyc       ADA-USDT         1d            178        180          2     98.9% ← 2
#   214  nonkyc       ADA-USDT         1h          4,318      4,320          2    100.0% ← 2
#   215  nonkyc       ADA-USDT         4h          1,078      1,080          2     99.8% ← 2
#   216  nonkyc       ADA-USDT         5m         51,826     51,840         14    100.0% ← 14
#   217  nonkyc       ALIAS-XMR        15m        17,277     17,280          3    100.0% ← 3
#   218  nonkyc       ALIAS-XMR        1d            178        180          2     98.9% ← 2
#   219  nonkyc       ALIAS-XMR        1h          4,318      4,320          2    100.0% ← 2
#   220  nonkyc       ALIAS-XMR        4h          1,078      1,080          2     99.8% ← 2
#   221  nonkyc       ALIAS-XMR        5m         51,823     51,840         17    100.0% ← 17
#   222  nonkyc       ARB-USDT         15m        17,277     17,280          3    100.0% ← 3
#   223  nonkyc       ARB-USDT         1d            178        180          2     98.9% ← 2
#   224  nonkyc       ARB-USDT         1h          4,318      4,320          2    100.0% ← 2
#   225  nonkyc       ARB-USDT         4h          1,078      1,080          2     99.8% ← 2
#   226  nonkyc       ARB-USDT         5m         51,831     51,840          9    100.0% ← 9
#   227  nonkyc       ARRR-USDT        15m        17,277     17,280          3    100.0% ← 3
#   228  nonkyc       ARRR-USDT        1d            178        180          2     98.9% ← 2
#   229  nonkyc       ARRR-USDT        1h          4,318      4,320          2    100.0% ← 2
#   230  nonkyc       ARRR-USDT        4h          1,078      1,080          2     99.8% ← 2
#   231  nonkyc       ARRR-USDT        5m         51,833     51,840          7    100.0% ← 7
#   232  nonkyc       ARRR-XMR         15m        17,277     17,280          3    100.0% ← 3
#   233  nonkyc       ARRR-XMR         1d            178        180          2     98.9% ← 2
#   234  nonkyc       ARRR-XMR         1h          4,318      4,320          2    100.0% ← 2
#   235  nonkyc       ARRR-XMR         4h          1,078      1,080          2     99.8% ← 2
#   236  nonkyc       ARRR-XMR         5m         51,833     51,840          7    100.0% ← 7
#   237  nonkyc       AVAX-USDT        15m        17,276     17,280          4    100.0% ← 4
#   238  nonkyc       AVAX-USDT        1d            178        180          2     98.9% ← 2
#   239  nonkyc       AVAX-USDT        1h          4,318      4,320          2    100.0% ← 2
#   240  nonkyc       AVAX-USDT        4h          1,078      1,080          2     99.8% ← 2
#   241  nonkyc       AVAX-USDT        5m         51,830     51,840         10    100.0% ← 10
#   242  nonkyc       BCH-USDT         15m        17,277     17,280          3    100.0% ← 3
#   243  nonkyc       BCH-USDT         1d            178        180          2     98.9% ← 2
#   244  nonkyc       BCH-USDT         1h          4,318      4,320          2    100.0% ← 2
#   245  nonkyc       BCH-USDT         4h          1,078      1,080          2     99.8% ← 2
#   246  nonkyc       BCH-USDT         5m         51,833     51,840          7    100.0% ← 7
#   247  nonkyc       BDX-USDT         15m        17,277     17,280          3    100.0% ← 3
#   248  nonkyc       BDX-USDT         1d            178        180          2     98.9% ← 2
#   249  nonkyc       BDX-USDT         1h          4,318      4,320          2    100.0% ← 2
#   250  nonkyc       BDX-USDT         4h          1,078      1,080          2     99.8% ← 2
#   251  nonkyc       BDX-USDT         5m         51,833     51,840          7    100.0% ← 7
#   252  nonkyc       BNB-USDT         15m           554     17,280     16,726      3.2% ← 16,726
#   253  nonkyc       BNB-USDT         1d            103        180         77     57.2% ← 77
#   254  nonkyc       BNB-USDT         1h            212      4,320      4,108      4.9% ← 4,108
#   255  nonkyc       BNB-USDT         4h            127      1,080        953     11.8% ← 953
#   256  nonkyc       BNB-USDT         5m          1,465     51,840     50,375      2.8% ← 50,375
#   257  nonkyc       BTC-USDT         15m        17,277     17,280          3    100.0% ← 3
#   258  nonkyc       BTC-USDT         1d            178        180          2     98.9% ← 2
#   259  nonkyc       BTC-USDT         1h          4,318      4,320          2    100.0% ← 2
#   260  nonkyc       BTC-USDT         4h          1,078      1,080          2     99.8% ← 2
#   261  nonkyc       BTC-USDT         5m         51,833     51,840          7    100.0% ← 7
#   262  nonkyc       DIVI-USDT        15m        14,438     17,280      2,842     83.6% ← 2,842
#   263  nonkyc       DIVI-USDT        1d            150        180         30     83.3% ← 30
#   264  nonkyc       DIVI-USDT        1h          3,609      4,320        711     83.5% ← 711
#   265  nonkyc       DIVI-USDT        4h            902      1,080        178     83.5% ← 178
#   266  nonkyc       DIVI-USDT        5m         43,313     51,840      8,527     83.6% ← 8,527
#   267  nonkyc       DOGE-USDT        15m        17,277     17,280          3    100.0% ← 3
#   268  nonkyc       DOGE-USDT        1d            178        180          2     98.9% ← 2
#   269  nonkyc       DOGE-USDT        1h          4,318      4,320          2    100.0% ← 2
#   270  nonkyc       DOGE-USDT        4h          1,078      1,080          2     99.8% ← 2
#   271  nonkyc       DOGE-USDT        5m         51,833     51,840          7    100.0% ← 7
#   272  nonkyc       ENA-USDT         15m        17,025     17,280        255     98.5% ← 255
#   273  nonkyc       ENA-USDT         1d            177        180          3     98.3% ← 3
#   274  nonkyc       ENA-USDT         1h          4,256      4,320         64     98.5% ← 64
#   275  nonkyc       ENA-USDT         4h          1,064      1,080         16     98.5% ← 16
#   276  nonkyc       ENA-USDT         5m         51,076     51,840        764     98.5% ← 764
#   277  nonkyc       EPIC-USDT        15m        11,430     17,280      5,850     66.1% ← 5,850
#   278  nonkyc       EPIC-USDT        1d            119        180         61     66.1% ← 61
#   279  nonkyc       EPIC-USDT        1h          2,857      4,320      1,463     66.1% ← 1,463
#   280  nonkyc       EPIC-USDT        4h            714      1,080        366     66.1% ← 366
#   281  nonkyc       EPIC-USDT        5m         34,289     51,840     17,551     66.1% ← 17,551
#   282  nonkyc       EPIC-XMR         15m        11,429     17,280      5,851     66.1% ← 5,851
#   283  nonkyc       EPIC-XMR         1d            119        180         61     66.1% ← 61
#   284  nonkyc       EPIC-XMR         1h          2,857      4,320      1,463     66.1% ← 1,463
#   285  nonkyc       EPIC-XMR         4h            714      1,080        366     66.1% ← 366
#   286  nonkyc       EPIC-XMR         5m         34,286     51,840     17,554     66.1% ← 17,554
#   287  nonkyc       ERG-USDT         15m        17,277     17,280          3    100.0% ← 3
#   288  nonkyc       ERG-USDT         1d            178        180          2     98.9% ← 2
#   289  nonkyc       ERG-USDT         1h          4,318      4,320          2    100.0% ← 2
#   290  nonkyc       ERG-USDT         4h          1,078      1,080          2     99.8% ← 2
#   291  nonkyc       ERG-USDT         5m         51,826     51,840         14    100.0% ← 14
#   292  nonkyc       ERG-XMR          15m        17,275     17,280          5    100.0% ← 5
#   293  nonkyc       ERG-XMR          1d            178        180          2     98.9% ← 2
#   294  nonkyc       ERG-XMR          1h          4,318      4,320          2    100.0% ← 2
#   295  nonkyc       ERG-XMR          4h          1,078      1,080          2     99.8% ← 2
#   296  nonkyc       ERG-XMR          5m         51,822     51,840         18    100.0% ← 18
#   297  nonkyc       ETH-USDT         15m        17,277     17,280          3    100.0% ← 3
#   298  nonkyc       ETH-USDT         1d            178        180          2     98.9% ← 2
#   299  nonkyc       ETH-USDT         1h          4,318      4,320          2    100.0% ← 2
#   300  nonkyc       ETH-USDT         4h          1,078      1,080          2     99.8% ← 2
#   301  nonkyc       ETH-USDT         5m         51,833     51,840          7    100.0% ← 7
#   302  nonkyc       FUSD-XMR         15m        17,276     17,280          4    100.0% ← 4
#   303  nonkyc       FUSD-XMR         1d            178        180          2     98.9% ← 2
#   304  nonkyc       FUSD-XMR         1h          4,318      4,320          2    100.0% ← 2
#   305  nonkyc       FUSD-XMR         4h          1,078      1,080          2     99.8% ← 2
#   306  nonkyc       FUSD-XMR         5m         51,821     51,840         19    100.0% ← 19
#   307  nonkyc       GHOST-XMR        15m        17,276     17,280          4    100.0% ← 4
#   308  nonkyc       GHOST-XMR        1d            178        180          2     98.9% ← 2
#   309  nonkyc       GHOST-XMR        1h          4,318      4,320          2    100.0% ← 2
#   310  nonkyc       GHOST-XMR        4h          1,078      1,080          2     99.8% ← 2
#   311  nonkyc       GHOST-XMR        5m         51,825     51,840         15    100.0% ← 15
#   312  nonkyc       INJ-USDT         15m        17,023     17,280        257     98.5% ← 257
#   313  nonkyc       INJ-USDT         1d            177        180          3     98.3% ← 3
#   314  nonkyc       INJ-USDT         1h          4,256      4,320         64     98.5% ← 64
#   315  nonkyc       INJ-USDT         4h          1,064      1,080         16     98.5% ← 16
#   316  nonkyc       INJ-USDT         5m         51,068     51,840        772     98.5% ← 772
#   317  nonkyc       LINK-USDT        15m        17,277     17,280          3    100.0% ← 3
#   318  nonkyc       LINK-USDT        1d            178        180          2     98.9% ← 2
#   319  nonkyc       LINK-USDT        1h          4,318      4,320          2    100.0% ← 2
#   320  nonkyc       LINK-USDT        4h          1,078      1,080          2     99.8% ← 2
#   321  nonkyc       LINK-USDT        5m         51,832     51,840          8    100.0% ← 8
#   322  nonkyc       LTC-USDT         15m           554     17,280     16,726      3.2% ← 16,726
#   323  nonkyc       LTC-USDT         1d            103        180         77     57.2% ← 77
#   324  nonkyc       LTC-USDT         1h            212      4,320      4,108      4.9% ← 4,108
#   325  nonkyc       LTC-USDT         4h            127      1,080        953     11.8% ← 953
#   326  nonkyc       LTC-USDT         5m          1,466     51,840     50,374      2.8% ← 50,374
#   327  nonkyc       LTC-XMR          15m        17,276     17,280          4    100.0% ← 4
#   328  nonkyc       LTC-XMR          1d            178        180          2     98.9% ← 2
#   329  nonkyc       LTC-XMR          1h          4,318      4,320          2    100.0% ← 2
#   330  nonkyc       LTC-XMR          4h          1,078      1,080          2     99.8% ← 2
#   331  nonkyc       LTC-XMR          5m         51,824     51,840         16    100.0% ← 16
#   332  nonkyc       MANA-USDT        15m         5,044     17,280     12,236     29.2% ← 12,236
#   333  nonkyc       MANA-USDT        1d             52        180        128     28.9% ← 128
#   334  nonkyc       MANA-USDT        1h          1,261      4,320      3,059     29.2% ← 3,059
#   335  nonkyc       MANA-USDT        4h            315      1,080        765     29.2% ← 765
#   336  nonkyc       MANA-USDT        5m         15,132     51,840     36,708     29.2% ← 36,708
#   337  nonkyc       NKYC-USDT        15m        17,277     17,280          3    100.0% ← 3
#   338  nonkyc       NKYC-USDT        1d            178        180          2     98.9% ← 2
#   339  nonkyc       NKYC-USDT        1h          4,318      4,320          2    100.0% ← 2
#   340  nonkyc       NKYC-USDT        4h          1,078      1,080          2     99.8% ← 2
#   341  nonkyc       NKYC-USDT        5m         51,833     51,840          7    100.0% ← 7
#   342  nonkyc       PEP-USDT         15m        17,277     17,280          3    100.0% ← 3
#   343  nonkyc       PEP-USDT         1d            178        180          2     98.9% ← 2
#   344  nonkyc       PEP-USDT         1h          4,318      4,320          2    100.0% ← 2
#   345  nonkyc       PEP-USDT         4h          1,078      1,080          2     99.8% ← 2
#   346  nonkyc       PEP-USDT         5m         51,833     51,840          7    100.0% ← 7
#   347  nonkyc       POL-USDT         15m        17,277     17,280          3    100.0% ← 3
#   348  nonkyc       POL-USDT         1d            178        180          2     98.9% ← 2
#   349  nonkyc       POL-USDT         1h          4,318      4,320          2    100.0% ← 2
#   350  nonkyc       POL-USDT         4h          1,078      1,080          2     99.8% ← 2
#   351  nonkyc       POL-USDT         5m         51,833     51,840          7    100.0% ← 7
#   352  nonkyc       RVN-USDT         15m        17,276     17,280          4    100.0% ← 4
#   353  nonkyc       RVN-USDT         1d            178        180          2     98.9% ← 2
#   354  nonkyc       RVN-USDT         1h          4,318      4,320          2    100.0% ← 2
#   355  nonkyc       RVN-USDT         4h          1,078      1,080          2     99.8% ← 2
#   356  nonkyc       RVN-USDT         5m         51,821     51,840         19    100.0% ← 19
#   357  nonkyc       RXD-USDT         15m        17,277     17,280          3    100.0% ← 3
#   358  nonkyc       RXD-USDT         1d            178        180          2     98.9% ← 2
#   359  nonkyc       RXD-USDT         1h          4,318      4,320          2    100.0% ← 2
#   360  nonkyc       RXD-USDT         4h          1,078      1,080          2     99.8% ← 2
#   361  nonkyc       RXD-USDT         5m         51,833     51,840          7    100.0% ← 7
#   362  nonkyc       SAL-USDT         15m        17,277     17,280          3    100.0% ← 3
#   363  nonkyc       SAL-USDT         1d            178        180          2     98.9% ← 2
#   364  nonkyc       SAL-USDT         1h          4,318      4,320          2    100.0% ← 2
#   365  nonkyc       SAL-USDT         4h          1,078      1,080          2     99.8% ← 2
#   366  nonkyc       SAL-USDT         5m         51,833     51,840          7    100.0% ← 7
#   367  nonkyc       SHIB-USDT        15m        17,277     17,280          3    100.0% ← 3
#   368  nonkyc       SHIB-USDT        1d            178        180          2     98.9% ← 2
#   369  nonkyc       SHIB-USDT        1h          4,318      4,320          2    100.0% ← 2
#   370  nonkyc       SHIB-USDT        30m            99      8,640      8,541      1.1% ← 8,541
#   371  nonkyc       SHIB-USDT        4h          1,078      1,080          2     99.8% ← 2
#   372  nonkyc       SHIB-USDT        5m         51,833     51,840          7    100.0% ← 7
#   373  nonkyc       SOL-USDT         15m        17,277     17,280          3    100.0% ← 3
#   374  nonkyc       SOL-USDT         1d            178        180          2     98.9% ← 2
#   375  nonkyc       SOL-USDT         1h          4,318      4,320          2    100.0% ← 2
#   376  nonkyc       SOL-USDT         4h          1,078      1,080          2     99.8% ← 2
#   377  nonkyc       SOL-USDT         5m         51,833     51,840          7    100.0% ← 7
#   378  nonkyc       TRX-USDT         15m           554     17,280     16,726      3.2% ← 16,726
#   379  nonkyc       TRX-USDT         1d            103        180         77     57.2% ← 77
#   380  nonkyc       TRX-USDT         1h            212      4,320      4,108      4.9% ← 4,108
#   381  nonkyc       TRX-USDT         4h            127      1,080        953     11.8% ← 953
#   382  nonkyc       TRX-USDT         5m          1,466     51,840     50,374      2.8% ← 50,374
#   383  nonkyc       USDC-USDT        15m           555     17,280     16,725      3.2% ← 16,725
#   384  nonkyc       USDC-USDT        1d            103        180         77     57.2% ← 77
#   385  nonkyc       USDC-USDT        1h            212      4,320      4,108      4.9% ← 4,108
#   386  nonkyc       USDC-USDT        30m            94      8,640      8,546      1.1% ← 8,546
#   387  nonkyc       USDC-USDT        4h            127      1,080        953     11.8% ← 953
#   388  nonkyc       USDC-USDT        5m          1,467     51,840     50,373      2.8% ← 50,373
#   389  nonkyc       VEIL-XMR         15m        17,275     17,280          5    100.0% ← 5
#   390  nonkyc       VEIL-XMR         1d            178        180          2     98.9% ← 2
#   391  nonkyc       VEIL-XMR         1h          4,318      4,320          2    100.0% ← 2
#   392  nonkyc       VEIL-XMR         4h          1,078      1,080          2     99.8% ← 2
#   393  nonkyc       VEIL-XMR         5m         51,821     51,840         19    100.0% ← 19
#   394  nonkyc       XKR-XMR          15m        17,277     17,280          3    100.0% ← 3
#   395  nonkyc       XKR-XMR          1d            178        180          2     98.9% ← 2
#   396  nonkyc       XKR-XMR          1h          4,318      4,320          2    100.0% ← 2
#   397  nonkyc       XKR-XMR          4h          1,078      1,080          2     99.8% ← 2
#   398  nonkyc       XKR-XMR          5m         51,822     51,840         18    100.0% ← 18
#   399  nonkyc       XMR-BTC          15m        17,270     17,280         10     99.9% ← 10
#   400  nonkyc       XMR-BTC          1d            178        180          2     98.9% ← 2
#   401  nonkyc       XMR-BTC          1h          4,318      4,320          2    100.0% ← 2
#   402  nonkyc       XMR-BTC          4h          1,078      1,080          2     99.8% ← 2
#   403  nonkyc       XMR-BTC          5m         51,787     51,840         53     99.9% ← 53
#   404  nonkyc       XMR-USDT         15m        17,277     17,280          3    100.0% ← 3
#   405  nonkyc       XMR-USDT         1d            178        180          2     98.9% ← 2
#   406  nonkyc       XMR-USDT         1h          4,318      4,320          2    100.0% ← 2
#   407  nonkyc       XMR-USDT         4h          1,078      1,080          2     99.8% ← 2
#   408  nonkyc       XMR-USDT         5m         51,833     51,840          7    100.0% ← 7
#   409  nonkyc       XMR-ZSD          15m        17,272     17,280          8    100.0% ← 8
#   410  nonkyc       XMR-ZSD          1d            178        180          2     98.9% ← 2
#   411  nonkyc       XMR-ZSD          1h          4,318      4,320          2    100.0% ← 2
#   412  nonkyc       XMR-ZSD          4h          1,078      1,080          2     99.8% ← 2
#   413  nonkyc       XMR-ZSD          5m         51,781     51,840         59     99.9% ← 59
#   414  nonkyc       XNV-XMR          15m         6,089     17,280     11,191     35.2% ← 11,191
#   415  nonkyc       XNV-XMR          1d             63        180        117     35.0% ← 117
#   416  nonkyc       XNV-XMR          1h          1,522      4,320      2,798     35.2% ← 2,798
#   417  nonkyc       XNV-XMR          4h            380      1,080        700     35.2% ← 700
#   418  nonkyc       XNV-XMR          5m         18,267     51,840     33,573     35.2% ← 33,573
#   419  nonkyc       XRP-USDT         15m        17,277     17,280          3    100.0% ← 3
#   420  nonkyc       XRP-USDT         1d            178        180          2     98.9% ← 2
#   421  nonkyc       XRP-USDT         1h          4,318      4,320          2    100.0% ← 2
#   422  nonkyc       XRP-USDT         4h          1,078      1,080          2     99.8% ← 2
#   423  nonkyc       XRP-USDT         5m         51,833     51,840          7    100.0% ← 7
#   424  nonkyc       XTM-XMR          15m        17,273     17,280          7    100.0% ← 7
#   425  nonkyc       XTM-XMR          1d            178        180          2     98.9% ← 2
#   426  nonkyc       XTM-XMR          1h          4,318      4,320          2    100.0% ← 2
#   427  nonkyc       XTM-XMR          4h          1,078      1,080          2     99.8% ← 2
#   428  nonkyc       XTM-XMR          5m         51,795     51,840         45     99.9% ← 45
#   429  nonkyc       ZANO-USDT        15m        17,270     17,280         10     99.9% ← 10
#   430  nonkyc       ZANO-USDT        1d            178        180          2     98.9% ← 2
#   431  nonkyc       ZANO-USDT        1h          4,318      4,320          2    100.0% ← 2
#   432  nonkyc       ZANO-USDT        4h          1,078      1,080          2     99.8% ← 2
#   433  nonkyc       ZANO-USDT        5m         51,772     51,840         68     99.9% ← 68
#   434  nonkyc       ZEC-XMR          15m        17,277     17,280          3    100.0% ← 3
#   435  nonkyc       ZEC-XMR          1d            178        180          2     98.9% ← 2
#   436  nonkyc       ZEC-XMR          1h          4,318      4,320          2    100.0% ← 2
#   437  nonkyc       ZEC-XMR          4h          1,078      1,080          2     99.8% ← 2
#   438  nonkyc       ZEC-XMR          5m         51,828     51,840         12    100.0% ← 12
#   439  nonkyc       ZSD-USDT         15m        17,277     17,280          3    100.0% ← 3
#   440  nonkyc       ZSD-USDT         1d            178        180          2     98.9% ← 2
#   441  nonkyc       ZSD-USDT         1h          4,318      4,320          2    100.0% ← 2
#   442  nonkyc       ZSD-USDT         4h          1,078      1,080          2     99.8% ← 2
#   443  nonkyc       ZSD-USDT         5m         51,832     51,840          8    100.0% ← 8
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
# Use these indices in Cell 8 to select what to backfill.

# %%
# ── Cell 8: Select what to backfill ──────────────────────────────────────────
#
# Choose ONE of these selection modes:
#
#   SELECTION = "all"              # backfill every combo with gaps
#   SELECTION = "nonkyc"           # backfill all series for a connector name
#   SELECTION = "mexc"             # backfill all series for a connector name
#   SELECTION = [0, 1, 2]          # backfill specific row indices from the table above
#   SELECTION = range(0, 25)       # backfill a range of row indices
#   SELECTION = [5]                # backfill a single row

SELECTION = "all"   # ← CHANGE THIS

# ── Resolve selection to a list of combos ──
if SELECTION == "all":
    selected_combos = [c for c in combos if c["missing"] > 0]
    sel_desc = "all connectors"
elif isinstance(SELECTION, str):
    # Connector name
    selected_combos = [c for c in combos if c["connector"] == SELECTION and c["missing"] > 0]
    sel_desc = f"connector '{SELECTION}'"
else:
    # List or range of row indices
    indices = list(SELECTION)
    selected_combos = [combos[i] for i in indices if i < len(combos) and combos[i]["missing"] > 0]
    sel_desc = f"rows {indices}"

total_to_fill = sum(c["missing"] for c in selected_combos)
print(f"Selection: {sel_desc}")
print(f"Series with gaps: {len(selected_combos)}")
print(f"Total missing candles to fill: {total_to_fill:,}")

if selected_combos:
    print(f"\nWill backfill:")
    for c in selected_combos:
        print(f"  {c['connector']:12s} {c['pair']:16s} {c['interval']:6s} — {c['missing']:,} missing")
    print(f"\nReady. Run the next cell to start.")
else:
    print("\n✓ Nothing to backfill — all selected series are complete!")
# Out:
# Selection: all connectors
# Series with gaps: 444
# Total missing candles to fill: 497,422
#
# Will backfill:
#   coinbase     BTC-USD          15m    — 3 missing
#   coinbase     BTC-USD          1d     — 2 missing
#   coinbase     BTC-USD          1h     — 2 missing
#   coinbase     BTC-USD          1m     — 29 missing
#   coinbase     BTC-USD          5m     — 7 missing
#   coinbase     ETH-USD          15m    — 3 missing
#   coinbase     ETH-USD          1d     — 2 missing
#   coinbase     ETH-USD          1h     — 2 missing
#   coinbase     ETH-USD          1m     — 29 missing
#   coinbase     ETH-USD          5m     — 7 missing
#   coinbase     USDT-USD         15m    — 3 missing
#   coinbase     USDT-USD         1d     — 2 missing
#   coinbase     USDT-USD         1h     — 2 missing
#   coinbase     USDT-USD         1m     — 29 missing
#   coinbase     USDT-USD         5m     — 7 missing
#   mexc         ADA-USDT         15m    — 4 missing
#   mexc         ADA-USDT         1d     — 3 missing
#   mexc         ADA-USDT         1h     — 3 missing
#   mexc         ADA-USDT         1m     — 30 missing
#   mexc         ADA-USDT         4h     — 3 missing
#   mexc         ADA-USDT         5m     — 7 missing
#   mexc         APT-USDT         15m    — 4 missing
#   mexc         APT-USDT         1d     — 3 missing
#   mexc         APT-USDT         1h     — 3 missing
#   mexc         APT-USDT         1m     — 28 missing
#   mexc         APT-USDT         4h     — 3 missing
#   mexc         APT-USDT         5m     — 7 missing
#   mexc         ASTER-USDT       15m    — 4 missing
#   mexc         ASTER-USDT       1d     — 3 missing
#   mexc         ASTER-USDT       1h     — 3 missing
#   mexc         ASTER-USDT       1m     — 25 missing
#   mexc         ASTER-USDT       4h     — 2 missing
#   mexc         ASTER-USDT       5m     — 6 missing
#   mexc         ATOM-USDT        15m    — 3 missing
#   mexc         ATOM-USDT        1d     — 2 missing
#   mexc         ATOM-USDT        1h     — 2 missing
#   mexc         ATOM-USDT        1m     — 23 missing
#   mexc         ATOM-USDT        4h     — 2 missing
#   mexc         ATOM-USDT        5m     — 6 missing
#   mexc         BNB-USDT         15m    — 3 missing
#   mexc         BNB-USDT         1d     — 2 missing
#   mexc         BNB-USDT         1h     — 2 missing
#   mexc         BNB-USDT         1m     — 20 missing
#   mexc         BNB-USDT         4h     — 2 missing
#   mexc         BNB-USDT         5m     — 5 missing
#   mexc         BTC-USDT         15m    — 3 missing
#   mexc         BTC-USDT         1d     — 2 missing
#   mexc         BTC-USDT         1h     — 2 missing
#   mexc         BTC-USDT         1m     — 19 missing
#   mexc         BTC-USDT         4h     — 2 missing
#   mexc         BTC-USDT         5m     — 5 missing
#   mexc         DOGE-USDT        15m    — 3 missing
#   mexc         DOGE-USDT        1d     — 2 missing
#   mexc         DOGE-USDT        1h     — 2 missing
#   mexc         DOGE-USDT        1m     — 16 missing
#   mexc         DOGE-USDT        4h     — 2 missing
#   mexc         DOGE-USDT        5m     — 4 missing
#   mexc         DOT-USDT         15m    — 3 missing
#   mexc         DOT-USDT         1d     — 2 missing
#   mexc         DOT-USDT         1h     — 2 missing
#   mexc         DOT-USDT         1m     — 13 missing
#   mexc         DOT-USDT         4h     — 2 missing
#   mexc         DOT-USDT         5m     — 4 missing
#   mexc         ETH-USDT         15m    — 3 missing
#   mexc         ETH-USDT         1d     — 2 missing
#   mexc         ETH-USDT         1h     — 2 missing
#   mexc         ETH-USDT         1m     — 11 missing
#   mexc         ETH-USDT         4h     — 2 missing
#   mexc         ETH-USDT         5m     — 3 missing
#   mexc         FET-USDT         15m    — 4 missing
#   mexc         FET-USDT         1d     — 3 missing
#   mexc         FET-USDT         1h     — 3 missing
#   mexc         FET-USDT         1m     — 34 missing
#   mexc         FET-USDT         4h     — 3 missing
#   mexc         FET-USDT         5m     — 8 missing
#   mexc         HYPE-USDT        15m    — 2 missing
#   mexc         HYPE-USDT        1d     — 2 missing
#   mexc         HYPE-USDT        1h     — 2 missing
#   mexc         HYPE-USDT        1m     — 9 missing
#   mexc         HYPE-USDT        4h     — 2 missing
#   mexc         HYPE-USDT        5m     — 4 missing
#   mexc         ICP-USDT         15m    — 2 missing
#   mexc         ICP-USDT         1d     — 2 missing
#   mexc         ICP-USDT         1h     — 2 missing
#   mexc         ICP-USDT         1m     — 32 missing
#   mexc         ICP-USDT         4h     — 3 missing
#   mexc         ICP-USDT         5m     — 8 missing
#   mexc         LTC-USDT         15m    — 4 missing
#   mexc         LTC-USDT         1d     — 3 missing
#   mexc         LTC-USDT         1h     — 3 missing
#   mexc         LTC-USDT         1m     — 108 missing
#   mexc         LTC-USDT         4h     — 3 missing
#   mexc         LTC-USDT         5m     — 8 missing
#   mexc         OP-USDT          15m    — 4 missing
#   mexc         OP-USDT          1d     — 3 missing
#   mexc         OP-USDT          1h     — 3 missing
#   mexc         OP-USDT          1m     — 34 missing
#   mexc         OP-USDT          4h     — 3 missing
#   mexc         OP-USDT          5m     — 8 missing
#   mexc         PEPE-USDT        15m    — 4 missing
#   mexc         PEPE-USDT        1d     — 3 missing
#   mexc         PEPE-USDT        1h     — 3 missing
#   mexc         PEPE-USDT        1m     — 34 missing
#   mexc         PEPE-USDT        4h     — 3 missing
#   mexc         PEPE-USDT        5m     — 8 missing
#   mexc         PUMP-USDT        15m    — 4 missing
#   mexc         PUMP-USDT        1d     — 3 missing
#   mexc         PUMP-USDT        1h     — 3 missing
#   mexc         PUMP-USDT        1m     — 104 missing
#   mexc         PUMP-USDT        4h     — 3 missing
#   mexc         PUMP-USDT        5m     — 8 missing
#   mexc         RENDER-USDT      15m    — 4 missing
#   mexc         RENDER-USDT      1d     — 3 missing
#   mexc         RENDER-USDT      1h     — 3 missing
#   mexc         RENDER-USDT      1m     — 34 missing
#   mexc         RENDER-USDT      4h     — 3 missing
#   mexc         RENDER-USDT      5m     — 8 missing
#   mexc         SAHARA-USDT      15m    — 4 missing
#   mexc         SAHARA-USDT      1d     — 3 missing
#   mexc         SAHARA-USDT      1h     — 3 missing
#   mexc         SAHARA-USDT      1m     — 124 missing
#   mexc         SAHARA-USDT      4h     — 3 missing
#   mexc         SAHARA-USDT      5m     — 8 missing
#   mexc         SAL-USDT         15m    — 4 missing
#   mexc         SAL-USDT         1d     — 3 missing
#   mexc         SAL-USDT         1h     — 3 missing
#   mexc         SAL-USDT         1m     — 34 missing
#   mexc         SAL-USDT         4h     — 3 missing
#   mexc         SAL-USDT         5m     — 8 missing
#   mexc         SHIB-USDT        15m    — 4 missing
#   mexc         SHIB-USDT        1d     — 3 missing
#   mexc         SHIB-USDT        1h     — 3 missing
#   mexc         SHIB-USDT        1m     — 34 missing
#   mexc         SHIB-USDT        4h     — 3 missing
#   mexc         SHIB-USDT        5m     — 8 missing
#   mexc         SOL-USDT         15m    — 4 missing
#   mexc         SOL-USDT         1d     — 3 missing
#   mexc         SOL-USDT         1h     — 3 missing
#   mexc         SOL-USDT         1m     — 107 missing
#   mexc         SOL-USDT         4h     — 3 missing
#   mexc         SOL-USDT         5m     — 10 missing
#   mexc         SUI-USDT         15m    — 4 missing
#   mexc         SUI-USDT         1d     — 3 missing
#   mexc         SUI-USDT         1h     — 3 missing
#   mexc         SUI-USDT         1m     — 33 missing
#   mexc         SUI-USDT         4h     — 3 missing
#   mexc         SUI-USDT         5m     — 8 missing
#   mexc         TON-USDT         15m    — 4 missing
#   mexc         TON-USDT         1d     — 3 missing
#   mexc         TON-USDT         1h     — 3 missing
#   mexc         TON-USDT         1m     — 34 missing
#   mexc         TON-USDT         4h     — 3 missing
#   mexc         TON-USDT         5m     — 8 missing
#   mexc         TRX-USDT         15m    — 4 missing
#   mexc         TRX-USDT         1d     — 3 missing
#   mexc         TRX-USDT         1h     — 3 missing
#   mexc         TRX-USDT         1m     — 34 missing
#   mexc         TRX-USDT         4h     — 3 missing
#   mexc         TRX-USDT         5m     — 8 missing
#   mexc         WLD-USDT         15m    — 4 missing
#   mexc         WLD-USDT         1d     — 3 missing
#   mexc         WLD-USDT         1h     — 3 missing
#   mexc         WLD-USDT         1m     — 34 missing
#   mexc         WLD-USDT         4h     — 3 missing
#   mexc         WLD-USDT         5m     — 8 missing
#   mexc         WLFI-USDT        15m    — 4 missing
#   mexc         WLFI-USDT        1d     — 3 missing
#   mexc         WLFI-USDT        1h     — 3 missing
#   mexc         WLFI-USDT        1m     — 34 missing
#   mexc         WLFI-USDT        4h     — 3 missing
#   mexc         WLFI-USDT        5m     — 8 missing
#   mexc         WXT-USDT         15m    — 4 missing
#   mexc         WXT-USDT         1d     — 3 missing
#   mexc         WXT-USDT         1h     — 3 missing
#   mexc         WXT-USDT         1m     — 34 missing
#   mexc         WXT-USDT         4h     — 3 missing
#   mexc         WXT-USDT         5m     — 8 missing
#   mexc         XLM-USDT         15m    — 4 missing
#   mexc         XLM-USDT         1d     — 3 missing
#   mexc         XLM-USDT         1h     — 3 missing
#   mexc         XLM-USDT         1m     — 34 missing
#   mexc         XLM-USDT         4h     — 3 missing
#   mexc         XLM-USDT         5m     — 8 missing
#   mexc         XMR-USDC         15m    — 4 missing
#   mexc         XMR-USDC         1d     — 3 missing
#   mexc         XMR-USDC         1h     — 3 missing
#   mexc         XMR-USDC         1m     — 80 missing
#   mexc         XMR-USDC         4h     — 3 missing
#   mexc         XMR-USDC         5m     — 8 missing
#   mexc         XMR-USDT         15m    — 4 missing
#   mexc         XMR-USDT         1d     — 3 missing
#   mexc         XMR-USDT         1h     — 3 missing
#   mexc         XMR-USDT         1m     — 102 missing
#   mexc         XMR-USDT         4h     — 3 missing
#   mexc         XMR-USDT         5m     — 8 missing
#   mexc         XRP-USDT         15m    — 4 missing
#   mexc         XRP-USDT         1d     — 3 missing
#   mexc         XRP-USDT         1h     — 3 missing
#   mexc         XRP-USDT         1m     — 108 missing
#   mexc         XRP-USDT         4h     — 3 missing
#   mexc         XRP-USDT         5m     — 22 missing
#   mexc         ZRO-USDT         15m    — 4 missing
#   mexc         ZRO-USDT         1d     — 3 missing
#   mexc         ZRO-USDT         1h     — 3 missing
#   mexc         ZRO-USDT         1m     — 88 missing
#   mexc         ZRO-USDT         4h     — 3 missing
#   mexc         ZRO-USDT         5m     — 18 missing
#   nonkyc       AAVE-USDT        15m    — 16,724 missing
#   nonkyc       AAVE-USDT        1d     — 77 missing
#   nonkyc       AAVE-USDT        1h     — 4,108 missing
#   nonkyc       AAVE-USDT        4h     — 953 missing
#   nonkyc       AAVE-USDT        5m     — 7 missing
#   nonkyc       ADA-USDT         15m    — 3 missing
#   nonkyc       ADA-USDT         1d     — 2 missing
#   nonkyc       ADA-USDT         1h     — 2 missing
#   nonkyc       ADA-USDT         4h     — 2 missing
#   nonkyc       ADA-USDT         5m     — 14 missing
#   nonkyc       ALIAS-XMR        15m    — 3 missing
#   nonkyc       ALIAS-XMR        1d     — 2 missing
#   nonkyc       ALIAS-XMR        1h     — 2 missing
#   nonkyc       ALIAS-XMR        4h     — 2 missing
#   nonkyc       ALIAS-XMR        5m     — 17 missing
#   nonkyc       ARB-USDT         15m    — 3 missing
#   nonkyc       ARB-USDT         1d     — 2 missing
#   nonkyc       ARB-USDT         1h     — 2 missing
#   nonkyc       ARB-USDT         4h     — 2 missing
#   nonkyc       ARB-USDT         5m     — 9 missing
#   nonkyc       ARRR-USDT        15m    — 3 missing
#   nonkyc       ARRR-USDT        1d     — 2 missing
#   nonkyc       ARRR-USDT        1h     — 2 missing
#   nonkyc       ARRR-USDT        4h     — 2 missing
#   nonkyc       ARRR-USDT        5m     — 7 missing
#   nonkyc       ARRR-XMR         15m    — 3 missing
#   nonkyc       ARRR-XMR         1d     — 2 missing
#   nonkyc       ARRR-XMR         1h     — 2 missing
#   nonkyc       ARRR-XMR         4h     — 2 missing
#   nonkyc       ARRR-XMR         5m     — 7 missing
#   nonkyc       AVAX-USDT        15m    — 4 missing
#   nonkyc       AVAX-USDT        1d     — 2 missing
#   nonkyc       AVAX-USDT        1h     — 2 missing
#   nonkyc       AVAX-USDT        4h     — 2 missing
#   nonkyc       AVAX-USDT        5m     — 10 missing
#   nonkyc       BCH-USDT         15m    — 3 missing
#   nonkyc       BCH-USDT         1d     — 2 missing
#   nonkyc       BCH-USDT         1h     — 2 missing
#   nonkyc       BCH-USDT         4h     — 2 missing
#   nonkyc       BCH-USDT         5m     — 7 missing
#   nonkyc       BDX-USDT         15m    — 3 missing
#   nonkyc       BDX-USDT         1d     — 2 missing
#   nonkyc       BDX-USDT         1h     — 2 missing
#   nonkyc       BDX-USDT         4h     — 2 missing
#   nonkyc       BDX-USDT         5m     — 7 missing
#   nonkyc       BNB-USDT         15m    — 16,726 missing
#   nonkyc       BNB-USDT         1d     — 77 missing
#   nonkyc       BNB-USDT         1h     — 4,108 missing
#   nonkyc       BNB-USDT         4h     — 953 missing
#   nonkyc       BNB-USDT         5m     — 50,375 missing
#   nonkyc       BTC-USDT         15m    — 3 missing
#   nonkyc       BTC-USDT         1d     — 2 missing
#   nonkyc       BTC-USDT         1h     — 2 missing
#   nonkyc       BTC-USDT         4h     — 2 missing
#   nonkyc       BTC-USDT         5m     — 7 missing
#   nonkyc       DIVI-USDT        15m    — 2,842 missing
#   nonkyc       DIVI-USDT        1d     — 30 missing
#   nonkyc       DIVI-USDT        1h     — 711 missing
#   nonkyc       DIVI-USDT        4h     — 178 missing
#   nonkyc       DIVI-USDT        5m     — 8,527 missing
#   nonkyc       DOGE-USDT        15m    — 3 missing
#   nonkyc       DOGE-USDT        1d     — 2 missing
#   nonkyc       DOGE-USDT        1h     — 2 missing
#   nonkyc       DOGE-USDT        4h     — 2 missing
#   nonkyc       DOGE-USDT        5m     — 7 missing
#   nonkyc       ENA-USDT         15m    — 255 missing
#   nonkyc       ENA-USDT         1d     — 3 missing
#   nonkyc       ENA-USDT         1h     — 64 missing
#   nonkyc       ENA-USDT         4h     — 16 missing
#   nonkyc       ENA-USDT         5m     — 764 missing
#   nonkyc       EPIC-USDT        15m    — 5,850 missing
#   nonkyc       EPIC-USDT        1d     — 61 missing
#   nonkyc       EPIC-USDT        1h     — 1,463 missing
#   nonkyc       EPIC-USDT        4h     — 366 missing
#   nonkyc       EPIC-USDT        5m     — 17,551 missing
#   nonkyc       EPIC-XMR         15m    — 5,851 missing
#   nonkyc       EPIC-XMR         1d     — 61 missing
#   nonkyc       EPIC-XMR         1h     — 1,463 missing
#   nonkyc       EPIC-XMR         4h     — 366 missing
#   nonkyc       EPIC-XMR         5m     — 17,554 missing
#   nonkyc       ERG-USDT         15m    — 3 missing
#   nonkyc       ERG-USDT         1d     — 2 missing
#   nonkyc       ERG-USDT         1h     — 2 missing
#   nonkyc       ERG-USDT         4h     — 2 missing
#   nonkyc       ERG-USDT         5m     — 14 missing
#   nonkyc       ERG-XMR          15m    — 5 missing
#   nonkyc       ERG-XMR          1d     — 2 missing
#   nonkyc       ERG-XMR          1h     — 2 missing
#   nonkyc       ERG-XMR          4h     — 2 missing
#   nonkyc       ERG-XMR          5m     — 18 missing
#   nonkyc       ETH-USDT         15m    — 3 missing
#   nonkyc       ETH-USDT         1d     — 2 missing
#   nonkyc       ETH-USDT         1h     — 2 missing
#   nonkyc       ETH-USDT         4h     — 2 missing
#   nonkyc       ETH-USDT         5m     — 7 missing
#   nonkyc       FUSD-XMR         15m    — 4 missing
#   nonkyc       FUSD-XMR         1d     — 2 missing
#   nonkyc       FUSD-XMR         1h     — 2 missing
#   nonkyc       FUSD-XMR         4h     — 2 missing
#   nonkyc       FUSD-XMR         5m     — 19 missing
#   nonkyc       GHOST-XMR        15m    — 4 missing
#   nonkyc       GHOST-XMR        1d     — 2 missing
#   nonkyc       GHOST-XMR        1h     — 2 missing
#   nonkyc       GHOST-XMR        4h     — 2 missing
#   nonkyc       GHOST-XMR        5m     — 15 missing
#   nonkyc       INJ-USDT         15m    — 257 missing
#   nonkyc       INJ-USDT         1d     — 3 missing
#   nonkyc       INJ-USDT         1h     — 64 missing
#   nonkyc       INJ-USDT         4h     — 16 missing
#   nonkyc       INJ-USDT         5m     — 772 missing
#   nonkyc       LINK-USDT        15m    — 3 missing
#   nonkyc       LINK-USDT        1d     — 2 missing
#   nonkyc       LINK-USDT        1h     — 2 missing
#   nonkyc       LINK-USDT        4h     — 2 missing
#   nonkyc       LINK-USDT        5m     — 8 missing
#   nonkyc       LTC-USDT         15m    — 16,726 missing
#   nonkyc       LTC-USDT         1d     — 77 missing
#   nonkyc       LTC-USDT         1h     — 4,108 missing
#   nonkyc       LTC-USDT         4h     — 953 missing
#   nonkyc       LTC-USDT         5m     — 50,374 missing
#   nonkyc       LTC-XMR          15m    — 4 missing
#   nonkyc       LTC-XMR          1d     — 2 missing
#   nonkyc       LTC-XMR          1h     — 2 missing
#   nonkyc       LTC-XMR          4h     — 2 missing
#   nonkyc       LTC-XMR          5m     — 16 missing
#   nonkyc       MANA-USDT        15m    — 12,236 missing
#   nonkyc       MANA-USDT        1d     — 128 missing
#   nonkyc       MANA-USDT        1h     — 3,059 missing
#   nonkyc       MANA-USDT        4h     — 765 missing
#   nonkyc       MANA-USDT        5m     — 36,708 missing
#   nonkyc       NKYC-USDT        15m    — 3 missing
#   nonkyc       NKYC-USDT        1d     — 2 missing
#   nonkyc       NKYC-USDT        1h     — 2 missing
#   nonkyc       NKYC-USDT        4h     — 2 missing
#   nonkyc       NKYC-USDT        5m     — 7 missing
#   nonkyc       PEP-USDT         15m    — 3 missing
#   nonkyc       PEP-USDT         1d     — 2 missing
#   nonkyc       PEP-USDT         1h     — 2 missing
#   nonkyc       PEP-USDT         4h     — 2 missing
#   nonkyc       PEP-USDT         5m     — 7 missing
#   nonkyc       POL-USDT         15m    — 3 missing
#   nonkyc       POL-USDT         1d     — 2 missing
#   nonkyc       POL-USDT         1h     — 2 missing
#   nonkyc       POL-USDT         4h     — 2 missing
#   nonkyc       POL-USDT         5m     — 7 missing
#   nonkyc       RVN-USDT         15m    — 4 missing
#   nonkyc       RVN-USDT         1d     — 2 missing
#   nonkyc       RVN-USDT         1h     — 2 missing
#   nonkyc       RVN-USDT         4h     — 2 missing
#   nonkyc       RVN-USDT         5m     — 19 missing
#   nonkyc       RXD-USDT         15m    — 3 missing
#   nonkyc       RXD-USDT         1d     — 2 missing
#   nonkyc       RXD-USDT         1h     — 2 missing
#   nonkyc       RXD-USDT         4h     — 2 missing
#   nonkyc       RXD-USDT         5m     — 7 missing
#   nonkyc       SAL-USDT         15m    — 3 missing
#   nonkyc       SAL-USDT         1d     — 2 missing
#   nonkyc       SAL-USDT         1h     — 2 missing
#   nonkyc       SAL-USDT         4h     — 2 missing
#   nonkyc       SAL-USDT         5m     — 7 missing
#   nonkyc       SHIB-USDT        15m    — 3 missing
#   nonkyc       SHIB-USDT        1d     — 2 missing
#   nonkyc       SHIB-USDT        1h     — 2 missing
#   nonkyc       SHIB-USDT        30m    — 8,541 missing
#   nonkyc       SHIB-USDT        4h     — 2 missing
#   nonkyc       SHIB-USDT        5m     — 7 missing
#   nonkyc       SOL-USDT         15m    — 3 missing
#   nonkyc       SOL-USDT         1d     — 2 missing
#   nonkyc       SOL-USDT         1h     — 2 missing
#   nonkyc       SOL-USDT         4h     — 2 missing
#   nonkyc       SOL-USDT         5m     — 7 missing
#   nonkyc       TRX-USDT         15m    — 16,726 missing
#   nonkyc       TRX-USDT         1d     — 77 missing
#   nonkyc       TRX-USDT         1h     — 4,108 missing
#   nonkyc       TRX-USDT         4h     — 953 missing
#   nonkyc       TRX-USDT         5m     — 50,374 missing
#   nonkyc       USDC-USDT        15m    — 16,725 missing
#   nonkyc       USDC-USDT        1d     — 77 missing
#   nonkyc       USDC-USDT        1h     — 4,108 missing
#   nonkyc       USDC-USDT        30m    — 8,546 missing
#   nonkyc       USDC-USDT        4h     — 953 missing
#   nonkyc       USDC-USDT        5m     — 50,373 missing
#   nonkyc       VEIL-XMR         15m    — 5 missing
#   nonkyc       VEIL-XMR         1d     — 2 missing
#   nonkyc       VEIL-XMR         1h     — 2 missing
#   nonkyc       VEIL-XMR         4h     — 2 missing
#   nonkyc       VEIL-XMR         5m     — 19 missing
#   nonkyc       XKR-XMR          15m    — 3 missing
#   nonkyc       XKR-XMR          1d     — 2 missing
#   nonkyc       XKR-XMR          1h     — 2 missing
#   nonkyc       XKR-XMR          4h     — 2 missing
#   nonkyc       XKR-XMR          5m     — 18 missing
#   nonkyc       XMR-BTC          15m    — 10 missing
#   nonkyc       XMR-BTC          1d     — 2 missing
#   nonkyc       XMR-BTC          1h     — 2 missing
#   nonkyc       XMR-BTC          4h     — 2 missing
#   nonkyc       XMR-BTC          5m     — 53 missing
#   nonkyc       XMR-USDT         15m    — 3 missing
#   nonkyc       XMR-USDT         1d     — 2 missing
#   nonkyc       XMR-USDT         1h     — 2 missing
#   nonkyc       XMR-USDT         4h     — 2 missing
#   nonkyc       XMR-USDT         5m     — 7 missing
#   nonkyc       XMR-ZSD          15m    — 8 missing
#   nonkyc       XMR-ZSD          1d     — 2 missing
#   nonkyc       XMR-ZSD          1h     — 2 missing
#   nonkyc       XMR-ZSD          4h     — 2 missing
#   nonkyc       XMR-ZSD          5m     — 59 missing
#   nonkyc       XNV-XMR          15m    — 11,191 missing
#   nonkyc       XNV-XMR          1d     — 117 missing
#   nonkyc       XNV-XMR          1h     — 2,798 missing
#   nonkyc       XNV-XMR          4h     — 700 missing
#   nonkyc       XNV-XMR          5m     — 33,573 missing
#   nonkyc       XRP-USDT         15m    — 3 missing
#   nonkyc       XRP-USDT         1d     — 2 missing
#   nonkyc       XRP-USDT         1h     — 2 missing
#   nonkyc       XRP-USDT         4h     — 2 missing
#   nonkyc       XRP-USDT         5m     — 7 missing
#   nonkyc       XTM-XMR          15m    — 7 missing
#   nonkyc       XTM-XMR          1d     — 2 missing
#   nonkyc       XTM-XMR          1h     — 2 missing
#   nonkyc       XTM-XMR          4h     — 2 missing
#   nonkyc       XTM-XMR          5m     — 45 missing
#   nonkyc       ZANO-USDT        15m    — 10 missing
#   nonkyc       ZANO-USDT        1d     — 2 missing
#   nonkyc       ZANO-USDT        1h     — 2 missing
#   nonkyc       ZANO-USDT        4h     — 2 missing
#   nonkyc       ZANO-USDT        5m     — 68 missing
#   nonkyc       ZEC-XMR          15m    — 3 missing
#   nonkyc       ZEC-XMR          1d     — 2 missing
#   nonkyc       ZEC-XMR          1h     — 2 missing
#   nonkyc       ZEC-XMR          4h     — 2 missing
#   nonkyc       ZEC-XMR          5m     — 12 missing
#   nonkyc       ZSD-USDT         15m    — 3 missing
#   nonkyc       ZSD-USDT         1d     — 2 missing
#   nonkyc       ZSD-USDT         1h     — 2 missing
#   nonkyc       ZSD-USDT         4h     — 2 missing
#   nonkyc       ZSD-USDT         5m     — 8 missing
#
# Ready. Run the next cell to start.

# %%
# ── Cell 9: Gap detection (streaming, memory-safe) ──────────────────────────

def find_gaps_in_window(coll, connector, pair, interval, step, window_start, window_end):
    """
    Find all gap ranges within the specified window.
    Also detects leading gaps (window_start to first candle) and trailing gaps
    (last candle to window_end).
    Returns list of (gap_start_ts, gap_end_ts) tuples.
    """
    effective_start = align_floor(window_start, step)
    effective_end = last_closed_open_ts(utc_now_ts(), step)
    
    if effective_end < effective_start:
        return []
    
    # Stream timestamps in ascending order
    cursor = coll.find(
        {"connector": connector, "trading_pair": pair, "interval": interval,
         "timestamp": {"$gte": effective_start, "$lte": effective_end}},
        projection={"timestamp": 1, "_id": 0},
        sort=[("timestamp", 1)],
        batch_size=5000,
    )
    
    ranges = []
    prev = None
    first_ts = None
    last_ts = None
    
    for doc in cursor:
        ts = int(doc["timestamp"])
        if first_ts is None:
            first_ts = ts
        last_ts = ts
        
        if prev is not None:
            expected_next = prev + step
            if ts > expected_next:
                ranges.append((expected_next, ts - step))
        prev = ts
    
    # Leading gap: window start to first candle
    if first_ts is not None and first_ts > effective_start:
        ranges.insert(0, (effective_start, first_ts - step))
    elif first_ts is None:
        # No candles at all in the window — entire range is a gap
        ranges.append((effective_start, effective_end))
    
    # Trailing gap: last candle to window end
    if last_ts is not None and last_ts < effective_end:
        trailing_start = last_ts + step
        if trailing_start <= effective_end:
            ranges.append((trailing_start, effective_end))
    
    # Filter out any invalid ranges
    ranges = [(s, e) for s, e in ranges if s <= e]
    
    return ranges


print("Gap detection loaded.")
# Out:
# Gap detection loaded.

# %%
# ── Cell 10: Run the backfill ────────────────────────────────────────────────
#
# This cell iterates through every (connector, pair, interval) combo that has
# gaps, finds the exact missing ranges, and fetches them from the exchange API.

if not selected_combos:
    print("Nothing to backfill.")
else:
    grand_total = 0
    grand_gaps = 0
    errors = []
    
    for i, combo in enumerate(selected_combos):
        connector = combo["connector"]
        pair = combo["pair"]
        interval = combo["interval"]
        step = combo["step"]
        
        ingester = INGESTERS.get(connector)
        if ingester is None:
            print(f"  ⚠ No ingester for '{connector}' — skipping")
            continue
        
        # Check that this connector supports this interval
        spec = INTERVAL_SPEC.get(interval)
        if not spec or spec.get(connector) is None:
            print(f"  ⚠ {connector} does not support {interval} — skipping {pair}")
            continue
        
        print(f"\n[{i+1}/{len(selected_combos)}] {connector} {pair} {interval} (est. {combo['missing']:,} missing)")
        
        # Find exact gaps (using per-interval window, not global 180-day)
        combo_ws = combo.get("window_start", window_start)
        gaps = find_gaps_in_window(coll, connector, pair, interval, step, combo_ws, now_ts)
        
        if not gaps:
            print(f"  ✓ No gaps found (may have been filled already)")
            continue
        
        total_missing_candles = sum(((e - s) // step) + 1 for s, e in gaps)
        print(f"  Found {len(gaps)} gap range(s), {total_missing_candles:,} missing candles")
        grand_gaps += len(gaps)
        
        combo_written = 0
        for gap_idx, (gs, ge) in enumerate(gaps):
            candles_needed = ((ge - gs) // step) + 1
            if gap_idx < 3 or gap_idx == len(gaps) - 1:  # Print first 3 and last
                print(f"    Range {gap_idx+1}/{len(gaps)}: {fmt_ts(gs)} → {fmt_ts(ge)} ({candles_needed:,} candles)")
            elif gap_idx == 3:
                print(f"    ... ({len(gaps) - 4} more ranges) ...")
            
            try:
                written = ingester(coll, pair, interval, gs, ge)
                combo_written += written
            except Exception as e:
                err_msg = f"{connector} {pair} {interval} range {fmt_ts(gs)}→{fmt_ts(ge)}: {e}"
                errors.append(err_msg)
                print(f"    ✗ ERROR: {e}")
        
        grand_total += combo_written
        print(f"  → Wrote {combo_written:,} candles")
    
    print(f"\n{'═' * 70}")
    print(f"BACKFILL COMPLETE")
    print(f"  Gap ranges processed: {grand_gaps:,}")
    print(f"  Total candles written: {grand_total:,}")
    if errors:
        print(f"  Errors: {len(errors)}")
        for e in errors[:10]:
            print(f"    ✗ {e}")
        if len(errors) > 10:
            print(f"    ... and {len(errors) - 10} more")
    else:
        print(f"  Errors: 0 ✓")
    print(f"{'═' * 70}")
# Out:
# [1/444] coinbase BTC-USD 15m (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:00 (2 candles)
#   → Wrote 2 candles
#
# [2/444] coinbase BTC-USD 1d (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 00:00 → 2026-04-03 00:00 (1 candles)
#   → Wrote 1 candles
#
# [3/444] coinbase BTC-USD 1h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 23:00 → 2026-04-03 23:00 (1 candles)
#   → Wrote 1 candles
#
# [4/444] coinbase BTC-USD 1m (est. 29 missing)
#   Found 1 gap range(s), 29 missing candles
#     Range 1/1: 2026-04-03 23:54 → 2026-04-04 00:22 (29 candles)
#   → Wrote 29 candles
#
# [5/444] coinbase BTC-USD 5m (est. 7 missing)
#   Found 1 gap range(s), 6 missing candles
#     Range 1/1: 2026-04-03 23:50 → 2026-04-04 00:15 (6 candles)
#   → Wrote 6 candles
#
# [6/444] coinbase ETH-USD 15m (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:00 (2 candles)
#   → Wrote 2 candles
#
# [7/444] coinbase ETH-USD 1d (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 00:00 → 2026-04-03 00:00 (1 candles)
#   → Wrote 1 candles
#
# [8/444] coinbase ETH-USD 1h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 23:00 → 2026-04-03 23:00 (1 candles)
#   → Wrote 1 candles
#
# [9/444] coinbase ETH-USD 1m (est. 29 missing)
#   Found 1 gap range(s), 29 missing candles
#     Range 1/1: 2026-04-03 23:54 → 2026-04-04 00:22 (29 candles)
#   → Wrote 29 candles
#
# [10/444] coinbase ETH-USD 5m (est. 7 missing)
#   Found 1 gap range(s), 6 missing candles
#     Range 1/1: 2026-04-03 23:50 → 2026-04-04 00:15 (6 candles)
#   → Wrote 6 candles
#
# [11/444] coinbase USDT-USD 15m (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:00 (2 candles)
#   → Wrote 2 candles
#
# [12/444] coinbase USDT-USD 1d (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 00:00 → 2026-04-03 00:00 (1 candles)
#   → Wrote 1 candles
#
# [13/444] coinbase USDT-USD 1h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 23:00 → 2026-04-03 23:00 (1 candles)
#   → Wrote 1 candles
#
# [14/444] coinbase USDT-USD 1m (est. 29 missing)
#   Found 1 gap range(s), 29 missing candles
#     Range 1/1: 2026-04-03 23:54 → 2026-04-04 00:22 (29 candles)
#   → Wrote 29 candles
#
# [15/444] coinbase USDT-USD 5m (est. 7 missing)
#   Found 1 gap range(s), 6 missing candles
#     Range 1/1: 2026-04-03 23:50 → 2026-04-04 00:15 (6 candles)
#   → Wrote 6 candles
#
# [16/444] mexc ADA-USDT 15m (est. 4 missing)
#   Found 1 gap range(s), 3 missing candles
#     Range 1/1: 2026-04-03 23:30 → 2026-04-04 00:00 (3 candles)
#   → Wrote 2 candles
#
# [17/444] mexc ADA-USDT 1d (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-02 00:00 → 2026-04-03 00:00 (2 candles)
#   → Wrote 1 candles
#
# [18/444] mexc ADA-USDT 1h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 22:00 → 2026-04-03 23:00 (2 candles)
#   → Wrote 1 candles
#
# [19/444] mexc ADA-USDT 1m (est. 30 missing)
#   Found 1 gap range(s), 30 missing candles
#     Range 1/1: 2026-04-03 23:53 → 2026-04-04 00:22 (30 candles)
#   → Wrote 29 candles
#
# [20/444] mexc ADA-USDT 4h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 16:00 → 2026-04-03 20:00 (2 candles)
#   → Wrote 1 candles
#
# [21/444] mexc ADA-USDT 5m (est. 7 missing)
#   Found 1 gap range(s), 6 missing candles
#     Range 1/1: 2026-04-03 23:50 → 2026-04-04 00:15 (6 candles)
#   → Wrote 5 candles
#
# [22/444] mexc APT-USDT 15m (est. 4 missing)
#   Found 1 gap range(s), 3 missing candles
#     Range 1/1: 2026-04-03 23:30 → 2026-04-04 00:00 (3 candles)
#   → Wrote 2 candles
#
# [23/444] mexc APT-USDT 1d (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-02 00:00 → 2026-04-03 00:00 (2 candles)
#   → Wrote 1 candles
#
# [24/444] mexc APT-USDT 1h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 22:00 → 2026-04-03 23:00 (2 candles)
#   → Wrote 1 candles
#
# [25/444] mexc APT-USDT 1m (est. 28 missing)
#   Found 1 gap range(s), 28 missing candles
#     Range 1/1: 2026-04-03 23:55 → 2026-04-04 00:22 (28 candles)
#   → Wrote 27 candles
#
# [26/444] mexc APT-USDT 4h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 16:00 → 2026-04-03 20:00 (2 candles)
#   → Wrote 1 candles
#
# [27/444] mexc APT-USDT 5m (est. 7 missing)
#   Found 1 gap range(s), 6 missing candles
#     Range 1/1: 2026-04-03 23:50 → 2026-04-04 00:15 (6 candles)
#   → Wrote 5 candles
#
# [28/444] mexc ASTER-USDT 15m (est. 4 missing)
#   Found 1 gap range(s), 3 missing candles
#     Range 1/1: 2026-04-03 23:30 → 2026-04-04 00:00 (3 candles)
#   → Wrote 2 candles
#
# [29/444] mexc ASTER-USDT 1d (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-02 00:00 → 2026-04-03 00:00 (2 candles)
#   → Wrote 1 candles
#
# [30/444] mexc ASTER-USDT 1h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 22:00 → 2026-04-03 23:00 (2 candles)
#   → Wrote 1 candles
#
# [31/444] mexc ASTER-USDT 1m (est. 25 missing)
#   Found 1 gap range(s), 25 missing candles
#     Range 1/1: 2026-04-03 23:58 → 2026-04-04 00:22 (25 candles)
#   → Wrote 24 candles
#
# [32/444] mexc ASTER-USDT 4h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 20:00 → 2026-04-03 20:00 (1 candles)
#   → Wrote 0 candles
#
# [33/444] mexc ASTER-USDT 5m (est. 6 missing)
#   Found 1 gap range(s), 5 missing candles
#     Range 1/1: 2026-04-03 23:55 → 2026-04-04 00:15 (5 candles)
#   → Wrote 4 candles
#
# [34/444] mexc ATOM-USDT 15m (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:00 (2 candles)
#   → Wrote 1 candles
#
# [35/444] mexc ATOM-USDT 1d (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 00:00 → 2026-04-03 00:00 (1 candles)
#   → Wrote 0 candles
#
# [36/444] mexc ATOM-USDT 1h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 23:00 → 2026-04-03 23:00 (1 candles)
#   → Wrote 0 candles
#
# [37/444] mexc ATOM-USDT 1m (est. 23 missing)
#   Found 1 gap range(s), 23 missing candles
#     Range 1/1: 2026-04-04 00:00 → 2026-04-04 00:22 (23 candles)
#   → Wrote 22 candles
#
# [38/444] mexc ATOM-USDT 4h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 20:00 → 2026-04-03 20:00 (1 candles)
#   → Wrote 0 candles
#
# [39/444] mexc ATOM-USDT 5m (est. 6 missing)
#   Found 1 gap range(s), 5 missing candles
#     Range 1/1: 2026-04-03 23:55 → 2026-04-04 00:15 (5 candles)
#   → Wrote 4 candles
#
# [40/444] mexc BNB-USDT 15m (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:00 (2 candles)
#   → Wrote 1 candles
#
# [41/444] mexc BNB-USDT 1d (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 00:00 → 2026-04-03 00:00 (1 candles)
#   → Wrote 0 candles
#
# [42/444] mexc BNB-USDT 1h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 23:00 → 2026-04-03 23:00 (1 candles)
#   → Wrote 0 candles
#
# [43/444] mexc BNB-USDT 1m (est. 20 missing)
#   Found 1 gap range(s), 20 missing candles
#     Range 1/1: 2026-04-04 00:03 → 2026-04-04 00:22 (20 candles)
#   → Wrote 19 candles
#
# [44/444] mexc BNB-USDT 4h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 20:00 → 2026-04-03 20:00 (1 candles)
#   → Wrote 0 candles
#
# [45/444] mexc BNB-USDT 5m (est. 5 missing)
#   Found 1 gap range(s), 4 missing candles
#     Range 1/1: 2026-04-04 00:00 → 2026-04-04 00:15 (4 candles)
#   → Wrote 3 candles
#
# [46/444] mexc BTC-USDT 15m (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:00 (2 candles)
#   → Wrote 1 candles
#
# [47/444] mexc BTC-USDT 1d (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 00:00 → 2026-04-03 00:00 (1 candles)
#   → Wrote 0 candles
#
# [48/444] mexc BTC-USDT 1h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 23:00 → 2026-04-03 23:00 (1 candles)
#   → Wrote 0 candles
#
# [49/444] mexc BTC-USDT 1m (est. 19 missing)
#   Found 2 gap range(s), 19 missing candles
#     Range 1/2: 2026-04-04 00:03 → 2026-04-04 00:03 (1 candles)
#     Range 2/2: 2026-04-04 00:05 → 2026-04-04 00:22 (18 candles)
#   → Wrote 17 candles
#
# [50/444] mexc BTC-USDT 4h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 20:00 → 2026-04-03 20:00 (1 candles)
#   → Wrote 0 candles
#
# [51/444] mexc BTC-USDT 5m (est. 5 missing)
#   Found 2 gap range(s), 4 missing candles
#     Range 1/2: 2026-04-03 23:55 → 2026-04-03 23:55 (1 candles)
#     Range 2/2: 2026-04-04 00:05 → 2026-04-04 00:15 (3 candles)
#   → Wrote 2 candles
#
# [52/444] mexc DOGE-USDT 15m (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:00 (2 candles)
#   → Wrote 1 candles
#
# [53/444] mexc DOGE-USDT 1d (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 00:00 → 2026-04-03 00:00 (1 candles)
#   → Wrote 0 candles
#
# [54/444] mexc DOGE-USDT 1h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 23:00 → 2026-04-03 23:00 (1 candles)
#   → Wrote 0 candles
#
# [55/444] mexc DOGE-USDT 1m (est. 16 missing)
#   Found 1 gap range(s), 16 missing candles
#     Range 1/1: 2026-04-04 00:07 → 2026-04-04 00:22 (16 candles)
#   → Wrote 15 candles
#
# [56/444] mexc DOGE-USDT 4h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 20:00 → 2026-04-03 20:00 (1 candles)
#   → Wrote 0 candles
#
# [57/444] mexc DOGE-USDT 5m (est. 4 missing)
#   Found 1 gap range(s), 3 missing candles
#     Range 1/1: 2026-04-04 00:05 → 2026-04-04 00:15 (3 candles)
#   → Wrote 2 candles
#
# [58/444] mexc DOT-USDT 15m (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:00 (2 candles)
#   → Wrote 1 candles
#
# [59/444] mexc DOT-USDT 1d (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 00:00 → 2026-04-03 00:00 (1 candles)
#   → Wrote 0 candles
#
# [60/444] mexc DOT-USDT 1h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 23:00 → 2026-04-03 23:00 (1 candles)
#   → Wrote 0 candles
#
# [61/444] mexc DOT-USDT 1m (est. 13 missing)
#   Found 1 gap range(s), 14 missing candles
#     Range 1/1: 2026-04-04 00:10 → 2026-04-04 00:23 (14 candles)
#   → Wrote 13 candles
#
# [62/444] mexc DOT-USDT 4h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 20:00 → 2026-04-03 20:00 (1 candles)
#   → Wrote 0 candles
#
# [63/444] mexc DOT-USDT 5m (est. 4 missing)
#   Found 1 gap range(s), 3 missing candles
#     Range 1/1: 2026-04-04 00:05 → 2026-04-04 00:15 (3 candles)
#   → Wrote 2 candles
#
# [64/444] mexc ETH-USDT 15m (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:00 (2 candles)
#   → Wrote 1 candles
#
# [65/444] mexc ETH-USDT 1d (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 00:00 → 2026-04-03 00:00 (1 candles)
#   → Wrote 0 candles
#
# [66/444] mexc ETH-USDT 1h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 23:00 → 2026-04-03 23:00 (1 candles)
#   → Wrote 0 candles
#
# [67/444] mexc ETH-USDT 1m (est. 11 missing)
#   Found 1 gap range(s), 12 missing candles
#     Range 1/1: 2026-04-04 00:12 → 2026-04-04 00:23 (12 candles)
#   → Wrote 11 candles
#
# [68/444] mexc ETH-USDT 4h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 20:00 → 2026-04-03 20:00 (1 candles)
#   → Wrote 0 candles
#
# [69/444] mexc ETH-USDT 5m (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-04 00:10 → 2026-04-04 00:15 (2 candles)
#   → Wrote 1 candles
#
# [70/444] mexc FET-USDT 15m (est. 4 missing)
#   Found 1 gap range(s), 3 missing candles
#     Range 1/1: 2026-04-03 23:30 → 2026-04-04 00:00 (3 candles)
#   → Wrote 2 candles
#
# [71/444] mexc FET-USDT 1d (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-02 00:00 → 2026-04-03 00:00 (2 candles)
#   → Wrote 1 candles
#
# [72/444] mexc FET-USDT 1h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 22:00 → 2026-04-03 23:00 (2 candles)
#   → Wrote 1 candles
#
# [73/444] mexc FET-USDT 1m (est. 34 missing)
#   Found 1 gap range(s), 35 missing candles
#     Range 1/1: 2026-04-03 23:49 → 2026-04-04 00:23 (35 candles)
#   → Wrote 34 candles
#
# [74/444] mexc FET-USDT 4h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 16:00 → 2026-04-03 20:00 (2 candles)
#   → Wrote 1 candles
#
# [75/444] mexc FET-USDT 5m (est. 8 missing)
#   Found 1 gap range(s), 7 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:15 (7 candles)
#   → Wrote 6 candles
#
# [76/444] mexc HYPE-USDT 15m (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-04 00:00 → 2026-04-04 00:00 (1 candles)
#   → Wrote 0 candles
#
# [77/444] mexc HYPE-USDT 1d (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 00:00 → 2026-04-03 00:00 (1 candles)
#   → Wrote 0 candles
#
# [78/444] mexc HYPE-USDT 1h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 23:00 → 2026-04-03 23:00 (1 candles)
#   → Wrote 0 candles
#
# [79/444] mexc HYPE-USDT 1m (est. 9 missing)
#   Found 1 gap range(s), 10 missing candles
#     Range 1/1: 2026-04-04 00:14 → 2026-04-04 00:23 (10 candles)
#   → Wrote 9 candles
#
# [80/444] mexc HYPE-USDT 4h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 20:00 → 2026-04-03 20:00 (1 candles)
#   → Wrote 0 candles
#
# [81/444] mexc HYPE-USDT 5m (est. 4 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-04 00:10 → 2026-04-04 00:15 (2 candles)
#   → Wrote 1 candles
#
# [82/444] mexc ICP-USDT 15m (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-04 00:00 → 2026-04-04 00:00 (1 candles)
#   → Wrote 0 candles
#
# [83/444] mexc ICP-USDT 1d (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 00:00 → 2026-04-03 00:00 (1 candles)
#   → Wrote 0 candles
#
# [84/444] mexc ICP-USDT 1h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 23:00 → 2026-04-03 23:00 (1 candles)
#   → Wrote 0 candles
#
# [85/444] mexc ICP-USDT 1m (est. 32 missing)
#   Found 3 gap range(s), 33 missing candles
#     Range 1/3: 2026-04-03 23:49 → 2026-04-04 00:13 (25 candles)
#     Range 2/3: 2026-04-04 00:15 → 2026-04-04 00:20 (6 candles)
#     Range 3/3: 2026-04-04 00:22 → 2026-04-04 00:23 (2 candles)
#   → Wrote 30 candles
#
# [86/444] mexc ICP-USDT 4h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 16:00 → 2026-04-03 20:00 (2 candles)
#   → Wrote 1 candles
#
# [87/444] mexc ICP-USDT 5m (est. 8 missing)
#   Found 1 gap range(s), 7 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:15 (7 candles)
#   → Wrote 6 candles
#
# [88/444] mexc LTC-USDT 15m (est. 4 missing)
#   Found 1 gap range(s), 3 missing candles
#     Range 1/1: 2026-04-03 23:30 → 2026-04-04 00:00 (3 candles)
#   → Wrote 2 candles
#
# [89/444] mexc LTC-USDT 1d (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-02 00:00 → 2026-04-03 00:00 (2 candles)
#   → Wrote 1 candles
#
# [90/444] mexc LTC-USDT 1h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 22:00 → 2026-04-03 23:00 (2 candles)
#   → Wrote 1 candles
#
# [91/444] mexc LTC-USDT 1m (est. 108 missing)
#   Found 4 gap range(s), 109 missing candles
#     Range 1/4: 2026-04-03 22:13 → 2026-04-03 22:45 (33 candles)
#     Range 2/4: 2026-04-03 22:47 → 2026-04-03 23:04 (18 candles)
#     Range 3/4: 2026-04-03 23:06 → 2026-04-03 23:28 (23 candles)
#     Range 4/4: 2026-04-03 23:49 → 2026-04-04 00:23 (35 candles)
#   → Wrote 105 candles
#
# [92/444] mexc LTC-USDT 4h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 16:00 → 2026-04-03 20:00 (2 candles)
#   → Wrote 1 candles
#
# [93/444] mexc LTC-USDT 5m (est. 8 missing)
#   Found 1 gap range(s), 7 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:15 (7 candles)
#   → Wrote 6 candles
#
# [94/444] mexc OP-USDT 15m (est. 4 missing)
#   Found 1 gap range(s), 3 missing candles
#     Range 1/1: 2026-04-03 23:30 → 2026-04-04 00:00 (3 candles)
#   → Wrote 2 candles
#
# [95/444] mexc OP-USDT 1d (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-02 00:00 → 2026-04-03 00:00 (2 candles)
#   → Wrote 1 candles
#
# [96/444] mexc OP-USDT 1h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 22:00 → 2026-04-03 23:00 (2 candles)
#   → Wrote 1 candles
#
# [97/444] mexc OP-USDT 1m (est. 34 missing)
#   Found 1 gap range(s), 35 missing candles
#     Range 1/1: 2026-04-03 23:49 → 2026-04-04 00:23 (35 candles)
#   → Wrote 34 candles
#
# [98/444] mexc OP-USDT 4h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 16:00 → 2026-04-03 20:00 (2 candles)
#   → Wrote 1 candles
#
# [99/444] mexc OP-USDT 5m (est. 8 missing)
#   Found 1 gap range(s), 7 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:15 (7 candles)
#   → Wrote 6 candles
#
# [100/444] mexc PEPE-USDT 15m (est. 4 missing)
#   Found 1 gap range(s), 3 missing candles
#     Range 1/1: 2026-04-03 23:30 → 2026-04-04 00:00 (3 candles)
#   → Wrote 2 candles
#
# [101/444] mexc PEPE-USDT 1d (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-02 00:00 → 2026-04-03 00:00 (2 candles)
#   → Wrote 1 candles
#
# [102/444] mexc PEPE-USDT 1h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 22:00 → 2026-04-03 23:00 (2 candles)
#   → Wrote 1 candles
#
# [103/444] mexc PEPE-USDT 1m (est. 34 missing)
#   Found 1 gap range(s), 35 missing candles
#     Range 1/1: 2026-04-03 23:49 → 2026-04-04 00:23 (35 candles)
#   → Wrote 34 candles
#
# [104/444] mexc PEPE-USDT 4h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 16:00 → 2026-04-03 20:00 (2 candles)
#   → Wrote 1 candles
#
# [105/444] mexc PEPE-USDT 5m (est. 8 missing)
#   Found 1 gap range(s), 7 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:15 (7 candles)
#   → Wrote 6 candles
#
# [106/444] mexc PUMP-USDT 15m (est. 4 missing)
#   Found 1 gap range(s), 3 missing candles
#     Range 1/1: 2026-04-03 23:30 → 2026-04-04 00:00 (3 candles)
#   → Wrote 2 candles
#
# [107/444] mexc PUMP-USDT 1d (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-02 00:00 → 2026-04-03 00:00 (2 candles)
#   → Wrote 1 candles
#
# [108/444] mexc PUMP-USDT 1h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 22:00 → 2026-04-03 23:00 (2 candles)
#   → Wrote 1 candles
#
# [109/444] mexc PUMP-USDT 1m (est. 104 missing)
#   Found 3 gap range(s), 105 missing candles
#     Range 1/3: 2026-04-03 22:13 → 2026-04-03 22:39 (27 candles)
#     Range 2/3: 2026-04-03 22:41 → 2026-04-03 23:23 (43 candles)
#     Range 3/3: 2026-04-03 23:49 → 2026-04-04 00:23 (35 candles)
#   → Wrote 102 candles
#
# [110/444] mexc PUMP-USDT 4h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 16:00 → 2026-04-03 20:00 (2 candles)
#   → Wrote 1 candles
#
# [111/444] mexc PUMP-USDT 5m (est. 8 missing)
#   Found 1 gap range(s), 7 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:15 (7 candles)
#   → Wrote 6 candles
#
# [112/444] mexc RENDER-USDT 15m (est. 4 missing)
#   Found 1 gap range(s), 3 missing candles
#     Range 1/1: 2026-04-03 23:30 → 2026-04-04 00:00 (3 candles)
#   → Wrote 2 candles
#
# [113/444] mexc RENDER-USDT 1d (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-02 00:00 → 2026-04-03 00:00 (2 candles)
#   → Wrote 1 candles
#
# [114/444] mexc RENDER-USDT 1h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 22:00 → 2026-04-03 23:00 (2 candles)
#   → Wrote 1 candles
#
# [115/444] mexc RENDER-USDT 1m (est. 34 missing)
#   Found 1 gap range(s), 35 missing candles
#     Range 1/1: 2026-04-03 23:49 → 2026-04-04 00:23 (35 candles)
#   → Wrote 34 candles
#
# [116/444] mexc RENDER-USDT 4h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 16:00 → 2026-04-03 20:00 (2 candles)
#   → Wrote 1 candles
#
# [117/444] mexc RENDER-USDT 5m (est. 8 missing)
#   Found 1 gap range(s), 7 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:15 (7 candles)
#   → Wrote 6 candles
#
# [118/444] mexc SAHARA-USDT 15m (est. 4 missing)
#   Found 1 gap range(s), 3 missing candles
#     Range 1/1: 2026-04-03 23:30 → 2026-04-04 00:00 (3 candles)
#   → Wrote 2 candles
#
# [119/444] mexc SAHARA-USDT 1d (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-02 00:00 → 2026-04-03 00:00 (2 candles)
#   → Wrote 1 candles
#
# [120/444] mexc SAHARA-USDT 1h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 22:00 → 2026-04-03 23:00 (2 candles)
#   → Wrote 1 candles
#
# [121/444] mexc SAHARA-USDT 1m (est. 124 missing)
#   Found 7 gap range(s), 126 missing candles
#     Range 1/7: 2026-04-03 22:13 → 2026-04-03 23:25 (73 candles)
#     Range 2/7: 2026-04-03 23:27 → 2026-04-03 23:30 (4 candles)
#     Range 3/7: 2026-04-03 23:32 → 2026-04-03 23:37 (6 candles)
#     ... (3 more ranges) ...
#     Range 7/7: 2026-04-04 00:08 → 2026-04-04 00:24 (17 candles)
#   → Wrote 119 candles
#
# [122/444] mexc SAHARA-USDT 4h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 16:00 → 2026-04-03 20:00 (2 candles)
#   → Wrote 1 candles
#
# [123/444] mexc SAHARA-USDT 5m (est. 8 missing)
#   Found 1 gap range(s), 8 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:20 (8 candles)
#   → Wrote 7 candles
#
# [124/444] mexc SAL-USDT 15m (est. 4 missing)
#   Found 1 gap range(s), 3 missing candles
#     Range 1/1: 2026-04-03 23:30 → 2026-04-04 00:00 (3 candles)
#   → Wrote 2 candles
#
# [125/444] mexc SAL-USDT 1d (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-02 00:00 → 2026-04-03 00:00 (2 candles)
#   → Wrote 1 candles
#
# [126/444] mexc SAL-USDT 1h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 22:00 → 2026-04-03 23:00 (2 candles)
#   → Wrote 1 candles
#
# [127/444] mexc SAL-USDT 1m (est. 34 missing)
#   Found 1 gap range(s), 36 missing candles
#     Range 1/1: 2026-04-03 23:49 → 2026-04-04 00:24 (36 candles)
#   → Wrote 35 candles
#
# [128/444] mexc SAL-USDT 4h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 16:00 → 2026-04-03 20:00 (2 candles)
#   → Wrote 1 candles
#
# [129/444] mexc SAL-USDT 5m (est. 8 missing)
#   Found 1 gap range(s), 8 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:20 (8 candles)
#   → Wrote 7 candles
#
# [130/444] mexc SHIB-USDT 15m (est. 4 missing)
#   Found 1 gap range(s), 3 missing candles
#     Range 1/1: 2026-04-03 23:30 → 2026-04-04 00:00 (3 candles)
#   → Wrote 2 candles
#
# [131/444] mexc SHIB-USDT 1d (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-02 00:00 → 2026-04-03 00:00 (2 candles)
#   → Wrote 1 candles
#
# [132/444] mexc SHIB-USDT 1h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 22:00 → 2026-04-03 23:00 (2 candles)
#   → Wrote 1 candles
#
# [133/444] mexc SHIB-USDT 1m (est. 34 missing)
#   Found 1 gap range(s), 36 missing candles
#     Range 1/1: 2026-04-03 23:49 → 2026-04-04 00:24 (36 candles)
#   → Wrote 35 candles
#
# [134/444] mexc SHIB-USDT 4h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 16:00 → 2026-04-03 20:00 (2 candles)
#   → Wrote 1 candles
#
# [135/444] mexc SHIB-USDT 5m (est. 8 missing)
#   Found 1 gap range(s), 8 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:20 (8 candles)
#   → Wrote 7 candles
#
# [136/444] mexc SOL-USDT 15m (est. 4 missing)
#   Found 1 gap range(s), 3 missing candles
#     Range 1/1: 2026-04-03 23:30 → 2026-04-04 00:00 (3 candles)
#   → Wrote 2 candles
#
# [137/444] mexc SOL-USDT 1d (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-02 00:00 → 2026-04-03 00:00 (2 candles)
#   → Wrote 1 candles
#
# [138/444] mexc SOL-USDT 1h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 22:00 → 2026-04-03 23:00 (2 candles)
#   → Wrote 1 candles
#
# [139/444] mexc SOL-USDT 1m (est. 107 missing)
#   Found 5 gap range(s), 109 missing candles
#     Range 1/5: 2026-04-03 22:13 → 2026-04-03 22:33 (21 candles)
#     Range 2/5: 2026-04-03 22:35 → 2026-04-03 23:28 (54 candles)
#     Range 3/5: 2026-04-03 23:49 → 2026-04-04 00:07 (19 candles)
#     ... (1 more ranges) ...
#     Range 5/5: 2026-04-04 00:11 → 2026-04-04 00:24 (14 candles)
#   → Wrote 104 candles
#
# [140/444] mexc SOL-USDT 4h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 16:00 → 2026-04-03 20:00 (2 candles)
#   → Wrote 1 candles
#
# [141/444] mexc SOL-USDT 5m (est. 10 missing)
#   Found 2 gap range(s), 10 missing candles
#     Range 1/2: 2026-04-03 22:10 → 2026-04-03 22:15 (2 candles)
#     Range 2/2: 2026-04-03 23:45 → 2026-04-04 00:20 (8 candles)
#   → Wrote 8 candles
#
# [142/444] mexc SUI-USDT 15m (est. 4 missing)
#   Found 1 gap range(s), 3 missing candles
#     Range 1/1: 2026-04-03 23:30 → 2026-04-04 00:00 (3 candles)
#   → Wrote 2 candles
#
# [143/444] mexc SUI-USDT 1d (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-02 00:00 → 2026-04-03 00:00 (2 candles)
#   → Wrote 1 candles
#
# [144/444] mexc SUI-USDT 1h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 22:00 → 2026-04-03 23:00 (2 candles)
#   → Wrote 1 candles
#
# [145/444] mexc SUI-USDT 1m (est. 33 missing)
#   Found 2 gap range(s), 35 missing candles
#     Range 1/2: 2026-04-03 23:49 → 2026-04-04 00:05 (17 candles)
#     Range 2/2: 2026-04-04 00:07 → 2026-04-04 00:24 (18 candles)
#   → Wrote 33 candles
#
# [146/444] mexc SUI-USDT 4h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 16:00 → 2026-04-03 20:00 (2 candles)
#   → Wrote 1 candles
#
# [147/444] mexc SUI-USDT 5m (est. 8 missing)
#   Found 1 gap range(s), 8 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:20 (8 candles)
#   → Wrote 7 candles
#
# [148/444] mexc TON-USDT 15m (est. 4 missing)
#   Found 1 gap range(s), 3 missing candles
#     Range 1/1: 2026-04-03 23:30 → 2026-04-04 00:00 (3 candles)
#   → Wrote 2 candles
#
# [149/444] mexc TON-USDT 1d (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-02 00:00 → 2026-04-03 00:00 (2 candles)
#   → Wrote 1 candles
#
# [150/444] mexc TON-USDT 1h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 22:00 → 2026-04-03 23:00 (2 candles)
#   → Wrote 1 candles
#
# [151/444] mexc TON-USDT 1m (est. 34 missing)
#   Found 1 gap range(s), 36 missing candles
#     Range 1/1: 2026-04-03 23:49 → 2026-04-04 00:24 (36 candles)
#   → Wrote 35 candles
#
# [152/444] mexc TON-USDT 4h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 16:00 → 2026-04-03 20:00 (2 candles)
#   → Wrote 1 candles
#
# [153/444] mexc TON-USDT 5m (est. 8 missing)
#   Found 1 gap range(s), 8 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:20 (8 candles)
#   → Wrote 7 candles
#
# [154/444] mexc TRX-USDT 15m (est. 4 missing)
#   Found 1 gap range(s), 3 missing candles
#     Range 1/1: 2026-04-03 23:30 → 2026-04-04 00:00 (3 candles)
#   → Wrote 2 candles
#
# [155/444] mexc TRX-USDT 1d (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-02 00:00 → 2026-04-03 00:00 (2 candles)
#   → Wrote 1 candles
#
# [156/444] mexc TRX-USDT 1h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 22:00 → 2026-04-03 23:00 (2 candles)
#   → Wrote 1 candles
#
# [157/444] mexc TRX-USDT 1m (est. 34 missing)
#   Found 1 gap range(s), 36 missing candles
#     Range 1/1: 2026-04-03 23:49 → 2026-04-04 00:24 (36 candles)
#   → Wrote 35 candles
#
# [158/444] mexc TRX-USDT 4h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 16:00 → 2026-04-03 20:00 (2 candles)
#   → Wrote 1 candles
#
# [159/444] mexc TRX-USDT 5m (est. 8 missing)
#   Found 1 gap range(s), 8 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:20 (8 candles)
#   → Wrote 7 candles
#
# [160/444] mexc WLD-USDT 15m (est. 4 missing)
#   Found 1 gap range(s), 3 missing candles
#     Range 1/1: 2026-04-03 23:30 → 2026-04-04 00:00 (3 candles)
#   → Wrote 2 candles
#
# [161/444] mexc WLD-USDT 1d (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-02 00:00 → 2026-04-03 00:00 (2 candles)
#   → Wrote 1 candles
#
# [162/444] mexc WLD-USDT 1h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 22:00 → 2026-04-03 23:00 (2 candles)
#   → Wrote 1 candles
#
# [163/444] mexc WLD-USDT 1m (est. 34 missing)
#   Found 1 gap range(s), 36 missing candles
#     Range 1/1: 2026-04-03 23:49 → 2026-04-04 00:24 (36 candles)
#   → Wrote 35 candles
#
# [164/444] mexc WLD-USDT 4h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 16:00 → 2026-04-03 20:00 (2 candles)
#   → Wrote 1 candles
#
# [165/444] mexc WLD-USDT 5m (est. 8 missing)
#   Found 1 gap range(s), 8 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:20 (8 candles)
#   → Wrote 7 candles
#
# [166/444] mexc WLFI-USDT 15m (est. 4 missing)
#   Found 1 gap range(s), 3 missing candles
#     Range 1/1: 2026-04-03 23:30 → 2026-04-04 00:00 (3 candles)
#   → Wrote 2 candles
#
# [167/444] mexc WLFI-USDT 1d (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-02 00:00 → 2026-04-03 00:00 (2 candles)
#   → Wrote 1 candles
#
# [168/444] mexc WLFI-USDT 1h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 22:00 → 2026-04-03 23:00 (2 candles)
#   → Wrote 1 candles
#
# [169/444] mexc WLFI-USDT 1m (est. 34 missing)
#   Found 1 gap range(s), 36 missing candles
#     Range 1/1: 2026-04-03 23:49 → 2026-04-04 00:24 (36 candles)
#   → Wrote 35 candles
#
# [170/444] mexc WLFI-USDT 4h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 16:00 → 2026-04-03 20:00 (2 candles)
#   → Wrote 1 candles
#
# [171/444] mexc WLFI-USDT 5m (est. 8 missing)
#   Found 1 gap range(s), 8 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:20 (8 candles)
#   → Wrote 7 candles
#
# [172/444] mexc WXT-USDT 15m (est. 4 missing)
#   Found 1 gap range(s), 3 missing candles
#     Range 1/1: 2026-04-03 23:30 → 2026-04-04 00:00 (3 candles)
#   → Wrote 2 candles
#
# [173/444] mexc WXT-USDT 1d (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-02 00:00 → 2026-04-03 00:00 (2 candles)
#   → Wrote 1 candles
#
# [174/444] mexc WXT-USDT 1h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 22:00 → 2026-04-03 23:00 (2 candles)
#   → Wrote 1 candles
#
# [175/444] mexc WXT-USDT 1m (est. 34 missing)
#   Found 1 gap range(s), 37 missing candles
#     Range 1/1: 2026-04-03 23:49 → 2026-04-04 00:25 (37 candles)
#   → Wrote 36 candles
#
# [176/444] mexc WXT-USDT 4h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 16:00 → 2026-04-03 20:00 (2 candles)
#   → Wrote 1 candles
#
# [177/444] mexc WXT-USDT 5m (est. 8 missing)
#   Found 1 gap range(s), 8 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:20 (8 candles)
#   → Wrote 7 candles
#
# [178/444] mexc XLM-USDT 15m (est. 4 missing)
#   Found 1 gap range(s), 3 missing candles
#     Range 1/1: 2026-04-03 23:30 → 2026-04-04 00:00 (3 candles)
#   → Wrote 2 candles
#
# [179/444] mexc XLM-USDT 1d (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-02 00:00 → 2026-04-03 00:00 (2 candles)
#   → Wrote 1 candles
#
# [180/444] mexc XLM-USDT 1h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 22:00 → 2026-04-03 23:00 (2 candles)
#   → Wrote 1 candles
#
# [181/444] mexc XLM-USDT 1m (est. 34 missing)
#   Found 1 gap range(s), 37 missing candles
#     Range 1/1: 2026-04-03 23:49 → 2026-04-04 00:25 (37 candles)
#   → Wrote 36 candles
#
# [182/444] mexc XLM-USDT 4h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 16:00 → 2026-04-03 20:00 (2 candles)
#   → Wrote 1 candles
#
# [183/444] mexc XLM-USDT 5m (est. 8 missing)
#   Found 1 gap range(s), 8 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:20 (8 candles)
#   → Wrote 7 candles
#
# [184/444] mexc XMR-USDC 15m (est. 4 missing)
#   Found 1 gap range(s), 3 missing candles
#     Range 1/1: 2026-04-03 23:30 → 2026-04-04 00:00 (3 candles)
#   → Wrote 2 candles
#
# [185/444] mexc XMR-USDC 1d (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-02 00:00 → 2026-04-03 00:00 (2 candles)
#   → Wrote 1 candles
#
# [186/444] mexc XMR-USDC 1h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 22:00 → 2026-04-03 23:00 (2 candles)
#   → Wrote 1 candles
#
# [187/444] mexc XMR-USDC 1m (est. 80 missing)
#   Found 2 gap range(s), 83 missing candles
#     Range 1/2: 2026-04-03 22:13 → 2026-04-03 22:58 (46 candles)
#     Range 2/2: 2026-04-03 23:49 → 2026-04-04 00:25 (37 candles)
#   → Wrote 81 candles
#
# [188/444] mexc XMR-USDC 4h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 16:00 → 2026-04-03 20:00 (2 candles)
#   → Wrote 1 candles
#
# [189/444] mexc XMR-USDC 5m (est. 8 missing)
#   Found 1 gap range(s), 8 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:20 (8 candles)
#   → Wrote 7 candles
#
# [190/444] mexc XMR-USDT 15m (est. 4 missing)
#   Found 1 gap range(s), 3 missing candles
#     Range 1/1: 2026-04-03 23:30 → 2026-04-04 00:00 (3 candles)
#   → Wrote 2 candles
#
# [191/444] mexc XMR-USDT 1d (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-02 00:00 → 2026-04-03 00:00 (2 candles)
#   → Wrote 1 candles
#
# [192/444] mexc XMR-USDT 1h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 22:00 → 2026-04-03 23:00 (2 candles)
#   → Wrote 1 candles
#
# [193/444] mexc XMR-USDT 1m (est. 102 missing)
#   Found 2 gap range(s), 105 missing candles
#     Range 1/2: 2026-04-03 22:13 → 2026-04-03 23:20 (68 candles)
#     Range 2/2: 2026-04-03 23:49 → 2026-04-04 00:25 (37 candles)
#   → Wrote 103 candles
#
# [194/444] mexc XMR-USDT 4h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 16:00 → 2026-04-03 20:00 (2 candles)
#   → Wrote 1 candles
#
# [195/444] mexc XMR-USDT 5m (est. 8 missing)
#   Found 1 gap range(s), 8 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:20 (8 candles)
#   → Wrote 7 candles
#
# [196/444] mexc XRP-USDT 15m (est. 4 missing)
#   Found 1 gap range(s), 3 missing candles
#     Range 1/1: 2026-04-03 23:30 → 2026-04-04 00:00 (3 candles)
#   → Wrote 2 candles
#
# [197/444] mexc XRP-USDT 1d (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-02 00:00 → 2026-04-03 00:00 (2 candles)
#   → Wrote 1 candles
#
# [198/444] mexc XRP-USDT 1h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 22:00 → 2026-04-03 23:00 (2 candles)
#   → Wrote 1 candles
#
# [199/444] mexc XRP-USDT 1m (est. 108 missing)
#   Found 6 gap range(s), 111 missing candles
#     Range 1/6: 2026-04-03 22:13 → 2026-04-03 22:56 (44 candles)
#     Range 2/6: 2026-04-03 22:58 → 2026-04-03 23:09 (12 candles)
#     Range 3/6: 2026-04-03 23:11 → 2026-04-03 23:27 (17 candles)
#     ... (2 more ranges) ...
#     Range 6/6: 2026-04-04 00:16 → 2026-04-04 00:25 (10 candles)
#   → Wrote 105 candles
#
# [200/444] mexc XRP-USDT 4h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 16:00 → 2026-04-03 20:00 (2 candles)
#   → Wrote 1 candles
#
# [201/444] mexc XRP-USDT 5m (est. 22 missing)
#   Found 2 gap range(s), 22 missing candles
#     Range 1/2: 2026-04-03 22:10 → 2026-04-03 23:15 (14 candles)
#     Range 2/2: 2026-04-03 23:45 → 2026-04-04 00:20 (8 candles)
#   → Wrote 20 candles
#
# [202/444] mexc ZRO-USDT 15m (est. 4 missing)
#   Found 1 gap range(s), 3 missing candles
#     Range 1/1: 2026-04-03 23:30 → 2026-04-04 00:00 (3 candles)
#   → Wrote 2 candles
#
# [203/444] mexc ZRO-USDT 1d (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-02 00:00 → 2026-04-03 00:00 (2 candles)
#   → Wrote 1 candles
#
# [204/444] mexc ZRO-USDT 1h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 22:00 → 2026-04-03 23:00 (2 candles)
#   → Wrote 1 candles
#
# [205/444] mexc ZRO-USDT 1m (est. 88 missing)
#   Found 2 gap range(s), 91 missing candles
#     Range 1/2: 2026-04-03 22:13 → 2026-04-03 23:06 (54 candles)
#     Range 2/2: 2026-04-03 23:49 → 2026-04-04 00:25 (37 candles)
#   → Wrote 89 candles
#
# [206/444] mexc ZRO-USDT 4h (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 16:00 → 2026-04-03 20:00 (2 candles)
#   → Wrote 1 candles
#
# [207/444] mexc ZRO-USDT 5m (est. 18 missing)
#   Found 2 gap range(s), 18 missing candles
#     Range 1/2: 2026-04-03 22:05 → 2026-04-03 22:50 (10 candles)
#     Range 2/2: 2026-04-03 23:45 → 2026-04-04 00:20 (8 candles)
#   → Wrote 16 candles
#
# [208/444] nonkyc AAVE-USDT 15m (est. 16,724 missing)
#   Found 2 gap range(s), 16,724 missing candles
#     Range 1/2: 2025-10-06 00:15 → 2026-03-29 04:30 (16,722 candles)
#     Range 2/2: 2026-04-03 23:45 → 2026-04-04 00:00 (2 candles)
#   → Wrote 16,688 candles
#
# [209/444] nonkyc AAVE-USDT 1d (est. 77 missing)
#   Found 2 gap range(s), 77 missing candles
#     Range 1/2: 2025-10-06 00:00 → 2025-12-20 00:00 (76 candles)
#     Range 2/2: 2026-04-03 00:00 → 2026-04-03 00:00 (1 candles)
#   → Wrote 77 candles
#
# [210/444] nonkyc AAVE-USDT 1h (est. 4,108 missing)
#   Found 2 gap range(s), 4,108 missing candles
#     Range 1/2: 2025-10-06 00:00 → 2026-03-26 02:00 (4,107 candles)
#     Range 2/2: 2026-04-03 23:00 → 2026-04-03 23:00 (1 candles)
#   → Wrote 4,103 candles
#
# [211/444] nonkyc AAVE-USDT 4h (est. 953 missing)
#   Found 2 gap range(s), 953 missing candles
#     Range 1/2: 2025-10-06 00:00 → 2026-03-13 12:00 (952 candles)
#     Range 2/2: 2026-04-03 20:00 → 2026-04-03 20:00 (1 candles)
#   → Wrote 953 candles
#
# [212/444] nonkyc AAVE-USDT 5m (est. 7 missing)
#   Found 1 gap range(s), 7 missing candles
#     Range 1/1: 2026-04-03 23:50 → 2026-04-04 00:20 (7 candles)
#   → Wrote 7 candles
#
# [213/444] nonkyc ADA-USDT 15m (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:00 (2 candles)
#   → Wrote 2 candles
#
# [214/444] nonkyc ADA-USDT 1d (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 00:00 → 2026-04-03 00:00 (1 candles)
#   → Wrote 1 candles
#
# [215/444] nonkyc ADA-USDT 1h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 23:00 → 2026-04-03 23:00 (1 candles)
#   → Wrote 1 candles
#
# [216/444] nonkyc ADA-USDT 4h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 20:00 → 2026-04-03 20:00 (1 candles)
#   → Wrote 1 candles
#
# [217/444] nonkyc ADA-USDT 5m (est. 14 missing)
#   Found 5 gap range(s), 14 missing candles
#     Range 1/5: 2026-04-03 22:50 → 2026-04-03 22:55 (2 candles)
#     Range 2/5: 2026-04-03 23:05 → 2026-04-03 23:10 (2 candles)
#     Range 3/5: 2026-04-03 23:25 → 2026-04-03 23:25 (1 candles)
#     ... (1 more ranges) ...
#     Range 5/5: 2026-04-03 23:50 → 2026-04-04 00:20 (7 candles)
#   → Wrote 7 candles
#
# [218/444] nonkyc ALIAS-XMR 15m (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:00 (2 candles)
#   → Wrote 2 candles
#
# [219/444] nonkyc ALIAS-XMR 1d (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 00:00 → 2026-04-03 00:00 (1 candles)
#   → Wrote 1 candles
#
# [220/444] nonkyc ALIAS-XMR 1h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 23:00 → 2026-04-03 23:00 (1 candles)
#   → Wrote 1 candles
#
# [221/444] nonkyc ALIAS-XMR 4h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 20:00 → 2026-04-03 20:00 (1 candles)
#   → Wrote 1 candles
#
# [222/444] nonkyc ALIAS-XMR 5m (est. 17 missing)
#   Found 6 gap range(s), 17 missing candles
#     Range 1/6: 2026-04-03 21:55 → 2026-04-03 22:05 (3 candles)
#     Range 2/6: 2026-04-03 22:15 → 2026-04-03 22:20 (2 candles)
#     Range 3/6: 2026-04-03 23:00 → 2026-04-03 23:00 (1 candles)
#     ... (2 more ranges) ...
#     Range 6/6: 2026-04-03 23:40 → 2026-04-04 00:20 (9 candles)
#   → Wrote 4 candles
#
# [223/444] nonkyc ARB-USDT 15m (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:00 (2 candles)
#   → Wrote 2 candles
#
# [224/444] nonkyc ARB-USDT 1d (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 00:00 → 2026-04-03 00:00 (1 candles)
#   → Wrote 1 candles
#
# [225/444] nonkyc ARB-USDT 1h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 23:00 → 2026-04-03 23:00 (1 candles)
#   → Wrote 1 candles
#
# [226/444] nonkyc ARB-USDT 4h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 20:00 → 2026-04-03 20:00 (1 candles)
#   → Wrote 1 candles
#
# [227/444] nonkyc ARB-USDT 5m (est. 9 missing)
#   Found 3 gap range(s), 9 missing candles
#     Range 1/3: 2026-04-03 23:25 → 2026-04-03 23:25 (1 candles)
#     Range 2/3: 2026-04-03 23:40 → 2026-04-03 23:40 (1 candles)
#     Range 3/3: 2026-04-03 23:50 → 2026-04-04 00:20 (7 candles)
#   → Wrote 7 candles
#
# [228/444] nonkyc ARRR-USDT 15m (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:00 (2 candles)
#   → Wrote 2 candles
#
# [229/444] nonkyc ARRR-USDT 1d (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 00:00 → 2026-04-03 00:00 (1 candles)
#   → Wrote 1 candles
#
# [230/444] nonkyc ARRR-USDT 1h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 23:00 → 2026-04-03 23:00 (1 candles)
#   → Wrote 1 candles
#
# [231/444] nonkyc ARRR-USDT 4h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 20:00 → 2026-04-03 20:00 (1 candles)
#   → Wrote 1 candles
#
# [232/444] nonkyc ARRR-USDT 5m (est. 7 missing)
#   Found 1 gap range(s), 7 missing candles
#     Range 1/1: 2026-04-03 23:50 → 2026-04-04 00:20 (7 candles)
#   → Wrote 7 candles
#
# [233/444] nonkyc ARRR-XMR 15m (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:00 (2 candles)
#   → Wrote 2 candles
#
# [234/444] nonkyc ARRR-XMR 1d (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 00:00 → 2026-04-03 00:00 (1 candles)
#   → Wrote 1 candles
#
# [235/444] nonkyc ARRR-XMR 1h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 23:00 → 2026-04-03 23:00 (1 candles)
#   → Wrote 1 candles
#
# [236/444] nonkyc ARRR-XMR 4h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 20:00 → 2026-04-03 20:00 (1 candles)
#   → Wrote 1 candles
#
# [237/444] nonkyc ARRR-XMR 5m (est. 7 missing)
#   Found 1 gap range(s), 7 missing candles
#     Range 1/1: 2026-04-03 23:50 → 2026-04-04 00:20 (7 candles)
#   → Wrote 7 candles
#
# [238/444] nonkyc AVAX-USDT 15m (est. 4 missing)
#   Found 2 gap range(s), 3 missing candles
#     Range 1/2: 2026-04-03 23:15 → 2026-04-03 23:15 (1 candles)
#     Range 2/2: 2026-04-03 23:45 → 2026-04-04 00:00 (2 candles)
#   → Wrote 2 candles
#
# [239/444] nonkyc AVAX-USDT 1d (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 00:00 → 2026-04-03 00:00 (1 candles)
#   → Wrote 1 candles
#
# [240/444] nonkyc AVAX-USDT 1h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 23:00 → 2026-04-03 23:00 (1 candles)
#   → Wrote 1 candles
#
# [241/444] nonkyc AVAX-USDT 4h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 20:00 → 2026-04-03 20:00 (1 candles)
#   → Wrote 1 candles
#
# [242/444] nonkyc AVAX-USDT 5m (est. 10 missing)
#   Found 2 gap range(s), 10 missing candles
#     Range 1/2: 2026-04-03 23:15 → 2026-04-03 23:25 (3 candles)
#     Range 2/2: 2026-04-03 23:50 → 2026-04-04 00:20 (7 candles)
#   → Wrote 7 candles
#
# [243/444] nonkyc BCH-USDT 15m (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:00 (2 candles)
#   → Wrote 2 candles
#
# [244/444] nonkyc BCH-USDT 1d (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 00:00 → 2026-04-03 00:00 (1 candles)
#   → Wrote 1 candles
#
# [245/444] nonkyc BCH-USDT 1h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 23:00 → 2026-04-03 23:00 (1 candles)
#   → Wrote 1 candles
#
# [246/444] nonkyc BCH-USDT 4h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 20:00 → 2026-04-03 20:00 (1 candles)
#   → Wrote 1 candles
#
# [247/444] nonkyc BCH-USDT 5m (est. 7 missing)
#   Found 1 gap range(s), 7 missing candles
#     Range 1/1: 2026-04-03 23:50 → 2026-04-04 00:20 (7 candles)
#   → Wrote 7 candles
#
# [248/444] nonkyc BDX-USDT 15m (est. 3 missing)
#   Found 1 gap range(s), 2 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:00 (2 candles)
#   → Wrote 2 candles
#
# [249/444] nonkyc BDX-USDT 1d (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 00:00 → 2026-04-03 00:00 (1 candles)
#   → Wrote 1 candles
#
# [250/444] nonkyc BDX-USDT 1h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 23:00 → 2026-04-03 23:00 (1 candles)
#   → Wrote 1 candles
#
# [251/444] nonkyc BDX-USDT 4h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 20:00 → 2026-04-03 20:00 (1 candles)
#   → Wrote 1 candles
#
# [252/444] nonkyc BDX-USDT 5m (est. 7 missing)
#   Found 1 gap range(s), 7 missing candles
#     Range 1/1: 2026-04-03 23:50 → 2026-04-04 00:20 (7 candles)
#   → Wrote 7 candles
#
# [253/444] nonkyc BNB-USDT 15m (est. 16,726 missing)
#   Found 2 gap range(s), 16,726 missing candles
#     Range 1/2: 2025-10-06 00:15 → 2026-03-29 05:00 (16,724 candles)
#     Range 2/2: 2026-04-03 23:45 → 2026-04-04 00:00 (2 candles)
#   → Wrote 16,674 candles
#
# [254/444] nonkyc BNB-USDT 1d (est. 77 missing)
#   Found 2 gap range(s), 77 missing candles
#     Range 1/2: 2025-10-06 00:00 → 2025-12-20 00:00 (76 candles)
#     Range 2/2: 2026-04-03 00:00 → 2026-04-03 00:00 (1 candles)
#   → Wrote 77 candles
#
# [255/444] nonkyc BNB-USDT 1h (est. 4,108 missing)
#   Found 2 gap range(s), 4,108 missing candles
#     Range 1/2: 2025-10-06 00:00 → 2026-03-26 02:00 (4,107 candles)
#     Range 2/2: 2026-04-03 23:00 → 2026-04-03 23:00 (1 candles)
#   → Wrote 4,100 candles
#
# [256/444] nonkyc BNB-USDT 4h (est. 953 missing)
#   Found 2 gap range(s), 953 missing candles
#     Range 1/2: 2025-10-06 00:00 → 2026-03-13 12:00 (952 candles)
#     Range 2/2: 2026-04-03 20:00 → 2026-04-03 20:00 (1 candles)
#   → Wrote 953 candles
#
# [257/444] nonkyc BNB-USDT 5m (est. 50,375 missing)
#   Found 2 gap range(s), 50,376 missing candles
#     Range 1/2: 2025-10-06 00:20 → 2026-03-29 21:40 (50,369 candles)
#     Range 2/2: 2026-04-03 23:50 → 2026-04-04 00:20 (7 candles)
#   → Wrote 50,128 candles
#
# [258/444] nonkyc BTC-USDT 15m (est. 3 missing)
#   Found 1 gap range(s), 3 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:15 (3 candles)
#   → Wrote 3 candles
#
# [259/444] nonkyc BTC-USDT 1d (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 00:00 → 2026-04-03 00:00 (1 candles)
#   → Wrote 1 candles
#
# [260/444] nonkyc BTC-USDT 1h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 23:00 → 2026-04-03 23:00 (1 candles)
#   → Wrote 1 candles
#
# [261/444] nonkyc BTC-USDT 4h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 20:00 → 2026-04-03 20:00 (1 candles)
#   → Wrote 1 candles
#
# [262/444] nonkyc BTC-USDT 5m (est. 7 missing)
#   Found 1 gap range(s), 8 missing candles
#     Range 1/1: 2026-04-03 23:50 → 2026-04-04 00:25 (8 candles)
#   → Wrote 8 candles
#
# ...
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 00:00 → 2026-04-03 00:00 (1 candles)
#   → Wrote 1 candles
#
# [376/444] nonkyc SOL-USDT 1h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 23:00 → 2026-04-03 23:00 (1 candles)
#   → Wrote 1 candles
#
# [377/444] nonkyc SOL-USDT 4h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 20:00 → 2026-04-03 20:00 (1 candles)
#   → Wrote 1 candles
#
# [378/444] nonkyc SOL-USDT 5m (est. 7 missing)
#   Found 1 gap range(s), 8 missing candles
#     Range 1/1: 2026-04-03 23:50 → 2026-04-04 00:25 (8 candles)
#   → Wrote 8 candles
#
# [379/444] nonkyc TRX-USDT 15m (est. 16,726 missing)
#   Found 2 gap range(s), 16,727 missing candles
#     Range 1/2: 2025-10-06 00:15 → 2026-03-29 05:00 (16,724 candles)
#     Range 2/2: 2026-04-03 23:45 → 2026-04-04 00:15 (3 candles)
#   → Wrote 16,698 candles
#
# [380/444] nonkyc TRX-USDT 1d (est. 77 missing)
#   Found 2 gap range(s), 77 missing candles
#     Range 1/2: 2025-10-06 00:00 → 2025-12-20 00:00 (76 candles)
#     Range 2/2: 2026-04-03 00:00 → 2026-04-03 00:00 (1 candles)
#   → Wrote 77 candles
#
# [381/444] nonkyc TRX-USDT 1h (est. 4,108 missing)
#   Found 2 gap range(s), 4,108 missing candles
#     Range 1/2: 2025-10-06 00:00 → 2026-03-26 02:00 (4,107 candles)
#     Range 2/2: 2026-04-03 23:00 → 2026-04-03 23:00 (1 candles)
#   → Wrote 4,102 candles
#
# [382/444] nonkyc TRX-USDT 4h (est. 953 missing)
#   Found 2 gap range(s), 953 missing candles
#     Range 1/2: 2025-10-06 00:00 → 2026-03-13 12:00 (952 candles)
#     Range 2/2: 2026-04-03 20:00 → 2026-04-03 20:00 (1 candles)
#   → Wrote 953 candles
#
# [383/444] nonkyc TRX-USDT 5m (est. 50,374 missing)
#   Found 2 gap range(s), 50,377 missing candles
#     Range 1/2: 2025-10-06 00:20 → 2026-03-29 21:35 (50,368 candles)
#     Range 2/2: 2026-04-03 23:50 → 2026-04-04 00:30 (9 candles)
#   → Wrote 50,229 candles
#
# [384/444] nonkyc USDC-USDT 15m (est. 16,725 missing)
#   Found 2 gap range(s), 16,726 missing candles
#     Range 1/2: 2025-10-06 00:15 → 2026-03-29 04:45 (16,723 candles)
#     Range 2/2: 2026-04-03 23:45 → 2026-04-04 00:15 (3 candles)
#   → Wrote 16,691 candles
#
# [385/444] nonkyc USDC-USDT 1d (est. 77 missing)
#   Found 2 gap range(s), 77 missing candles
#     Range 1/2: 2025-10-06 00:00 → 2025-12-20 00:00 (76 candles)
#     Range 2/2: 2026-04-03 00:00 → 2026-04-03 00:00 (1 candles)
#   → Wrote 77 candles
#
# [386/444] nonkyc USDC-USDT 1h (est. 4,108 missing)
#   Found 2 gap range(s), 4,108 missing candles
#     Range 1/2: 2025-10-06 00:00 → 2026-03-26 02:00 (4,107 candles)
#     Range 2/2: 2026-04-03 23:00 → 2026-04-03 23:00 (1 candles)
#   → Wrote 4,108 candles
#
# [387/444] nonkyc USDC-USDT 30m (est. 8,546 missing)
#   Found 2 gap range(s), 8,623 missing candles
#     Range 1/2: 2025-10-06 00:00 → 2026-03-30 09:55 (8,420 candles)
#     Range 2/2: 2026-03-30 18:40 → 2026-04-04 00:00 (203 candles)
#   → Wrote 8,618 candles
#
# [388/444] nonkyc USDC-USDT 4h (est. 953 missing)
#   Found 2 gap range(s), 953 missing candles
#     Range 1/2: 2025-10-06 00:00 → 2026-03-13 12:00 (952 candles)
#     Range 2/2: 2026-04-03 20:00 → 2026-04-03 20:00 (1 candles)
#   → Wrote 953 candles
#
# [389/444] nonkyc USDC-USDT 5m (est. 50,373 missing)
#   Found 2 gap range(s), 50,376 missing candles
#     Range 1/2: 2025-10-06 00:20 → 2026-03-29 21:30 (50,367 candles)
#     Range 2/2: 2026-04-03 23:50 → 2026-04-04 00:30 (9 candles)
#   → Wrote 49,879 candles
#
# [390/444] nonkyc VEIL-XMR 15m (est. 5 missing)
#   Found 2 gap range(s), 5 missing candles
#     Range 1/2: 2026-04-03 21:45 → 2026-04-03 21:45 (1 candles)
#     Range 2/2: 2026-04-03 23:30 → 2026-04-04 00:15 (4 candles)
#   → Wrote 2 candles
#
# [391/444] nonkyc VEIL-XMR 1d (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 00:00 → 2026-04-03 00:00 (1 candles)
#   → Wrote 1 candles
#
# [392/444] nonkyc VEIL-XMR 1h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 23:00 → 2026-04-03 23:00 (1 candles)
#   → Wrote 1 candles
#
# [393/444] nonkyc VEIL-XMR 4h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 20:00 → 2026-04-03 20:00 (1 candles)
#   → Wrote 1 candles
#
# [394/444] nonkyc VEIL-XMR 5m (est. 19 missing)
#   Found 5 gap range(s), 21 missing candles
#     Range 1/5: 2026-04-03 22:05 → 2026-04-03 22:05 (1 candles)
#     Range 2/5: 2026-04-03 22:20 → 2026-04-03 22:25 (2 candles)
#     Range 3/5: 2026-04-03 22:50 → 2026-04-03 22:55 (2 candles)
#     ... (1 more ranges) ...
#     Range 5/5: 2026-04-03 23:30 → 2026-04-04 00:30 (13 candles)
#   → Wrote 4 candles
#
# [395/444] nonkyc XKR-XMR 15m (est. 3 missing)
#   Found 1 gap range(s), 3 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:15 (3 candles)
#   → Wrote 2 candles
#
# [396/444] nonkyc XKR-XMR 1d (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 00:00 → 2026-04-03 00:00 (1 candles)
#   → Wrote 1 candles
#
# [397/444] nonkyc XKR-XMR 1h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 23:00 → 2026-04-03 23:00 (1 candles)
#   → Wrote 1 candles
#
# [398/444] nonkyc XKR-XMR 4h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 20:00 → 2026-04-03 20:00 (1 candles)
#   → Wrote 1 candles
#
# [399/444] nonkyc XKR-XMR 5m (est. 18 missing)
#   Found 9 gap range(s), 20 missing candles
#     Range 1/9: 2026-04-03 22:00 → 2026-04-03 22:10 (3 candles)
#     Range 2/9: 2026-04-03 22:20 → 2026-04-03 22:25 (2 candles)
#     Range 3/9: 2026-04-03 22:35 → 2026-04-03 22:35 (1 candles)
#     ... (5 more ranges) ...
#     Range 9/9: 2026-04-03 23:50 → 2026-04-04 00:30 (9 candles)
#   → Wrote 5 candles
#
# [400/444] nonkyc XMR-BTC 15m (est. 10 missing)
#   Found 5 gap range(s), 10 missing candles
#     Range 1/5: 2026-04-03 16:30 → 2026-04-03 16:45 (2 candles)
#     Range 2/5: 2026-04-03 21:00 → 2026-04-03 21:00 (1 candles)
#     Range 3/5: 2026-04-03 21:45 → 2026-04-03 21:45 (1 candles)
#     ... (1 more ranges) ...
#     Range 5/5: 2026-04-03 23:30 → 2026-04-04 00:15 (4 candles)
#   → Wrote 3 candles
#
# [401/444] nonkyc XMR-BTC 1d (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 00:00 → 2026-04-03 00:00 (1 candles)
#   → Wrote 1 candles
#
# [402/444] nonkyc XMR-BTC 1h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 23:00 → 2026-04-03 23:00 (1 candles)
#   → Wrote 1 candles
#
# [403/444] nonkyc XMR-BTC 4h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 20:00 → 2026-04-03 20:00 (1 candles)
#   → Wrote 1 candles
#
# [404/444] nonkyc XMR-BTC 5m (est. 53 missing)
#   Found 18 gap range(s), 55 missing candles
#     Range 1/18: 2026-04-03 16:30 → 2026-04-03 16:55 (6 candles)
#     Range 2/18: 2026-04-03 17:45 → 2026-04-03 17:50 (2 candles)
#     Range 3/18: 2026-04-03 18:20 → 2026-04-03 18:20 (1 candles)
#     ... (14 more ranges) ...
#     Range 18/18: 2026-04-03 23:50 → 2026-04-04 00:30 (9 candles)
#   → Wrote 4 candles
#
# [405/444] nonkyc XMR-USDT 15m (est. 3 missing)
#   Found 1 gap range(s), 3 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:15 (3 candles)
#   → Wrote 3 candles
#
# [406/444] nonkyc XMR-USDT 1d (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 00:00 → 2026-04-03 00:00 (1 candles)
#   → Wrote 1 candles
#
# [407/444] nonkyc XMR-USDT 1h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 23:00 → 2026-04-03 23:00 (1 candles)
#   → Wrote 1 candles
#
# [408/444] nonkyc XMR-USDT 4h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 20:00 → 2026-04-03 20:00 (1 candles)
#   → Wrote 1 candles
#
# [409/444] nonkyc XMR-USDT 5m (est. 7 missing)
#   Found 1 gap range(s), 9 missing candles
#     Range 1/1: 2026-04-03 23:50 → 2026-04-04 00:30 (9 candles)
#   → Wrote 9 candles
#
# [410/444] nonkyc XMR-ZSD 15m (est. 8 missing)
#   Found 4 gap range(s), 8 missing candles
#     Range 1/4: 2026-04-03 15:45 → 2026-04-03 15:45 (1 candles)
#     Range 2/4: 2026-04-03 18:30 → 2026-04-03 18:30 (1 candles)
#     Range 3/4: 2026-04-03 21:45 → 2026-04-03 22:00 (2 candles)
#     Range 4/4: 2026-04-03 23:30 → 2026-04-04 00:15 (4 candles)
#   → Wrote 3 candles
#
# [411/444] nonkyc XMR-ZSD 1d (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 00:00 → 2026-04-03 00:00 (1 candles)
#   → Wrote 1 candles
#
# [412/444] nonkyc XMR-ZSD 1h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 23:00 → 2026-04-03 23:00 (1 candles)
#   → Wrote 1 candles
#
# [413/444] nonkyc XMR-ZSD 4h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 20:00 → 2026-04-03 20:00 (1 candles)
#   → Wrote 1 candles
#
# [414/444] nonkyc XMR-ZSD 5m (est. 59 missing)
#   Found 23 gap range(s), 62 missing candles
#     Range 1/23: 2026-04-03 15:35 → 2026-04-03 16:05 (7 candles)
#     Range 2/23: 2026-04-03 16:30 → 2026-04-03 16:30 (1 candles)
#     Range 3/23: 2026-04-03 17:05 → 2026-04-03 17:10 (2 candles)
#     ... (19 more ranges) ...
#     Range 23/23: 2026-04-03 23:50 → 2026-04-04 00:35 (10 candles)
#   → Wrote 5 candles
#
# [415/444] nonkyc XNV-XMR 15m (est. 11,191 missing)
#   Found 2 gap range(s), 11,192 missing candles
#     Range 1/2: 2025-10-06 00:15 → 2026-01-30 13:15 (11,189 candles)
#     Range 2/2: 2026-04-03 23:45 → 2026-04-04 00:15 (3 candles)
#   → Wrote 3 candles
#
# [416/444] nonkyc XNV-XMR 1d (est. 117 missing)
#   Found 2 gap range(s), 117 missing candles
#     Range 1/2: 2025-10-06 00:00 → 2026-01-29 00:00 (116 candles)
#     Range 2/2: 2026-04-03 00:00 → 2026-04-03 00:00 (1 candles)
#   → Wrote 1 candles
#
# [417/444] nonkyc XNV-XMR 1h (est. 2,798 missing)
#   Found 2 gap range(s), 2,798 missing candles
#     Range 1/2: 2025-10-06 00:00 → 2026-01-30 12:00 (2,797 candles)
#     Range 2/2: 2026-04-03 23:00 → 2026-04-03 23:00 (1 candles)
#   → Wrote 1 candles
#
# [418/444] nonkyc XNV-XMR 4h (est. 700 missing)
#   Found 2 gap range(s), 700 missing candles
#     Range 1/2: 2025-10-06 00:00 → 2026-01-30 08:00 (699 candles)
#     Range 2/2: 2026-04-03 20:00 → 2026-04-03 20:00 (1 candles)
#   → Wrote 1 candles
#
# [419/444] nonkyc XNV-XMR 5m (est. 33,573 missing)
#   Found 2 gap range(s), 33,577 missing candles
#     Range 1/2: 2025-10-06 00:20 → 2026-01-30 13:30 (33,567 candles)
#     Range 2/2: 2026-04-03 23:50 → 2026-04-04 00:35 (10 candles)
#   → Wrote 9 candles
#
# [420/444] nonkyc XRP-USDT 15m (est. 3 missing)
#   Found 1 gap range(s), 3 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:15 (3 candles)
#   → Wrote 3 candles
#
# [421/444] nonkyc XRP-USDT 1d (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 00:00 → 2026-04-03 00:00 (1 candles)
#   → Wrote 1 candles
#
# [422/444] nonkyc XRP-USDT 1h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 23:00 → 2026-04-03 23:00 (1 candles)
#   → Wrote 1 candles
#
# [423/444] nonkyc XRP-USDT 4h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 20:00 → 2026-04-03 20:00 (1 candles)
#   → Wrote 1 candles
#
# [424/444] nonkyc XRP-USDT 5m (est. 7 missing)
#   Found 1 gap range(s), 10 missing candles
#     Range 1/1: 2026-04-03 23:50 → 2026-04-04 00:35 (10 candles)
#   → Wrote 10 candles
#
# [425/444] nonkyc XTM-XMR 15m (est. 7 missing)
#   Found 4 gap range(s), 7 missing candles
#     Range 1/4: 2026-04-03 17:00 → 2026-04-03 17:00 (1 candles)
#     Range 2/4: 2026-04-03 17:30 → 2026-04-03 17:30 (1 candles)
#     Range 3/4: 2026-04-03 18:15 → 2026-04-03 18:30 (2 candles)
#     Range 4/4: 2026-04-03 23:45 → 2026-04-04 00:15 (3 candles)
#   → Wrote 3 candles
#
# [426/444] nonkyc XTM-XMR 1d (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 00:00 → 2026-04-03 00:00 (1 candles)
#   → Wrote 1 candles
#
# [427/444] nonkyc XTM-XMR 1h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 23:00 → 2026-04-03 23:00 (1 candles)
#   → Wrote 1 candles
#
# [428/444] nonkyc XTM-XMR 4h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 20:00 → 2026-04-03 20:00 (1 candles)
#   → Wrote 1 candles
#
# [429/444] nonkyc XTM-XMR 5m (est. 45 missing)
#   Found 22 gap range(s), 48 missing candles
#     Range 1/22: 2026-04-03 16:05 → 2026-04-03 16:10 (2 candles)
#     Range 2/22: 2026-04-03 16:35 → 2026-04-03 16:35 (1 candles)
#     Range 3/22: 2026-04-03 16:45 → 2026-04-03 16:50 (2 candles)
#     ... (18 more ranges) ...
#     Range 22/22: 2026-04-03 23:50 → 2026-04-04 00:35 (10 candles)
#   → Wrote 4 candles
#
# [430/444] nonkyc ZANO-USDT 15m (est. 10 missing)
#   Found 8 gap range(s), 10 missing candles
#     Range 1/8: 2026-04-03 16:00 → 2026-04-03 16:00 (1 candles)
#     Range 2/8: 2026-04-03 17:15 → 2026-04-03 17:15 (1 candles)
#     Range 3/8: 2026-04-03 17:45 → 2026-04-03 17:45 (1 candles)
#     ... (4 more ranges) ...
#     Range 8/8: 2026-04-03 23:45 → 2026-04-04 00:15 (3 candles)
#   → Wrote 2 candles
#
# [431/444] nonkyc ZANO-USDT 1d (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 00:00 → 2026-04-03 00:00 (1 candles)
#   → Wrote 1 candles
#
# [432/444] nonkyc ZANO-USDT 1h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 23:00 → 2026-04-03 23:00 (1 candles)
#   → Wrote 1 candles
#
# [433/444] nonkyc ZANO-USDT 4h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 20:00 → 2026-04-03 20:00 (1 candles)
#   → Wrote 1 candles
#
# [434/444] nonkyc ZANO-USDT 5m (est. 68 missing)
#   Found 23 gap range(s), 71 missing candles
#     Range 1/23: 2026-04-03 16:00 → 2026-04-03 16:15 (4 candles)
#     Range 2/23: 2026-04-03 16:25 → 2026-04-03 16:25 (1 candles)
#     Range 3/23: 2026-04-03 16:35 → 2026-04-03 16:45 (3 candles)
#     ... (19 more ranges) ...
#     Range 23/23: 2026-04-03 23:50 → 2026-04-04 00:35 (10 candles)
#   → Wrote 4 candles
#
# [435/444] nonkyc ZEC-XMR 15m (est. 3 missing)
#   Found 1 gap range(s), 3 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:15 (3 candles)
#   → Wrote 3 candles
#
# [436/444] nonkyc ZEC-XMR 1d (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 00:00 → 2026-04-03 00:00 (1 candles)
#   → Wrote 1 candles
#
# [437/444] nonkyc ZEC-XMR 1h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 23:00 → 2026-04-03 23:00 (1 candles)
#   → Wrote 1 candles
#
# [438/444] nonkyc ZEC-XMR 4h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 20:00 → 2026-04-03 20:00 (1 candles)
#   → Wrote 1 candles
#
# [439/444] nonkyc ZEC-XMR 5m (est. 12 missing)
#   Found 5 gap range(s), 15 missing candles
#     Range 1/5: 2026-04-03 18:05 → 2026-04-03 18:05 (1 candles)
#     Range 2/5: 2026-04-03 19:40 → 2026-04-03 19:40 (1 candles)
#     Range 3/5: 2026-04-03 21:20 → 2026-04-03 21:20 (1 candles)
#     ... (1 more ranges) ...
#     Range 5/5: 2026-04-03 23:50 → 2026-04-04 00:35 (10 candles)
#   → Wrote 10 candles
#
# [440/444] nonkyc ZSD-USDT 15m (est. 3 missing)
#   Found 1 gap range(s), 3 missing candles
#     Range 1/1: 2026-04-03 23:45 → 2026-04-04 00:15 (3 candles)
#   → Wrote 3 candles
#
# [441/444] nonkyc ZSD-USDT 1d (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 00:00 → 2026-04-03 00:00 (1 candles)
#   → Wrote 1 candles
#
# [442/444] nonkyc ZSD-USDT 1h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 23:00 → 2026-04-03 23:00 (1 candles)
#   → Wrote 1 candles
#
# [443/444] nonkyc ZSD-USDT 4h (est. 2 missing)
#   Found 1 gap range(s), 1 missing candles
#     Range 1/1: 2026-04-03 20:00 → 2026-04-03 20:00 (1 candles)
#   → Wrote 1 candles
#
# [444/444] nonkyc ZSD-USDT 5m (est. 8 missing)
#   Found 2 gap range(s), 11 missing candles
#     Range 1/2: 2026-04-03 21:35 → 2026-04-03 21:35 (1 candles)
#     Range 2/2: 2026-04-03 23:50 → 2026-04-04 00:35 (10 candles)
#   → Wrote 10 candles
#
# ══════════════════════════════════════════════════════════════════════
# BACKFILL COMPLETE
#   Gap ranges processed: 801
#   Total candles written: 328,721
#   Errors: 0 ✓
# ══════════════════════════════════════════════════════════════════════

# %%
# ── Cell 11: Post-backfill verification ──────────────────────────────────────
#
# Re-scan the selected combos to verify completeness after backfill.

# Derive the set of connectors from what was selected in Cell 8
selected_connectors_set = set(c["connector"] for c in selected_combos)

print(f"Post-backfill verification ({', '.join(sorted(selected_connectors_set))})")
print(f"{'─' * 100}")
print(f"{'Idx':>5s}  {'Connector':12s} {'Pair':16s} {'Intv':6s} {'In Window':>10s} {'Expected':>10s} {'Missing':>10s} {'Complete':>9s}")
print(f"{'─' * 100}")

still_missing_total = 0

for i, c in enumerate(combos):
    if c["connector"] not in selected_connectors_set:
        continue
    
    # Recount (use per-interval window)
    combo_ws = c.get("window_start", window_start)
    in_window = coll.count_documents({
        "connector": c["connector"], "trading_pair": c["pair"], "interval": c["interval"],
        "timestamp": {"$gte": combo_ws}
    })
    missing = max(0, c["expected"] - in_window)
    pct = (in_window / c["expected"] * 100) if c["expected"] > 0 else 100.0
    still_missing_total += missing
    flag = " ✓" if missing == 0 else f" ← {missing:,} still missing"
    print(f"{i:>5d}  {c['connector']:12s} {c['pair']:16s} {c['interval']:6s} "
          f"{in_window:>10,d} {c['expected']:>10,d} {missing:>10,d} {pct:>8.1f}%{flag}")

print(f"{'─' * 100}")
if still_missing_total == 0:
    print("✓ All series are 100% complete!")
else:
    print(f"⚠ {still_missing_total:,} candles still missing (exchange may not have data for those periods)")
# Out:
# Post-backfill verification (coinbase, mexc, nonkyc)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   Idx  Connector    Pair             Intv    In Window   Expected    Missing  Complete
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#     0  coinbase     BTC-USD          15m        17,279     17,280          1    100.0% ← 1 still missing
#     1  coinbase     BTC-USD          1d            179        180          1     99.4% ← 1 still missing
#     2  coinbase     BTC-USD          1h          4,319      4,320          1    100.0% ← 1 still missing
#     3  coinbase     BTC-USD          1m         43,200     43,200          0    100.0% ✓
#     4  coinbase     BTC-USD          5m         51,839     51,840          1    100.0% ← 1 still missing
#     5  coinbase     ETH-USD          15m        17,279     17,280          1    100.0% ← 1 still missing
#     6  coinbase     ETH-USD          1d            179        180          1     99.4% ← 1 still missing
#     7  coinbase     ETH-USD          1h          4,319      4,320          1    100.0% ← 1 still missing
#     8  coinbase     ETH-USD          1m         43,200     43,200          0    100.0% ✓
#     9  coinbase     ETH-USD          5m         51,839     51,840          1    100.0% ← 1 still missing
#    10  coinbase     USDT-USD         15m        17,279     17,280          1    100.0% ← 1 still missing
#    11  coinbase     USDT-USD         1d            179        180          1     99.4% ← 1 still missing
#    12  coinbase     USDT-USD         1h          4,319      4,320          1    100.0% ← 1 still missing
#    13  coinbase     USDT-USD         1m         43,200     43,200          0    100.0% ✓
#    14  coinbase     USDT-USD         5m         51,839     51,840          1    100.0% ← 1 still missing
#    15  mexc         ADA-USDT         15m        17,278     17,280          2    100.0% ← 2 still missing
#    16  mexc         ADA-USDT         1d            178        180          2     98.9% ← 2 still missing
#    17  mexc         ADA-USDT         1h          4,318      4,320          2    100.0% ← 2 still missing
#    18  mexc         ADA-USDT         1m         43,199     43,200          1    100.0% ← 1 still missing
#    19  mexc         ADA-USDT         4h          1,078      1,080          2     99.8% ← 2 still missing
#    20  mexc         ADA-USDT         5m         51,838     51,840          2    100.0% ← 2 still missing
#    21  mexc         APT-USDT         15m        17,278     17,280          2    100.0% ← 2 still missing
#    22  mexc         APT-USDT         1d            178        180          2     98.9% ← 2 still missing
#    23  mexc         APT-USDT         1h          4,318      4,320          2    100.0% ← 2 still missing
#    24  mexc         APT-USDT         1m         43,199     43,200          1    100.0% ← 1 still missing
#    25  mexc         APT-USDT         4h          1,078      1,080          2     99.8% ← 2 still missing
#    26  mexc         APT-USDT         5m         51,838     51,840          2    100.0% ← 2 still missing
#    27  mexc         ASTER-USDT       15m        17,278     17,280          2    100.0% ← 2 still missing
#    28  mexc         ASTER-USDT       1d            178        180          2     98.9% ← 2 still missing
#    29  mexc         ASTER-USDT       1h          4,318      4,320          2    100.0% ← 2 still missing
#    30  mexc         ASTER-USDT       1m         43,201     43,200          0    100.0% ✓
#    31  mexc         ASTER-USDT       4h          1,078      1,080          2     99.8% ← 2 still missing
#    32  mexc         ASTER-USDT       5m         51,838     51,840          2    100.0% ← 2 still missing
#    33  mexc         ATOM-USDT        15m        17,278     17,280          2    100.0% ← 2 still missing
#    34  mexc         ATOM-USDT        1d            178        180          2     98.9% ← 2 still missing
#    35  mexc         ATOM-USDT        1h          4,318      4,320          2    100.0% ← 2 still missing
#    36  mexc         ATOM-USDT        1m         43,199     43,200          1    100.0% ← 1 still missing
#    37  mexc         ATOM-USDT        4h          1,078      1,080          2     99.8% ← 2 still missing
#    38  mexc         ATOM-USDT        5m         51,838     51,840          2    100.0% ← 2 still missing
#    39  mexc         BNB-USDT         15m        17,278     17,280          2    100.0% ← 2 still missing
#    40  mexc         BNB-USDT         1d            178        180          2     98.9% ← 2 still missing
#    41  mexc         BNB-USDT         1h          4,318      4,320          2    100.0% ← 2 still missing
#    42  mexc         BNB-USDT         1m         43,199     43,200          1    100.0% ← 1 still missing
#    43  mexc         BNB-USDT         4h          1,078      1,080          2     99.8% ← 2 still missing
#    44  mexc         BNB-USDT         5m         51,838     51,840          2    100.0% ← 2 still missing
#    45  mexc         BTC-USDT         15m        17,278     17,280          2    100.0% ← 2 still missing
#    46  mexc         BTC-USDT         1d            178        180          2     98.9% ← 2 still missing
#    47  mexc         BTC-USDT         1h          4,318      4,320          2    100.0% ← 2 still missing
#    48  mexc         BTC-USDT         1m         43,199     43,200          1    100.0% ← 1 still missing
#    49  mexc         BTC-USDT         4h          1,078      1,080          2     99.8% ← 2 still missing
#    50  mexc         BTC-USDT         5m         51,838     51,840          2    100.0% ← 2 still missing
#    51  mexc         DOGE-USDT        15m        17,278     17,280          2    100.0% ← 2 still missing
#    52  mexc         DOGE-USDT        1d            178        180          2     98.9% ← 2 still missing
#    53  mexc         DOGE-USDT        1h          4,318      4,320          2    100.0% ← 2 still missing
#    54  mexc         DOGE-USDT        1m         43,199     43,200          1    100.0% ← 1 still missing
#    55  mexc         DOGE-USDT        4h          1,078      1,080          2     99.8% ← 2 still missing
#    56  mexc         DOGE-USDT        5m         51,838     51,840          2    100.0% ← 2 still missing
#    57  mexc         DOT-USDT         15m        17,278     17,280          2    100.0% ← 2 still missing
#    58  mexc         DOT-USDT         1d            178        180          2     98.9% ← 2 still missing
#    59  mexc         DOT-USDT         1h          4,318      4,320          2    100.0% ← 2 still missing
#    60  mexc         DOT-USDT         1m         43,200     43,200          0    100.0% ✓
#    61  mexc         DOT-USDT         4h          1,078      1,080          2     99.8% ← 2 still missing
#    62  mexc         DOT-USDT         5m         51,838     51,840          2    100.0% ← 2 still missing
#    63  mexc         ETH-USDT         15m        17,278     17,280          2    100.0% ← 2 still missing
#    64  mexc         ETH-USDT         1d            178        180          2     98.9% ← 2 still missing
#    65  mexc         ETH-USDT         1h          4,318      4,320          2    100.0% ← 2 still missing
#    66  mexc         ETH-USDT         1m         43,200     43,200          0    100.0% ✓
#    67  mexc         ETH-USDT         4h          1,078      1,080          2     99.8% ← 2 still missing
#    68  mexc         ETH-USDT         5m         51,838     51,840          2    100.0% ← 2 still missing
#    69  mexc         FET-USDT         15m        17,278     17,280          2    100.0% ← 2 still missing
#    70  mexc         FET-USDT         1d            178        180          2     98.9% ← 2 still missing
#    71  mexc         FET-USDT         1h          4,318      4,320          2    100.0% ← 2 still missing
#    72  mexc         FET-USDT         1m         43,200     43,200          0    100.0% ✓
#    73  mexc         FET-USDT         4h          1,078      1,080          2     99.8% ← 2 still missing
#    74  mexc         FET-USDT         5m         51,838     51,840          2    100.0% ← 2 still missing
#    75  mexc         HYPE-USDT        15m        17,278     17,280          2    100.0% ← 2 still missing
#    76  mexc         HYPE-USDT        1d            178        180          2     98.9% ← 2 still missing
#    77  mexc         HYPE-USDT        1h          4,318      4,320          2    100.0% ← 2 still missing
#    78  mexc         HYPE-USDT        1m         43,200     43,200          0    100.0% ✓
#    79  mexc         HYPE-USDT        4h          1,078      1,080          2     99.8% ← 2 still missing
#    80  mexc         HYPE-USDT        5m         51,838     51,840          2    100.0% ← 2 still missing
#    81  mexc         ICP-USDT         15m        17,278     17,280          2    100.0% ← 2 still missing
#    82  mexc         ICP-USDT         1d            178        180          2     98.9% ← 2 still missing
#    83  mexc         ICP-USDT         1h          4,318      4,320          2    100.0% ← 2 still missing
#    84  mexc         ICP-USDT         1m         43,198     43,200          2    100.0% ← 2 still missing
#    85  mexc         ICP-USDT         4h          1,078      1,080          2     99.8% ← 2 still missing
#    86  mexc         ICP-USDT         5m         51,838     51,840          2    100.0% ← 2 still missing
#    87  mexc         LTC-USDT         15m        17,278     17,280          2    100.0% ← 2 still missing
#    88  mexc         LTC-USDT         1d            178        180          2     98.9% ← 2 still missing
#    89  mexc         LTC-USDT         1h          4,318      4,320          2    100.0% ← 2 still missing
#    90  mexc         LTC-USDT         1m         43,200     43,200          0    100.0% ✓
#    91  mexc         LTC-USDT         4h          1,078      1,080          2     99.8% ← 2 still missing
#    92  mexc         LTC-USDT         5m         51,838     51,840          2    100.0% ← 2 still missing
#    93  mexc         OP-USDT          15m        17,278     17,280          2    100.0% ← 2 still missing
#    94  mexc         OP-USDT          1d            178        180          2     98.9% ← 2 still missing
#    95  mexc         OP-USDT          1h          4,318      4,320          2    100.0% ← 2 still missing
#    96  mexc         OP-USDT          1m         43,200     43,200          0    100.0% ✓
#    97  mexc         OP-USDT          4h          1,078      1,080          2     99.8% ← 2 still missing
#    98  mexc         OP-USDT          5m         51,838     51,840          2    100.0% ← 2 still missing
#    99  mexc         PEPE-USDT        15m        17,278     17,280          2    100.0% ← 2 still missing
#   100  mexc         PEPE-USDT        1d            178        180          2     98.9% ← 2 still missing
#   101  mexc         PEPE-USDT        1h          4,318      4,320          2    100.0% ← 2 still missing
#   102  mexc         PEPE-USDT        1m         43,200     43,200          0    100.0% ✓
#   103  mexc         PEPE-USDT        4h          1,078      1,080          2     99.8% ← 2 still missing
#   104  mexc         PEPE-USDT        5m         51,838     51,840          2    100.0% ← 2 still missing
#   105  mexc         PUMP-USDT        15m        17,278     17,280          2    100.0% ← 2 still missing
#   106  mexc         PUMP-USDT        1d            178        180          2     98.9% ← 2 still missing
#   107  mexc         PUMP-USDT        1h          4,318      4,320          2    100.0% ← 2 still missing
#   108  mexc         PUMP-USDT        1m         43,200     43,200          0    100.0% ✓
#   109  mexc         PUMP-USDT        4h          1,078      1,080          2     99.8% ← 2 still missing
#   110  mexc         PUMP-USDT        5m         51,838     51,840          2    100.0% ← 2 still missing
#   111  mexc         RENDER-USDT      15m        17,278     17,280          2    100.0% ← 2 still missing
#   112  mexc         RENDER-USDT      1d            178        180          2     98.9% ← 2 still missing
#   113  mexc         RENDER-USDT      1h          4,318      4,320          2    100.0% ← 2 still missing
#   114  mexc         RENDER-USDT      1m         43,200     43,200          0    100.0% ✓
#   115  mexc         RENDER-USDT      4h          1,078      1,080          2     99.8% ← 2 still missing
#   116  mexc         RENDER-USDT      5m         51,838     51,840          2    100.0% ← 2 still missing
#   117  mexc         SAHARA-USDT      15m        17,278     17,280          2    100.0% ← 2 still missing
#   118  mexc         SAHARA-USDT      1d            178        180          2     98.9% ← 2 still missing
#   119  mexc         SAHARA-USDT      1h          4,318      4,320          2    100.0% ← 2 still missing
#   120  mexc         SAHARA-USDT      1m         43,199     43,200          1    100.0% ← 1 still missing
#   121  mexc         SAHARA-USDT      4h          1,078      1,080          2     99.8% ← 2 still missing
#   122  mexc         SAHARA-USDT      5m         51,839     51,840          1    100.0% ← 1 still missing
#   123  mexc         SAL-USDT         15m        17,278     17,280          2    100.0% ← 2 still missing
#   124  mexc         SAL-USDT         1d            178        180          2     98.9% ← 2 still missing
#   125  mexc         SAL-USDT         1h          4,318      4,320          2    100.0% ← 2 still missing
#   126  mexc         SAL-USDT         1m         43,201     43,200          0    100.0% ✓
#   127  mexc         SAL-USDT         4h          1,078      1,080          2     99.8% ← 2 still missing
#   128  mexc         SAL-USDT         5m         51,839     51,840          1    100.0% ← 1 still missing
#   129  mexc         SHIB-USDT        15m        17,278     17,280          2    100.0% ← 2 still missing
#   130  mexc         SHIB-USDT        1d            178        180          2     98.9% ← 2 still missing
#   131  mexc         SHIB-USDT        1h          4,318      4,320          2    100.0% ← 2 still missing
#   132  mexc         SHIB-USDT        1m         43,201     43,200          0    100.0% ✓
#   133  mexc         SHIB-USDT        4h          1,078      1,080          2     99.8% ← 2 still missing
#   134  mexc         SHIB-USDT        5m         51,839     51,840          1    100.0% ← 1 still missing
#   135  mexc         SOL-USDT         15m        17,278     17,280          2    100.0% ← 2 still missing
#   136  mexc         SOL-USDT         1d            178        180          2     98.9% ← 2 still missing
#   137  mexc         SOL-USDT         1h          4,318      4,320          2    100.0% ← 2 still missing
#   138  mexc         SOL-USDT         1m         43,199     43,200          1    100.0% ← 1 still missing
#   139  mexc         SOL-USDT         4h          1,078      1,080          2     99.8% ← 2 still missing
#   140  mexc         SOL-USDT         5m         51,839     51,840          1    100.0% ← 1 still missing
#   141  mexc         SUI-USDT         15m        17,278     17,280          2    100.0% ← 2 still missing
#   142  mexc         SUI-USDT         1d            178        180          2     98.9% ← 2 still missing
#   143  mexc         SUI-USDT         1h          4,318      4,320          2    100.0% ← 2 still missing
#   144  mexc         SUI-USDT         1m         43,200     43,200          0    100.0% ✓
#   145  mexc         SUI-USDT         4h          1,078      1,080          2     99.8% ← 2 still missing
#   146  mexc         SUI-USDT         5m         51,839     51,840          1    100.0% ← 1 still missing
#   147  mexc         TON-USDT         15m        17,278     17,280          2    100.0% ← 2 still missing
#   148  mexc         TON-USDT         1d            178        180          2     98.9% ← 2 still missing
#   149  mexc         TON-USDT         1h          4,318      4,320          2    100.0% ← 2 still missing
#   150  mexc         TON-USDT         1m         43,201     43,200          0    100.0% ✓
#   151  mexc         TON-USDT         4h          1,078      1,080          2     99.8% ← 2 still missing
#   152  mexc         TON-USDT         5m         51,839     51,840          1    100.0% ← 1 still missing
#   153  mexc         TRX-USDT         15m        17,278     17,280          2    100.0% ← 2 still missing
#   154  mexc         TRX-USDT         1d            178        180          2     98.9% ← 2 still missing
#   155  mexc         TRX-USDT         1h          4,318      4,320          2    100.0% ← 2 still missing
#   156  mexc         TRX-USDT         1m         43,201     43,200          0    100.0% ✓
#   157  mexc         TRX-USDT         4h          1,078      1,080          2     99.8% ← 2 still missing
#   158  mexc         TRX-USDT         5m         51,839     51,840          1    100.0% ← 1 still missing
#   159  mexc         WLD-USDT         15m        17,278     17,280          2    100.0% ← 2 still missing
#   160  mexc         WLD-USDT         1d            178        180          2     98.9% ← 2 still missing
#   161  mexc         WLD-USDT         1h          4,318      4,320          2    100.0% ← 2 still missing
#   162  mexc         WLD-USDT         1m         43,201     43,200          0    100.0% ✓
#   163  mexc         WLD-USDT         4h          1,078      1,080          2     99.8% ← 2 still missing
#   164  mexc         WLD-USDT         5m         51,839     51,840          1    100.0% ← 1 still missing
#   165  mexc         WLFI-USDT        15m        17,278     17,280          2    100.0% ← 2 still missing
#   166  mexc         WLFI-USDT        1d            178        180          2     98.9% ← 2 still missing
#   167  mexc         WLFI-USDT        1h          4,318      4,320          2    100.0% ← 2 still missing
#   168  mexc         WLFI-USDT        1m         43,201     43,200          0    100.0% ✓
#   169  mexc         WLFI-USDT        4h          1,078      1,080          2     99.8% ← 2 still missing
#   170  mexc         WLFI-USDT        5m         51,839     51,840          1    100.0% ← 1 still missing
#   171  mexc         WXT-USDT         15m        17,278     17,280          2    100.0% ← 2 still missing
#   172  mexc         WXT-USDT         1d            178        180          2     98.9% ← 2 still missing
#   173  mexc         WXT-USDT         1h          4,318      4,320          2    100.0% ← 2 still missing
#   174  mexc         WXT-USDT         1m         43,202     43,200          0    100.0% ✓
#   175  mexc         WXT-USDT         4h          1,078      1,080          2     99.8% ← 2 still missing
#   176  mexc         WXT-USDT         5m         51,839     51,840          1    100.0% ← 1 still missing
#   177  mexc         XLM-USDT         15m        17,278     17,280          2    100.0% ← 2 still missing
#   178  mexc         XLM-USDT         1d            178        180          2     98.9% ← 2 still missing
#   179  mexc         XLM-USDT         1h          4,318      4,320          2    100.0% ← 2 still missing
#   180  mexc         XLM-USDT         1m         43,202     43,200          0    100.0% ✓
#   181  mexc         XLM-USDT         4h          1,078      1,080          2     99.8% ← 2 still missing
#   182  mexc         XLM-USDT         5m         51,839     51,840          1    100.0% ← 1 still missing
#   183  mexc         XMR-USDC         15m        17,278     17,280          2    100.0% ← 2 still missing
#   184  mexc         XMR-USDC         1d            178        180          2     98.9% ← 2 still missing
#   185  mexc         XMR-USDC         1h          4,318      4,320          2    100.0% ← 2 still missing
#   186  mexc         XMR-USDC         1m         43,201     43,200          0    100.0% ✓
#   187  mexc         XMR-USDC         4h          1,078      1,080          2     99.8% ← 2 still missing
#   188  mexc         XMR-USDC         5m         51,839     51,840          1    100.0% ← 1 still missing
#   189  mexc         XMR-USDT         15m        17,278     17,280          2    100.0% ← 2 still missing
#   190  mexc         XMR-USDT         1d            178        180          2     98.9% ← 2 still missing
#   191  mexc         XMR-USDT         1h          4,318      4,320          2    100.0% ← 2 still missing
#   192  mexc         XMR-USDT         1m         43,202     43,200          0    100.0% ✓
#   193  mexc         XMR-USDT         4h          1,078      1,080          2     99.8% ← 2 still missing
#   194  mexc         XMR-USDT         5m         51,839     51,840          1    100.0% ← 1 still missing
#   195  mexc         XRP-USDT         15m        17,278     17,280          2    100.0% ← 2 still missing
#   196  mexc         XRP-USDT         1d            178        180          2     98.9% ← 2 still missing
#   197  mexc         XRP-USDT         1h          4,318      4,320          2    100.0% ← 2 still missing
#   198  mexc         XRP-USDT         1m         43,197     43,200          3    100.0% ← 3 still missing
#   199  mexc         XRP-USDT         4h          1,078      1,080          2     99.8% ← 2 still missing
#   200  mexc         XRP-USDT         5m         51,838     51,840          2    100.0% ← 2 still missing
#   201  mexc         ZRO-USDT         15m        17,278     17,280          2    100.0% ← 2 still missing
#   202  mexc         ZRO-USDT         1d            178        180          2     98.9% ← 2 still missing
#   203  mexc         ZRO-USDT         1h          4,318      4,320          2    100.0% ← 2 still missing
#   204  mexc         ZRO-USDT         1m         43,201     43,200          0    100.0% ✓
#   205  mexc         ZRO-USDT         4h          1,078      1,080          2     99.8% ← 2 still missing
#   206  mexc         ZRO-USDT         5m         51,838     51,840          2    100.0% ← 2 still missing
#   207  nonkyc       AAVE-USDT        15m        17,243     17,280         37     99.8% ← 37 still missing
#   208  nonkyc       AAVE-USDT        1d            179        180          1     99.4% ← 1 still missing
#   209  nonkyc       AAVE-USDT        1h          4,314      4,320          6     99.9% ← 6 still missing
#   210  nonkyc       AAVE-USDT        4h          1,079      1,080          1     99.9% ← 1 still missing
#   211  nonkyc       AAVE-USDT        5m         51,840     51,840          0    100.0% ✓
#   212  nonkyc       ADA-USDT         15m        17,279     17,280          1    100.0% ← 1 still missing
#   213  nonkyc       ADA-USDT         1d            179        180          1     99.4% ← 1 still missing
#   214  nonkyc       ADA-USDT         1h          4,319      4,320          1    100.0% ← 1 still missing
#   215  nonkyc       ADA-USDT         4h          1,079      1,080          1     99.9% ← 1 still missing
#   216  nonkyc       ADA-USDT         5m         51,833     51,840          7    100.0% ← 7 still missing
#   217  nonkyc       ALIAS-XMR        15m        17,279     17,280          1    100.0% ← 1 still missing
#   218  nonkyc       ALIAS-XMR        1d            179        180          1     99.4% ← 1 still missing
#   219  nonkyc       ALIAS-XMR        1h          4,319      4,320          1    100.0% ← 1 still missing
#   220  nonkyc       ALIAS-XMR        4h          1,079      1,080          1     99.9% ← 1 still missing
#   221  nonkyc       ALIAS-XMR        5m         51,827     51,840         13    100.0% ← 13 still missing
#   222  nonkyc       ARB-USDT         15m        17,279     17,280          1    100.0% ← 1 still missing
#   223  nonkyc       ARB-USDT         1d            179        180          1     99.4% ← 1 still missing
#   224  nonkyc       ARB-USDT         1h          4,319      4,320          1    100.0% ← 1 still missing
#   225  nonkyc       ARB-USDT         4h          1,079      1,080          1     99.9% ← 1 still missing
#   226  nonkyc       ARB-USDT         5m         51,838     51,840          2    100.0% ← 2 still missing
#   227  nonkyc       ARRR-USDT        15m        17,279     17,280          1    100.0% ← 1 still missing
#   228  nonkyc       ARRR-USDT        1d            179        180          1     99.4% ← 1 still missing
#   229  nonkyc       ARRR-USDT        1h          4,319      4,320          1    100.0% ← 1 still missing
#   230  nonkyc       ARRR-USDT        4h          1,079      1,080          1     99.9% ← 1 still missing
#   231  nonkyc       ARRR-USDT        5m         51,840     51,840          0    100.0% ✓
#   232  nonkyc       ARRR-XMR         15m        17,279     17,280          1    100.0% ← 1 still missing
#   233  nonkyc       ARRR-XMR         1d            179        180          1     99.4% ← 1 still missing
#   234  nonkyc       ARRR-XMR         1h          4,319      4,320          1    100.0% ← 1 still missing
#   235  nonkyc       ARRR-XMR         4h          1,079      1,080          1     99.9% ← 1 still missing
#   236  nonkyc       ARRR-XMR         5m         51,840     51,840          0    100.0% ✓
#   237  nonkyc       AVAX-USDT        15m        17,278     17,280          2    100.0% ← 2 still missing
#   238  nonkyc       AVAX-USDT        1d            179        180          1     99.4% ← 1 still missing
#   239  nonkyc       AVAX-USDT        1h          4,319      4,320          1    100.0% ← 1 still missing
#   240  nonkyc       AVAX-USDT        4h          1,079      1,080          1     99.9% ← 1 still missing
#   241  nonkyc       AVAX-USDT        5m         51,837     51,840          3    100.0% ← 3 still missing
#   242  nonkyc       BCH-USDT         15m        17,279     17,280          1    100.0% ← 1 still missing
#   243  nonkyc       BCH-USDT         1d            179        180          1     99.4% ← 1 still missing
#   244  nonkyc       BCH-USDT         1h          4,319      4,320          1    100.0% ← 1 still missing
#   245  nonkyc       BCH-USDT         4h          1,079      1,080          1     99.9% ← 1 still missing
#   246  nonkyc       BCH-USDT         5m         51,840     51,840          0    100.0% ✓
#   247  nonkyc       BDX-USDT         15m        17,279     17,280          1    100.0% ← 1 still missing
#   248  nonkyc       BDX-USDT         1d            179        180          1     99.4% ← 1 still missing
#   249  nonkyc       BDX-USDT         1h          4,319      4,320          1    100.0% ← 1 still missing
#   250  nonkyc       BDX-USDT         4h          1,079      1,080          1     99.9% ← 1 still missing
#   251  nonkyc       BDX-USDT         5m         51,840     51,840          0    100.0% ✓
#   252  nonkyc       BNB-USDT         15m        17,227     17,280         53     99.7% ← 53 still missing
#   253  nonkyc       BNB-USDT         1d            179        180          1     99.4% ← 1 still missing
#   254  nonkyc       BNB-USDT         1h          4,311      4,320          9     99.8% ← 9 still missing
#   255  nonkyc       BNB-USDT         4h          1,079      1,080          1     99.9% ← 1 still missing
#   256  nonkyc       BNB-USDT         5m         51,592     51,840        248     99.5% ← 248 still missing
#   257  nonkyc       BTC-USDT         15m        17,280     17,280          0    100.0% ✓
#   258  nonkyc       BTC-USDT         1d            179        180          1     99.4% ← 1 still missing
#   259  nonkyc       BTC-USDT         1h          4,319      4,320          1    100.0% ← 1 still missing
#   260  nonkyc       BTC-USDT         4h          1,079      1,080          1     99.9% ← 1 still missing
#   261  nonkyc       BTC-USDT         5m         51,841     51,840          0    100.0% ✓
#   262  nonkyc       DIVI-USDT        15m        14,441     17,280      2,839     83.6% ← 2,839 still missing
#   263  nonkyc       DIVI-USDT        1d            151        180         29     83.9% ← 29 still missing
#   264  nonkyc       DIVI-USDT        1h          3,610      4,320        710     83.6% ← 710 still missing
#   265  nonkyc       DIVI-USDT        4h            903      1,080        177     83.6% ← 177 still missing
#   266  nonkyc       DIVI-USDT        5m         43,320     51,840      8,520     83.6% ← 8,520 still missing
#   267  nonkyc       DOGE-USDT        15m        17,280     17,280          0    100.0% ✓
#   268  nonkyc       DOGE-USDT        1d            179        180          1     99.4% ← 1 still missing
#   269  nonkyc       DOGE-USDT        1h          4,319      4,320          1    100.0% ← 1 still missing
#   270  nonkyc       DOGE-USDT        4h          1,079      1,080          1     99.9% ← 1 still missing
#   271  nonkyc       DOGE-USDT        5m         51,841     51,840          0    100.0% ✓
#   272  nonkyc       ENA-USDT         15m        17,028     17,280        252     98.5% ← 252 still missing
#   273  nonkyc       ENA-USDT         1d            178        180          2     98.9% ← 2 still missing
#   274  nonkyc       ENA-USDT         1h          4,257      4,320         63     98.5% ← 63 still missing
#   275  nonkyc       ENA-USDT         4h          1,065      1,080         15     98.6% ← 15 still missing
#   276  nonkyc       ENA-USDT         5m         51,084     51,840        756     98.5% ← 756 still missing
#   277  nonkyc       EPIC-USDT        15m        11,433     17,280      5,847     66.2% ← 5,847 still missing
#   278  nonkyc       EPIC-USDT        1d            120        180         60     66.7% ← 60 still missing
#   279  nonkyc       EPIC-USDT        1h          2,858      4,320      1,462     66.2% ← 1,462 still missing
#   280  nonkyc       EPIC-USDT        4h            715      1,080        365     66.2% ← 365 still missing
#   281  nonkyc       EPIC-USDT        5m         34,297     51,840     17,543     66.2% ← 17,543 still missing
#   282  nonkyc       EPIC-XMR         15m        11,432     17,280      5,848     66.2% ← 5,848 still missing
#   283  nonkyc       EPIC-XMR         1d            120        180         60     66.7% ← 60 still missing
#   284  nonkyc       EPIC-XMR         1h          2,858      4,320      1,462     66.2% ← 1,462 still missing
#   285  nonkyc       EPIC-XMR         4h            715      1,080        365     66.2% ← 365 still missing
#   286  nonkyc       EPIC-XMR         5m         34,294     51,840     17,546     66.2% ← 17,546 still missing
#   287  nonkyc       ERG-USDT         15m        17,280     17,280          0    100.0% ✓
#   288  nonkyc       ERG-USDT         1d            179        180          1     99.4% ← 1 still missing
#   289  nonkyc       ERG-USDT         1h          4,319      4,320          1    100.0% ← 1 still missing
#   290  nonkyc       ERG-USDT         4h          1,079      1,080          1     99.9% ← 1 still missing
#   291  nonkyc       ERG-USDT         5m         51,830     51,840         10    100.0% ← 10 still missing
#   292  nonkyc       ERG-XMR          15m        17,277     17,280          3    100.0% ← 3 still missing
#   293  nonkyc       ERG-XMR          1d            179        180          1     99.4% ← 1 still missing
#   294  nonkyc       ERG-XMR          1h          4,319      4,320          1    100.0% ← 1 still missing
#   295  nonkyc       ERG-XMR          4h          1,079      1,080          1     99.9% ← 1 still missing
#   296  nonkyc       ERG-XMR          5m         51,825     51,840         15    100.0% ← 15 still missing
#   297  nonkyc       ETH-USDT         15m        17,280     17,280          0    100.0% ✓
#   298  nonkyc       ETH-USDT         1d            179        180          1     99.4% ← 1 still missing
#   299  nonkyc       ETH-USDT         1h          4,319      4,320          1    100.0% ← 1 still missing
#   300  nonkyc       ETH-USDT         4h          1,079      1,080          1     99.9% ← 1 still missing
#   301  nonkyc       ETH-USDT         5m         51,841     51,840          0    100.0% ✓
#   302  nonkyc       FUSD-XMR         15m        17,279     17,280          1    100.0% ← 1 still missing
#   303  nonkyc       FUSD-XMR         1d            179        180          1     99.4% ← 1 still missing
#   304  nonkyc       FUSD-XMR         1h          4,319      4,320          1    100.0% ← 1 still missing
#   305  nonkyc       FUSD-XMR         4h          1,079      1,080          1     99.9% ← 1 still missing
#   306  nonkyc       FUSD-XMR         5m         51,824     51,840         16    100.0% ← 16 still missing
#   307  nonkyc       GHOST-XMR        15m        17,278     17,280          2    100.0% ← 2 still missing
#   308  nonkyc       GHOST-XMR        1d            179        180          1     99.4% ← 1 still missing
#   309  nonkyc       GHOST-XMR        1h          4,319      4,320          1    100.0% ← 1 still missing
#   310  nonkyc       GHOST-XMR        4h          1,079      1,080          1     99.9% ← 1 still missing
#   311  nonkyc       GHOST-XMR        5m         51,828     51,840         12    100.0% ← 12 still missing
#   312  nonkyc       INJ-USDT         15m        17,024     17,280        256     98.5% ← 256 still missing
#   313  nonkyc       INJ-USDT         1d            178        180          2     98.9% ← 2 still missing
#   314  nonkyc       INJ-USDT         1h          4,257      4,320         63     98.5% ← 63 still missing
#   315  nonkyc       INJ-USDT         4h          1,065      1,080         15     98.6% ← 15 still missing
#   316  nonkyc       INJ-USDT         5m         51,069     51,840        771     98.5% ← 771 still missing
#   317  nonkyc       LINK-USDT        15m        17,280     17,280          0    100.0% ✓
#   318  nonkyc       LINK-USDT        1d            179        180          1     99.4% ← 1 still missing
#   319  nonkyc       LINK-USDT        1h          4,319      4,320          1    100.0% ← 1 still missing
#   320  nonkyc       LINK-USDT        4h          1,079      1,080          1     99.9% ← 1 still missing
#   321  nonkyc       LINK-USDT        5m         51,839     51,840          1    100.0% ← 1 still missing
#   322  nonkyc       LTC-USDT         15m        17,231     17,280         49     99.7% ← 49 still missing
#   323  nonkyc       LTC-USDT         1d            179        180          1     99.4% ← 1 still missing
#   324  nonkyc       LTC-USDT         1h          4,318      4,320          2    100.0% ← 2 still missing
#   325  nonkyc       LTC-USDT         4h          1,079      1,080          1     99.9% ← 1 still missing
#   326  nonkyc       LTC-USDT         5m         51,273     51,840        567     98.9% ← 567 still missing
#   327  nonkyc       LTC-XMR          15m        17,279     17,280          1    100.0% ← 1 still missing
#   328  nonkyc       LTC-XMR          1d            179        180          1     99.4% ← 1 still missing
#   329  nonkyc       LTC-XMR          1h          4,319      4,320          1    100.0% ← 1 still missing
#   330  nonkyc       LTC-XMR          4h          1,079      1,080          1     99.9% ← 1 still missing
#   331  nonkyc       LTC-XMR          5m         51,830     51,840         10    100.0% ← 10 still missing
#   332  nonkyc       MANA-USDT        15m         5,047     17,280     12,233     29.2% ← 12,233 still missing
#   333  nonkyc       MANA-USDT        1d             53        180        127     29.4% ← 127 still missing
#   334  nonkyc       MANA-USDT        1h          1,262      4,320      3,058     29.2% ← 3,058 still missing
#   335  nonkyc       MANA-USDT        4h            316      1,080        764     29.3% ← 764 still missing
#   336  nonkyc       MANA-USDT        5m         15,139     51,840     36,701     29.2% ← 36,701 still missing
#   337  nonkyc       NKYC-USDT        15m        17,280     17,280          0    100.0% ✓
#   338  nonkyc       NKYC-USDT        1d            179        180          1     99.4% ← 1 still missing
#   339  nonkyc       NKYC-USDT        1h          4,319      4,320          1    100.0% ← 1 still missing
#   340  nonkyc       NKYC-USDT        4h          1,079      1,080          1     99.9% ← 1 still missing
#   341  nonkyc       NKYC-USDT        5m         51,841     51,840          0    100.0% ✓
#   342  nonkyc       PEP-USDT         15m        17,280     17,280          0    100.0% ✓
#   343  nonkyc       PEP-USDT         1d            179        180          1     99.4% ← 1 still missing
#   344  nonkyc       PEP-USDT         1h          4,319      4,320          1    100.0% ← 1 still missing
#   345  nonkyc       PEP-USDT         4h          1,079      1,080          1     99.9% ← 1 still missing
#   346  nonkyc       PEP-USDT         5m         51,841     51,840          0    100.0% ✓
#   347  nonkyc       POL-USDT         15m        17,280     17,280          0    100.0% ✓
#   348  nonkyc       POL-USDT         1d            179        180          1     99.4% ← 1 still missing
#   349  nonkyc       POL-USDT         1h          4,319      4,320          1    100.0% ← 1 still missing
#   350  nonkyc       POL-USDT         4h          1,079      1,080          1     99.9% ← 1 still missing
#   351  nonkyc       POL-USDT         5m         51,840     51,840          0    100.0% ✓
#   352  nonkyc       RVN-USDT         15m        17,278     17,280          2    100.0% ← 2 still missing
#   353  nonkyc       RVN-USDT         1d            179        180          1     99.4% ← 1 still missing
#   354  nonkyc       RVN-USDT         1h          4,319      4,320          1    100.0% ← 1 still missing
#   355  nonkyc       RVN-USDT         4h          1,079      1,080          1     99.9% ← 1 still missing
#   356  nonkyc       RVN-USDT         5m         51,823     51,840         17    100.0% ← 17 still missing
#   357  nonkyc       RXD-USDT         15m        17,280     17,280          0    100.0% ✓
#   358  nonkyc       RXD-USDT         1d            179        180          1     99.4% ← 1 still missing
#   359  nonkyc       RXD-USDT         1h          4,319      4,320          1    100.0% ← 1 still missing
#   360  nonkyc       RXD-USDT         4h          1,079      1,080          1     99.9% ← 1 still missing
#   361  nonkyc       RXD-USDT         5m         51,840     51,840          0    100.0% ✓
#   362  nonkyc       SAL-USDT         15m        17,280     17,280          0    100.0% ✓
#   363  nonkyc       SAL-USDT         1d            179        180          1     99.4% ← 1 still missing
#   364  nonkyc       SAL-USDT         1h          4,319      4,320          1    100.0% ← 1 still missing
#   365  nonkyc       SAL-USDT         4h          1,079      1,080          1     99.9% ← 1 still missing
#   366  nonkyc       SAL-USDT         5m         51,840     51,840          0    100.0% ✓
#   367  nonkyc       SHIB-USDT        15m        17,280     17,280          0    100.0% ✓
#   368  nonkyc       SHIB-USDT        1d            179        180          1     99.4% ← 1 still missing
#   369  nonkyc       SHIB-USDT        1h          4,319      4,320          1    100.0% ← 1 still missing
#   370  nonkyc       SHIB-USDT        30m         8,627      8,640         13     99.8% ← 13 still missing
#   371  nonkyc       SHIB-USDT        4h          1,079      1,080          1     99.9% ← 1 still missing
#   372  nonkyc       SHIB-USDT        5m         51,841     51,840          0    100.0% ✓
#   373  nonkyc       SOL-USDT         15m        17,280     17,280          0    100.0% ✓
#   374  nonkyc       SOL-USDT         1d            179        180          1     99.4% ← 1 still missing
#   375  nonkyc       SOL-USDT         1h          4,319      4,320          1    100.0% ← 1 still missing
#   376  nonkyc       SOL-USDT         4h          1,079      1,080          1     99.9% ← 1 still missing
#   377  nonkyc       SOL-USDT         5m         51,841     51,840          0    100.0% ✓
#   378  nonkyc       TRX-USDT         15m        17,251     17,280         29     99.8% ← 29 still missing
#   379  nonkyc       TRX-USDT         1d            179        180          1     99.4% ← 1 still missing
#   380  nonkyc       TRX-USDT         1h          4,313      4,320          7     99.8% ← 7 still missing
#   381  nonkyc       TRX-USDT         4h          1,079      1,080          1     99.9% ← 1 still missing
#   382  nonkyc       TRX-USDT         5m         51,694     51,840        146     99.7% ← 146 still missing
#   383  nonkyc       USDC-USDT        15m        17,245     17,280         35     99.8% ← 35 still missing
#   384  nonkyc       USDC-USDT        1d            179        180          1     99.4% ← 1 still missing
#   385  nonkyc       USDC-USDT        1h          4,319      4,320          1    100.0% ← 1 still missing
#   386  nonkyc       USDC-USDT        30m         8,711      8,640          0    100.8% ✓
#   387  nonkyc       USDC-USDT        4h          1,079      1,080          1     99.9% ← 1 still missing
#   388  nonkyc       USDC-USDT        5m         51,345     51,840        495     99.0% ← 495 still missing
#   389  nonkyc       VEIL-XMR         15m        17,277     17,280          3    100.0% ← 3 still missing
#   390  nonkyc       VEIL-XMR         1d            179        180          1     99.4% ← 1 still missing
#   391  nonkyc       VEIL-XMR         1h          4,319      4,320          1    100.0% ← 1 still missing
#   392  nonkyc       VEIL-XMR         4h          1,079      1,080          1     99.9% ← 1 still missing
#   393  nonkyc       VEIL-XMR         5m         51,825     51,840         15    100.0% ← 15 still missing
#   394  nonkyc       XKR-XMR          15m        17,279     17,280          1    100.0% ← 1 still missing
#   395  nonkyc       XKR-XMR          1d            179        180          1     99.4% ← 1 still missing
#   396  nonkyc       XKR-XMR          1h          4,319      4,320          1    100.0% ← 1 still missing
#   397  nonkyc       XKR-XMR          4h          1,079      1,080          1     99.9% ← 1 still missing
#   398  nonkyc       XKR-XMR          5m         51,827     51,840         13    100.0% ← 13 still missing
#   399  nonkyc       XMR-BTC          15m        17,273     17,280          7    100.0% ← 7 still missing
#   400  nonkyc       XMR-BTC          1d            179        180          1     99.4% ← 1 still missing
#   401  nonkyc       XMR-BTC          1h          4,319      4,320          1    100.0% ← 1 still missing
#   402  nonkyc       XMR-BTC          4h          1,079      1,080          1     99.9% ← 1 still missing
#   403  nonkyc       XMR-BTC          5m         51,791     51,840         49     99.9% ← 49 still missing
#   404  nonkyc       XMR-USDT         15m        17,280     17,280          0    100.0% ✓
#   405  nonkyc       XMR-USDT         1d            179        180          1     99.4% ← 1 still missing
#   406  nonkyc       XMR-USDT         1h          4,319      4,320          1    100.0% ← 1 still missing
#   407  nonkyc       XMR-USDT         4h          1,079      1,080          1     99.9% ← 1 still missing
#   408  nonkyc       XMR-USDT         5m         51,842     51,840          0    100.0% ✓
#   409  nonkyc       XMR-ZSD          15m        17,275     17,280          5    100.0% ← 5 still missing
#   410  nonkyc       XMR-ZSD          1d            179        180          1     99.4% ← 1 still missing
#   411  nonkyc       XMR-ZSD          1h          4,319      4,320          1    100.0% ← 1 still missing
#   412  nonkyc       XMR-ZSD          4h          1,079      1,080          1     99.9% ← 1 still missing
#   413  nonkyc       XMR-ZSD          5m         51,786     51,840         54     99.9% ← 54 still missing
#   414  nonkyc       XNV-XMR          15m         6,092     17,280     11,188     35.3% ← 11,188 still missing
#   415  nonkyc       XNV-XMR          1d             64        180        116     35.6% ← 116 still missing
#   416  nonkyc       XNV-XMR          1h          1,523      4,320      2,797     35.3% ← 2,797 still missing
#   417  nonkyc       XNV-XMR          4h            381      1,080        699     35.3% ← 699 still missing
#   418  nonkyc       XNV-XMR          5m         18,276     51,840     33,564     35.3% ← 33,564 still missing
#   419  nonkyc       XRP-USDT         15m        17,280     17,280          0    100.0% ✓
#   420  nonkyc       XRP-USDT         1d            179        180          1     99.4% ← 1 still missing
#   421  nonkyc       XRP-USDT         1h          4,319      4,320          1    100.0% ← 1 still missing
#   422  nonkyc       XRP-USDT         4h          1,079      1,080          1     99.9% ← 1 still missing
#   423  nonkyc       XRP-USDT         5m         51,843     51,840          0    100.0% ✓
#   424  nonkyc       XTM-XMR          15m        17,276     17,280          4    100.0% ← 4 still missing
#   425  nonkyc       XTM-XMR          1d            179        180          1     99.4% ← 1 still missing
#   426  nonkyc       XTM-XMR          1h          4,319      4,320          1    100.0% ← 1 still missing
#   427  nonkyc       XTM-XMR          4h          1,079      1,080          1     99.9% ← 1 still missing
#   428  nonkyc       XTM-XMR          5m         51,799     51,840         41     99.9% ← 41 still missing
#   429  nonkyc       ZANO-USDT        15m        17,272     17,280          8    100.0% ← 8 still missing
#   430  nonkyc       ZANO-USDT        1d            179        180          1     99.4% ← 1 still missing
#   431  nonkyc       ZANO-USDT        1h          4,319      4,320          1    100.0% ← 1 still missing
#   432  nonkyc       ZANO-USDT        4h          1,079      1,080          1     99.9% ← 1 still missing
#   433  nonkyc       ZANO-USDT        5m         51,776     51,840         64     99.9% ← 64 still missing
#   434  nonkyc       ZEC-XMR          15m        17,280     17,280          0    100.0% ✓
#   435  nonkyc       ZEC-XMR          1d            179        180          1     99.4% ← 1 still missing
#   436  nonkyc       ZEC-XMR          1h          4,319      4,320          1    100.0% ← 1 still missing
#   437  nonkyc       ZEC-XMR          4h          1,079      1,080          1     99.9% ← 1 still missing
#   438  nonkyc       ZEC-XMR          5m         51,838     51,840          2    100.0% ← 2 still missing
#   439  nonkyc       ZSD-USDT         15m        17,280     17,280          0    100.0% ✓
#   440  nonkyc       ZSD-USDT         1d            179        180          1     99.4% ← 1 still missing
#   441  nonkyc       ZSD-USDT         1h          4,319      4,320          1    100.0% ← 1 still missing
#   442  nonkyc       ZSD-USDT         4h          1,079      1,080          1     99.9% ← 1 still missing
#   443  nonkyc       ZSD-USDT         5m         51,842     51,840          0    100.0% ✓
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# ⚠ 168,809 candles still missing (exchange may not have data for those periods)

# %%
# ── Cell 12 (Optional): Inspect a specific series ───────────────────────────
#
# Change these to drill into a specific pair's gap details.

INSPECT_CONNECTOR = "nonkyc"    # ← change as needed
INSPECT_PAIR = "BTC-USDT"       # ← change as needed
INSPECT_INTERVAL = "5m"         # ← change as needed

spec = INTERVAL_SPEC.get(INSPECT_INTERVAL)
if spec:
    step = spec["seconds"]
    inspect_max_days = spec.get("max_days", BACKFILL_DAYS)
    inspect_window_start = utc_now_ts() - min(BACKFILL_DAYS, inspect_max_days) * 86400
    gaps = find_gaps_in_window(coll, INSPECT_CONNECTOR, INSPECT_PAIR, INSPECT_INTERVAL, step, inspect_window_start, now_ts)
    
    total_missing = sum(((e - s) // step) + 1 for s, e in gaps)
    print(f"Gaps for {INSPECT_CONNECTOR} {INSPECT_PAIR} {INSPECT_INTERVAL}:")
    print(f"  Total gap ranges: {len(gaps)}")
    print(f"  Total missing candles: {total_missing:,}")
    print()
    for i, (gs, ge) in enumerate(gaps[:20]):
        cnt = ((ge - gs) // step) + 1
        dur_hours = cnt * step / 3600
        print(f"  [{i+1:3d}] {fmt_ts(gs)} → {fmt_ts(ge)}  ({cnt:>6,d} candles, {dur_hours:>7.1f}h)")
    if len(gaps) > 20:
        print(f"  ... and {len(gaps) - 20} more ranges")
else:
    print(f"Unknown interval: {INSPECT_INTERVAL}")
# Out:
# Gaps for nonkyc BTC-USDT 5m:
#   Total gap ranges: 1
#   Total missing candles: 2
#
#   [  1] 2026-04-04 00:30 → 2026-04-04 00:35  (     2 candles,     0.2h)
