# %%
# ── Optuna Study Manager ──
# Run this cell to list, delete one, or delete all studies.
# Works with both SQLite (optuna_studies.db) and Postgres (OPTUNA_STORAGE env).

import optuna
import os

from pmm_lab.optuna.storage import get_storage_url

storage_url = get_storage_url()
print(f"Storage: {storage_url}\n")

# ── List all studies ──
studies = optuna.study.get_all_study_summaries(storage=storage_url)
if not studies:
    print("No studies found.")
else:
    print(f"Found {len(studies)} study/studies:\n")
    for i, s in enumerate(studies):
        n_trials = s.n_trials
        best = f"{s.best_trial.value:.4f}" if s.best_trial else "N/A"
        print(f"  [{i}] {s.study_name}  —  {n_trials} trials, best={best}")
# Out:
# Storage: postgresql+psycopg2://optuna:optuna@optuna-postgres:5432/optuna
#
# Found 64 study/studies:
#
#   [0] mexc_ADA-USDT_5m_sweep_v1  —  12000 trials, best=0.0043
#   [1] mexc_APT-USDT_5m_sweep_v1  —  12000 trials, best=-0.0026
#   [2] mexc_ASTER-USDT_5m_sweep_v1  —  12000 trials, best=0.0076
#   [3] mexc_ATOM-USDT_5m_sweep_v1  —  12000 trials, best=0.0020
#   [4] mexc_BNB-USDT_5m_sweep_v1  —  12000 trials, best=0.7995
#   [5] mexc_BTC-USDT_5m_sweep_v1  —  12000 trials, best=0.8258
#   [6] mexc_DOGE-USDT_5m_sweep_v1  —  12000 trials, best=1.2421
#   [7] mexc_DOT-USDT_5m_sweep_v1  —  12000 trials, best=0.0013
#   [8] mexc_ETH-USDT_5m_sweep_v1  —  12000 trials, best=1.2829
#   [9] mexc_HYPE-USDT_5m_sweep_v1  —  12000 trials, best=1.4963
#   [10] mexc_ICP-USDT_5m_sweep_v1  —  12000 trials, best=1.2836
#   [11] mexc_LTC-USDT_5m_sweep_v1  —  12000 trials, best=1.1155
#   [12] mexc_OP-USDT_5m_sweep_v1  —  12000 trials, best=0.0057
# ...

# %%
# ═══════════════════════════════════════════════════════════
# UNCOMMENT ONE of the blocks below, then re-run this cell.
# ═══════════════════════════════════════════════════════════

# ── Delete a single study by name ──
# TARGET = "nonkyc_DOT-USDT_5m_sweep_v1"   # <-- change this
# optuna.delete_study(study_name=TARGET, storage=storage_url)
# print(f"\nDeleted: {TARGET}")

# ── Delete a single study by index from the list above ──
# idx = 0   # <-- change this to the [i] number from the list
# optuna.delete_study(study_name=studies[idx].study_name, storage=storage_url)
# print(f"\nDeleted: {studies[idx].study_name}")

# ── Delete ALL studies (careful!) ──
# confirm = input("Type YES to delete all studies: ")
# if confirm == "YES":
print("starting.")
for s in studies:
    optuna.delete_study(study_name=s.study_name, storage=storage_url)
    print(f"  Deleted: {s.study_name}")
print(f"\nDeleted {len(studies)} study/studies.")
# else:
print("done.")
# Out:
# starting.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 20
#      18 print("starting.")
#      19 for s in studies:
# ---> 20     optuna.delete_study(study_name=s.study_name, storage=storage_url)
#      21     print(f"  Deleted: {s.study_name}")
#      22 print(f"\nDeleted {len(studies)} study/studies.")
#
# File /opt/conda/envs/quants-lab/lib/python3.12/site-packages/optuna/_convert_positional_args.py:134, in convert_positional_args.<locals>.converter_decorator.<locals>.converter_wrapper(*args, **kwargs)
#     128     raise TypeError(
#     129         f"{func.__name__}() got multiple values for arguments {duplicated_kwds}."
#     130     )
#     132 kwargs.update(inferred_kwargs)
# --> 134 return func(**kwargs)
#
# File /opt/conda/envs/quants-lab/lib/python3.12/site-packages/optuna/study/study.py:1465, in delete_study(study_name, storage)
# ...
